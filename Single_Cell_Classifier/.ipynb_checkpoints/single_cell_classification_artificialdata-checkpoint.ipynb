# %%
# all neccessary imports
import torch
import os
from PIL import Image
import label_converter # make sure the label_converter.py is in the folder with this notebook
import numpy as np
import glob
from torchvision import transforms
import torch.nn as nn

# %%
# define paths
#PATH_TO_IMAGES = '/mnt/volume/shared/data'
PATH_TO_IMAGES = "/mnt/volume/shared/data_file/test_data"
PATH_TO_IMAGES = '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data'
PATH_TO_MODEL = os.path.join(os.getcwd(), "/home/hhauger/CMSCB-SCEMILA/Single_Cell_Classifier/class_conversion-csv/model.pt")
#PATH_TO_MODEL = os.path.join(os.getcwd(), "class_conversion-csv/model.pt")
# load model and print architecture
model = torch.load(PATH_TO_MODEL, map_location=torch.device('cpu'))
#model.state_dict

# %%
def create_dataset(root_dirs):
    # Create dataset
    data = []
    for sgl_dir in root_dirs:
        for file_sgl in os.listdir(sgl_dir):

            if not '.tif' in file_sgl:
                        continue

            data.append(os.path.join(sgl_dir, file_sgl))
    
    # Convert the list to a NumPy array
    data = np.array(data)

    # Extract numerical part for sorting
    numeric_part = np.array([int(name.split('image_')[1].split('.tif')[0]) for name in data])

    # Get the indices that would sort the numeric part
    sorted_indices = np.argsort(numeric_part)

    # Use the sorted indices to rearrange the file names array
    sorted_images = data[sorted_indices]

    return sorted_images

def get_image(idx, data):
        '''returns specific item from this dataset'''

        # load image, remove alpha channel, transform
        image = Image.open(data[idx])
        image_arr = np.asarray(image)[:,:,:3]
        image = Image.fromarray(image_arr)

        return torch.tensor(image_arr)

def save_single_cell_probabilities(data, folder_patient):
    array_list = []
    #print("Target \t Prediction")
    for idx in range(len(data)):
        input = get_image(idx, data)
        input = input.permute(2, 0, 1).unsqueeze(0)
        
        # Convert input to float
        input = input.float()
        input = input / 255.

        # Normalize the input
        normalize = transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
        input = normalize(input)
        
        model.eval()
        pred = model(input)
        softmax = nn.Softmax(dim=1)
        pred_probability = softmax(pred)

        # Save probabilities in a file
        pred_vect = pred_probability.detach().numpy().flatten()
        array_list.append([pred_vect])
        
    #Concatenate all features for one artificial patient    
    single_cell_probs = np.concatenate(array_list,axis=0)
    output_npy_file = folder_patient + '/single_cell_probabilities.npy'
    # Save the array to the .npy file
    np.save(output_npy_file, single_cell_probs)

# %%
# Save class probabilities for each patient
for folder_class in os.listdir(PATH_TO_IMAGES):
    folder_class = os.path.join(PATH_TO_IMAGES, folder_class)
    
    if os.path.isdir(folder_class):
       print(folder_class)
       for folder_patient in os.listdir(folder_class):
            folder_patient = os.path.join(folder_class, folder_patient)
            if os.path.isdir(folder_patient):
                # Check if there are .tif files in the patient folder
                tif_files = [file for file in os.listdir(folder_patient) if file.endswith(".tif")]
                if tif_files:
                    print("Processing patient folder with .tif files:", folder_patient)
                    data = create_dataset([folder_patient])
                    save_single_cell_probabilities(data, folder_patient)
                else:
                    print("Skipping patient folder without .tif files:", folder_patient)
# Out:
# /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_36
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_19
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_11
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_34
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_18
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_21
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_20
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_33
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_23
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_27
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_5
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_8
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_7
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_26
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_28
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_22
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_1
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_25
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_41
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_13
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_6
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_16
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_39
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_17
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_37
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_14
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_24
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_32
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_38
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_40
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_3
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_15
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_12
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_30
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_31
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_4
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_35
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_9
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_29
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_2
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_10
# /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/RUNX1_RUNX1T1
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/RUNX1_RUNX1T1/patient_36
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/RUNX1_RUNX1T1/patient_19
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/RUNX1_RUNX1T1/patient_11
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/RUNX1_RUNX1T1/patient_34
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/RUNX1_RUNX1T1/patient_18
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/RUNX1_RUNX1T1/patient_21
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/RUNX1_RUNX1T1/patient_20
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/RUNX1_RUNX1T1/patient_33
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/RUNX1_RUNX1T1/patient_23
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/RUNX1_RUNX1T1/patient_27
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/RUNX1_RUNX1T1/patient_5
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/RUNX1_RUNX1T1/patient_8
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/RUNX1_RUNX1T1/patient_7
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/RUNX1_RUNX1T1/patient_26
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/RUNX1_RUNX1T1/patient_28
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/RUNX1_RUNX1T1/patient_22
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/RUNX1_RUNX1T1/patient_1
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/RUNX1_RUNX1T1/patient_25
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/RUNX1_RUNX1T1/patient_41
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/RUNX1_RUNX1T1/patient_13
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/RUNX1_RUNX1T1/patient_6
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/RUNX1_RUNX1T1/patient_16
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/RUNX1_RUNX1T1/patient_39
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/RUNX1_RUNX1T1/patient_17
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/RUNX1_RUNX1T1/patient_37
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/RUNX1_RUNX1T1/patient_14
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/RUNX1_RUNX1T1/patient_24
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/RUNX1_RUNX1T1/patient_32
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/RUNX1_RUNX1T1/patient_38
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/RUNX1_RUNX1T1/patient_40
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/RUNX1_RUNX1T1/patient_3
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/RUNX1_RUNX1T1/patient_15
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/RUNX1_RUNX1T1/patient_12
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/RUNX1_RUNX1T1/patient_30
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/RUNX1_RUNX1T1/patient_31
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/RUNX1_RUNX1T1/patient_4
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/RUNX1_RUNX1T1/patient_35
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/RUNX1_RUNX1T1/patient_9
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/RUNX1_RUNX1T1/patient_29
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/RUNX1_RUNX1T1/patient_2
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/RUNX1_RUNX1T1/patient_10
# /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/CBFB_MYH11
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/CBFB_MYH11/patient_36
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/CBFB_MYH11/patient_19
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/CBFB_MYH11/patient_11
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/CBFB_MYH11/patient_34
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/CBFB_MYH11/patient_18
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/CBFB_MYH11/patient_21
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/CBFB_MYH11/patient_20
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/CBFB_MYH11/patient_33
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/CBFB_MYH11/patient_23
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/CBFB_MYH11/patient_27
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/CBFB_MYH11/patient_5
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/CBFB_MYH11/patient_8
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/CBFB_MYH11/patient_7
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/CBFB_MYH11/patient_26
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/CBFB_MYH11/patient_28
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/CBFB_MYH11/patient_22
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/CBFB_MYH11/patient_1
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/CBFB_MYH11/patient_25
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/CBFB_MYH11/patient_41
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/CBFB_MYH11/patient_13
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/CBFB_MYH11/patient_6
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/CBFB_MYH11/patient_16
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/CBFB_MYH11/patient_39
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/CBFB_MYH11/patient_17
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/CBFB_MYH11/patient_37
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/CBFB_MYH11/patient_14
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/CBFB_MYH11/patient_24
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/CBFB_MYH11/patient_32
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/CBFB_MYH11/patient_38
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/CBFB_MYH11/patient_40
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/CBFB_MYH11/patient_3
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/CBFB_MYH11/patient_15
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/CBFB_MYH11/patient_12
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/CBFB_MYH11/patient_30
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/CBFB_MYH11/patient_31
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/CBFB_MYH11/patient_4
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/CBFB_MYH11/patient_35
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/CBFB_MYH11/patient_9
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/CBFB_MYH11/patient_29
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/CBFB_MYH11/patient_2
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/CBFB_MYH11/patient_10
# /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/PML_RARA
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/PML_RARA/patient_36
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/PML_RARA/patient_19
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/PML_RARA/patient_11
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/PML_RARA/patient_34
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/PML_RARA/patient_18
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/PML_RARA/patient_21
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/PML_RARA/patient_20
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/PML_RARA/patient_33
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/PML_RARA/patient_23
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/PML_RARA/patient_27
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/PML_RARA/patient_5
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/PML_RARA/patient_8
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/PML_RARA/patient_7
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/PML_RARA/patient_26
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/PML_RARA/patient_28
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/PML_RARA/patient_22
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/PML_RARA/patient_1
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/PML_RARA/patient_25
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/PML_RARA/patient_41
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/PML_RARA/patient_13
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/PML_RARA/patient_6
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/PML_RARA/patient_16
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/PML_RARA/patient_39
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/PML_RARA/patient_17
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/PML_RARA/patient_37
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/PML_RARA/patient_14
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/PML_RARA/patient_24
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/PML_RARA/patient_32
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/PML_RARA/patient_38
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/PML_RARA/patient_40
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/PML_RARA/patient_3
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/PML_RARA/patient_15
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/PML_RARA/patient_12
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/PML_RARA/patient_30
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/PML_RARA/patient_31
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/PML_RARA/patient_4
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/PML_RARA/patient_35
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/PML_RARA/patient_9
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/PML_RARA/patient_29
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/PML_RARA/patient_2
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/PML_RARA/patient_10
# /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/NPM1
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/NPM1/patient_36
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/NPM1/patient_19
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/NPM1/patient_11
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/NPM1/patient_34
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/NPM1/patient_18
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/NPM1/patient_21
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/NPM1/patient_20
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/NPM1/patient_33
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/NPM1/patient_23
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/NPM1/patient_27
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/NPM1/patient_5
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/NPM1/patient_8
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/NPM1/patient_7
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/NPM1/patient_26
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/NPM1/patient_28
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/NPM1/patient_22
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/NPM1/patient_1
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/NPM1/patient_25
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/NPM1/patient_41
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/NPM1/patient_13
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/NPM1/patient_6
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/NPM1/patient_16
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/NPM1/patient_39
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/NPM1/patient_17
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/NPM1/patient_37
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/NPM1/patient_14
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/NPM1/patient_24
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/NPM1/patient_32
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/NPM1/patient_38
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/NPM1/patient_40
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/NPM1/patient_3
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/NPM1/patient_15
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/NPM1/patient_12
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/NPM1/patient_30
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/NPM1/patient_31
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/NPM1/patient_4
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/NPM1/patient_35
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/NPM1/patient_9
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/NPM1/patient_29
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/NPM1/patient_2
# Skipping patient folder without .tif files: /mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/NPM1/patient_10
