# %%
import os.path
from tqdm import tqdm
import torch
import torch.nn.functional as F
from dataset_mixed import *  # dataset
from model import *  # actual MIL model
from sklearn import metrics as metrics
import csv
import os
import shutil
import pandas as pd
import re

# %%
CLASSES = ['control', 'RUNX1_RUNX1T1', 'NPM1', 'CBFB_MYH11', 'PML_RARA']
num_classes = 5
seed=42
experiment_source=f'experiment_3_seed{seed}'
real_data_source='/mnt/volume/shared/data_file/data'
SOURCE_FOLDER = '/mnt/volume/shared/data_file/artificialdata/'+experiment_source
TARGET_FOLDER = '/mnt/volume/shared/exp4/dropout_original/result_folder_1'
output_folder = f'/mnt/volume/shared/data_file/mixed_uncertain_seed{seed}'

def get_patient_name(path):
    return re.search(r"/data/\w+/([0-9a-zA-Z_]*)", path).group(1)

def get_class_name(path):
    return re.search(r"/data/(\w+)", path).group(1)

# %%
patients = {}
with open(os.path.join(SOURCE_FOLDER,'metadata.csv'), newline='') as csvfile:
    reader = csv.reader(csvfile)
    next(reader, None)
    idx = 0
    for line in reader:
        key = line[0] + "_" + line[3]
        patients[key] = [os.path.join(SOURCE_FOLDER,
                                         "data",
                                         line[3],
                                         line[0],
                                         "fnl34_bn_features_layer_7.npy"), line[3]]

# %%
def update_misclassification_count(probability_vector, one_hot_target, current_misclassification_count):
    """
    Update misclassification count based on the given probability vector and one-hot encoded target vector.

    Parameters:
    - probability_vector: Tensor representing the probability vector.
    - one_hot_target: Tensor representing the one-hot encoded target vector.
    - current_misclassification_count: Current misclassification count.

    Returns:
    - Updated misclassification count.
    """
    #print("Target: ", one_hot_target)
    #print(probability_vector)
    # Convert probability vector to one-hot encoded vector
    one_hot_prediction = torch.zeros_like(probability_vector)
    one_hot_prediction[0, torch.argmax(probability_vector).item()] = 1
    #print("One hot prediction is: ", one_hot_prediction)

    # Find the index where the target is 1
    target_index = torch.argmax(one_hot_target).item()
    #print("Target index is :", target_index)

    # Check for misclassification and update count
    if torch.argmax(one_hot_prediction).item() != target_index:
        current_misclassification_count += 1

    return current_misclassification_count

# %%
# Number of Monte Carlo samples
num_samples = 10

class_converter = {}

with open(os.path.join(TARGET_FOLDER,'class_conversion.csv'), newline='') as csvfile:
    reader = csv.reader(csvfile)
    next(reader, None)
    for line in reader:
        class_converter[line[1]] = int(line[0])

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")


# load best performing model, and launch on test set
model = torch.load(os.path.join(TARGET_FOLDER, "state_dictmodel.pt"),map_location="cpu")
model = model.to(device)
model.train()

# Initialize arrays to store uncertainties
all_uncertainties = {}
missclassification_counts = {}
max_uncertainties = {}
sum_uncertainties = {}

# Perform Monte Carlo Dropout
with torch.no_grad():
    for p in patients.keys():
        # Make predictions with dropout enabled multiple times
        pred = []
        missclassification_count = 0
        for j in range(num_samples):
            path, lbl_name = patients[p]
            lbl = np.zeros(5)
            lbl[class_converter[lbl_name]] = 1

            bag = np.load(path)

            bag = torch.tensor(bag).to(device)
            bag = torch.unsqueeze(bag,0)
            prediction, _, _, _,  = model(bag)
            pred.append(F.softmax(prediction,dim=1).cpu().detach().numpy())

            # Class missclassification count update
            missclassification_count = update_misclassification_count(F.softmax(prediction,dim=1), torch.tensor(lbl), missclassification_count)

        # Convert the list of tensors to a PyTorch tensor
        pred_tensor = [torch.from_numpy(arr) for arr in pred]
        pred_tensor = torch.stack(pred_tensor)
        
        # Compute mean and uncertainty
        mean_prediction = pred_tensor.mean(dim=0)
        #print('Mean prediction is:', mean_prediction)
        
        uncertainty = pred_tensor.std(dim=0)
        #print('Uncertainty tensor is:', uncertainty)
        
        uncertainty_value_max = torch.max(uncertainty).item()
        uncertainty_value_sum = torch.sum(uncertainty).item()
        path=os.path.dirname(path)
        # Save uncertainty results along with the path
        max_uncertainties[p] = {'path': path, 'data': uncertainty.cpu().numpy().squeeze(), 'uncertainty': uncertainty_value_max}
        sum_uncertainties[p] = {'path': path, 'data': uncertainty.cpu().numpy().squeeze(), 'uncertainty': uncertainty_value_sum}
        missclassification_counts[p] = {'path': path, 'uncertainty' : missclassification_count / num_samples}

# %%
def sort_and_print(uncertainties):
    # Sort misclassification counts dictionary by values (highest to lowest)
    sorted_uncertainties = dict(sorted(uncertainties.items(), key=lambda item: item[1]['uncertainty'], reverse=True))
    
    # Print sorted misclassification counts
    for p, data in sorted_uncertainties.items():
        uncertainty_rate = data['uncertainty']
        print(f"Patient {p}: Uncertainty - {uncertainty_rate:.4}")

# %%
sort_and_print(max_uncertainties)
sort_and_print(sum_uncertainties)
sort_and_print(missclassification_counts)
# Out:
# Patient patient_30_CBFB_MYH11: Uncertainty - 0.2385
# Patient patient_10_PML_RARA: Uncertainty - 0.2088
# Patient patient_19_NPM1: Uncertainty - 0.1975
# Patient patient_34_RUNX1_RUNX1T1: Uncertainty - 0.185
# Patient patient_8_RUNX1_RUNX1T1: Uncertainty - 0.1847
# Patient patient_32_NPM1: Uncertainty - 0.1827
# Patient patient_25_NPM1: Uncertainty - 0.1752
# Patient patient_7_CBFB_MYH11: Uncertainty - 0.1724
# Patient patient_32_PML_RARA: Uncertainty - 0.1697
# Patient patient_20_PML_RARA: Uncertainty - 0.166
# Patient patient_21_PML_RARA: Uncertainty - 0.166
# Patient patient_24_RUNX1_RUNX1T1: Uncertainty - 0.1625
# Patient patient_8_NPM1: Uncertainty - 0.1617
# Patient patient_11_NPM1: Uncertainty - 0.156
# Patient patient_10_RUNX1_RUNX1T1: Uncertainty - 0.1554
# Patient patient_31_PML_RARA: Uncertainty - 0.1552
# Patient patient_27_NPM1: Uncertainty - 0.155
# Patient patient_11_RUNX1_RUNX1T1: Uncertainty - 0.1539
# Patient patient_39_PML_RARA: Uncertainty - 0.1539
# Patient patient_33_PML_RARA: Uncertainty - 0.1532
# Patient patient_8_PML_RARA: Uncertainty - 0.1531
# Patient patient_30_control: Uncertainty - 0.1521
# Patient patient_2_RUNX1_RUNX1T1: Uncertainty - 0.1499
# Patient patient_18_RUNX1_RUNX1T1: Uncertainty - 0.1488
# Patient patient_7_RUNX1_RUNX1T1: Uncertainty - 0.1471
# Patient patient_27_RUNX1_RUNX1T1: Uncertainty - 0.1458
# Patient patient_21_RUNX1_RUNX1T1: Uncertainty - 0.1438
# Patient patient_23_RUNX1_RUNX1T1: Uncertainty - 0.1432
# Patient patient_39_CBFB_MYH11: Uncertainty - 0.142
# Patient patient_32_RUNX1_RUNX1T1: Uncertainty - 0.1417
# Patient patient_28_NPM1: Uncertainty - 0.1411
# Patient patient_9_PML_RARA: Uncertainty - 0.1405
# Patient patient_28_RUNX1_RUNX1T1: Uncertainty - 0.1376
# Patient patient_25_CBFB_MYH11: Uncertainty - 0.1373
# Patient patient_10_control: Uncertainty - 0.1365
# Patient patient_11_PML_RARA: Uncertainty - 0.134
# Patient patient_19_PML_RARA: Uncertainty - 0.1333
# Patient patient_16_PML_RARA: Uncertainty - 0.1328
# Patient patient_40_NPM1: Uncertainty - 0.1312
# Patient patient_27_CBFB_MYH11: Uncertainty - 0.1295
# Patient patient_5_PML_RARA: Uncertainty - 0.129
# Patient patient_14_PML_RARA: Uncertainty - 0.1287
# Patient patient_1_RUNX1_RUNX1T1: Uncertainty - 0.1279
# Patient patient_30_RUNX1_RUNX1T1: Uncertainty - 0.1264
# Patient patient_21_NPM1: Uncertainty - 0.1235
# Patient patient_34_CBFB_MYH11: Uncertainty - 0.1221
# Patient patient_4_PML_RARA: Uncertainty - 0.1221
# Patient patient_31_NPM1: Uncertainty - 0.1211
# Patient patient_2_NPM1: Uncertainty - 0.1182
# Patient patient_38_RUNX1_RUNX1T1: Uncertainty - 0.1181
# Patient patient_37_RUNX1_RUNX1T1: Uncertainty - 0.1175
# Patient patient_31_CBFB_MYH11: Uncertainty - 0.1174
# Patient patient_35_PML_RARA: Uncertainty - 0.1159
# Patient patient_20_RUNX1_RUNX1T1: Uncertainty - 0.1149
# Patient patient_25_RUNX1_RUNX1T1: Uncertainty - 0.1148
# Patient patient_4_RUNX1_RUNX1T1: Uncertainty - 0.1139
# Patient patient_29_RUNX1_RUNX1T1: Uncertainty - 0.1136
# Patient patient_22_CBFB_MYH11: Uncertainty - 0.1134
# Patient patient_37_CBFB_MYH11: Uncertainty - 0.113
# Patient patient_28_control: Uncertainty - 0.1125
# Patient patient_2_PML_RARA: Uncertainty - 0.1119
# Patient patient_20_NPM1: Uncertainty - 0.11
# Patient patient_38_NPM1: Uncertainty - 0.1085
# Patient patient_33_RUNX1_RUNX1T1: Uncertainty - 0.1078
# Patient patient_28_PML_RARA: Uncertainty - 0.1075
# Patient patient_13_RUNX1_RUNX1T1: Uncertainty - 0.1074
# Patient patient_39_NPM1: Uncertainty - 0.1051
# Patient patient_31_RUNX1_RUNX1T1: Uncertainty - 0.1046
# Patient patient_30_NPM1: Uncertainty - 0.1038
# Patient patient_35_CBFB_MYH11: Uncertainty - 0.1024
# Patient patient_10_NPM1: Uncertainty - 0.1016
# Patient patient_22_RUNX1_RUNX1T1: Uncertainty - 0.1015
# Patient patient_3_NPM1: Uncertainty - 0.1008
# Patient patient_6_NPM1: Uncertainty - 0.09876
# Patient patient_39_RUNX1_RUNX1T1: Uncertainty - 0.09843
# Patient patient_23_PML_RARA: Uncertainty - 0.09779
# Patient patient_10_CBFB_MYH11: Uncertainty - 0.09652
# Patient patient_16_RUNX1_RUNX1T1: Uncertainty - 0.09515
# Patient patient_30_PML_RARA: Uncertainty - 0.09346
# Patient patient_5_RUNX1_RUNX1T1: Uncertainty - 0.0931
# Patient patient_12_control: Uncertainty - 0.09236
# Patient patient_17_RUNX1_RUNX1T1: Uncertainty - 0.09235
# Patient patient_5_CBFB_MYH11: Uncertainty - 0.09094
# Patient patient_13_PML_RARA: Uncertainty - 0.08907
# Patient patient_34_PML_RARA: Uncertainty - 0.08857
# Patient patient_36_NPM1: Uncertainty - 0.08829
# Patient patient_3_CBFB_MYH11: Uncertainty - 0.08737
# Patient patient_26_PML_RARA: Uncertainty - 0.08734
# Patient patient_2_CBFB_MYH11: Uncertainty - 0.08691
# Patient patient_3_RUNX1_RUNX1T1: Uncertainty - 0.08683
# Patient patient_17_NPM1: Uncertainty - 0.08548
# Patient patient_26_CBFB_MYH11: Uncertainty - 0.08545
# Patient patient_13_NPM1: Uncertainty - 0.08435
# Patient patient_24_CBFB_MYH11: Uncertainty - 0.08429
# Patient patient_41_CBFB_MYH11: Uncertainty - 0.08345
# Patient patient_37_PML_RARA: Uncertainty - 0.0831
# Patient patient_15_RUNX1_RUNX1T1: Uncertainty - 0.08297
# Patient patient_14_NPM1: Uncertainty - 0.08256
# Patient patient_27_control: Uncertainty - 0.08204
# Patient patient_9_NPM1: Uncertainty - 0.07919
# Patient patient_40_PML_RARA: Uncertainty - 0.07841
# Patient patient_41_RUNX1_RUNX1T1: Uncertainty - 0.07745
# Patient patient_5_NPM1: Uncertainty - 0.07622
# Patient patient_13_CBFB_MYH11: Uncertainty - 0.07548
# Patient patient_41_NPM1: Uncertainty - 0.07507
# Patient patient_14_RUNX1_RUNX1T1: Uncertainty - 0.07485
# Patient patient_36_CBFB_MYH11: Uncertainty - 0.07399
# Patient patient_15_PML_RARA: Uncertainty - 0.07376
# Patient patient_33_NPM1: Uncertainty - 0.07125
# Patient patient_29_NPM1: Uncertainty - 0.07021
# Patient patient_40_RUNX1_RUNX1T1: Uncertainty - 0.06999
# Patient patient_6_CBFB_MYH11: Uncertainty - 0.06956
# Patient patient_26_RUNX1_RUNX1T1: Uncertainty - 0.06932
# Patient patient_24_control: Uncertainty - 0.0693
# Patient patient_37_NPM1: Uncertainty - 0.06929
# Patient patient_15_CBFB_MYH11: Uncertainty - 0.06609
# Patient patient_6_RUNX1_RUNX1T1: Uncertainty - 0.06366
# Patient patient_25_PML_RARA: Uncertainty - 0.06314
# Patient patient_12_PML_RARA: Uncertainty - 0.06124
# Patient patient_35_RUNX1_RUNX1T1: Uncertainty - 0.06102
# Patient patient_16_CBFB_MYH11: Uncertainty - 0.06088
# Patient patient_15_NPM1: Uncertainty - 0.05824
# Patient patient_17_CBFB_MYH11: Uncertainty - 0.0581
# Patient patient_7_NPM1: Uncertainty - 0.05773
# Patient patient_12_NPM1: Uncertainty - 0.05696
# Patient patient_9_RUNX1_RUNX1T1: Uncertainty - 0.05643
# Patient patient_23_NPM1: Uncertainty - 0.05522
# Patient patient_24_NPM1: Uncertainty - 0.05478
# Patient patient_11_control: Uncertainty - 0.05314
# Patient patient_36_RUNX1_RUNX1T1: Uncertainty - 0.05215
# Patient patient_12_CBFB_MYH11: Uncertainty - 0.05213
# Patient patient_29_PML_RARA: Uncertainty - 0.04973
# Patient patient_12_RUNX1_RUNX1T1: Uncertainty - 0.04672
# Patient patient_7_PML_RARA: Uncertainty - 0.04603
# Patient patient_26_NPM1: Uncertainty - 0.04387
# Patient patient_4_NPM1: Uncertainty - 0.04313
# Patient patient_39_control: Uncertainty - 0.04257
# Patient patient_35_NPM1: Uncertainty - 0.04158
# Patient patient_34_NPM1: Uncertainty - 0.03854
# Patient patient_22_NPM1: Uncertainty - 0.03544
# Patient patient_17_PML_RARA: Uncertainty - 0.03485
# Patient patient_19_RUNX1_RUNX1T1: Uncertainty - 0.03484
# Patient patient_29_CBFB_MYH11: Uncertainty - 0.03278
# Patient patient_23_CBFB_MYH11: Uncertainty - 0.03239
# Patient patient_4_control: Uncertainty - 0.03207
# Patient patient_1_NPM1: Uncertainty - 0.02918
# Patient patient_36_PML_RARA: Uncertainty - 0.0283
# Patient patient_24_PML_RARA: Uncertainty - 0.02806
# Patient patient_41_PML_RARA: Uncertainty - 0.02748
# Patient patient_14_control: Uncertainty - 0.0261
# Patient patient_40_CBFB_MYH11: Uncertainty - 0.02534
# Patient patient_22_PML_RARA: Uncertainty - 0.02239
# Patient patient_4_CBFB_MYH11: Uncertainty - 0.02172
# Patient patient_16_NPM1: Uncertainty - 0.02148
# Patient patient_19_CBFB_MYH11: Uncertainty - 0.0207
# Patient patient_1_CBFB_MYH11: Uncertainty - 0.01793
# Patient patient_21_CBFB_MYH11: Uncertainty - 0.01673
# Patient patient_41_control: Uncertainty - 0.01662
# Patient patient_32_CBFB_MYH11: Uncertainty - 0.01549
# Patient patient_33_CBFB_MYH11: Uncertainty - 0.01475
# Patient patient_1_PML_RARA: Uncertainty - 0.01447
# Patient patient_22_control: Uncertainty - 0.01445
# Patient patient_6_PML_RARA: Uncertainty - 0.014
# Patient patient_18_PML_RARA: Uncertainty - 0.01394
# Patient patient_20_CBFB_MYH11: Uncertainty - 0.01393
# Patient patient_34_control: Uncertainty - 0.01371
# Patient patient_14_CBFB_MYH11: Uncertainty - 0.01304
# Patient patient_27_PML_RARA: Uncertainty - 0.01179
# Patient patient_23_control: Uncertainty - 0.01143
# Patient patient_8_CBFB_MYH11: Uncertainty - 0.01086
# Patient patient_28_CBFB_MYH11: Uncertainty - 0.009984
# Patient patient_18_NPM1: Uncertainty - 0.008992
# Patient patient_9_CBFB_MYH11: Uncertainty - 0.008207
# Patient patient_3_PML_RARA: Uncertainty - 0.007478
# Patient patient_35_control: Uncertainty - 0.007366
# Patient patient_25_control: Uncertainty - 0.006852
# Patient patient_11_CBFB_MYH11: Uncertainty - 0.006205
# Patient patient_9_control: Uncertainty - 0.005882
# Patient patient_36_control: Uncertainty - 0.005535
# Patient patient_40_control: Uncertainty - 0.005186
# Patient patient_2_control: Uncertainty - 0.004978
# Patient patient_17_control: Uncertainty - 0.004806
# Patient patient_32_control: Uncertainty - 0.004426
# Patient patient_15_control: Uncertainty - 0.00439
# Patient patient_8_control: Uncertainty - 0.004372
# Patient patient_7_control: Uncertainty - 0.003635
# Patient patient_33_control: Uncertainty - 0.003533
# Patient patient_18_control: Uncertainty - 0.003162
# Patient patient_38_CBFB_MYH11: Uncertainty - 0.003057
# Patient patient_37_control: Uncertainty - 0.002826
# Patient patient_38_PML_RARA: Uncertainty - 0.002285
# Patient patient_19_control: Uncertainty - 0.002173
# Patient patient_13_control: Uncertainty - 0.001773
# Patient patient_26_control: Uncertainty - 0.001548
# Patient patient_5_control: Uncertainty - 0.0015
# Patient patient_16_control: Uncertainty - 0.001129
# Patient patient_20_control: Uncertainty - 0.00107
# Patient patient_21_control: Uncertainty - 0.001009
# Patient patient_18_CBFB_MYH11: Uncertainty - 0.000872
# Patient patient_38_control: Uncertainty - 0.0008437
# Patient patient_6_control: Uncertainty - 0.0008107
# Patient patient_31_control: Uncertainty - 0.0006793
# Patient patient_3_control: Uncertainty - 0.0005042
# Patient patient_1_control: Uncertainty - 0.0003335
# Patient patient_29_control: Uncertainty - 0.0002516
# Patient patient_19_NPM1: Uncertainty - 0.5124
# Patient patient_30_CBFB_MYH11: Uncertainty - 0.4853
# Patient patient_28_NPM1: Uncertainty - 0.4441
# Patient patient_10_PML_RARA: Uncertainty - 0.4316
# Patient patient_39_PML_RARA: Uncertainty - 0.4301
# Patient patient_8_RUNX1_RUNX1T1: Uncertainty - 0.425
# Patient patient_20_PML_RARA: Uncertainty - 0.395
# Patient patient_32_PML_RARA: Uncertainty - 0.3901
# Patient patient_7_CBFB_MYH11: Uncertainty - 0.3865
# Patient patient_34_RUNX1_RUNX1T1: Uncertainty - 0.3729
# Patient patient_32_NPM1: Uncertainty - 0.3679
# Patient patient_25_NPM1: Uncertainty - 0.3622
# Patient patient_27_NPM1: Uncertainty - 0.3559
# Patient patient_10_RUNX1_RUNX1T1: Uncertainty - 0.3537
# Patient patient_31_PML_RARA: Uncertainty - 0.3527
# Patient patient_21_PML_RARA: Uncertainty - 0.3478
# Patient patient_8_NPM1: Uncertainty - 0.3477
# Patient patient_21_RUNX1_RUNX1T1: Uncertainty - 0.3466
# Patient patient_2_RUNX1_RUNX1T1: Uncertainty - 0.3462
# Patient patient_23_RUNX1_RUNX1T1: Uncertainty - 0.3458
# Patient patient_24_RUNX1_RUNX1T1: Uncertainty - 0.3411
# Patient patient_11_PML_RARA: Uncertainty - 0.3274
# Patient patient_34_CBFB_MYH11: Uncertainty - 0.3267
# Patient patient_7_RUNX1_RUNX1T1: Uncertainty - 0.3265
# Patient patient_39_CBFB_MYH11: Uncertainty - 0.324
# Patient patient_32_RUNX1_RUNX1T1: Uncertainty - 0.3196
# Patient patient_8_PML_RARA: Uncertainty - 0.3193
# Patient patient_30_control: Uncertainty - 0.3174
# Patient patient_33_PML_RARA: Uncertainty - 0.3172
# Patient patient_11_NPM1: Uncertainty - 0.3166
# Patient patient_1_RUNX1_RUNX1T1: Uncertainty - 0.314
# Patient patient_18_RUNX1_RUNX1T1: Uncertainty - 0.313
# Patient patient_11_RUNX1_RUNX1T1: Uncertainty - 0.3097
# Patient patient_27_RUNX1_RUNX1T1: Uncertainty - 0.3036
# Patient patient_2_PML_RARA: Uncertainty - 0.3019
# Patient patient_13_RUNX1_RUNX1T1: Uncertainty - 0.3011
# Patient patient_37_RUNX1_RUNX1T1: Uncertainty - 0.3007
# Patient patient_25_CBFB_MYH11: Uncertainty - 0.2977
# Patient patient_28_RUNX1_RUNX1T1: Uncertainty - 0.2964
# Patient patient_19_PML_RARA: Uncertainty - 0.293
# Patient patient_9_PML_RARA: Uncertainty - 0.2861
# Patient patient_28_control: Uncertainty - 0.2815
# Patient patient_20_RUNX1_RUNX1T1: Uncertainty - 0.2812
# Patient patient_2_NPM1: Uncertainty - 0.2788
# Patient patient_10_control: Uncertainty - 0.2765
# Patient patient_16_PML_RARA: Uncertainty - 0.2752
# Patient patient_20_NPM1: Uncertainty - 0.2736
# Patient patient_5_PML_RARA: Uncertainty - 0.2733
# Patient patient_40_NPM1: Uncertainty - 0.2708
# Patient patient_4_RUNX1_RUNX1T1: Uncertainty - 0.2698
# Patient patient_27_CBFB_MYH11: Uncertainty - 0.2689
# Patient patient_29_RUNX1_RUNX1T1: Uncertainty - 0.268
# Patient patient_21_NPM1: Uncertainty - 0.2665
# Patient patient_34_PML_RARA: Uncertainty - 0.2643
# Patient patient_14_PML_RARA: Uncertainty - 0.2635
# Patient patient_37_CBFB_MYH11: Uncertainty - 0.2603
# Patient patient_30_RUNX1_RUNX1T1: Uncertainty - 0.2602
# Patient patient_31_NPM1: Uncertainty - 0.2528
# Patient patient_4_PML_RARA: Uncertainty - 0.248
# Patient patient_31_CBFB_MYH11: Uncertainty - 0.2463
# Patient patient_38_RUNX1_RUNX1T1: Uncertainty - 0.2462
# Patient patient_25_RUNX1_RUNX1T1: Uncertainty - 0.2433
# Patient patient_35_PML_RARA: Uncertainty - 0.2374
# Patient patient_35_CBFB_MYH11: Uncertainty - 0.2358
# Patient patient_37_PML_RARA: Uncertainty - 0.2353
# Patient patient_22_CBFB_MYH11: Uncertainty - 0.2325
# Patient patient_33_RUNX1_RUNX1T1: Uncertainty - 0.2302
# Patient patient_30_NPM1: Uncertainty - 0.2302
# Patient patient_38_NPM1: Uncertainty - 0.2261
# Patient patient_28_PML_RARA: Uncertainty - 0.2254
# Patient patient_31_RUNX1_RUNX1T1: Uncertainty - 0.2236
# Patient patient_13_PML_RARA: Uncertainty - 0.2199
# Patient patient_22_RUNX1_RUNX1T1: Uncertainty - 0.2181
# Patient patient_10_CBFB_MYH11: Uncertainty - 0.2157
# Patient patient_3_NPM1: Uncertainty - 0.2119
# Patient patient_39_NPM1: Uncertainty - 0.2118
# Patient patient_10_NPM1: Uncertainty - 0.2098
# Patient patient_36_NPM1: Uncertainty - 0.2091
# Patient patient_23_PML_RARA: Uncertainty - 0.2084
# Patient patient_39_RUNX1_RUNX1T1: Uncertainty - 0.2074
# Patient patient_5_RUNX1_RUNX1T1: Uncertainty - 0.2051
# Patient patient_6_NPM1: Uncertainty - 0.1996
# Patient patient_17_RUNX1_RUNX1T1: Uncertainty - 0.1992
# Patient patient_16_RUNX1_RUNX1T1: Uncertainty - 0.1968
# Patient patient_3_CBFB_MYH11: Uncertainty - 0.1956
# Patient patient_26_PML_RARA: Uncertainty - 0.1932
# Patient patient_27_control: Uncertainty - 0.1931
# Patient patient_17_NPM1: Uncertainty - 0.1919
# Patient patient_30_PML_RARA: Uncertainty - 0.19
# Patient patient_12_control: Uncertainty - 0.1882
# Patient patient_5_CBFB_MYH11: Uncertainty - 0.1832
# Patient patient_2_CBFB_MYH11: Uncertainty - 0.1826
# Patient patient_41_RUNX1_RUNX1T1: Uncertainty - 0.1812
# Patient patient_26_CBFB_MYH11: Uncertainty - 0.1812
# Patient patient_13_NPM1: Uncertainty - 0.1803
# Patient patient_15_RUNX1_RUNX1T1: Uncertainty - 0.1782
# Patient patient_3_RUNX1_RUNX1T1: Uncertainty - 0.1764
# Patient patient_14_NPM1: Uncertainty - 0.176
# Patient patient_40_PML_RARA: Uncertainty - 0.1749
# Patient patient_36_CBFB_MYH11: Uncertainty - 0.1734
# Patient patient_24_CBFB_MYH11: Uncertainty - 0.1709
# Patient patient_41_CBFB_MYH11: Uncertainty - 0.1683
# Patient patient_5_NPM1: Uncertainty - 0.1677
# Patient patient_9_NPM1: Uncertainty - 0.1614
# Patient patient_25_PML_RARA: Uncertainty - 0.1601
# Patient patient_41_NPM1: Uncertainty - 0.157
# Patient patient_15_PML_RARA: Uncertainty - 0.1542
# Patient patient_14_RUNX1_RUNX1T1: Uncertainty - 0.1537
# Patient patient_13_CBFB_MYH11: Uncertainty - 0.1531
# Patient patient_26_RUNX1_RUNX1T1: Uncertainty - 0.1522
# Patient patient_33_NPM1: Uncertainty - 0.1469
# Patient patient_29_NPM1: Uncertainty - 0.1464
# Patient patient_6_CBFB_MYH11: Uncertainty - 0.1459
# Patient patient_37_NPM1: Uncertainty - 0.1449
# Patient patient_40_RUNX1_RUNX1T1: Uncertainty - 0.1442
# Patient patient_24_control: Uncertainty - 0.1408
# Patient patient_15_CBFB_MYH11: Uncertainty - 0.1389
# Patient patient_12_PML_RARA: Uncertainty - 0.1344
# Patient patient_6_RUNX1_RUNX1T1: Uncertainty - 0.1341
# Patient patient_15_NPM1: Uncertainty - 0.1318
# Patient patient_35_RUNX1_RUNX1T1: Uncertainty - 0.1283
# Patient patient_16_CBFB_MYH11: Uncertainty - 0.1235
# Patient patient_7_NPM1: Uncertainty - 0.1229
# Patient patient_12_NPM1: Uncertainty - 0.1184
# Patient patient_17_CBFB_MYH11: Uncertainty - 0.1169
# Patient patient_9_RUNX1_RUNX1T1: Uncertainty - 0.116
# Patient patient_23_NPM1: Uncertainty - 0.1137
# Patient patient_24_NPM1: Uncertainty - 0.1114
# Patient patient_11_control: Uncertainty - 0.11
# Patient patient_36_RUNX1_RUNX1T1: Uncertainty - 0.1096
# Patient patient_12_CBFB_MYH11: Uncertainty - 0.1044
# Patient patient_29_PML_RARA: Uncertainty - 0.1027
# Patient patient_12_RUNX1_RUNX1T1: Uncertainty - 0.09986
# Patient patient_26_NPM1: Uncertainty - 0.09954
# Patient patient_7_PML_RARA: Uncertainty - 0.09597
# Patient patient_39_control: Uncertainty - 0.09067
# Patient patient_4_NPM1: Uncertainty - 0.09066
# Patient patient_35_NPM1: Uncertainty - 0.08647
# Patient patient_22_NPM1: Uncertainty - 0.0834
# Patient patient_34_NPM1: Uncertainty - 0.08212
# Patient patient_17_PML_RARA: Uncertainty - 0.08146
# Patient patient_19_RUNX1_RUNX1T1: Uncertainty - 0.07494
# Patient patient_29_CBFB_MYH11: Uncertainty - 0.06751
# Patient patient_4_control: Uncertainty - 0.06588
# Patient patient_23_CBFB_MYH11: Uncertainty - 0.06587
# Patient patient_1_NPM1: Uncertainty - 0.06208
# Patient patient_36_PML_RARA: Uncertainty - 0.05842
# Patient patient_24_PML_RARA: Uncertainty - 0.0572
# Patient patient_41_PML_RARA: Uncertainty - 0.05645
# Patient patient_14_control: Uncertainty - 0.05504
# Patient patient_40_CBFB_MYH11: Uncertainty - 0.05152
# Patient patient_22_PML_RARA: Uncertainty - 0.04664
# Patient patient_16_NPM1: Uncertainty - 0.04614
# Patient patient_4_CBFB_MYH11: Uncertainty - 0.04548
# Patient patient_19_CBFB_MYH11: Uncertainty - 0.04161
# Patient patient_1_CBFB_MYH11: Uncertainty - 0.03719
# Patient patient_41_control: Uncertainty - 0.0347
# Patient patient_21_CBFB_MYH11: Uncertainty - 0.03406
# Patient patient_32_CBFB_MYH11: Uncertainty - 0.03163
# Patient patient_33_CBFB_MYH11: Uncertainty - 0.02972
# Patient patient_22_control: Uncertainty - 0.02948
# Patient patient_1_PML_RARA: Uncertainty - 0.02948
# Patient patient_18_PML_RARA: Uncertainty - 0.0291
# Patient patient_14_CBFB_MYH11: Uncertainty - 0.02893
# Patient patient_6_PML_RARA: Uncertainty - 0.02881
# Patient patient_20_CBFB_MYH11: Uncertainty - 0.02865
# Patient patient_34_control: Uncertainty - 0.0281
# Patient patient_27_PML_RARA: Uncertainty - 0.02565
# Patient patient_23_control: Uncertainty - 0.02286
# Patient patient_8_CBFB_MYH11: Uncertainty - 0.02228
# Patient patient_28_CBFB_MYH11: Uncertainty - 0.02024
# Patient patient_18_NPM1: Uncertainty - 0.01866
# Patient patient_9_CBFB_MYH11: Uncertainty - 0.01717
# Patient patient_3_PML_RARA: Uncertainty - 0.01589
# Patient patient_35_control: Uncertainty - 0.01481
# Patient patient_25_control: Uncertainty - 0.01413
# Patient patient_11_CBFB_MYH11: Uncertainty - 0.01295
# Patient patient_9_control: Uncertainty - 0.01289
# Patient patient_36_control: Uncertainty - 0.0113
# Patient patient_40_control: Uncertainty - 0.01057
# Patient patient_2_control: Uncertainty - 0.01013
# Patient patient_17_control: Uncertainty - 0.009946
# Patient patient_32_control: Uncertainty - 0.009127
# Patient patient_15_control: Uncertainty - 0.0091
# Patient patient_8_control: Uncertainty - 0.008763
# Patient patient_7_control: Uncertainty - 0.007353
# Patient patient_33_control: Uncertainty - 0.007088
# Patient patient_18_control: Uncertainty - 0.006438
# Patient patient_38_CBFB_MYH11: Uncertainty - 0.006415
# Patient patient_37_control: Uncertainty - 0.006187
# Patient patient_38_PML_RARA: Uncertainty - 0.004841
# Patient patient_19_control: Uncertainty - 0.004356
# Patient patient_13_control: Uncertainty - 0.003556
# Patient patient_26_control: Uncertainty - 0.003115
# Patient patient_5_control: Uncertainty - 0.003021
# Patient patient_16_control: Uncertainty - 0.002343
# Patient patient_20_control: Uncertainty - 0.002192
# Patient patient_21_control: Uncertainty - 0.002108
# Patient patient_18_CBFB_MYH11: Uncertainty - 0.001958
# Patient patient_38_control: Uncertainty - 0.001718
# Patient patient_6_control: Uncertainty - 0.001701
# Patient patient_31_control: Uncertainty - 0.001489
# Patient patient_3_control: Uncertainty - 0.001068
# Patient patient_1_control: Uncertainty - 0.0007132
# Patient patient_29_control: Uncertainty - 0.000514
# Patient patient_3_CBFB_MYH11: Uncertainty - 1.0
# Patient patient_10_CBFB_MYH11: Uncertainty - 1.0
# Patient patient_25_CBFB_MYH11: Uncertainty - 1.0
# Patient patient_27_CBFB_MYH11: Uncertainty - 1.0
# Patient patient_34_CBFB_MYH11: Uncertainty - 1.0
# Patient patient_36_CBFB_MYH11: Uncertainty - 1.0
# Patient patient_27_control: Uncertainty - 1.0
# Patient patient_28_control: Uncertainty - 1.0
# Patient patient_12_NPM1: Uncertainty - 1.0
# Patient patient_18_NPM1: Uncertainty - 1.0
# Patient patient_21_NPM1: Uncertainty - 1.0
# Patient patient_22_NPM1: Uncertainty - 1.0
# Patient patient_31_NPM1: Uncertainty - 1.0
# Patient patient_2_PML_RARA: Uncertainty - 1.0
# Patient patient_13_PML_RARA: Uncertainty - 1.0
# Patient patient_14_PML_RARA: Uncertainty - 1.0
# Patient patient_17_PML_RARA: Uncertainty - 1.0
# Patient patient_20_PML_RARA: Uncertainty - 1.0
# Patient patient_23_PML_RARA: Uncertainty - 1.0
# Patient patient_25_PML_RARA: Uncertainty - 1.0
# Patient patient_28_PML_RARA: Uncertainty - 1.0
# Patient patient_40_PML_RARA: Uncertainty - 1.0
# Patient patient_3_RUNX1_RUNX1T1: Uncertainty - 1.0
# Patient patient_4_RUNX1_RUNX1T1: Uncertainty - 1.0
# Patient patient_6_RUNX1_RUNX1T1: Uncertainty - 1.0
# Patient patient_8_RUNX1_RUNX1T1: Uncertainty - 1.0
# Patient patient_9_RUNX1_RUNX1T1: Uncertainty - 1.0
# Patient patient_12_RUNX1_RUNX1T1: Uncertainty - 1.0
# Patient patient_14_RUNX1_RUNX1T1: Uncertainty - 1.0
# Patient patient_15_RUNX1_RUNX1T1: Uncertainty - 1.0
# Patient patient_16_RUNX1_RUNX1T1: Uncertainty - 1.0
# Patient patient_17_RUNX1_RUNX1T1: Uncertainty - 1.0
# Patient patient_18_RUNX1_RUNX1T1: Uncertainty - 1.0
# Patient patient_19_RUNX1_RUNX1T1: Uncertainty - 1.0
# Patient patient_20_RUNX1_RUNX1T1: Uncertainty - 1.0
# Patient patient_22_RUNX1_RUNX1T1: Uncertainty - 1.0
# Patient patient_23_RUNX1_RUNX1T1: Uncertainty - 1.0
# Patient patient_25_RUNX1_RUNX1T1: Uncertainty - 1.0
# Patient patient_26_RUNX1_RUNX1T1: Uncertainty - 1.0
# Patient patient_28_RUNX1_RUNX1T1: Uncertainty - 1.0
# Patient patient_31_RUNX1_RUNX1T1: Uncertainty - 1.0
# Patient patient_32_RUNX1_RUNX1T1: Uncertainty - 1.0
# Patient patient_33_RUNX1_RUNX1T1: Uncertainty - 1.0
# Patient patient_36_RUNX1_RUNX1T1: Uncertainty - 1.0
# Patient patient_37_RUNX1_RUNX1T1: Uncertainty - 1.0
# Patient patient_38_RUNX1_RUNX1T1: Uncertainty - 1.0
# Patient patient_39_RUNX1_RUNX1T1: Uncertainty - 1.0
# Patient patient_40_RUNX1_RUNX1T1: Uncertainty - 1.0
# Patient patient_41_RUNX1_RUNX1T1: Uncertainty - 1.0
# Patient patient_6_NPM1: Uncertainty - 0.9
# Patient patient_11_NPM1: Uncertainty - 0.9
# Patient patient_19_NPM1: Uncertainty - 0.9
# Patient patient_39_PML_RARA: Uncertainty - 0.9
# Patient patient_24_RUNX1_RUNX1T1: Uncertainty - 0.9
# Patient patient_29_RUNX1_RUNX1T1: Uncertainty - 0.9
# Patient patient_35_RUNX1_RUNX1T1: Uncertainty - 0.9
# Patient patient_37_CBFB_MYH11: Uncertainty - 0.8
# Patient patient_39_CBFB_MYH11: Uncertainty - 0.8
# Patient patient_25_NPM1: Uncertainty - 0.8
# Patient patient_34_PML_RARA: Uncertainty - 0.8
# Patient patient_7_RUNX1_RUNX1T1: Uncertainty - 0.8
# Patient patient_11_RUNX1_RUNX1T1: Uncertainty - 0.8
# Patient patient_13_RUNX1_RUNX1T1: Uncertainty - 0.8
# Patient patient_34_RUNX1_RUNX1T1: Uncertainty - 0.8
# Patient patient_11_PML_RARA: Uncertainty - 0.7
# Patient patient_5_RUNX1_RUNX1T1: Uncertainty - 0.7
# Patient patient_27_NPM1: Uncertainty - 0.6
# Patient patient_2_RUNX1_RUNX1T1: Uncertainty - 0.6
# Patient patient_28_NPM1: Uncertainty - 0.5
# Patient patient_21_RUNX1_RUNX1T1: Uncertainty - 0.5
# Patient patient_7_CBFB_MYH11: Uncertainty - 0.4
# Patient patient_32_PML_RARA: Uncertainty - 0.4
# Patient patient_1_RUNX1_RUNX1T1: Uncertainty - 0.4
# Patient patient_10_RUNX1_RUNX1T1: Uncertainty - 0.4
# Patient patient_30_RUNX1_RUNX1T1: Uncertainty - 0.4
# Patient patient_30_CBFB_MYH11: Uncertainty - 0.3
# Patient patient_8_NPM1: Uncertainty - 0.2
# Patient patient_10_PML_RARA: Uncertainty - 0.2
# Patient patient_19_PML_RARA: Uncertainty - 0.2
# Patient patient_27_RUNX1_RUNX1T1: Uncertainty - 0.2
# Patient patient_31_CBFB_MYH11: Uncertainty - 0.1
# Patient patient_30_control: Uncertainty - 0.1
# Patient patient_32_NPM1: Uncertainty - 0.1
# Patient patient_1_CBFB_MYH11: Uncertainty - 0.0
# Patient patient_2_CBFB_MYH11: Uncertainty - 0.0
# Patient patient_4_CBFB_MYH11: Uncertainty - 0.0
# Patient patient_5_CBFB_MYH11: Uncertainty - 0.0
# Patient patient_6_CBFB_MYH11: Uncertainty - 0.0
# Patient patient_8_CBFB_MYH11: Uncertainty - 0.0
# Patient patient_9_CBFB_MYH11: Uncertainty - 0.0
# Patient patient_11_CBFB_MYH11: Uncertainty - 0.0
# Patient patient_12_CBFB_MYH11: Uncertainty - 0.0
# Patient patient_13_CBFB_MYH11: Uncertainty - 0.0
# Patient patient_14_CBFB_MYH11: Uncertainty - 0.0
# Patient patient_15_CBFB_MYH11: Uncertainty - 0.0
# Patient patient_16_CBFB_MYH11: Uncertainty - 0.0
# Patient patient_17_CBFB_MYH11: Uncertainty - 0.0
# Patient patient_18_CBFB_MYH11: Uncertainty - 0.0
# Patient patient_19_CBFB_MYH11: Uncertainty - 0.0
# Patient patient_20_CBFB_MYH11: Uncertainty - 0.0
# Patient patient_21_CBFB_MYH11: Uncertainty - 0.0
# Patient patient_22_CBFB_MYH11: Uncertainty - 0.0
# Patient patient_23_CBFB_MYH11: Uncertainty - 0.0
# Patient patient_24_CBFB_MYH11: Uncertainty - 0.0
# Patient patient_26_CBFB_MYH11: Uncertainty - 0.0
# Patient patient_28_CBFB_MYH11: Uncertainty - 0.0
# Patient patient_29_CBFB_MYH11: Uncertainty - 0.0
# Patient patient_32_CBFB_MYH11: Uncertainty - 0.0
# Patient patient_33_CBFB_MYH11: Uncertainty - 0.0
# Patient patient_35_CBFB_MYH11: Uncertainty - 0.0
# Patient patient_38_CBFB_MYH11: Uncertainty - 0.0
# Patient patient_40_CBFB_MYH11: Uncertainty - 0.0
# Patient patient_41_CBFB_MYH11: Uncertainty - 0.0
# Patient patient_1_control: Uncertainty - 0.0
# Patient patient_2_control: Uncertainty - 0.0
# Patient patient_3_control: Uncertainty - 0.0
# Patient patient_4_control: Uncertainty - 0.0
# Patient patient_5_control: Uncertainty - 0.0
# Patient patient_6_control: Uncertainty - 0.0
# Patient patient_7_control: Uncertainty - 0.0
# Patient patient_8_control: Uncertainty - 0.0
# Patient patient_9_control: Uncertainty - 0.0
# Patient patient_10_control: Uncertainty - 0.0
# Patient patient_11_control: Uncertainty - 0.0
# Patient patient_12_control: Uncertainty - 0.0
# Patient patient_13_control: Uncertainty - 0.0
# Patient patient_14_control: Uncertainty - 0.0
# Patient patient_15_control: Uncertainty - 0.0
# Patient patient_16_control: Uncertainty - 0.0
# Patient patient_17_control: Uncertainty - 0.0
# Patient patient_18_control: Uncertainty - 0.0
# Patient patient_19_control: Uncertainty - 0.0
# Patient patient_20_control: Uncertainty - 0.0
# Patient patient_21_control: Uncertainty - 0.0
# Patient patient_22_control: Uncertainty - 0.0
# Patient patient_23_control: Uncertainty - 0.0
# Patient patient_24_control: Uncertainty - 0.0
# Patient patient_25_control: Uncertainty - 0.0
# Patient patient_26_control: Uncertainty - 0.0
# Patient patient_29_control: Uncertainty - 0.0
# Patient patient_31_control: Uncertainty - 0.0
# Patient patient_32_control: Uncertainty - 0.0
# Patient patient_33_control: Uncertainty - 0.0
# Patient patient_34_control: Uncertainty - 0.0
# Patient patient_35_control: Uncertainty - 0.0
# Patient patient_36_control: Uncertainty - 0.0
# Patient patient_37_control: Uncertainty - 0.0
# Patient patient_38_control: Uncertainty - 0.0
# Patient patient_39_control: Uncertainty - 0.0
# Patient patient_40_control: Uncertainty - 0.0
# Patient patient_41_control: Uncertainty - 0.0
# Patient patient_1_NPM1: Uncertainty - 0.0
# Patient patient_2_NPM1: Uncertainty - 0.0
# Patient patient_3_NPM1: Uncertainty - 0.0
# Patient patient_4_NPM1: Uncertainty - 0.0
# Patient patient_5_NPM1: Uncertainty - 0.0
# Patient patient_7_NPM1: Uncertainty - 0.0
# Patient patient_9_NPM1: Uncertainty - 0.0
# Patient patient_10_NPM1: Uncertainty - 0.0
# Patient patient_13_NPM1: Uncertainty - 0.0
# Patient patient_14_NPM1: Uncertainty - 0.0
# Patient patient_15_NPM1: Uncertainty - 0.0
# Patient patient_16_NPM1: Uncertainty - 0.0
# Patient patient_17_NPM1: Uncertainty - 0.0
# Patient patient_20_NPM1: Uncertainty - 0.0
# Patient patient_23_NPM1: Uncertainty - 0.0
# Patient patient_24_NPM1: Uncertainty - 0.0
# Patient patient_26_NPM1: Uncertainty - 0.0
# Patient patient_29_NPM1: Uncertainty - 0.0
# Patient patient_30_NPM1: Uncertainty - 0.0
# Patient patient_33_NPM1: Uncertainty - 0.0
# Patient patient_34_NPM1: Uncertainty - 0.0
# Patient patient_35_NPM1: Uncertainty - 0.0
# Patient patient_36_NPM1: Uncertainty - 0.0
# Patient patient_37_NPM1: Uncertainty - 0.0
# Patient patient_38_NPM1: Uncertainty - 0.0
# Patient patient_39_NPM1: Uncertainty - 0.0
# Patient patient_40_NPM1: Uncertainty - 0.0
# Patient patient_41_NPM1: Uncertainty - 0.0
# Patient patient_1_PML_RARA: Uncertainty - 0.0
# Patient patient_3_PML_RARA: Uncertainty - 0.0
# Patient patient_4_PML_RARA: Uncertainty - 0.0
# Patient patient_5_PML_RARA: Uncertainty - 0.0
# Patient patient_6_PML_RARA: Uncertainty - 0.0
# Patient patient_7_PML_RARA: Uncertainty - 0.0
# Patient patient_8_PML_RARA: Uncertainty - 0.0
# Patient patient_9_PML_RARA: Uncertainty - 0.0
# Patient patient_12_PML_RARA: Uncertainty - 0.0
# Patient patient_15_PML_RARA: Uncertainty - 0.0
# Patient patient_16_PML_RARA: Uncertainty - 0.0
# Patient patient_18_PML_RARA: Uncertainty - 0.0
# Patient patient_21_PML_RARA: Uncertainty - 0.0
# Patient patient_22_PML_RARA: Uncertainty - 0.0
# Patient patient_24_PML_RARA: Uncertainty - 0.0
# Patient patient_26_PML_RARA: Uncertainty - 0.0
# Patient patient_27_PML_RARA: Uncertainty - 0.0
# Patient patient_29_PML_RARA: Uncertainty - 0.0
# Patient patient_30_PML_RARA: Uncertainty - 0.0
# Patient patient_31_PML_RARA: Uncertainty - 0.0
# Patient patient_33_PML_RARA: Uncertainty - 0.0
# Patient patient_35_PML_RARA: Uncertainty - 0.0
# Patient patient_36_PML_RARA: Uncertainty - 0.0
# Patient patient_37_PML_RARA: Uncertainty - 0.0
# Patient patient_38_PML_RARA: Uncertainty - 0.0
# Patient patient_41_PML_RARA: Uncertainty - 0.0

# %%
def select_paths(uncertainties, percentage):
    sorted_uncertainties = dict(sorted(uncertainties.items(), key=lambda item: item[1]['uncertainty'], reverse=True))
    
    # Calculate the number of paths based on the percentage
    num_paths = int(len(sorted_uncertainties) * (percentage / 100.0))
    
    # Select the top percentage of paths
    selected_paths = {p: data['path'] for p, data in list(sorted_uncertainties.items())[:num_paths]}
    
    return selected_paths

metadata_path = SOURCE_FOLDER + "/metadata.csv"

def create_metadata(selected_paths, target_folder):
    # Load the existing metadata CSV file into a DataFrame
    metadata_df = pd.read_csv(metadata_path)

    # Dictionary to store the extracted information
    metadata_dict = {}

    # Loop over each key in selected_paths
    for key in selected_paths:
        path = selected_paths[key]

        # Extract patient_id and bag_label from the key
        match = re.search(r'\d', key)
        if match:
            index_of_second_digit = key.find('_', match.start() + 1)
            if index_of_second_digit != -1:
                patient_id = key[:index_of_second_digit + 1]  # Include everything up to the second underscore
                patient_id = patient_id[:-1]
                bag_label = key[index_of_second_digit + 1:]  # Remove the first underscore in bag_label
            else:
                # If no second underscore found, consider the entire key as patient_id
                patient_id = key
                bag_label = ''
        else:
            # If no digit found, consider the entire key as patient_id
            patient_id = key
            bag_label = ''

        # Filter the metadata DataFrame based on patient_id and bag_label
        metadata_row = metadata_df[(metadata_df['patient_id'] == patient_id) & (metadata_df['bag_label'] == bag_label)]

        # Check if any matching rows are found
        if not metadata_row.empty:
            # Get the first matching row (assuming there's only one match)
            metadata_dict[key] = metadata_row.iloc[0].to_dict()
        else:
            # Handle the case when no matching rows are found
            print(f"No metadata found for {key}: {path}")

    # Create a new DataFrame from the extracted metadata dictionary
    new_metadata_df = pd.DataFrame.from_dict(metadata_dict, orient='index')


    # Save the new metadata DataFrame to a CSV file in the target folder
    new_metadata_path = os.path.join(target_folder, 'metadata_uncertain_patients.csv')
    new_metadata_df.to_csv(new_metadata_path, index=False)

    return new_metadata_path


#returns dict that contains number of real patients per leukemia class
def get_realpatients_filepaths_dictionary(src_folder):
    paths = {}
    for class_name in os.listdir(src_folder):
        class_path=os.path.join(src_folder, class_name)
        for file in  os.listdir(class_path):
            src_path = os.path.join(class_path, file)
            # Extract class and patient information from the source path
            patient_name = get_patient_name(src_path)
            if class_name not in paths.keys():
                paths[class_name] = []
            paths[class_name].append(src_path)
    return paths

# %%
def save_patient_filepaths(selected_paths, new_folder,paths_real_patients):
    # save filepaths to the new folder
    print(f"Save file paths for uncertain patients in {new_folder}")
    os.makedirs(new_folder, exist_ok=True)
    # save filepath in dictionary paths with keys as class and values list of file paths
    paths_uncertain_patients = {}
    #Initilialise 
    for class_name in CLASSES:
        if class_name not in paths_uncertain_patients.keys():
                    paths_uncertain_patients[class_name] = []
            
    for p, path in selected_paths.items():   
        class_name = get_class_name(path)
        paths_uncertain_patients[class_name].append(path)    
    
    #Concatenate the two dictionaries
    paths_mixed_patients={}
    for key, value in paths_real_patients.items():
        paths_mixed_patients[key] = value
        paths_mixed_patients[key] += paths_uncertain_patients[key]
    print(paths_mixed_patients)   
    
    #Save ditionary
    with open(new_folder+'/file_paths.pkl', 'wb') as f:
        pickle.dump(paths_mixed_patients, f)

# %%
# Iterate over different percentages from 10 to 50 and save uncertain patients
paths_real_patients=get_realpatients_filepaths_dictionary(real_data_source)
for percentage in range(10, 51, 10):
    # Define folder to save the uncertain patients
    new_folder_misscl = output_folder+f'/misscl_{percentage}_percent'
    new_folder_max = output_folder+f'/max_{percentage}_percent'
    new_folder_sum = output_folder+f'/sum_{percentage}_percent'

    # Select uncertain paths based on the current percentage for missclassification_counts
    selected_misscl_paths = select_paths(missclassification_counts, percentage)
    # Save uncertain patients to the new folder
    save_patient_filepaths(selected_misscl_paths, new_folder_misscl,paths_real_patients)
    create_metadata(selected_misscl_paths, new_folder_misscl)

    # Select uncertain paths based on the current percentage for max_uncertainties
    selected_max_paths = select_paths(max_uncertainties, percentage)
    # Save uncertain patients to the new folder
    save_patient_filepaths(selected_max_paths, new_folder_max,paths_real_patients)
    create_metadata(selected_max_paths, new_folder_max)

    # Select uncertain paths based on the current percentage for sum_uncertainties
    selected_sum_paths = select_paths(sum_uncertainties, percentage)
    # Save uncertain patients to the new folder
    save_patient_filepaths(selected_sum_paths, new_folder_sum,paths_real_patients)
    create_metadata(selected_sum_paths, new_folder_sum)
# Out:
# Save file paths for uncertain patients in /mnt/volume/shared/data_file/mixed_uncertain_seed42/misscl_10_percent
# {'control': ['/mnt/volume/shared/data_file/data/control/CIQ', '/mnt/volume/shared/data_file/data/control/FDW', '/mnt/volume/shared/data_file/data/control/ICS', '/mnt/volume/shared/data_file/data/control/WXO', '/mnt/volume/shared/data_file/data/control/NXO', '/mnt/volume/shared/data_file/data/control/ATM', '/mnt/volume/shared/data_file/data/control/MPP', '/mnt/volume/shared/data_file/data/control/DJJ', '/mnt/volume/shared/data_file/data/control/UNX', '/mnt/volume/shared/data_file/data/control/UOU', '/mnt/volume/shared/data_file/data/control/AVL', '/mnt/volume/shared/data_file/data/control/WSD', '/mnt/volume/shared/data_file/data/control/ZNK', '/mnt/volume/shared/data_file/data/control/TBZ', '/mnt/volume/shared/data_file/data/control/RDV', '/mnt/volume/shared/data_file/data/control/MKF', '/mnt/volume/shared/data_file/data/control/LCW', '/mnt/volume/shared/data_file/data/control/XXJ', '/mnt/volume/shared/data_file/data/control/YWQ', '/mnt/volume/shared/data_file/data/control/DNX', '/mnt/volume/shared/data_file/data/control/ZNL', '/mnt/volume/shared/data_file/data/control/UBG', '/mnt/volume/shared/data_file/data/control/GJZ', '/mnt/volume/shared/data_file/data/control/IPY', '/mnt/volume/shared/data_file/data/control/YXY', '/mnt/volume/shared/data_file/data/control/NOL', '/mnt/volume/shared/data_file/data/control/NFI', '/mnt/volume/shared/data_file/data/control/VPN', '/mnt/volume/shared/data_file/data/control/CDA', '/mnt/volume/shared/data_file/data/control/FAQ', '/mnt/volume/shared/data_file/data/control/DHE', '/mnt/volume/shared/data_file/data/control/XXI', '/mnt/volume/shared/data_file/data/control/GJQ', '/mnt/volume/shared/data_file/data/control/TVZ', '/mnt/volume/shared/data_file/data/control/CCO', '/mnt/volume/shared/data_file/data/control/GXQ', '/mnt/volume/shared/data_file/data/control/KDW', '/mnt/volume/shared/data_file/data/control/QIZ', '/mnt/volume/shared/data_file/data/control/ORD', '/mnt/volume/shared/data_file/data/control/HQQ', '/mnt/volume/shared/data_file/data/control/AIH', '/mnt/volume/shared/data_file/data/control/NRL', '/mnt/volume/shared/data_file/data/control/OTU', '/mnt/volume/shared/data_file/data/control/YDL', '/mnt/volume/shared/data_file/data/control/MOR', '/mnt/volume/shared/data_file/data/control/ENH', '/mnt/volume/shared/data_file/data/control/LAM', '/mnt/volume/shared/data_file/data/control/WOA', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_27', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_28'], 'RUNX1_RUNX1T1': ['/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/ONF', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/KRG', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/BOE', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/SWN', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/RHX', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/IIG', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/ILZ', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/GUE', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/XOB', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/VXU', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/UWF', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/VMO', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/RGG', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/XTK', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/NRB', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/LPA', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/HMC', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/RJQ', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/ZVX', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/UGU', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/XXX', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/ISW', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/BHG', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/ZJJ', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/ORE', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/FED'], 'CB ...
# Save file paths for uncertain patients in /mnt/volume/shared/data_file/mixed_uncertain_seed42/max_10_percent
# {'control': ['/mnt/volume/shared/data_file/data/control/CIQ', '/mnt/volume/shared/data_file/data/control/FDW', '/mnt/volume/shared/data_file/data/control/ICS', '/mnt/volume/shared/data_file/data/control/WXO', '/mnt/volume/shared/data_file/data/control/NXO', '/mnt/volume/shared/data_file/data/control/ATM', '/mnt/volume/shared/data_file/data/control/MPP', '/mnt/volume/shared/data_file/data/control/DJJ', '/mnt/volume/shared/data_file/data/control/UNX', '/mnt/volume/shared/data_file/data/control/UOU', '/mnt/volume/shared/data_file/data/control/AVL', '/mnt/volume/shared/data_file/data/control/WSD', '/mnt/volume/shared/data_file/data/control/ZNK', '/mnt/volume/shared/data_file/data/control/TBZ', '/mnt/volume/shared/data_file/data/control/RDV', '/mnt/volume/shared/data_file/data/control/MKF', '/mnt/volume/shared/data_file/data/control/LCW', '/mnt/volume/shared/data_file/data/control/XXJ', '/mnt/volume/shared/data_file/data/control/YWQ', '/mnt/volume/shared/data_file/data/control/DNX', '/mnt/volume/shared/data_file/data/control/ZNL', '/mnt/volume/shared/data_file/data/control/UBG', '/mnt/volume/shared/data_file/data/control/GJZ', '/mnt/volume/shared/data_file/data/control/IPY', '/mnt/volume/shared/data_file/data/control/YXY', '/mnt/volume/shared/data_file/data/control/NOL', '/mnt/volume/shared/data_file/data/control/NFI', '/mnt/volume/shared/data_file/data/control/VPN', '/mnt/volume/shared/data_file/data/control/CDA', '/mnt/volume/shared/data_file/data/control/FAQ', '/mnt/volume/shared/data_file/data/control/DHE', '/mnt/volume/shared/data_file/data/control/XXI', '/mnt/volume/shared/data_file/data/control/GJQ', '/mnt/volume/shared/data_file/data/control/TVZ', '/mnt/volume/shared/data_file/data/control/CCO', '/mnt/volume/shared/data_file/data/control/GXQ', '/mnt/volume/shared/data_file/data/control/KDW', '/mnt/volume/shared/data_file/data/control/QIZ', '/mnt/volume/shared/data_file/data/control/ORD', '/mnt/volume/shared/data_file/data/control/HQQ', '/mnt/volume/shared/data_file/data/control/AIH', '/mnt/volume/shared/data_file/data/control/NRL', '/mnt/volume/shared/data_file/data/control/OTU', '/mnt/volume/shared/data_file/data/control/YDL', '/mnt/volume/shared/data_file/data/control/MOR', '/mnt/volume/shared/data_file/data/control/ENH', '/mnt/volume/shared/data_file/data/control/LAM', '/mnt/volume/shared/data_file/data/control/WOA', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_27', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_28'], 'RUNX1_RUNX1T1': ['/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/ONF', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/KRG', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/BOE', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/SWN', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/RHX', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/IIG', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/ILZ', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/GUE', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/XOB', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/VXU', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/UWF', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/VMO', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/RGG', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/XTK', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/NRB', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/LPA', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/HMC', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/RJQ', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/ZVX', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/UGU', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/XXX', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/ISW', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/BHG', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/ZJJ', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/ORE', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/FED', '/mn ...
# Save file paths for uncertain patients in /mnt/volume/shared/data_file/mixed_uncertain_seed42/sum_10_percent
# {'control': ['/mnt/volume/shared/data_file/data/control/CIQ', '/mnt/volume/shared/data_file/data/control/FDW', '/mnt/volume/shared/data_file/data/control/ICS', '/mnt/volume/shared/data_file/data/control/WXO', '/mnt/volume/shared/data_file/data/control/NXO', '/mnt/volume/shared/data_file/data/control/ATM', '/mnt/volume/shared/data_file/data/control/MPP', '/mnt/volume/shared/data_file/data/control/DJJ', '/mnt/volume/shared/data_file/data/control/UNX', '/mnt/volume/shared/data_file/data/control/UOU', '/mnt/volume/shared/data_file/data/control/AVL', '/mnt/volume/shared/data_file/data/control/WSD', '/mnt/volume/shared/data_file/data/control/ZNK', '/mnt/volume/shared/data_file/data/control/TBZ', '/mnt/volume/shared/data_file/data/control/RDV', '/mnt/volume/shared/data_file/data/control/MKF', '/mnt/volume/shared/data_file/data/control/LCW', '/mnt/volume/shared/data_file/data/control/XXJ', '/mnt/volume/shared/data_file/data/control/YWQ', '/mnt/volume/shared/data_file/data/control/DNX', '/mnt/volume/shared/data_file/data/control/ZNL', '/mnt/volume/shared/data_file/data/control/UBG', '/mnt/volume/shared/data_file/data/control/GJZ', '/mnt/volume/shared/data_file/data/control/IPY', '/mnt/volume/shared/data_file/data/control/YXY', '/mnt/volume/shared/data_file/data/control/NOL', '/mnt/volume/shared/data_file/data/control/NFI', '/mnt/volume/shared/data_file/data/control/VPN', '/mnt/volume/shared/data_file/data/control/CDA', '/mnt/volume/shared/data_file/data/control/FAQ', '/mnt/volume/shared/data_file/data/control/DHE', '/mnt/volume/shared/data_file/data/control/XXI', '/mnt/volume/shared/data_file/data/control/GJQ', '/mnt/volume/shared/data_file/data/control/TVZ', '/mnt/volume/shared/data_file/data/control/CCO', '/mnt/volume/shared/data_file/data/control/GXQ', '/mnt/volume/shared/data_file/data/control/KDW', '/mnt/volume/shared/data_file/data/control/QIZ', '/mnt/volume/shared/data_file/data/control/ORD', '/mnt/volume/shared/data_file/data/control/HQQ', '/mnt/volume/shared/data_file/data/control/AIH', '/mnt/volume/shared/data_file/data/control/NRL', '/mnt/volume/shared/data_file/data/control/OTU', '/mnt/volume/shared/data_file/data/control/YDL', '/mnt/volume/shared/data_file/data/control/MOR', '/mnt/volume/shared/data_file/data/control/ENH', '/mnt/volume/shared/data_file/data/control/LAM', '/mnt/volume/shared/data_file/data/control/WOA', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_27', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_28'], 'RUNX1_RUNX1T1': ['/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/ONF', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/KRG', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/BOE', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/SWN', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/RHX', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/IIG', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/ILZ', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/GUE', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/XOB', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/VXU', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/UWF', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/VMO', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/RGG', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/XTK', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/NRB', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/LPA', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/HMC', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/RJQ', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/ZVX', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/UGU', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/XXX', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/ISW', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/BHG', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/ZJJ', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/ORE', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/FED', '/mn ...
# Save file paths for uncertain patients in /mnt/volume/shared/data_file/mixed_uncertain_seed42/misscl_20_percent
# {'control': ['/mnt/volume/shared/data_file/data/control/CIQ', '/mnt/volume/shared/data_file/data/control/FDW', '/mnt/volume/shared/data_file/data/control/ICS', '/mnt/volume/shared/data_file/data/control/WXO', '/mnt/volume/shared/data_file/data/control/NXO', '/mnt/volume/shared/data_file/data/control/ATM', '/mnt/volume/shared/data_file/data/control/MPP', '/mnt/volume/shared/data_file/data/control/DJJ', '/mnt/volume/shared/data_file/data/control/UNX', '/mnt/volume/shared/data_file/data/control/UOU', '/mnt/volume/shared/data_file/data/control/AVL', '/mnt/volume/shared/data_file/data/control/WSD', '/mnt/volume/shared/data_file/data/control/ZNK', '/mnt/volume/shared/data_file/data/control/TBZ', '/mnt/volume/shared/data_file/data/control/RDV', '/mnt/volume/shared/data_file/data/control/MKF', '/mnt/volume/shared/data_file/data/control/LCW', '/mnt/volume/shared/data_file/data/control/XXJ', '/mnt/volume/shared/data_file/data/control/YWQ', '/mnt/volume/shared/data_file/data/control/DNX', '/mnt/volume/shared/data_file/data/control/ZNL', '/mnt/volume/shared/data_file/data/control/UBG', '/mnt/volume/shared/data_file/data/control/GJZ', '/mnt/volume/shared/data_file/data/control/IPY', '/mnt/volume/shared/data_file/data/control/YXY', '/mnt/volume/shared/data_file/data/control/NOL', '/mnt/volume/shared/data_file/data/control/NFI', '/mnt/volume/shared/data_file/data/control/VPN', '/mnt/volume/shared/data_file/data/control/CDA', '/mnt/volume/shared/data_file/data/control/FAQ', '/mnt/volume/shared/data_file/data/control/DHE', '/mnt/volume/shared/data_file/data/control/XXI', '/mnt/volume/shared/data_file/data/control/GJQ', '/mnt/volume/shared/data_file/data/control/TVZ', '/mnt/volume/shared/data_file/data/control/CCO', '/mnt/volume/shared/data_file/data/control/GXQ', '/mnt/volume/shared/data_file/data/control/KDW', '/mnt/volume/shared/data_file/data/control/QIZ', '/mnt/volume/shared/data_file/data/control/ORD', '/mnt/volume/shared/data_file/data/control/HQQ', '/mnt/volume/shared/data_file/data/control/AIH', '/mnt/volume/shared/data_file/data/control/NRL', '/mnt/volume/shared/data_file/data/control/OTU', '/mnt/volume/shared/data_file/data/control/YDL', '/mnt/volume/shared/data_file/data/control/MOR', '/mnt/volume/shared/data_file/data/control/ENH', '/mnt/volume/shared/data_file/data/control/LAM', '/mnt/volume/shared/data_file/data/control/WOA', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_27', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_28', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_27', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_28'], 'RUNX1_RUNX1T1': ['/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/ONF', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/KRG', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/BOE', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/SWN', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/RHX', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/IIG', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/ILZ', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/GUE', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/XOB', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/VXU', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/UWF', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/VMO', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/RGG', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/XTK', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/NRB', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/LPA', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/HMC', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/RJQ', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/ZVX', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/UGU', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/XXX', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/ISW', '/mnt/volume/shared/data_file/data/RUNX1_R ...
# Save file paths for uncertain patients in /mnt/volume/shared/data_file/mixed_uncertain_seed42/max_20_percent
# {'control': ['/mnt/volume/shared/data_file/data/control/CIQ', '/mnt/volume/shared/data_file/data/control/FDW', '/mnt/volume/shared/data_file/data/control/ICS', '/mnt/volume/shared/data_file/data/control/WXO', '/mnt/volume/shared/data_file/data/control/NXO', '/mnt/volume/shared/data_file/data/control/ATM', '/mnt/volume/shared/data_file/data/control/MPP', '/mnt/volume/shared/data_file/data/control/DJJ', '/mnt/volume/shared/data_file/data/control/UNX', '/mnt/volume/shared/data_file/data/control/UOU', '/mnt/volume/shared/data_file/data/control/AVL', '/mnt/volume/shared/data_file/data/control/WSD', '/mnt/volume/shared/data_file/data/control/ZNK', '/mnt/volume/shared/data_file/data/control/TBZ', '/mnt/volume/shared/data_file/data/control/RDV', '/mnt/volume/shared/data_file/data/control/MKF', '/mnt/volume/shared/data_file/data/control/LCW', '/mnt/volume/shared/data_file/data/control/XXJ', '/mnt/volume/shared/data_file/data/control/YWQ', '/mnt/volume/shared/data_file/data/control/DNX', '/mnt/volume/shared/data_file/data/control/ZNL', '/mnt/volume/shared/data_file/data/control/UBG', '/mnt/volume/shared/data_file/data/control/GJZ', '/mnt/volume/shared/data_file/data/control/IPY', '/mnt/volume/shared/data_file/data/control/YXY', '/mnt/volume/shared/data_file/data/control/NOL', '/mnt/volume/shared/data_file/data/control/NFI', '/mnt/volume/shared/data_file/data/control/VPN', '/mnt/volume/shared/data_file/data/control/CDA', '/mnt/volume/shared/data_file/data/control/FAQ', '/mnt/volume/shared/data_file/data/control/DHE', '/mnt/volume/shared/data_file/data/control/XXI', '/mnt/volume/shared/data_file/data/control/GJQ', '/mnt/volume/shared/data_file/data/control/TVZ', '/mnt/volume/shared/data_file/data/control/CCO', '/mnt/volume/shared/data_file/data/control/GXQ', '/mnt/volume/shared/data_file/data/control/KDW', '/mnt/volume/shared/data_file/data/control/QIZ', '/mnt/volume/shared/data_file/data/control/ORD', '/mnt/volume/shared/data_file/data/control/HQQ', '/mnt/volume/shared/data_file/data/control/AIH', '/mnt/volume/shared/data_file/data/control/NRL', '/mnt/volume/shared/data_file/data/control/OTU', '/mnt/volume/shared/data_file/data/control/YDL', '/mnt/volume/shared/data_file/data/control/MOR', '/mnt/volume/shared/data_file/data/control/ENH', '/mnt/volume/shared/data_file/data/control/LAM', '/mnt/volume/shared/data_file/data/control/WOA', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_27', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_28', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_27', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_28', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_30', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_10'], 'RUNX1_RUNX1T1': ['/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/ONF', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/KRG', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/BOE', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/SWN', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/RHX', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/IIG', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/ILZ', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/GUE', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/XOB', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/VXU', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/UWF', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/VMO', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/RGG', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/XTK', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/NRB', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/LPA', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/HMC', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/RJQ', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/ZVX', '/mnt/volume/shared/data_ ...
# Save file paths for uncertain patients in /mnt/volume/shared/data_file/mixed_uncertain_seed42/sum_20_percent
# {'control': ['/mnt/volume/shared/data_file/data/control/CIQ', '/mnt/volume/shared/data_file/data/control/FDW', '/mnt/volume/shared/data_file/data/control/ICS', '/mnt/volume/shared/data_file/data/control/WXO', '/mnt/volume/shared/data_file/data/control/NXO', '/mnt/volume/shared/data_file/data/control/ATM', '/mnt/volume/shared/data_file/data/control/MPP', '/mnt/volume/shared/data_file/data/control/DJJ', '/mnt/volume/shared/data_file/data/control/UNX', '/mnt/volume/shared/data_file/data/control/UOU', '/mnt/volume/shared/data_file/data/control/AVL', '/mnt/volume/shared/data_file/data/control/WSD', '/mnt/volume/shared/data_file/data/control/ZNK', '/mnt/volume/shared/data_file/data/control/TBZ', '/mnt/volume/shared/data_file/data/control/RDV', '/mnt/volume/shared/data_file/data/control/MKF', '/mnt/volume/shared/data_file/data/control/LCW', '/mnt/volume/shared/data_file/data/control/XXJ', '/mnt/volume/shared/data_file/data/control/YWQ', '/mnt/volume/shared/data_file/data/control/DNX', '/mnt/volume/shared/data_file/data/control/ZNL', '/mnt/volume/shared/data_file/data/control/UBG', '/mnt/volume/shared/data_file/data/control/GJZ', '/mnt/volume/shared/data_file/data/control/IPY', '/mnt/volume/shared/data_file/data/control/YXY', '/mnt/volume/shared/data_file/data/control/NOL', '/mnt/volume/shared/data_file/data/control/NFI', '/mnt/volume/shared/data_file/data/control/VPN', '/mnt/volume/shared/data_file/data/control/CDA', '/mnt/volume/shared/data_file/data/control/FAQ', '/mnt/volume/shared/data_file/data/control/DHE', '/mnt/volume/shared/data_file/data/control/XXI', '/mnt/volume/shared/data_file/data/control/GJQ', '/mnt/volume/shared/data_file/data/control/TVZ', '/mnt/volume/shared/data_file/data/control/CCO', '/mnt/volume/shared/data_file/data/control/GXQ', '/mnt/volume/shared/data_file/data/control/KDW', '/mnt/volume/shared/data_file/data/control/QIZ', '/mnt/volume/shared/data_file/data/control/ORD', '/mnt/volume/shared/data_file/data/control/HQQ', '/mnt/volume/shared/data_file/data/control/AIH', '/mnt/volume/shared/data_file/data/control/NRL', '/mnt/volume/shared/data_file/data/control/OTU', '/mnt/volume/shared/data_file/data/control/YDL', '/mnt/volume/shared/data_file/data/control/MOR', '/mnt/volume/shared/data_file/data/control/ENH', '/mnt/volume/shared/data_file/data/control/LAM', '/mnt/volume/shared/data_file/data/control/WOA', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_27', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_28', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_27', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_28', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_30', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_10', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_30'], 'RUNX1_RUNX1T1': ['/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/ONF', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/KRG', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/BOE', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/SWN', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/RHX', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/IIG', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/ILZ', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/GUE', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/XOB', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/VXU', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/UWF', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/VMO', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/RGG', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/XTK', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/NRB', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/LPA', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/HMC', '/mnt/volume/shared/data_file/data/RUNX1_RUN ...
# Save file paths for uncertain patients in /mnt/volume/shared/data_file/mixed_uncertain_seed42/misscl_30_percent
# {'control': ['/mnt/volume/shared/data_file/data/control/CIQ', '/mnt/volume/shared/data_file/data/control/FDW', '/mnt/volume/shared/data_file/data/control/ICS', '/mnt/volume/shared/data_file/data/control/WXO', '/mnt/volume/shared/data_file/data/control/NXO', '/mnt/volume/shared/data_file/data/control/ATM', '/mnt/volume/shared/data_file/data/control/MPP', '/mnt/volume/shared/data_file/data/control/DJJ', '/mnt/volume/shared/data_file/data/control/UNX', '/mnt/volume/shared/data_file/data/control/UOU', '/mnt/volume/shared/data_file/data/control/AVL', '/mnt/volume/shared/data_file/data/control/WSD', '/mnt/volume/shared/data_file/data/control/ZNK', '/mnt/volume/shared/data_file/data/control/TBZ', '/mnt/volume/shared/data_file/data/control/RDV', '/mnt/volume/shared/data_file/data/control/MKF', '/mnt/volume/shared/data_file/data/control/LCW', '/mnt/volume/shared/data_file/data/control/XXJ', '/mnt/volume/shared/data_file/data/control/YWQ', '/mnt/volume/shared/data_file/data/control/DNX', '/mnt/volume/shared/data_file/data/control/ZNL', '/mnt/volume/shared/data_file/data/control/UBG', '/mnt/volume/shared/data_file/data/control/GJZ', '/mnt/volume/shared/data_file/data/control/IPY', '/mnt/volume/shared/data_file/data/control/YXY', '/mnt/volume/shared/data_file/data/control/NOL', '/mnt/volume/shared/data_file/data/control/NFI', '/mnt/volume/shared/data_file/data/control/VPN', '/mnt/volume/shared/data_file/data/control/CDA', '/mnt/volume/shared/data_file/data/control/FAQ', '/mnt/volume/shared/data_file/data/control/DHE', '/mnt/volume/shared/data_file/data/control/XXI', '/mnt/volume/shared/data_file/data/control/GJQ', '/mnt/volume/shared/data_file/data/control/TVZ', '/mnt/volume/shared/data_file/data/control/CCO', '/mnt/volume/shared/data_file/data/control/GXQ', '/mnt/volume/shared/data_file/data/control/KDW', '/mnt/volume/shared/data_file/data/control/QIZ', '/mnt/volume/shared/data_file/data/control/ORD', '/mnt/volume/shared/data_file/data/control/HQQ', '/mnt/volume/shared/data_file/data/control/AIH', '/mnt/volume/shared/data_file/data/control/NRL', '/mnt/volume/shared/data_file/data/control/OTU', '/mnt/volume/shared/data_file/data/control/YDL', '/mnt/volume/shared/data_file/data/control/MOR', '/mnt/volume/shared/data_file/data/control/ENH', '/mnt/volume/shared/data_file/data/control/LAM', '/mnt/volume/shared/data_file/data/control/WOA', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_27', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_28', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_27', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_28', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_30', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_10', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_30', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_27', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_28'], 'RUNX1_RUNX1T1': ['/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/ONF', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/KRG', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/BOE', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/SWN', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/RHX', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/IIG', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/ILZ', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/GUE', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/XOB', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/VXU', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/UWF', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/VMO', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/RGG', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/XTK', '/mnt/volume/shared/data_fi ...
# Save file paths for uncertain patients in /mnt/volume/shared/data_file/mixed_uncertain_seed42/max_30_percent
# {'control': ['/mnt/volume/shared/data_file/data/control/CIQ', '/mnt/volume/shared/data_file/data/control/FDW', '/mnt/volume/shared/data_file/data/control/ICS', '/mnt/volume/shared/data_file/data/control/WXO', '/mnt/volume/shared/data_file/data/control/NXO', '/mnt/volume/shared/data_file/data/control/ATM', '/mnt/volume/shared/data_file/data/control/MPP', '/mnt/volume/shared/data_file/data/control/DJJ', '/mnt/volume/shared/data_file/data/control/UNX', '/mnt/volume/shared/data_file/data/control/UOU', '/mnt/volume/shared/data_file/data/control/AVL', '/mnt/volume/shared/data_file/data/control/WSD', '/mnt/volume/shared/data_file/data/control/ZNK', '/mnt/volume/shared/data_file/data/control/TBZ', '/mnt/volume/shared/data_file/data/control/RDV', '/mnt/volume/shared/data_file/data/control/MKF', '/mnt/volume/shared/data_file/data/control/LCW', '/mnt/volume/shared/data_file/data/control/XXJ', '/mnt/volume/shared/data_file/data/control/YWQ', '/mnt/volume/shared/data_file/data/control/DNX', '/mnt/volume/shared/data_file/data/control/ZNL', '/mnt/volume/shared/data_file/data/control/UBG', '/mnt/volume/shared/data_file/data/control/GJZ', '/mnt/volume/shared/data_file/data/control/IPY', '/mnt/volume/shared/data_file/data/control/YXY', '/mnt/volume/shared/data_file/data/control/NOL', '/mnt/volume/shared/data_file/data/control/NFI', '/mnt/volume/shared/data_file/data/control/VPN', '/mnt/volume/shared/data_file/data/control/CDA', '/mnt/volume/shared/data_file/data/control/FAQ', '/mnt/volume/shared/data_file/data/control/DHE', '/mnt/volume/shared/data_file/data/control/XXI', '/mnt/volume/shared/data_file/data/control/GJQ', '/mnt/volume/shared/data_file/data/control/TVZ', '/mnt/volume/shared/data_file/data/control/CCO', '/mnt/volume/shared/data_file/data/control/GXQ', '/mnt/volume/shared/data_file/data/control/KDW', '/mnt/volume/shared/data_file/data/control/QIZ', '/mnt/volume/shared/data_file/data/control/ORD', '/mnt/volume/shared/data_file/data/control/HQQ', '/mnt/volume/shared/data_file/data/control/AIH', '/mnt/volume/shared/data_file/data/control/NRL', '/mnt/volume/shared/data_file/data/control/OTU', '/mnt/volume/shared/data_file/data/control/YDL', '/mnt/volume/shared/data_file/data/control/MOR', '/mnt/volume/shared/data_file/data/control/ENH', '/mnt/volume/shared/data_file/data/control/LAM', '/mnt/volume/shared/data_file/data/control/WOA', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_27', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_28', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_27', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_28', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_30', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_10', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_30', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_27', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_28', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_30', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_10', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_28'], 'RUNX1_RUNX1T1': ['/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/ONF', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/KRG', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/BOE', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/SWN', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/RHX', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/IIG', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/ILZ', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/GUE', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/XOB', '/mnt/volume/shared/data_file ...
# Save file paths for uncertain patients in /mnt/volume/shared/data_file/mixed_uncertain_seed42/sum_30_percent
# {'control': ['/mnt/volume/shared/data_file/data/control/CIQ', '/mnt/volume/shared/data_file/data/control/FDW', '/mnt/volume/shared/data_file/data/control/ICS', '/mnt/volume/shared/data_file/data/control/WXO', '/mnt/volume/shared/data_file/data/control/NXO', '/mnt/volume/shared/data_file/data/control/ATM', '/mnt/volume/shared/data_file/data/control/MPP', '/mnt/volume/shared/data_file/data/control/DJJ', '/mnt/volume/shared/data_file/data/control/UNX', '/mnt/volume/shared/data_file/data/control/UOU', '/mnt/volume/shared/data_file/data/control/AVL', '/mnt/volume/shared/data_file/data/control/WSD', '/mnt/volume/shared/data_file/data/control/ZNK', '/mnt/volume/shared/data_file/data/control/TBZ', '/mnt/volume/shared/data_file/data/control/RDV', '/mnt/volume/shared/data_file/data/control/MKF', '/mnt/volume/shared/data_file/data/control/LCW', '/mnt/volume/shared/data_file/data/control/XXJ', '/mnt/volume/shared/data_file/data/control/YWQ', '/mnt/volume/shared/data_file/data/control/DNX', '/mnt/volume/shared/data_file/data/control/ZNL', '/mnt/volume/shared/data_file/data/control/UBG', '/mnt/volume/shared/data_file/data/control/GJZ', '/mnt/volume/shared/data_file/data/control/IPY', '/mnt/volume/shared/data_file/data/control/YXY', '/mnt/volume/shared/data_file/data/control/NOL', '/mnt/volume/shared/data_file/data/control/NFI', '/mnt/volume/shared/data_file/data/control/VPN', '/mnt/volume/shared/data_file/data/control/CDA', '/mnt/volume/shared/data_file/data/control/FAQ', '/mnt/volume/shared/data_file/data/control/DHE', '/mnt/volume/shared/data_file/data/control/XXI', '/mnt/volume/shared/data_file/data/control/GJQ', '/mnt/volume/shared/data_file/data/control/TVZ', '/mnt/volume/shared/data_file/data/control/CCO', '/mnt/volume/shared/data_file/data/control/GXQ', '/mnt/volume/shared/data_file/data/control/KDW', '/mnt/volume/shared/data_file/data/control/QIZ', '/mnt/volume/shared/data_file/data/control/ORD', '/mnt/volume/shared/data_file/data/control/HQQ', '/mnt/volume/shared/data_file/data/control/AIH', '/mnt/volume/shared/data_file/data/control/NRL', '/mnt/volume/shared/data_file/data/control/OTU', '/mnt/volume/shared/data_file/data/control/YDL', '/mnt/volume/shared/data_file/data/control/MOR', '/mnt/volume/shared/data_file/data/control/ENH', '/mnt/volume/shared/data_file/data/control/LAM', '/mnt/volume/shared/data_file/data/control/WOA', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_27', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_28', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_27', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_28', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_30', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_10', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_30', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_27', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_28', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_30', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_10', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_28', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_30', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_28', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_10'], 'RUNX1_RUNX1T1': ['/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/ONF', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/KRG', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/BOE', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/SWN', '/mnt/volume/shared/data_file/d ...
# Save file paths for uncertain patients in /mnt/volume/shared/data_file/mixed_uncertain_seed42/misscl_40_percent
# {'control': ['/mnt/volume/shared/data_file/data/control/CIQ', '/mnt/volume/shared/data_file/data/control/FDW', '/mnt/volume/shared/data_file/data/control/ICS', '/mnt/volume/shared/data_file/data/control/WXO', '/mnt/volume/shared/data_file/data/control/NXO', '/mnt/volume/shared/data_file/data/control/ATM', '/mnt/volume/shared/data_file/data/control/MPP', '/mnt/volume/shared/data_file/data/control/DJJ', '/mnt/volume/shared/data_file/data/control/UNX', '/mnt/volume/shared/data_file/data/control/UOU', '/mnt/volume/shared/data_file/data/control/AVL', '/mnt/volume/shared/data_file/data/control/WSD', '/mnt/volume/shared/data_file/data/control/ZNK', '/mnt/volume/shared/data_file/data/control/TBZ', '/mnt/volume/shared/data_file/data/control/RDV', '/mnt/volume/shared/data_file/data/control/MKF', '/mnt/volume/shared/data_file/data/control/LCW', '/mnt/volume/shared/data_file/data/control/XXJ', '/mnt/volume/shared/data_file/data/control/YWQ', '/mnt/volume/shared/data_file/data/control/DNX', '/mnt/volume/shared/data_file/data/control/ZNL', '/mnt/volume/shared/data_file/data/control/UBG', '/mnt/volume/shared/data_file/data/control/GJZ', '/mnt/volume/shared/data_file/data/control/IPY', '/mnt/volume/shared/data_file/data/control/YXY', '/mnt/volume/shared/data_file/data/control/NOL', '/mnt/volume/shared/data_file/data/control/NFI', '/mnt/volume/shared/data_file/data/control/VPN', '/mnt/volume/shared/data_file/data/control/CDA', '/mnt/volume/shared/data_file/data/control/FAQ', '/mnt/volume/shared/data_file/data/control/DHE', '/mnt/volume/shared/data_file/data/control/XXI', '/mnt/volume/shared/data_file/data/control/GJQ', '/mnt/volume/shared/data_file/data/control/TVZ', '/mnt/volume/shared/data_file/data/control/CCO', '/mnt/volume/shared/data_file/data/control/GXQ', '/mnt/volume/shared/data_file/data/control/KDW', '/mnt/volume/shared/data_file/data/control/QIZ', '/mnt/volume/shared/data_file/data/control/ORD', '/mnt/volume/shared/data_file/data/control/HQQ', '/mnt/volume/shared/data_file/data/control/AIH', '/mnt/volume/shared/data_file/data/control/NRL', '/mnt/volume/shared/data_file/data/control/OTU', '/mnt/volume/shared/data_file/data/control/YDL', '/mnt/volume/shared/data_file/data/control/MOR', '/mnt/volume/shared/data_file/data/control/ENH', '/mnt/volume/shared/data_file/data/control/LAM', '/mnt/volume/shared/data_file/data/control/WOA', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_27', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_28', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_27', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_28', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_30', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_10', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_30', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_27', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_28', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_30', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_10', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_28', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_30', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_28', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_10', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_27', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_28', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_30 ...
# Save file paths for uncertain patients in /mnt/volume/shared/data_file/mixed_uncertain_seed42/max_40_percent
# {'control': ['/mnt/volume/shared/data_file/data/control/CIQ', '/mnt/volume/shared/data_file/data/control/FDW', '/mnt/volume/shared/data_file/data/control/ICS', '/mnt/volume/shared/data_file/data/control/WXO', '/mnt/volume/shared/data_file/data/control/NXO', '/mnt/volume/shared/data_file/data/control/ATM', '/mnt/volume/shared/data_file/data/control/MPP', '/mnt/volume/shared/data_file/data/control/DJJ', '/mnt/volume/shared/data_file/data/control/UNX', '/mnt/volume/shared/data_file/data/control/UOU', '/mnt/volume/shared/data_file/data/control/AVL', '/mnt/volume/shared/data_file/data/control/WSD', '/mnt/volume/shared/data_file/data/control/ZNK', '/mnt/volume/shared/data_file/data/control/TBZ', '/mnt/volume/shared/data_file/data/control/RDV', '/mnt/volume/shared/data_file/data/control/MKF', '/mnt/volume/shared/data_file/data/control/LCW', '/mnt/volume/shared/data_file/data/control/XXJ', '/mnt/volume/shared/data_file/data/control/YWQ', '/mnt/volume/shared/data_file/data/control/DNX', '/mnt/volume/shared/data_file/data/control/ZNL', '/mnt/volume/shared/data_file/data/control/UBG', '/mnt/volume/shared/data_file/data/control/GJZ', '/mnt/volume/shared/data_file/data/control/IPY', '/mnt/volume/shared/data_file/data/control/YXY', '/mnt/volume/shared/data_file/data/control/NOL', '/mnt/volume/shared/data_file/data/control/NFI', '/mnt/volume/shared/data_file/data/control/VPN', '/mnt/volume/shared/data_file/data/control/CDA', '/mnt/volume/shared/data_file/data/control/FAQ', '/mnt/volume/shared/data_file/data/control/DHE', '/mnt/volume/shared/data_file/data/control/XXI', '/mnt/volume/shared/data_file/data/control/GJQ', '/mnt/volume/shared/data_file/data/control/TVZ', '/mnt/volume/shared/data_file/data/control/CCO', '/mnt/volume/shared/data_file/data/control/GXQ', '/mnt/volume/shared/data_file/data/control/KDW', '/mnt/volume/shared/data_file/data/control/QIZ', '/mnt/volume/shared/data_file/data/control/ORD', '/mnt/volume/shared/data_file/data/control/HQQ', '/mnt/volume/shared/data_file/data/control/AIH', '/mnt/volume/shared/data_file/data/control/NRL', '/mnt/volume/shared/data_file/data/control/OTU', '/mnt/volume/shared/data_file/data/control/YDL', '/mnt/volume/shared/data_file/data/control/MOR', '/mnt/volume/shared/data_file/data/control/ENH', '/mnt/volume/shared/data_file/data/control/LAM', '/mnt/volume/shared/data_file/data/control/WOA', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_27', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_28', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_27', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_28', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_30', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_10', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_30', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_27', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_28', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_30', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_10', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_28', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_30', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_28', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_10', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_27', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_28', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_30 ...
# Save file paths for uncertain patients in /mnt/volume/shared/data_file/mixed_uncertain_seed42/sum_40_percent
# {'control': ['/mnt/volume/shared/data_file/data/control/CIQ', '/mnt/volume/shared/data_file/data/control/FDW', '/mnt/volume/shared/data_file/data/control/ICS', '/mnt/volume/shared/data_file/data/control/WXO', '/mnt/volume/shared/data_file/data/control/NXO', '/mnt/volume/shared/data_file/data/control/ATM', '/mnt/volume/shared/data_file/data/control/MPP', '/mnt/volume/shared/data_file/data/control/DJJ', '/mnt/volume/shared/data_file/data/control/UNX', '/mnt/volume/shared/data_file/data/control/UOU', '/mnt/volume/shared/data_file/data/control/AVL', '/mnt/volume/shared/data_file/data/control/WSD', '/mnt/volume/shared/data_file/data/control/ZNK', '/mnt/volume/shared/data_file/data/control/TBZ', '/mnt/volume/shared/data_file/data/control/RDV', '/mnt/volume/shared/data_file/data/control/MKF', '/mnt/volume/shared/data_file/data/control/LCW', '/mnt/volume/shared/data_file/data/control/XXJ', '/mnt/volume/shared/data_file/data/control/YWQ', '/mnt/volume/shared/data_file/data/control/DNX', '/mnt/volume/shared/data_file/data/control/ZNL', '/mnt/volume/shared/data_file/data/control/UBG', '/mnt/volume/shared/data_file/data/control/GJZ', '/mnt/volume/shared/data_file/data/control/IPY', '/mnt/volume/shared/data_file/data/control/YXY', '/mnt/volume/shared/data_file/data/control/NOL', '/mnt/volume/shared/data_file/data/control/NFI', '/mnt/volume/shared/data_file/data/control/VPN', '/mnt/volume/shared/data_file/data/control/CDA', '/mnt/volume/shared/data_file/data/control/FAQ', '/mnt/volume/shared/data_file/data/control/DHE', '/mnt/volume/shared/data_file/data/control/XXI', '/mnt/volume/shared/data_file/data/control/GJQ', '/mnt/volume/shared/data_file/data/control/TVZ', '/mnt/volume/shared/data_file/data/control/CCO', '/mnt/volume/shared/data_file/data/control/GXQ', '/mnt/volume/shared/data_file/data/control/KDW', '/mnt/volume/shared/data_file/data/control/QIZ', '/mnt/volume/shared/data_file/data/control/ORD', '/mnt/volume/shared/data_file/data/control/HQQ', '/mnt/volume/shared/data_file/data/control/AIH', '/mnt/volume/shared/data_file/data/control/NRL', '/mnt/volume/shared/data_file/data/control/OTU', '/mnt/volume/shared/data_file/data/control/YDL', '/mnt/volume/shared/data_file/data/control/MOR', '/mnt/volume/shared/data_file/data/control/ENH', '/mnt/volume/shared/data_file/data/control/LAM', '/mnt/volume/shared/data_file/data/control/WOA', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_27', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_28', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_27', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_28', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_30', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_10', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_30', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_27', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_28', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_30', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_10', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_28', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_30', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_28', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_10', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_27', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_28', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_30 ...
# Save file paths for uncertain patients in /mnt/volume/shared/data_file/mixed_uncertain_seed42/misscl_50_percent
# {'control': ['/mnt/volume/shared/data_file/data/control/CIQ', '/mnt/volume/shared/data_file/data/control/FDW', '/mnt/volume/shared/data_file/data/control/ICS', '/mnt/volume/shared/data_file/data/control/WXO', '/mnt/volume/shared/data_file/data/control/NXO', '/mnt/volume/shared/data_file/data/control/ATM', '/mnt/volume/shared/data_file/data/control/MPP', '/mnt/volume/shared/data_file/data/control/DJJ', '/mnt/volume/shared/data_file/data/control/UNX', '/mnt/volume/shared/data_file/data/control/UOU', '/mnt/volume/shared/data_file/data/control/AVL', '/mnt/volume/shared/data_file/data/control/WSD', '/mnt/volume/shared/data_file/data/control/ZNK', '/mnt/volume/shared/data_file/data/control/TBZ', '/mnt/volume/shared/data_file/data/control/RDV', '/mnt/volume/shared/data_file/data/control/MKF', '/mnt/volume/shared/data_file/data/control/LCW', '/mnt/volume/shared/data_file/data/control/XXJ', '/mnt/volume/shared/data_file/data/control/YWQ', '/mnt/volume/shared/data_file/data/control/DNX', '/mnt/volume/shared/data_file/data/control/ZNL', '/mnt/volume/shared/data_file/data/control/UBG', '/mnt/volume/shared/data_file/data/control/GJZ', '/mnt/volume/shared/data_file/data/control/IPY', '/mnt/volume/shared/data_file/data/control/YXY', '/mnt/volume/shared/data_file/data/control/NOL', '/mnt/volume/shared/data_file/data/control/NFI', '/mnt/volume/shared/data_file/data/control/VPN', '/mnt/volume/shared/data_file/data/control/CDA', '/mnt/volume/shared/data_file/data/control/FAQ', '/mnt/volume/shared/data_file/data/control/DHE', '/mnt/volume/shared/data_file/data/control/XXI', '/mnt/volume/shared/data_file/data/control/GJQ', '/mnt/volume/shared/data_file/data/control/TVZ', '/mnt/volume/shared/data_file/data/control/CCO', '/mnt/volume/shared/data_file/data/control/GXQ', '/mnt/volume/shared/data_file/data/control/KDW', '/mnt/volume/shared/data_file/data/control/QIZ', '/mnt/volume/shared/data_file/data/control/ORD', '/mnt/volume/shared/data_file/data/control/HQQ', '/mnt/volume/shared/data_file/data/control/AIH', '/mnt/volume/shared/data_file/data/control/NRL', '/mnt/volume/shared/data_file/data/control/OTU', '/mnt/volume/shared/data_file/data/control/YDL', '/mnt/volume/shared/data_file/data/control/MOR', '/mnt/volume/shared/data_file/data/control/ENH', '/mnt/volume/shared/data_file/data/control/LAM', '/mnt/volume/shared/data_file/data/control/WOA', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_27', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_28', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_27', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_28', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_30', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_10', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_30', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_27', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_28', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_30', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_10', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_28', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_30', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_28', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_10', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_27', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_28', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_30 ...
# Save file paths for uncertain patients in /mnt/volume/shared/data_file/mixed_uncertain_seed42/max_50_percent
# {'control': ['/mnt/volume/shared/data_file/data/control/CIQ', '/mnt/volume/shared/data_file/data/control/FDW', '/mnt/volume/shared/data_file/data/control/ICS', '/mnt/volume/shared/data_file/data/control/WXO', '/mnt/volume/shared/data_file/data/control/NXO', '/mnt/volume/shared/data_file/data/control/ATM', '/mnt/volume/shared/data_file/data/control/MPP', '/mnt/volume/shared/data_file/data/control/DJJ', '/mnt/volume/shared/data_file/data/control/UNX', '/mnt/volume/shared/data_file/data/control/UOU', '/mnt/volume/shared/data_file/data/control/AVL', '/mnt/volume/shared/data_file/data/control/WSD', '/mnt/volume/shared/data_file/data/control/ZNK', '/mnt/volume/shared/data_file/data/control/TBZ', '/mnt/volume/shared/data_file/data/control/RDV', '/mnt/volume/shared/data_file/data/control/MKF', '/mnt/volume/shared/data_file/data/control/LCW', '/mnt/volume/shared/data_file/data/control/XXJ', '/mnt/volume/shared/data_file/data/control/YWQ', '/mnt/volume/shared/data_file/data/control/DNX', '/mnt/volume/shared/data_file/data/control/ZNL', '/mnt/volume/shared/data_file/data/control/UBG', '/mnt/volume/shared/data_file/data/control/GJZ', '/mnt/volume/shared/data_file/data/control/IPY', '/mnt/volume/shared/data_file/data/control/YXY', '/mnt/volume/shared/data_file/data/control/NOL', '/mnt/volume/shared/data_file/data/control/NFI', '/mnt/volume/shared/data_file/data/control/VPN', '/mnt/volume/shared/data_file/data/control/CDA', '/mnt/volume/shared/data_file/data/control/FAQ', '/mnt/volume/shared/data_file/data/control/DHE', '/mnt/volume/shared/data_file/data/control/XXI', '/mnt/volume/shared/data_file/data/control/GJQ', '/mnt/volume/shared/data_file/data/control/TVZ', '/mnt/volume/shared/data_file/data/control/CCO', '/mnt/volume/shared/data_file/data/control/GXQ', '/mnt/volume/shared/data_file/data/control/KDW', '/mnt/volume/shared/data_file/data/control/QIZ', '/mnt/volume/shared/data_file/data/control/ORD', '/mnt/volume/shared/data_file/data/control/HQQ', '/mnt/volume/shared/data_file/data/control/AIH', '/mnt/volume/shared/data_file/data/control/NRL', '/mnt/volume/shared/data_file/data/control/OTU', '/mnt/volume/shared/data_file/data/control/YDL', '/mnt/volume/shared/data_file/data/control/MOR', '/mnt/volume/shared/data_file/data/control/ENH', '/mnt/volume/shared/data_file/data/control/LAM', '/mnt/volume/shared/data_file/data/control/WOA', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_27', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_28', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_27', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_28', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_30', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_10', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_30', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_27', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_28', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_30', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_10', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_28', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_30', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_28', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_10', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_27', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_28', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_30 ...
# Save file paths for uncertain patients in /mnt/volume/shared/data_file/mixed_uncertain_seed42/sum_50_percent
# {'control': ['/mnt/volume/shared/data_file/data/control/CIQ', '/mnt/volume/shared/data_file/data/control/FDW', '/mnt/volume/shared/data_file/data/control/ICS', '/mnt/volume/shared/data_file/data/control/WXO', '/mnt/volume/shared/data_file/data/control/NXO', '/mnt/volume/shared/data_file/data/control/ATM', '/mnt/volume/shared/data_file/data/control/MPP', '/mnt/volume/shared/data_file/data/control/DJJ', '/mnt/volume/shared/data_file/data/control/UNX', '/mnt/volume/shared/data_file/data/control/UOU', '/mnt/volume/shared/data_file/data/control/AVL', '/mnt/volume/shared/data_file/data/control/WSD', '/mnt/volume/shared/data_file/data/control/ZNK', '/mnt/volume/shared/data_file/data/control/TBZ', '/mnt/volume/shared/data_file/data/control/RDV', '/mnt/volume/shared/data_file/data/control/MKF', '/mnt/volume/shared/data_file/data/control/LCW', '/mnt/volume/shared/data_file/data/control/XXJ', '/mnt/volume/shared/data_file/data/control/YWQ', '/mnt/volume/shared/data_file/data/control/DNX', '/mnt/volume/shared/data_file/data/control/ZNL', '/mnt/volume/shared/data_file/data/control/UBG', '/mnt/volume/shared/data_file/data/control/GJZ', '/mnt/volume/shared/data_file/data/control/IPY', '/mnt/volume/shared/data_file/data/control/YXY', '/mnt/volume/shared/data_file/data/control/NOL', '/mnt/volume/shared/data_file/data/control/NFI', '/mnt/volume/shared/data_file/data/control/VPN', '/mnt/volume/shared/data_file/data/control/CDA', '/mnt/volume/shared/data_file/data/control/FAQ', '/mnt/volume/shared/data_file/data/control/DHE', '/mnt/volume/shared/data_file/data/control/XXI', '/mnt/volume/shared/data_file/data/control/GJQ', '/mnt/volume/shared/data_file/data/control/TVZ', '/mnt/volume/shared/data_file/data/control/CCO', '/mnt/volume/shared/data_file/data/control/GXQ', '/mnt/volume/shared/data_file/data/control/KDW', '/mnt/volume/shared/data_file/data/control/QIZ', '/mnt/volume/shared/data_file/data/control/ORD', '/mnt/volume/shared/data_file/data/control/HQQ', '/mnt/volume/shared/data_file/data/control/AIH', '/mnt/volume/shared/data_file/data/control/NRL', '/mnt/volume/shared/data_file/data/control/OTU', '/mnt/volume/shared/data_file/data/control/YDL', '/mnt/volume/shared/data_file/data/control/MOR', '/mnt/volume/shared/data_file/data/control/ENH', '/mnt/volume/shared/data_file/data/control/LAM', '/mnt/volume/shared/data_file/data/control/WOA', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_27', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_28', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_27', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_28', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_30', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_10', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_30', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_27', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_28', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_30', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_10', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_28', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_30', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_28', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_10', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_27', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_28', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed42/data/control/patient_30 ...

# %%
def concatenate_metadata(original_metadata_path,uncertain_patients_folder):
    # Load the original metadata CSV file
    original_metadata_df = pd.read_csv(original_metadata_path)

    # Loop over folders in uncertain_patients
    for folder in os.listdir(uncertain_patients_folder):
        folder_path = os.path.join(uncertain_patients_folder, folder)
        #print(folder_path)

        # Check if the item in the uncertain_patients_folder is a directory
        if os.path.isdir(folder_path):
            # Look for metadata.csv in each folder
            metadata_file_path = os.path.join(folder_path, 'metadata_uncertain_patients.csv')
            print("metadata is:")
            print(metadata_file_path)

            if os.path.exists(metadata_file_path):
                # Load the metadata from the current folder
                uncertain_metadata_df = pd.read_csv(metadata_file_path)

                # Concatenate with the original metadata
                concatenated_metadata_df = pd.concat([original_metadata_df, uncertain_metadata_df], ignore_index=True)
                # Save the concatenated metadata to a new CSV file in the output folder
                output_folder_new = uncertain_patients_folder + f'/{folder}'
                os.makedirs(output_folder_new, exist_ok=True)
                output_file_path = os.path.join(output_folder_new, 'metadata.csv')
                print("Output is:")
                print(output_file_path)
                concatenated_metadata_df.to_csv(output_file_path, index=False)

# %%
original_metadata_path="/mnt/volume/shared/data_file/metadata.csv"
concatenate_metadata(original_metadata_path,output_folder)
# Out:
# metadata is:
# /mnt/volume/shared/data_file/mixed_uncertain_seed42/misscl_30_percent/metadata_uncertain_patients.csv
# Output is:
# /mnt/volume/shared/data_file/mixed_uncertain_seed42/misscl_30_percent/metadata.csv
# metadata is:
# /mnt/volume/shared/data_file/mixed_uncertain_seed42/sum_40_percent/metadata_uncertain_patients.csv
# Output is:
# /mnt/volume/shared/data_file/mixed_uncertain_seed42/sum_40_percent/metadata.csv
# metadata is:
# /mnt/volume/shared/data_file/mixed_uncertain_seed42/sum_50_percent/metadata_uncertain_patients.csv
# Output is:
# /mnt/volume/shared/data_file/mixed_uncertain_seed42/sum_50_percent/metadata.csv
# metadata is:
# /mnt/volume/shared/data_file/mixed_uncertain_seed42/max_20_percent/metadata_uncertain_patients.csv
# Output is:
# /mnt/volume/shared/data_file/mixed_uncertain_seed42/max_20_percent/metadata.csv
# metadata is:
# /mnt/volume/shared/data_file/mixed_uncertain_seed42/sum_10_percent/metadata_uncertain_patients.csv
# Output is:
# /mnt/volume/shared/data_file/mixed_uncertain_seed42/sum_10_percent/metadata.csv
# metadata is:
# /mnt/volume/shared/data_file/mixed_uncertain_seed42/misscl_20_percent/metadata_uncertain_patients.csv
# Output is:
# /mnt/volume/shared/data_file/mixed_uncertain_seed42/misscl_20_percent/metadata.csv
# metadata is:
# /mnt/volume/shared/data_file/mixed_uncertain_seed42/max_50_percent/metadata_uncertain_patients.csv
# Output is:
# /mnt/volume/shared/data_file/mixed_uncertain_seed42/max_50_percent/metadata.csv
# metadata is:
# /mnt/volume/shared/data_file/mixed_uncertain_seed42/sum_20_percent/metadata_uncertain_patients.csv
# Output is:
# /mnt/volume/shared/data_file/mixed_uncertain_seed42/sum_20_percent/metadata.csv
# metadata is:
# /mnt/volume/shared/data_file/mixed_uncertain_seed42/misscl_40_percent/metadata_uncertain_patients.csv
# Output is:
# /mnt/volume/shared/data_file/mixed_uncertain_seed42/misscl_40_percent/metadata.csv
# metadata is:
# /mnt/volume/shared/data_file/mixed_uncertain_seed42/max_40_percent/metadata_uncertain_patients.csv
# Output is:
# /mnt/volume/shared/data_file/mixed_uncertain_seed42/max_40_percent/metadata.csv
# metadata is:
# /mnt/volume/shared/data_file/mixed_uncertain_seed42/max_30_percent/metadata_uncertain_patients.csv
# Output is:
# /mnt/volume/shared/data_file/mixed_uncertain_seed42/max_30_percent/metadata.csv
# metadata is:
# /mnt/volume/shared/data_file/mixed_uncertain_seed42/misscl_50_percent/metadata_uncertain_patients.csv
# Output is:
# /mnt/volume/shared/data_file/mixed_uncertain_seed42/misscl_50_percent/metadata.csv
# metadata is:
# /mnt/volume/shared/data_file/mixed_uncertain_seed42/sum_30_percent/metadata_uncertain_patients.csv
# Output is:
# /mnt/volume/shared/data_file/mixed_uncertain_seed42/sum_30_percent/metadata.csv
# metadata is:
# /mnt/volume/shared/data_file/mixed_uncertain_seed42/misscl_10_percent/metadata_uncertain_patients.csv
# Output is:
# /mnt/volume/shared/data_file/mixed_uncertain_seed42/misscl_10_percent/metadata.csv
# metadata is:
# /mnt/volume/shared/data_file/mixed_uncertain_seed42/max_10_percent/metadata_uncertain_patients.csv
# Output is:
# /mnt/volume/shared/data_file/mixed_uncertain_seed42/max_10_percent/metadata.csv
