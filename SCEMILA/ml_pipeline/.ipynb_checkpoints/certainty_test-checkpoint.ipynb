# %%
import os.path
from tqdm import tqdm
import torch
import torch.nn.functional as F
from dataset_mixed import *  # dataset
from model import *  # actual MIL model
from sklearn import metrics as metrics
import csv
import os
import shutil
import pandas as pd
import re

# %%
CLASSES = ['control', 'RUNX1_RUNX1T1', 'NPM1', 'CBFB_MYH11', 'PML_RARA']
num_classes = 5
seed=1
experiment_source=f'experiment_3_seed{seed}'
real_data_source='/mnt/volume/shared/data_file/data'
SOURCE_FOLDER = '/mnt/volume/shared/data_file/artificialdata/'+experiment_source
TARGET_FOLDER = '/mnt/volume/shared/exp4/dropout_original/result_folder_1'
output_folder = f'/mnt/volume/shared/data_file/mixed_uncertain_seed{seed}'

def get_patient_name(path):
    return re.search(r"/data/\w+/([0-9a-zA-Z_]*)", path).group(1)

def get_class_name(path):
    return re.search(r"/data/(\w+)", path).group(1)

# %%
patients = {}
with open(os.path.join(SOURCE_FOLDER,'metadata.csv'), newline='') as csvfile:
    reader = csv.reader(csvfile)
    next(reader, None)
    idx = 0
    for line in reader:
        key = line[0] + "_" + line[3]
        patients[key] = [os.path.join(SOURCE_FOLDER,
                                         "data",
                                         line[3],
                                         line[0],
                                         "fnl34_bn_features_layer_7.npy"), line[3]]

# %%
def update_misclassification_count(probability_vector, one_hot_target, current_misclassification_count):
    """
    Update misclassification count based on the given probability vector and one-hot encoded target vector.

    Parameters:
    - probability_vector: Tensor representing the probability vector.
    - one_hot_target: Tensor representing the one-hot encoded target vector.
    - current_misclassification_count: Current misclassification count.

    Returns:
    - Updated misclassification count.
    """
    #print("Target: ", one_hot_target)
    #print(probability_vector)
    # Convert probability vector to one-hot encoded vector
    one_hot_prediction = torch.zeros_like(probability_vector)
    one_hot_prediction[0, torch.argmax(probability_vector).item()] = 1
    #print("One hot prediction is: ", one_hot_prediction)

    # Find the index where the target is 1
    target_index = torch.argmax(one_hot_target).item()
    #print("Target index is :", target_index)

    # Check for misclassification and update count
    if torch.argmax(one_hot_prediction).item() != target_index:
        current_misclassification_count += 1

    return current_misclassification_count

# %%
# Number of Monte Carlo samples
num_samples = 10

class_converter = {}

with open(os.path.join(TARGET_FOLDER,'class_conversion.csv'), newline='') as csvfile:
    reader = csv.reader(csvfile)
    next(reader, None)
    for line in reader:
        class_converter[line[1]] = int(line[0])

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")


# load best performing model, and launch on test set
model = torch.load(os.path.join(TARGET_FOLDER, "state_dictmodel.pt"),map_location="cpu")
model = model.to(device)
model.train()

# Initialize arrays to store uncertainties
all_uncertainties = {}
missclassification_counts = {}
max_uncertainties = {}
sum_uncertainties = {}

# Perform Monte Carlo Dropout
with torch.no_grad():
    for p in patients.keys():
        # Make predictions with dropout enabled multiple times
        pred = []
        missclassification_count = 0
        for j in range(num_samples):
            path, lbl_name = patients[p]
            lbl = np.zeros(5)
            lbl[class_converter[lbl_name]] = 1

            bag = np.load(path)

            bag = torch.tensor(bag).to(device)
            bag = torch.unsqueeze(bag,0)
            prediction, _, _, _,  = model(bag)
            pred.append(F.softmax(prediction,dim=1).cpu().detach().numpy())

            # Class missclassification count update
            missclassification_count = update_misclassification_count(F.softmax(prediction,dim=1), torch.tensor(lbl), missclassification_count)

        # Convert the list of tensors to a PyTorch tensor
        pred_tensor = [torch.from_numpy(arr) for arr in pred]
        pred_tensor = torch.stack(pred_tensor)
        
        # Compute mean and uncertainty
        mean_prediction = pred_tensor.mean(dim=0)
        #print('Mean prediction is:', mean_prediction)
        
        uncertainty = pred_tensor.std(dim=0)
        #print('Uncertainty tensor is:', uncertainty)
        
        uncertainty_value_max = torch.max(uncertainty).item()
        uncertainty_value_sum = torch.sum(uncertainty).item()
        path=os.path.dirname(path)
        # Save uncertainty results along with the path
        max_uncertainties[p] = {'path': path, 'data': uncertainty.cpu().numpy().squeeze(), 'uncertainty': uncertainty_value_max}
        sum_uncertainties[p] = {'path': path, 'data': uncertainty.cpu().numpy().squeeze(), 'uncertainty': uncertainty_value_sum}
        missclassification_counts[p] = {'path': path, 'uncertainty' : missclassification_count / num_samples}

# %%
def sort_and_print(uncertainties):
    # Sort misclassification counts dictionary by values (highest to lowest)
    sorted_uncertainties = dict(sorted(uncertainties.items(), key=lambda item: item[1]['uncertainty'], reverse=True))
    
    # Print sorted misclassification counts
    for p, data in sorted_uncertainties.items():
        uncertainty_rate = data['uncertainty']
        print(f"Patient {p}: Uncertainty - {uncertainty_rate:.4}")

# %%
sort_and_print(max_uncertainties)
sort_and_print(sum_uncertainties)
sort_and_print(missclassification_counts)
# Out:
# Patient patient_23_PML_RARA: Uncertainty - 0.2187
# Patient patient_41_control: Uncertainty - 0.2095
# Patient patient_12_PML_RARA: Uncertainty - 0.2079
# Patient patient_30_NPM1: Uncertainty - 0.1964
# Patient patient_6_PML_RARA: Uncertainty - 0.1918
# Patient patient_25_PML_RARA: Uncertainty - 0.1869
# Patient patient_21_NPM1: Uncertainty - 0.1848
# Patient patient_8_PML_RARA: Uncertainty - 0.1838
# Patient patient_27_CBFB_MYH11: Uncertainty - 0.1835
# Patient patient_35_RUNX1_RUNX1T1: Uncertainty - 0.1726
# Patient patient_26_PML_RARA: Uncertainty - 0.1679
# Patient patient_24_RUNX1_RUNX1T1: Uncertainty - 0.1653
# Patient patient_23_NPM1: Uncertainty - 0.1649
# Patient patient_24_NPM1: Uncertainty - 0.1636
# Patient patient_16_PML_RARA: Uncertainty - 0.1634
# Patient patient_16_CBFB_MYH11: Uncertainty - 0.1616
# Patient patient_24_CBFB_MYH11: Uncertainty - 0.1588
# Patient patient_12_RUNX1_RUNX1T1: Uncertainty - 0.157
# Patient patient_33_RUNX1_RUNX1T1: Uncertainty - 0.1563
# Patient patient_26_NPM1: Uncertainty - 0.1527
# Patient patient_17_RUNX1_RUNX1T1: Uncertainty - 0.1515
# Patient patient_10_RUNX1_RUNX1T1: Uncertainty - 0.1501
# Patient patient_32_RUNX1_RUNX1T1: Uncertainty - 0.1478
# Patient patient_30_PML_RARA: Uncertainty - 0.1446
# Patient patient_18_CBFB_MYH11: Uncertainty - 0.1422
# Patient patient_3_RUNX1_RUNX1T1: Uncertainty - 0.1422
# Patient patient_11_RUNX1_RUNX1T1: Uncertainty - 0.142
# Patient patient_36_PML_RARA: Uncertainty - 0.1413
# Patient patient_27_NPM1: Uncertainty - 0.1404
# Patient patient_18_control: Uncertainty - 0.139
# Patient patient_40_CBFB_MYH11: Uncertainty - 0.1389
# Patient patient_26_CBFB_MYH11: Uncertainty - 0.1388
# Patient patient_40_RUNX1_RUNX1T1: Uncertainty - 0.1385
# Patient patient_23_control: Uncertainty - 0.1369
# Patient patient_13_RUNX1_RUNX1T1: Uncertainty - 0.1369
# Patient patient_18_NPM1: Uncertainty - 0.1368
# Patient patient_28_PML_RARA: Uncertainty - 0.136
# Patient patient_3_PML_RARA: Uncertainty - 0.1357
# Patient patient_17_CBFB_MYH11: Uncertainty - 0.1347
# Patient patient_16_NPM1: Uncertainty - 0.132
# Patient patient_29_RUNX1_RUNX1T1: Uncertainty - 0.13
# Patient patient_17_control: Uncertainty - 0.1288
# Patient patient_31_RUNX1_RUNX1T1: Uncertainty - 0.125
# Patient patient_3_NPM1: Uncertainty - 0.1249
# Patient patient_39_CBFB_MYH11: Uncertainty - 0.1247
# Patient patient_41_NPM1: Uncertainty - 0.1245
# Patient patient_40_PML_RARA: Uncertainty - 0.1235
# Patient patient_15_RUNX1_RUNX1T1: Uncertainty - 0.1217
# Patient patient_36_RUNX1_RUNX1T1: Uncertainty - 0.1212
# Patient patient_15_control: Uncertainty - 0.1204
# Patient patient_41_RUNX1_RUNX1T1: Uncertainty - 0.1198
# Patient patient_30_CBFB_MYH11: Uncertainty - 0.1196
# Patient patient_39_RUNX1_RUNX1T1: Uncertainty - 0.1185
# Patient patient_34_PML_RARA: Uncertainty - 0.1184
# Patient patient_22_NPM1: Uncertainty - 0.1181
# Patient patient_11_NPM1: Uncertainty - 0.1165
# Patient patient_22_PML_RARA: Uncertainty - 0.1162
# Patient patient_28_RUNX1_RUNX1T1: Uncertainty - 0.1158
# Patient patient_7_NPM1: Uncertainty - 0.1141
# Patient patient_35_PML_RARA: Uncertainty - 0.114
# Patient patient_35_CBFB_MYH11: Uncertainty - 0.1129
# Patient patient_12_NPM1: Uncertainty - 0.1126
# Patient patient_4_CBFB_MYH11: Uncertainty - 0.1124
# Patient patient_34_RUNX1_RUNX1T1: Uncertainty - 0.1121
# Patient patient_32_PML_RARA: Uncertainty - 0.11
# Patient patient_18_PML_RARA: Uncertainty - 0.1096
# Patient patient_37_RUNX1_RUNX1T1: Uncertainty - 0.1092
# Patient patient_6_RUNX1_RUNX1T1: Uncertainty - 0.106
# Patient patient_32_control: Uncertainty - 0.1056
# Patient patient_13_PML_RARA: Uncertainty - 0.1055
# Patient patient_11_CBFB_MYH11: Uncertainty - 0.1051
# Patient patient_1_RUNX1_RUNX1T1: Uncertainty - 0.1044
# Patient patient_5_PML_RARA: Uncertainty - 0.1025
# Patient patient_37_NPM1: Uncertainty - 0.1017
# Patient patient_31_NPM1: Uncertainty - 0.1003
# Patient patient_10_PML_RARA: Uncertainty - 0.09952
# Patient patient_14_RUNX1_RUNX1T1: Uncertainty - 0.09887
# Patient patient_2_RUNX1_RUNX1T1: Uncertainty - 0.09861
# Patient patient_16_RUNX1_RUNX1T1: Uncertainty - 0.09859
# Patient patient_22_CBFB_MYH11: Uncertainty - 0.09658
# Patient patient_27_RUNX1_RUNX1T1: Uncertainty - 0.09604
# Patient patient_15_PML_RARA: Uncertainty - 0.09593
# Patient patient_1_NPM1: Uncertainty - 0.09491
# Patient patient_23_RUNX1_RUNX1T1: Uncertainty - 0.09473
# Patient patient_13_NPM1: Uncertainty - 0.09398
# Patient patient_7_RUNX1_RUNX1T1: Uncertainty - 0.09391
# Patient patient_10_NPM1: Uncertainty - 0.0916
# Patient patient_33_CBFB_MYH11: Uncertainty - 0.08962
# Patient patient_38_PML_RARA: Uncertainty - 0.0864
# Patient patient_17_NPM1: Uncertainty - 0.08424
# Patient patient_28_control: Uncertainty - 0.08196
# Patient patient_26_control: Uncertainty - 0.08185
# Patient patient_40_NPM1: Uncertainty - 0.08112
# Patient patient_41_CBFB_MYH11: Uncertainty - 0.07851
# Patient patient_25_CBFB_MYH11: Uncertainty - 0.07841
# Patient patient_17_PML_RARA: Uncertainty - 0.0782
# Patient patient_20_RUNX1_RUNX1T1: Uncertainty - 0.07784
# Patient patient_33_NPM1: Uncertainty - 0.07674
# Patient patient_31_control: Uncertainty - 0.07655
# Patient patient_18_RUNX1_RUNX1T1: Uncertainty - 0.07618
# Patient patient_4_PML_RARA: Uncertainty - 0.07577
# Patient patient_31_PML_RARA: Uncertainty - 0.07571
# Patient patient_1_PML_RARA: Uncertainty - 0.07256
# Patient patient_22_RUNX1_RUNX1T1: Uncertainty - 0.07112
# Patient patient_4_NPM1: Uncertainty - 0.07074
# Patient patient_2_NPM1: Uncertainty - 0.07006
# Patient patient_15_CBFB_MYH11: Uncertainty - 0.06944
# Patient patient_11_PML_RARA: Uncertainty - 0.06783
# Patient patient_32_NPM1: Uncertainty - 0.06763
# Patient patient_37_PML_RARA: Uncertainty - 0.06612
# Patient patient_20_PML_RARA: Uncertainty - 0.06449
# Patient patient_21_RUNX1_RUNX1T1: Uncertainty - 0.06369
# Patient patient_23_CBFB_MYH11: Uncertainty - 0.06319
# Patient patient_5_NPM1: Uncertainty - 0.0626
# Patient patient_20_NPM1: Uncertainty - 0.06252
# Patient patient_29_NPM1: Uncertainty - 0.06231
# Patient patient_34_CBFB_MYH11: Uncertainty - 0.0614
# Patient patient_8_NPM1: Uncertainty - 0.0611
# Patient patient_30_RUNX1_RUNX1T1: Uncertainty - 0.05969
# Patient patient_19_NPM1: Uncertainty - 0.05954
# Patient patient_9_RUNX1_RUNX1T1: Uncertainty - 0.05912
# Patient patient_27_PML_RARA: Uncertainty - 0.05838
# Patient patient_29_CBFB_MYH11: Uncertainty - 0.05833
# Patient patient_30_control: Uncertainty - 0.05615
# Patient patient_8_RUNX1_RUNX1T1: Uncertainty - 0.05503
# Patient patient_26_RUNX1_RUNX1T1: Uncertainty - 0.05419
# Patient patient_14_NPM1: Uncertainty - 0.05374
# Patient patient_28_NPM1: Uncertainty - 0.05353
# Patient patient_16_control: Uncertainty - 0.05315
# Patient patient_41_PML_RARA: Uncertainty - 0.05301
# Patient patient_15_NPM1: Uncertainty - 0.05177
# Patient patient_31_CBFB_MYH11: Uncertainty - 0.05176
# Patient patient_38_CBFB_MYH11: Uncertainty - 0.05135
# Patient patient_29_control: Uncertainty - 0.04958
# Patient patient_34_NPM1: Uncertainty - 0.04835
# Patient patient_19_RUNX1_RUNX1T1: Uncertainty - 0.048
# Patient patient_6_CBFB_MYH11: Uncertainty - 0.04447
# Patient patient_5_RUNX1_RUNX1T1: Uncertainty - 0.04368
# Patient patient_7_PML_RARA: Uncertainty - 0.0434
# Patient patient_12_CBFB_MYH11: Uncertainty - 0.0434
# Patient patient_36_CBFB_MYH11: Uncertainty - 0.04272
# Patient patient_11_control: Uncertainty - 0.04224
# Patient patient_14_PML_RARA: Uncertainty - 0.04197
# Patient patient_9_NPM1: Uncertainty - 0.04169
# Patient patient_40_control: Uncertainty - 0.04166
# Patient patient_8_control: Uncertainty - 0.04046
# Patient patient_39_PML_RARA: Uncertainty - 0.04037
# Patient patient_4_control: Uncertainty - 0.04027
# Patient patient_37_control: Uncertainty - 0.04014
# Patient patient_8_CBFB_MYH11: Uncertainty - 0.03843
# Patient patient_9_PML_RARA: Uncertainty - 0.03747
# Patient patient_33_PML_RARA: Uncertainty - 0.03713
# Patient patient_2_PML_RARA: Uncertainty - 0.03695
# Patient patient_6_NPM1: Uncertainty - 0.03633
# Patient patient_36_NPM1: Uncertainty - 0.03556
# Patient patient_25_RUNX1_RUNX1T1: Uncertainty - 0.03556
# Patient patient_39_NPM1: Uncertainty - 0.0355
# Patient patient_4_RUNX1_RUNX1T1: Uncertainty - 0.03428
# Patient patient_7_CBFB_MYH11: Uncertainty - 0.03047
# Patient patient_25_NPM1: Uncertainty - 0.03045
# Patient patient_35_NPM1: Uncertainty - 0.02778
# Patient patient_21_CBFB_MYH11: Uncertainty - 0.02721
# Patient patient_38_NPM1: Uncertainty - 0.02715
# Patient patient_29_PML_RARA: Uncertainty - 0.02704
# Patient patient_19_CBFB_MYH11: Uncertainty - 0.02616
# Patient patient_34_control: Uncertainty - 0.02523
# Patient patient_32_CBFB_MYH11: Uncertainty - 0.02462
# Patient patient_2_CBFB_MYH11: Uncertainty - 0.02408
# Patient patient_38_RUNX1_RUNX1T1: Uncertainty - 0.02339
# Patient patient_5_CBFB_MYH11: Uncertainty - 0.02181
# Patient patient_19_PML_RARA: Uncertainty - 0.02134
# Patient patient_3_CBFB_MYH11: Uncertainty - 0.01993
# Patient patient_10_control: Uncertainty - 0.01969
# Patient patient_6_control: Uncertainty - 0.01932
# Patient patient_1_CBFB_MYH11: Uncertainty - 0.01908
# Patient patient_20_CBFB_MYH11: Uncertainty - 0.01901
# Patient patient_14_CBFB_MYH11: Uncertainty - 0.01877
# Patient patient_13_CBFB_MYH11: Uncertainty - 0.01678
# Patient patient_9_control: Uncertainty - 0.01628
# Patient patient_37_CBFB_MYH11: Uncertainty - 0.01507
# Patient patient_22_control: Uncertainty - 0.01404
# Patient patient_24_PML_RARA: Uncertainty - 0.01237
# Patient patient_33_control: Uncertainty - 0.01208
# Patient patient_39_control: Uncertainty - 0.009099
# Patient patient_28_CBFB_MYH11: Uncertainty - 0.00682
# Patient patient_35_control: Uncertainty - 0.0066
# Patient patient_9_CBFB_MYH11: Uncertainty - 0.006348
# Patient patient_13_control: Uncertainty - 0.006299
# Patient patient_20_control: Uncertainty - 0.005867
# Patient patient_7_control: Uncertainty - 0.00535
# Patient patient_1_control: Uncertainty - 0.005121
# Patient patient_2_control: Uncertainty - 0.0039
# Patient patient_10_CBFB_MYH11: Uncertainty - 0.003588
# Patient patient_19_control: Uncertainty - 0.002696
# Patient patient_14_control: Uncertainty - 0.002672
# Patient patient_21_control: Uncertainty - 0.002354
# Patient patient_38_control: Uncertainty - 0.002074
# Patient patient_27_control: Uncertainty - 0.002071
# Patient patient_3_control: Uncertainty - 0.001752
# Patient patient_21_PML_RARA: Uncertainty - 0.001737
# Patient patient_25_control: Uncertainty - 0.001712
# Patient patient_36_control: Uncertainty - 0.00151
# Patient patient_5_control: Uncertainty - 0.001096
# Patient patient_12_control: Uncertainty - 0.0007824
# Patient patient_24_control: Uncertainty - 0.000264
# Patient patient_25_PML_RARA: Uncertainty - 0.5428
# Patient patient_41_control: Uncertainty - 0.5002
# Patient patient_12_PML_RARA: Uncertainty - 0.4697
# Patient patient_23_PML_RARA: Uncertainty - 0.4529
# Patient patient_6_PML_RARA: Uncertainty - 0.4118
# Patient patient_30_NPM1: Uncertainty - 0.4043
# Patient patient_8_PML_RARA: Uncertainty - 0.3983
# Patient patient_17_RUNX1_RUNX1T1: Uncertainty - 0.3982
# Patient patient_21_NPM1: Uncertainty - 0.3859
# Patient patient_24_RUNX1_RUNX1T1: Uncertainty - 0.3813
# Patient patient_27_CBFB_MYH11: Uncertainty - 0.3781
# Patient patient_23_control: Uncertainty - 0.3758
# Patient patient_23_NPM1: Uncertainty - 0.3738
# Patient patient_10_RUNX1_RUNX1T1: Uncertainty - 0.3727
# Patient patient_13_RUNX1_RUNX1T1: Uncertainty - 0.3613
# Patient patient_32_RUNX1_RUNX1T1: Uncertainty - 0.3533
# Patient patient_35_RUNX1_RUNX1T1: Uncertainty - 0.3501
# Patient patient_26_PML_RARA: Uncertainty - 0.3485
# Patient patient_24_NPM1: Uncertainty - 0.3455
# Patient patient_26_NPM1: Uncertainty - 0.3403
# Patient patient_30_PML_RARA: Uncertainty - 0.3391
# Patient patient_28_PML_RARA: Uncertainty - 0.3385
# Patient patient_16_PML_RARA: Uncertainty - 0.3359
# Patient patient_16_CBFB_MYH11: Uncertainty - 0.3351
# Patient patient_40_PML_RARA: Uncertainty - 0.3347
# Patient patient_24_CBFB_MYH11: Uncertainty - 0.3285
# Patient patient_12_RUNX1_RUNX1T1: Uncertainty - 0.3236
# Patient patient_33_RUNX1_RUNX1T1: Uncertainty - 0.3193
# Patient patient_3_PML_RARA: Uncertainty - 0.3102
# Patient patient_17_control: Uncertainty - 0.3003
# Patient patient_34_RUNX1_RUNX1T1: Uncertainty - 0.2994
# Patient patient_18_CBFB_MYH11: Uncertainty - 0.298
# Patient patient_3_RUNX1_RUNX1T1: Uncertainty - 0.297
# Patient patient_40_RUNX1_RUNX1T1: Uncertainty - 0.2964
# Patient patient_11_RUNX1_RUNX1T1: Uncertainty - 0.2911
# Patient patient_18_control: Uncertainty - 0.2907
# Patient patient_22_PML_RARA: Uncertainty - 0.2893
# Patient patient_28_RUNX1_RUNX1T1: Uncertainty - 0.2885
# Patient patient_17_CBFB_MYH11: Uncertainty - 0.287
# Patient patient_36_PML_RARA: Uncertainty - 0.2867
# Patient patient_26_CBFB_MYH11: Uncertainty - 0.2862
# Patient patient_16_NPM1: Uncertainty - 0.2843
# Patient patient_40_CBFB_MYH11: Uncertainty - 0.2825
# Patient patient_27_NPM1: Uncertainty - 0.2821
# Patient patient_18_NPM1: Uncertainty - 0.2768
# Patient patient_30_CBFB_MYH11: Uncertainty - 0.2707
# Patient patient_39_CBFB_MYH11: Uncertainty - 0.2684
# Patient patient_29_RUNX1_RUNX1T1: Uncertainty - 0.2662
# Patient patient_32_PML_RARA: Uncertainty - 0.2612
# Patient patient_5_PML_RARA: Uncertainty - 0.2608
# Patient patient_31_RUNX1_RUNX1T1: Uncertainty - 0.259
# Patient patient_37_RUNX1_RUNX1T1: Uncertainty - 0.2543
# Patient patient_15_RUNX1_RUNX1T1: Uncertainty - 0.2531
# Patient patient_35_PML_RARA: Uncertainty - 0.2529
# Patient patient_41_NPM1: Uncertainty - 0.2522
# Patient patient_3_NPM1: Uncertainty - 0.2509
# Patient patient_36_RUNX1_RUNX1T1: Uncertainty - 0.2492
# Patient patient_7_NPM1: Uncertainty - 0.2454
# Patient patient_41_RUNX1_RUNX1T1: Uncertainty - 0.2452
# Patient patient_15_control: Uncertainty - 0.2439
# Patient patient_34_PML_RARA: Uncertainty - 0.2435
# Patient patient_39_RUNX1_RUNX1T1: Uncertainty - 0.2419
# Patient patient_35_CBFB_MYH11: Uncertainty - 0.2409
# Patient patient_4_CBFB_MYH11: Uncertainty - 0.2395
# Patient patient_22_NPM1: Uncertainty - 0.2379
# Patient patient_18_PML_RARA: Uncertainty - 0.237
# Patient patient_11_NPM1: Uncertainty - 0.2343
# Patient patient_1_RUNX1_RUNX1T1: Uncertainty - 0.2342
# Patient patient_12_NPM1: Uncertainty - 0.2335
# Patient patient_32_control: Uncertainty - 0.2285
# Patient patient_6_RUNX1_RUNX1T1: Uncertainty - 0.2269
# Patient patient_11_CBFB_MYH11: Uncertainty - 0.225
# Patient patient_37_NPM1: Uncertainty - 0.2229
# Patient patient_14_RUNX1_RUNX1T1: Uncertainty - 0.2204
# Patient patient_13_PML_RARA: Uncertainty - 0.2173
# Patient patient_1_NPM1: Uncertainty - 0.2171
# Patient patient_22_CBFB_MYH11: Uncertainty - 0.2143
# Patient patient_15_PML_RARA: Uncertainty - 0.2142
# Patient patient_2_RUNX1_RUNX1T1: Uncertainty - 0.2131
# Patient patient_31_NPM1: Uncertainty - 0.2122
# Patient patient_7_RUNX1_RUNX1T1: Uncertainty - 0.2012
# Patient patient_13_NPM1: Uncertainty - 0.2008
# Patient patient_10_PML_RARA: Uncertainty - 0.1993
# Patient patient_40_NPM1: Uncertainty - 0.1987
# Patient patient_16_RUNX1_RUNX1T1: Uncertainty - 0.1983
# Patient patient_23_RUNX1_RUNX1T1: Uncertainty - 0.1958
# Patient patient_27_RUNX1_RUNX1T1: Uncertainty - 0.1933
# Patient patient_10_NPM1: Uncertainty - 0.1926
# Patient patient_33_CBFB_MYH11: Uncertainty - 0.1871
# Patient patient_28_control: Uncertainty - 0.1751
# Patient patient_38_PML_RARA: Uncertainty - 0.1749
# Patient patient_17_NPM1: Uncertainty - 0.1704
# Patient patient_20_PML_RARA: Uncertainty - 0.1652
# Patient patient_26_control: Uncertainty - 0.1639
# Patient patient_20_RUNX1_RUNX1T1: Uncertainty - 0.1638
# Patient patient_22_RUNX1_RUNX1T1: Uncertainty - 0.1636
# Patient patient_4_PML_RARA: Uncertainty - 0.162
# Patient patient_25_CBFB_MYH11: Uncertainty - 0.1613
# Patient patient_41_CBFB_MYH11: Uncertainty - 0.1613
# Patient patient_33_NPM1: Uncertainty - 0.1591
# Patient patient_17_PML_RARA: Uncertainty - 0.1581
# Patient patient_18_RUNX1_RUNX1T1: Uncertainty - 0.1556
# Patient patient_31_PML_RARA: Uncertainty - 0.1553
# Patient patient_31_control: Uncertainty - 0.1543
# Patient patient_2_NPM1: Uncertainty - 0.1479
# Patient patient_1_PML_RARA: Uncertainty - 0.1471
# Patient patient_4_NPM1: Uncertainty - 0.145
# Patient patient_11_PML_RARA: Uncertainty - 0.1442
# Patient patient_37_PML_RARA: Uncertainty - 0.1416
# Patient patient_15_CBFB_MYH11: Uncertainty - 0.1389
# Patient patient_21_RUNX1_RUNX1T1: Uncertainty - 0.1385
# Patient patient_32_NPM1: Uncertainty - 0.1382
# Patient patient_8_NPM1: Uncertainty - 0.1371
# Patient patient_20_NPM1: Uncertainty - 0.1326
# Patient patient_29_NPM1: Uncertainty - 0.1315
# Patient patient_30_RUNX1_RUNX1T1: Uncertainty - 0.1313
# Patient patient_34_CBFB_MYH11: Uncertainty - 0.1294
# Patient patient_5_NPM1: Uncertainty - 0.1288
# Patient patient_9_RUNX1_RUNX1T1: Uncertainty - 0.1287
# Patient patient_19_NPM1: Uncertainty - 0.1285
# Patient patient_23_CBFB_MYH11: Uncertainty - 0.1271
# Patient patient_8_RUNX1_RUNX1T1: Uncertainty - 0.1221
# Patient patient_27_PML_RARA: Uncertainty - 0.1216
# Patient patient_30_control: Uncertainty - 0.1206
# Patient patient_14_NPM1: Uncertainty - 0.1198
# Patient patient_26_RUNX1_RUNX1T1: Uncertainty - 0.1183
# Patient patient_16_control: Uncertainty - 0.1182
# Patient patient_29_CBFB_MYH11: Uncertainty - 0.1169
# Patient patient_41_PML_RARA: Uncertainty - 0.1088
# Patient patient_28_NPM1: Uncertainty - 0.1076
# Patient patient_31_CBFB_MYH11: Uncertainty - 0.1055
# Patient patient_15_NPM1: Uncertainty - 0.1053
# Patient patient_38_CBFB_MYH11: Uncertainty - 0.105
# Patient patient_14_PML_RARA: Uncertainty - 0.1034
# Patient patient_29_control: Uncertainty - 0.1025
# Patient patient_34_NPM1: Uncertainty - 0.1002
# Patient patient_19_RUNX1_RUNX1T1: Uncertainty - 0.09807
# Patient patient_25_RUNX1_RUNX1T1: Uncertainty - 0.09526
# Patient patient_5_RUNX1_RUNX1T1: Uncertainty - 0.09222
# Patient patient_8_control: Uncertainty - 0.09071
# Patient patient_7_PML_RARA: Uncertainty - 0.09052
# Patient patient_6_CBFB_MYH11: Uncertainty - 0.08948
# Patient patient_12_CBFB_MYH11: Uncertainty - 0.0889
# Patient patient_11_control: Uncertainty - 0.08798
# Patient patient_36_CBFB_MYH11: Uncertainty - 0.08647
# Patient patient_40_control: Uncertainty - 0.08529
# Patient patient_39_PML_RARA: Uncertainty - 0.08522
# Patient patient_9_NPM1: Uncertainty - 0.08512
# Patient patient_37_control: Uncertainty - 0.08337
# Patient patient_4_control: Uncertainty - 0.0811
# Patient patient_8_CBFB_MYH11: Uncertainty - 0.07695
# Patient patient_2_PML_RARA: Uncertainty - 0.07644
# Patient patient_9_PML_RARA: Uncertainty - 0.07575
# Patient patient_33_PML_RARA: Uncertainty - 0.07525
# Patient patient_36_NPM1: Uncertainty - 0.073
# Patient patient_6_NPM1: Uncertainty - 0.07271
# Patient patient_39_NPM1: Uncertainty - 0.07222
# Patient patient_4_RUNX1_RUNX1T1: Uncertainty - 0.06989
# Patient patient_25_NPM1: Uncertainty - 0.06638
# Patient patient_7_CBFB_MYH11: Uncertainty - 0.06135
# Patient patient_35_NPM1: Uncertainty - 0.05714
# Patient patient_29_PML_RARA: Uncertainty - 0.05599
# Patient patient_38_NPM1: Uncertainty - 0.05544
# Patient patient_19_CBFB_MYH11: Uncertainty - 0.05509
# Patient patient_21_CBFB_MYH11: Uncertainty - 0.05472
# Patient patient_34_control: Uncertainty - 0.05089
# Patient patient_32_CBFB_MYH11: Uncertainty - 0.04995
# Patient patient_2_CBFB_MYH11: Uncertainty - 0.04958
# Patient patient_38_RUNX1_RUNX1T1: Uncertainty - 0.04708
# Patient patient_5_CBFB_MYH11: Uncertainty - 0.04522
# Patient patient_19_PML_RARA: Uncertainty - 0.04387
# Patient patient_3_CBFB_MYH11: Uncertainty - 0.04003
# Patient patient_10_control: Uncertainty - 0.03996
# Patient patient_6_control: Uncertainty - 0.03956
# Patient patient_20_CBFB_MYH11: Uncertainty - 0.03871
# Patient patient_1_CBFB_MYH11: Uncertainty - 0.03823
# Patient patient_14_CBFB_MYH11: Uncertainty - 0.03761
# Patient patient_13_CBFB_MYH11: Uncertainty - 0.03419
# Patient patient_9_control: Uncertainty - 0.03295
# Patient patient_37_CBFB_MYH11: Uncertainty - 0.03087
# Patient patient_22_control: Uncertainty - 0.02847
# Patient patient_24_PML_RARA: Uncertainty - 0.02569
# Patient patient_33_control: Uncertainty - 0.02439
# Patient patient_39_control: Uncertainty - 0.02013
# Patient patient_28_CBFB_MYH11: Uncertainty - 0.01376
# Patient patient_35_control: Uncertainty - 0.01337
# Patient patient_13_control: Uncertainty - 0.01334
# Patient patient_9_CBFB_MYH11: Uncertainty - 0.01322
# Patient patient_20_control: Uncertainty - 0.01241
# Patient patient_7_control: Uncertainty - 0.0107
# Patient patient_1_control: Uncertainty - 0.01025
# Patient patient_2_control: Uncertainty - 0.007974
# Patient patient_10_CBFB_MYH11: Uncertainty - 0.007327
# Patient patient_19_control: Uncertainty - 0.005483
# Patient patient_14_control: Uncertainty - 0.005377
# Patient patient_21_control: Uncertainty - 0.004841
# Patient patient_27_control: Uncertainty - 0.004453
# Patient patient_38_control: Uncertainty - 0.004229
# Patient patient_21_PML_RARA: Uncertainty - 0.003889
# Patient patient_3_control: Uncertainty - 0.00372
# Patient patient_25_control: Uncertainty - 0.003566
# Patient patient_36_control: Uncertainty - 0.003055
# Patient patient_5_control: Uncertainty - 0.002207
# Patient patient_12_control: Uncertainty - 0.001627
# Patient patient_24_control: Uncertainty - 0.0005774
# Patient patient_11_CBFB_MYH11: Uncertainty - 1.0
# Patient patient_22_CBFB_MYH11: Uncertainty - 1.0
# Patient patient_30_CBFB_MYH11: Uncertainty - 1.0
# Patient patient_33_CBFB_MYH11: Uncertainty - 1.0
# Patient patient_40_CBFB_MYH11: Uncertainty - 1.0
# Patient patient_32_control: Uncertainty - 1.0
# Patient patient_3_NPM1: Uncertainty - 1.0
# Patient patient_4_NPM1: Uncertainty - 1.0
# Patient patient_5_NPM1: Uncertainty - 1.0
# Patient patient_6_NPM1: Uncertainty - 1.0
# Patient patient_20_NPM1: Uncertainty - 1.0
# Patient patient_22_NPM1: Uncertainty - 1.0
# Patient patient_32_NPM1: Uncertainty - 1.0
# Patient patient_5_PML_RARA: Uncertainty - 1.0
# Patient patient_10_PML_RARA: Uncertainty - 1.0
# Patient patient_18_PML_RARA: Uncertainty - 1.0
# Patient patient_20_PML_RARA: Uncertainty - 1.0
# Patient patient_22_PML_RARA: Uncertainty - 1.0
# Patient patient_28_PML_RARA: Uncertainty - 1.0
# Patient patient_32_PML_RARA: Uncertainty - 1.0
# Patient patient_34_PML_RARA: Uncertainty - 1.0
# Patient patient_1_RUNX1_RUNX1T1: Uncertainty - 1.0
# Patient patient_2_RUNX1_RUNX1T1: Uncertainty - 1.0
# Patient patient_4_RUNX1_RUNX1T1: Uncertainty - 1.0
# Patient patient_5_RUNX1_RUNX1T1: Uncertainty - 1.0
# Patient patient_6_RUNX1_RUNX1T1: Uncertainty - 1.0
# Patient patient_7_RUNX1_RUNX1T1: Uncertainty - 1.0
# Patient patient_8_RUNX1_RUNX1T1: Uncertainty - 1.0
# Patient patient_9_RUNX1_RUNX1T1: Uncertainty - 1.0
# Patient patient_11_RUNX1_RUNX1T1: Uncertainty - 1.0
# Patient patient_14_RUNX1_RUNX1T1: Uncertainty - 1.0
# Patient patient_16_RUNX1_RUNX1T1: Uncertainty - 1.0
# Patient patient_18_RUNX1_RUNX1T1: Uncertainty - 1.0
# Patient patient_19_RUNX1_RUNX1T1: Uncertainty - 1.0
# Patient patient_20_RUNX1_RUNX1T1: Uncertainty - 1.0
# Patient patient_21_RUNX1_RUNX1T1: Uncertainty - 1.0
# Patient patient_22_RUNX1_RUNX1T1: Uncertainty - 1.0
# Patient patient_23_RUNX1_RUNX1T1: Uncertainty - 1.0
# Patient patient_24_RUNX1_RUNX1T1: Uncertainty - 1.0
# Patient patient_25_RUNX1_RUNX1T1: Uncertainty - 1.0
# Patient patient_26_RUNX1_RUNX1T1: Uncertainty - 1.0
# Patient patient_27_RUNX1_RUNX1T1: Uncertainty - 1.0
# Patient patient_28_RUNX1_RUNX1T1: Uncertainty - 1.0
# Patient patient_29_RUNX1_RUNX1T1: Uncertainty - 1.0
# Patient patient_30_RUNX1_RUNX1T1: Uncertainty - 1.0
# Patient patient_31_RUNX1_RUNX1T1: Uncertainty - 1.0
# Patient patient_36_RUNX1_RUNX1T1: Uncertainty - 1.0
# Patient patient_38_RUNX1_RUNX1T1: Uncertainty - 1.0
# Patient patient_23_control: Uncertainty - 0.9
# Patient patient_30_NPM1: Uncertainty - 0.9
# Patient patient_30_PML_RARA: Uncertainty - 0.9
# Patient patient_3_RUNX1_RUNX1T1: Uncertainty - 0.9
# Patient patient_10_RUNX1_RUNX1T1: Uncertainty - 0.9
# Patient patient_13_RUNX1_RUNX1T1: Uncertainty - 0.9
# Patient patient_15_RUNX1_RUNX1T1: Uncertainty - 0.9
# Patient patient_32_RUNX1_RUNX1T1: Uncertainty - 0.9
# Patient patient_35_RUNX1_RUNX1T1: Uncertainty - 0.9
# Patient patient_37_RUNX1_RUNX1T1: Uncertainty - 0.9
# Patient patient_25_PML_RARA: Uncertainty - 0.8
# Patient patient_40_RUNX1_RUNX1T1: Uncertainty - 0.8
# Patient patient_41_RUNX1_RUNX1T1: Uncertainty - 0.8
# Patient patient_12_RUNX1_RUNX1T1: Uncertainty - 0.7
# Patient patient_27_CBFB_MYH11: Uncertainty - 0.6
# Patient patient_39_CBFB_MYH11: Uncertainty - 0.6
# Patient patient_41_control: Uncertainty - 0.6
# Patient patient_33_RUNX1_RUNX1T1: Uncertainty - 0.6
# Patient patient_23_NPM1: Uncertainty - 0.5
# Patient patient_24_NPM1: Uncertainty - 0.5
# Patient patient_8_PML_RARA: Uncertainty - 0.5
# Patient patient_16_PML_RARA: Uncertainty - 0.4
# Patient patient_23_PML_RARA: Uncertainty - 0.4
# Patient patient_39_RUNX1_RUNX1T1: Uncertainty - 0.4
# Patient patient_18_CBFB_MYH11: Uncertainty - 0.3
# Patient patient_21_NPM1: Uncertainty - 0.3
# Patient patient_40_PML_RARA: Uncertainty - 0.3
# Patient patient_34_RUNX1_RUNX1T1: Uncertainty - 0.3
# Patient patient_17_control: Uncertainty - 0.2
# Patient patient_18_NPM1: Uncertainty - 0.2
# Patient patient_26_NPM1: Uncertainty - 0.2
# Patient patient_3_PML_RARA: Uncertainty - 0.2
# Patient patient_6_PML_RARA: Uncertainty - 0.2
# Patient patient_12_PML_RARA: Uncertainty - 0.2
# Patient patient_16_CBFB_MYH11: Uncertainty - 0.1
# Patient patient_17_CBFB_MYH11: Uncertainty - 0.1
# Patient patient_26_CBFB_MYH11: Uncertainty - 0.1
# Patient patient_18_control: Uncertainty - 0.1
# Patient patient_27_NPM1: Uncertainty - 0.1
# Patient patient_26_PML_RARA: Uncertainty - 0.1
# Patient patient_36_PML_RARA: Uncertainty - 0.1
# Patient patient_17_RUNX1_RUNX1T1: Uncertainty - 0.1
# Patient patient_1_CBFB_MYH11: Uncertainty - 0.0
# Patient patient_2_CBFB_MYH11: Uncertainty - 0.0
# Patient patient_3_CBFB_MYH11: Uncertainty - 0.0
# Patient patient_4_CBFB_MYH11: Uncertainty - 0.0
# Patient patient_5_CBFB_MYH11: Uncertainty - 0.0
# Patient patient_6_CBFB_MYH11: Uncertainty - 0.0
# Patient patient_7_CBFB_MYH11: Uncertainty - 0.0
# Patient patient_8_CBFB_MYH11: Uncertainty - 0.0
# Patient patient_9_CBFB_MYH11: Uncertainty - 0.0
# Patient patient_10_CBFB_MYH11: Uncertainty - 0.0
# Patient patient_12_CBFB_MYH11: Uncertainty - 0.0
# Patient patient_13_CBFB_MYH11: Uncertainty - 0.0
# Patient patient_14_CBFB_MYH11: Uncertainty - 0.0
# Patient patient_15_CBFB_MYH11: Uncertainty - 0.0
# Patient patient_19_CBFB_MYH11: Uncertainty - 0.0
# Patient patient_20_CBFB_MYH11: Uncertainty - 0.0
# Patient patient_21_CBFB_MYH11: Uncertainty - 0.0
# Patient patient_23_CBFB_MYH11: Uncertainty - 0.0
# Patient patient_24_CBFB_MYH11: Uncertainty - 0.0
# Patient patient_25_CBFB_MYH11: Uncertainty - 0.0
# Patient patient_28_CBFB_MYH11: Uncertainty - 0.0
# Patient patient_29_CBFB_MYH11: Uncertainty - 0.0
# Patient patient_31_CBFB_MYH11: Uncertainty - 0.0
# Patient patient_32_CBFB_MYH11: Uncertainty - 0.0
# Patient patient_34_CBFB_MYH11: Uncertainty - 0.0
# Patient patient_35_CBFB_MYH11: Uncertainty - 0.0
# Patient patient_36_CBFB_MYH11: Uncertainty - 0.0
# Patient patient_37_CBFB_MYH11: Uncertainty - 0.0
# Patient patient_38_CBFB_MYH11: Uncertainty - 0.0
# Patient patient_41_CBFB_MYH11: Uncertainty - 0.0
# Patient patient_1_control: Uncertainty - 0.0
# Patient patient_2_control: Uncertainty - 0.0
# Patient patient_3_control: Uncertainty - 0.0
# Patient patient_4_control: Uncertainty - 0.0
# Patient patient_5_control: Uncertainty - 0.0
# Patient patient_6_control: Uncertainty - 0.0
# Patient patient_7_control: Uncertainty - 0.0
# Patient patient_8_control: Uncertainty - 0.0
# Patient patient_9_control: Uncertainty - 0.0
# Patient patient_10_control: Uncertainty - 0.0
# Patient patient_11_control: Uncertainty - 0.0
# Patient patient_12_control: Uncertainty - 0.0
# Patient patient_13_control: Uncertainty - 0.0
# Patient patient_14_control: Uncertainty - 0.0
# Patient patient_15_control: Uncertainty - 0.0
# Patient patient_16_control: Uncertainty - 0.0
# Patient patient_19_control: Uncertainty - 0.0
# Patient patient_20_control: Uncertainty - 0.0
# Patient patient_21_control: Uncertainty - 0.0
# Patient patient_22_control: Uncertainty - 0.0
# Patient patient_24_control: Uncertainty - 0.0
# Patient patient_25_control: Uncertainty - 0.0
# Patient patient_26_control: Uncertainty - 0.0
# Patient patient_27_control: Uncertainty - 0.0
# Patient patient_28_control: Uncertainty - 0.0
# Patient patient_29_control: Uncertainty - 0.0
# Patient patient_30_control: Uncertainty - 0.0
# Patient patient_31_control: Uncertainty - 0.0
# Patient patient_33_control: Uncertainty - 0.0
# Patient patient_34_control: Uncertainty - 0.0
# Patient patient_35_control: Uncertainty - 0.0
# Patient patient_36_control: Uncertainty - 0.0
# Patient patient_37_control: Uncertainty - 0.0
# Patient patient_38_control: Uncertainty - 0.0
# Patient patient_39_control: Uncertainty - 0.0
# Patient patient_40_control: Uncertainty - 0.0
# Patient patient_1_NPM1: Uncertainty - 0.0
# Patient patient_2_NPM1: Uncertainty - 0.0
# Patient patient_7_NPM1: Uncertainty - 0.0
# Patient patient_8_NPM1: Uncertainty - 0.0
# Patient patient_9_NPM1: Uncertainty - 0.0
# Patient patient_10_NPM1: Uncertainty - 0.0
# Patient patient_11_NPM1: Uncertainty - 0.0
# Patient patient_12_NPM1: Uncertainty - 0.0
# Patient patient_13_NPM1: Uncertainty - 0.0
# Patient patient_14_NPM1: Uncertainty - 0.0
# Patient patient_15_NPM1: Uncertainty - 0.0
# Patient patient_16_NPM1: Uncertainty - 0.0
# Patient patient_17_NPM1: Uncertainty - 0.0
# Patient patient_19_NPM1: Uncertainty - 0.0
# Patient patient_25_NPM1: Uncertainty - 0.0
# Patient patient_28_NPM1: Uncertainty - 0.0
# Patient patient_29_NPM1: Uncertainty - 0.0
# Patient patient_31_NPM1: Uncertainty - 0.0
# Patient patient_33_NPM1: Uncertainty - 0.0
# Patient patient_34_NPM1: Uncertainty - 0.0
# Patient patient_35_NPM1: Uncertainty - 0.0
# Patient patient_36_NPM1: Uncertainty - 0.0
# Patient patient_37_NPM1: Uncertainty - 0.0
# Patient patient_38_NPM1: Uncertainty - 0.0
# Patient patient_39_NPM1: Uncertainty - 0.0
# Patient patient_40_NPM1: Uncertainty - 0.0
# Patient patient_41_NPM1: Uncertainty - 0.0
# Patient patient_1_PML_RARA: Uncertainty - 0.0
# Patient patient_2_PML_RARA: Uncertainty - 0.0
# Patient patient_4_PML_RARA: Uncertainty - 0.0
# Patient patient_7_PML_RARA: Uncertainty - 0.0
# Patient patient_9_PML_RARA: Uncertainty - 0.0
# Patient patient_11_PML_RARA: Uncertainty - 0.0
# Patient patient_13_PML_RARA: Uncertainty - 0.0
# Patient patient_14_PML_RARA: Uncertainty - 0.0
# Patient patient_15_PML_RARA: Uncertainty - 0.0
# Patient patient_17_PML_RARA: Uncertainty - 0.0
# Patient patient_19_PML_RARA: Uncertainty - 0.0
# Patient patient_21_PML_RARA: Uncertainty - 0.0
# Patient patient_24_PML_RARA: Uncertainty - 0.0
# Patient patient_27_PML_RARA: Uncertainty - 0.0
# Patient patient_29_PML_RARA: Uncertainty - 0.0
# Patient patient_31_PML_RARA: Uncertainty - 0.0
# Patient patient_33_PML_RARA: Uncertainty - 0.0
# Patient patient_35_PML_RARA: Uncertainty - 0.0
# Patient patient_37_PML_RARA: Uncertainty - 0.0
# Patient patient_38_PML_RARA: Uncertainty - 0.0
# Patient patient_39_PML_RARA: Uncertainty - 0.0
# Patient patient_41_PML_RARA: Uncertainty - 0.0

# %%
def select_paths(uncertainties, percentage):
    sorted_uncertainties = dict(sorted(uncertainties.items(), key=lambda item: item[1]['uncertainty'], reverse=True))
    
    # Calculate the number of paths based on the percentage
    num_paths = int(len(sorted_uncertainties) * (percentage / 100.0))
    
    # Select the top percentage of paths
    selected_paths = {p: data['path'] for p, data in list(sorted_uncertainties.items())[:num_paths]}
    
    return selected_paths

metadata_path = SOURCE_FOLDER + "/metadata.csv"

def create_metadata(selected_paths, target_folder):
    # Load the existing metadata CSV file into a DataFrame
    metadata_df = pd.read_csv(metadata_path)

    # Dictionary to store the extracted information
    metadata_dict = {}

    # Loop over each key in selected_paths
    for key in selected_paths:
        path = selected_paths[key]

        # Extract patient_id and bag_label from the key
        match = re.search(r'\d', key)
        if match:
            index_of_second_digit = key.find('_', match.start() + 1)
            if index_of_second_digit != -1:
                patient_id = key[:index_of_second_digit + 1]  # Include everything up to the second underscore
                patient_id = patient_id[:-1]
                bag_label = key[index_of_second_digit + 1:]  # Remove the first underscore in bag_label
            else:
                # If no second underscore found, consider the entire key as patient_id
                patient_id = key
                bag_label = ''
        else:
            # If no digit found, consider the entire key as patient_id
            patient_id = key
            bag_label = ''

        # Filter the metadata DataFrame based on patient_id and bag_label
        metadata_row = metadata_df[(metadata_df['patient_id'] == patient_id) & (metadata_df['bag_label'] == bag_label)]

        # Check if any matching rows are found
        if not metadata_row.empty:
            # Get the first matching row (assuming there's only one match)
            metadata_dict[key] = metadata_row.iloc[0].to_dict()
        else:
            # Handle the case when no matching rows are found
            print(f"No metadata found for {key}: {path}")

    # Create a new DataFrame from the extracted metadata dictionary
    new_metadata_df = pd.DataFrame.from_dict(metadata_dict, orient='index')


    # Save the new metadata DataFrame to a CSV file in the target folder
    new_metadata_path = os.path.join(target_folder, 'metadata_old.csv')
    new_metadata_df.to_csv(new_metadata_path, index=False)

    return new_metadata_path


#returns dict that contains number of real patients per leukemia class
def get_realpatients_filepaths_dictionary(src_folder):
    paths = {}
    for class_name in os.listdir(src_folder):
        class_path=os.path.join(src_folder, class_name)
        for file in  os.listdir(class_path):
            src_path = os.path.join(class_path, file)
            # Extract class and patient information from the source path
            patient_name = get_patient_name(src_path)
            if class_name not in paths.keys():
                paths[class_name] = []
            paths[class_name].append(src_path)
    return paths

# %%
def save_patient_filepaths(selected_paths, new_folder,paths_real_patients):
    # save filepaths to the new folder
    print(f"Save file paths for uncertain patients in {new_folder}")
    os.makedirs(new_folder, exist_ok=True)
    # save filepath in dictionary paths with keys as class and values list of file paths
    paths_uncertain_patients = {}
    #Initilialise 
    for class_name in CLASSES:
        if class_name not in paths_uncertain_patients.keys():
                    paths_uncertain_patients[class_name] = []
            
    for p, path in selected_paths.items():   
        class_name = get_class_name(path)
        paths_uncertain_patients[class_name].append(path)    
    
    #Concatenate the two dictionaries
    paths_mixed_patients={}
    for key, value in paths_real_patients.items():
        paths_mixed_patients[key] = value
        paths_mixed_patients[key] += paths_uncertain_patients[key]
    print(paths_mixed_patients)   
    
    #Save ditionary
    with open(new_folder+'/file_paths.pkl', 'wb') as f:
        pickle.dump(paths_mixed_patients, f)

# %%
# Iterate over different percentages from 10 to 50 and save uncertain patients
paths_real_patients=get_realpatients_filepaths_dictionary(real_data_source)
for percentage in range(10, 51, 10):
    # Define folder to save the uncertain patients
    new_folder_misscl = output_folder+f'/misscl_{percentage}_percent'
    new_folder_max = output_folder+f'/max_{percentage}_percent'
    new_folder_sum = output_folder+f'/sum_{percentage}_percent'

    # Select uncertain paths based on the current percentage for missclassification_counts
    selected_misscl_paths = select_paths(missclassification_counts, percentage)
    # Save uncertain patients to the new folder
    save_patient_filepaths(selected_misscl_paths, new_folder_misscl,paths_real_patients)
    create_metadata(selected_misscl_paths, new_folder_misscl)

    # Select uncertain paths based on the current percentage for max_uncertainties
    selected_max_paths = select_paths(max_uncertainties, percentage)
    # Save uncertain patients to the new folder
    save_patient_filepaths(selected_max_paths, new_folder_max,paths_real_patients)
    create_metadata(selected_max_paths, new_folder_max)

    # Select uncertain paths based on the current percentage for sum_uncertainties
    selected_sum_paths = select_paths(sum_uncertainties, percentage)
    # Save uncertain patients to the new folder
    save_patient_filepaths(selected_sum_paths, new_folder_sum,paths_real_patients)
    create_metadata(selected_sum_paths, new_folder_sum)
# Out:
# Save file paths for uncertain patients in /mnt/volume/shared/data_file/mixed_uncertain_seed1/misscl_10_percent
# {'control': ['/mnt/volume/shared/data_file/data/control/CIQ', '/mnt/volume/shared/data_file/data/control/FDW', '/mnt/volume/shared/data_file/data/control/ICS', '/mnt/volume/shared/data_file/data/control/WXO', '/mnt/volume/shared/data_file/data/control/NXO', '/mnt/volume/shared/data_file/data/control/ATM', '/mnt/volume/shared/data_file/data/control/MPP', '/mnt/volume/shared/data_file/data/control/DJJ', '/mnt/volume/shared/data_file/data/control/UNX', '/mnt/volume/shared/data_file/data/control/UOU', '/mnt/volume/shared/data_file/data/control/AVL', '/mnt/volume/shared/data_file/data/control/WSD', '/mnt/volume/shared/data_file/data/control/ZNK', '/mnt/volume/shared/data_file/data/control/TBZ', '/mnt/volume/shared/data_file/data/control/RDV', '/mnt/volume/shared/data_file/data/control/MKF', '/mnt/volume/shared/data_file/data/control/LCW', '/mnt/volume/shared/data_file/data/control/XXJ', '/mnt/volume/shared/data_file/data/control/YWQ', '/mnt/volume/shared/data_file/data/control/DNX', '/mnt/volume/shared/data_file/data/control/ZNL', '/mnt/volume/shared/data_file/data/control/UBG', '/mnt/volume/shared/data_file/data/control/GJZ', '/mnt/volume/shared/data_file/data/control/IPY', '/mnt/volume/shared/data_file/data/control/YXY', '/mnt/volume/shared/data_file/data/control/NOL', '/mnt/volume/shared/data_file/data/control/NFI', '/mnt/volume/shared/data_file/data/control/VPN', '/mnt/volume/shared/data_file/data/control/CDA', '/mnt/volume/shared/data_file/data/control/FAQ', '/mnt/volume/shared/data_file/data/control/DHE', '/mnt/volume/shared/data_file/data/control/XXI', '/mnt/volume/shared/data_file/data/control/GJQ', '/mnt/volume/shared/data_file/data/control/TVZ', '/mnt/volume/shared/data_file/data/control/CCO', '/mnt/volume/shared/data_file/data/control/GXQ', '/mnt/volume/shared/data_file/data/control/KDW', '/mnt/volume/shared/data_file/data/control/QIZ', '/mnt/volume/shared/data_file/data/control/ORD', '/mnt/volume/shared/data_file/data/control/HQQ', '/mnt/volume/shared/data_file/data/control/AIH', '/mnt/volume/shared/data_file/data/control/NRL', '/mnt/volume/shared/data_file/data/control/OTU', '/mnt/volume/shared/data_file/data/control/YDL', '/mnt/volume/shared/data_file/data/control/MOR', '/mnt/volume/shared/data_file/data/control/ENH', '/mnt/volume/shared/data_file/data/control/LAM', '/mnt/volume/shared/data_file/data/control/WOA', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_32'], 'RUNX1_RUNX1T1': ['/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/ONF', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/KRG', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/BOE', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/SWN', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/RHX', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/IIG', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/ILZ', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/GUE', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/XOB', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/VXU', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/UWF', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/VMO', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/RGG', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/XTK', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/NRB', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/LPA', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/HMC', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/RJQ', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/ZVX', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/UGU', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/XXX', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/ISW', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/BHG', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/ZJJ', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/ORE', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/FED'], 'CBFB_MYH11': ['/mnt/volume/shared/data_file/data/CBFB_MYH11/KOV', '/mnt/volume/shared/data_fil ...
# Save file paths for uncertain patients in /mnt/volume/shared/data_file/mixed_uncertain_seed1/max_10_percent
# {'control': ['/mnt/volume/shared/data_file/data/control/CIQ', '/mnt/volume/shared/data_file/data/control/FDW', '/mnt/volume/shared/data_file/data/control/ICS', '/mnt/volume/shared/data_file/data/control/WXO', '/mnt/volume/shared/data_file/data/control/NXO', '/mnt/volume/shared/data_file/data/control/ATM', '/mnt/volume/shared/data_file/data/control/MPP', '/mnt/volume/shared/data_file/data/control/DJJ', '/mnt/volume/shared/data_file/data/control/UNX', '/mnt/volume/shared/data_file/data/control/UOU', '/mnt/volume/shared/data_file/data/control/AVL', '/mnt/volume/shared/data_file/data/control/WSD', '/mnt/volume/shared/data_file/data/control/ZNK', '/mnt/volume/shared/data_file/data/control/TBZ', '/mnt/volume/shared/data_file/data/control/RDV', '/mnt/volume/shared/data_file/data/control/MKF', '/mnt/volume/shared/data_file/data/control/LCW', '/mnt/volume/shared/data_file/data/control/XXJ', '/mnt/volume/shared/data_file/data/control/YWQ', '/mnt/volume/shared/data_file/data/control/DNX', '/mnt/volume/shared/data_file/data/control/ZNL', '/mnt/volume/shared/data_file/data/control/UBG', '/mnt/volume/shared/data_file/data/control/GJZ', '/mnt/volume/shared/data_file/data/control/IPY', '/mnt/volume/shared/data_file/data/control/YXY', '/mnt/volume/shared/data_file/data/control/NOL', '/mnt/volume/shared/data_file/data/control/NFI', '/mnt/volume/shared/data_file/data/control/VPN', '/mnt/volume/shared/data_file/data/control/CDA', '/mnt/volume/shared/data_file/data/control/FAQ', '/mnt/volume/shared/data_file/data/control/DHE', '/mnt/volume/shared/data_file/data/control/XXI', '/mnt/volume/shared/data_file/data/control/GJQ', '/mnt/volume/shared/data_file/data/control/TVZ', '/mnt/volume/shared/data_file/data/control/CCO', '/mnt/volume/shared/data_file/data/control/GXQ', '/mnt/volume/shared/data_file/data/control/KDW', '/mnt/volume/shared/data_file/data/control/QIZ', '/mnt/volume/shared/data_file/data/control/ORD', '/mnt/volume/shared/data_file/data/control/HQQ', '/mnt/volume/shared/data_file/data/control/AIH', '/mnt/volume/shared/data_file/data/control/NRL', '/mnt/volume/shared/data_file/data/control/OTU', '/mnt/volume/shared/data_file/data/control/YDL', '/mnt/volume/shared/data_file/data/control/MOR', '/mnt/volume/shared/data_file/data/control/ENH', '/mnt/volume/shared/data_file/data/control/LAM', '/mnt/volume/shared/data_file/data/control/WOA', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_32', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_41'], 'RUNX1_RUNX1T1': ['/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/ONF', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/KRG', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/BOE', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/SWN', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/RHX', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/IIG', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/ILZ', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/GUE', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/XOB', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/VXU', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/UWF', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/VMO', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/RGG', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/XTK', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/NRB', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/LPA', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/HMC', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/RJQ', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/ZVX', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/UGU', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/XXX', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/ISW', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/BHG', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/ZJJ', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/ORE', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/FED', '/mnt/ ...
# Save file paths for uncertain patients in /mnt/volume/shared/data_file/mixed_uncertain_seed1/ sum_10_percent
# {'control': ['/mnt/volume/shared/data_file/data/control/CIQ', '/mnt/volume/shared/data_file/data/control/FDW', '/mnt/volume/shared/data_file/data/control/ICS', '/mnt/volume/shared/data_file/data/control/WXO', '/mnt/volume/shared/data_file/data/control/NXO', '/mnt/volume/shared/data_file/data/control/ATM', '/mnt/volume/shared/data_file/data/control/MPP', '/mnt/volume/shared/data_file/data/control/DJJ', '/mnt/volume/shared/data_file/data/control/UNX', '/mnt/volume/shared/data_file/data/control/UOU', '/mnt/volume/shared/data_file/data/control/AVL', '/mnt/volume/shared/data_file/data/control/WSD', '/mnt/volume/shared/data_file/data/control/ZNK', '/mnt/volume/shared/data_file/data/control/TBZ', '/mnt/volume/shared/data_file/data/control/RDV', '/mnt/volume/shared/data_file/data/control/MKF', '/mnt/volume/shared/data_file/data/control/LCW', '/mnt/volume/shared/data_file/data/control/XXJ', '/mnt/volume/shared/data_file/data/control/YWQ', '/mnt/volume/shared/data_file/data/control/DNX', '/mnt/volume/shared/data_file/data/control/ZNL', '/mnt/volume/shared/data_file/data/control/UBG', '/mnt/volume/shared/data_file/data/control/GJZ', '/mnt/volume/shared/data_file/data/control/IPY', '/mnt/volume/shared/data_file/data/control/YXY', '/mnt/volume/shared/data_file/data/control/NOL', '/mnt/volume/shared/data_file/data/control/NFI', '/mnt/volume/shared/data_file/data/control/VPN', '/mnt/volume/shared/data_file/data/control/CDA', '/mnt/volume/shared/data_file/data/control/FAQ', '/mnt/volume/shared/data_file/data/control/DHE', '/mnt/volume/shared/data_file/data/control/XXI', '/mnt/volume/shared/data_file/data/control/GJQ', '/mnt/volume/shared/data_file/data/control/TVZ', '/mnt/volume/shared/data_file/data/control/CCO', '/mnt/volume/shared/data_file/data/control/GXQ', '/mnt/volume/shared/data_file/data/control/KDW', '/mnt/volume/shared/data_file/data/control/QIZ', '/mnt/volume/shared/data_file/data/control/ORD', '/mnt/volume/shared/data_file/data/control/HQQ', '/mnt/volume/shared/data_file/data/control/AIH', '/mnt/volume/shared/data_file/data/control/NRL', '/mnt/volume/shared/data_file/data/control/OTU', '/mnt/volume/shared/data_file/data/control/YDL', '/mnt/volume/shared/data_file/data/control/MOR', '/mnt/volume/shared/data_file/data/control/ENH', '/mnt/volume/shared/data_file/data/control/LAM', '/mnt/volume/shared/data_file/data/control/WOA', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_32', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_41', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_41', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_23'], 'RUNX1_RUNX1T1': ['/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/ONF', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/KRG', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/BOE', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/SWN', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/RHX', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/IIG', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/ILZ', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/GUE', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/XOB', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/VXU', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/UWF', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/VMO', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/RGG', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/XTK', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/NRB', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/LPA', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/HMC', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/RJQ', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/ZVX', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/UGU', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/XXX', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/ISW', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1 ...
# Save file paths for uncertain patients in /mnt/volume/shared/data_file/mixed_uncertain_seed1/misscl_20_percent
# {'control': ['/mnt/volume/shared/data_file/data/control/CIQ', '/mnt/volume/shared/data_file/data/control/FDW', '/mnt/volume/shared/data_file/data/control/ICS', '/mnt/volume/shared/data_file/data/control/WXO', '/mnt/volume/shared/data_file/data/control/NXO', '/mnt/volume/shared/data_file/data/control/ATM', '/mnt/volume/shared/data_file/data/control/MPP', '/mnt/volume/shared/data_file/data/control/DJJ', '/mnt/volume/shared/data_file/data/control/UNX', '/mnt/volume/shared/data_file/data/control/UOU', '/mnt/volume/shared/data_file/data/control/AVL', '/mnt/volume/shared/data_file/data/control/WSD', '/mnt/volume/shared/data_file/data/control/ZNK', '/mnt/volume/shared/data_file/data/control/TBZ', '/mnt/volume/shared/data_file/data/control/RDV', '/mnt/volume/shared/data_file/data/control/MKF', '/mnt/volume/shared/data_file/data/control/LCW', '/mnt/volume/shared/data_file/data/control/XXJ', '/mnt/volume/shared/data_file/data/control/YWQ', '/mnt/volume/shared/data_file/data/control/DNX', '/mnt/volume/shared/data_file/data/control/ZNL', '/mnt/volume/shared/data_file/data/control/UBG', '/mnt/volume/shared/data_file/data/control/GJZ', '/mnt/volume/shared/data_file/data/control/IPY', '/mnt/volume/shared/data_file/data/control/YXY', '/mnt/volume/shared/data_file/data/control/NOL', '/mnt/volume/shared/data_file/data/control/NFI', '/mnt/volume/shared/data_file/data/control/VPN', '/mnt/volume/shared/data_file/data/control/CDA', '/mnt/volume/shared/data_file/data/control/FAQ', '/mnt/volume/shared/data_file/data/control/DHE', '/mnt/volume/shared/data_file/data/control/XXI', '/mnt/volume/shared/data_file/data/control/GJQ', '/mnt/volume/shared/data_file/data/control/TVZ', '/mnt/volume/shared/data_file/data/control/CCO', '/mnt/volume/shared/data_file/data/control/GXQ', '/mnt/volume/shared/data_file/data/control/KDW', '/mnt/volume/shared/data_file/data/control/QIZ', '/mnt/volume/shared/data_file/data/control/ORD', '/mnt/volume/shared/data_file/data/control/HQQ', '/mnt/volume/shared/data_file/data/control/AIH', '/mnt/volume/shared/data_file/data/control/NRL', '/mnt/volume/shared/data_file/data/control/OTU', '/mnt/volume/shared/data_file/data/control/YDL', '/mnt/volume/shared/data_file/data/control/MOR', '/mnt/volume/shared/data_file/data/control/ENH', '/mnt/volume/shared/data_file/data/control/LAM', '/mnt/volume/shared/data_file/data/control/WOA', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_32', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_41', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_41', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_23', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_32'], 'RUNX1_RUNX1T1': ['/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/ONF', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/KRG', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/BOE', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/SWN', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/RHX', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/IIG', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/ILZ', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/GUE', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/XOB', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/VXU', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/UWF', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/VMO', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/RGG', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/XTK', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/NRB', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/LPA', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/HMC', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/RJQ', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/ZVX', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/UGU', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/XXX', '/mnt/volum ...
# Save file paths for uncertain patients in /mnt/volume/shared/data_file/mixed_uncertain_seed1/max_20_percent
# {'control': ['/mnt/volume/shared/data_file/data/control/CIQ', '/mnt/volume/shared/data_file/data/control/FDW', '/mnt/volume/shared/data_file/data/control/ICS', '/mnt/volume/shared/data_file/data/control/WXO', '/mnt/volume/shared/data_file/data/control/NXO', '/mnt/volume/shared/data_file/data/control/ATM', '/mnt/volume/shared/data_file/data/control/MPP', '/mnt/volume/shared/data_file/data/control/DJJ', '/mnt/volume/shared/data_file/data/control/UNX', '/mnt/volume/shared/data_file/data/control/UOU', '/mnt/volume/shared/data_file/data/control/AVL', '/mnt/volume/shared/data_file/data/control/WSD', '/mnt/volume/shared/data_file/data/control/ZNK', '/mnt/volume/shared/data_file/data/control/TBZ', '/mnt/volume/shared/data_file/data/control/RDV', '/mnt/volume/shared/data_file/data/control/MKF', '/mnt/volume/shared/data_file/data/control/LCW', '/mnt/volume/shared/data_file/data/control/XXJ', '/mnt/volume/shared/data_file/data/control/YWQ', '/mnt/volume/shared/data_file/data/control/DNX', '/mnt/volume/shared/data_file/data/control/ZNL', '/mnt/volume/shared/data_file/data/control/UBG', '/mnt/volume/shared/data_file/data/control/GJZ', '/mnt/volume/shared/data_file/data/control/IPY', '/mnt/volume/shared/data_file/data/control/YXY', '/mnt/volume/shared/data_file/data/control/NOL', '/mnt/volume/shared/data_file/data/control/NFI', '/mnt/volume/shared/data_file/data/control/VPN', '/mnt/volume/shared/data_file/data/control/CDA', '/mnt/volume/shared/data_file/data/control/FAQ', '/mnt/volume/shared/data_file/data/control/DHE', '/mnt/volume/shared/data_file/data/control/XXI', '/mnt/volume/shared/data_file/data/control/GJQ', '/mnt/volume/shared/data_file/data/control/TVZ', '/mnt/volume/shared/data_file/data/control/CCO', '/mnt/volume/shared/data_file/data/control/GXQ', '/mnt/volume/shared/data_file/data/control/KDW', '/mnt/volume/shared/data_file/data/control/QIZ', '/mnt/volume/shared/data_file/data/control/ORD', '/mnt/volume/shared/data_file/data/control/HQQ', '/mnt/volume/shared/data_file/data/control/AIH', '/mnt/volume/shared/data_file/data/control/NRL', '/mnt/volume/shared/data_file/data/control/OTU', '/mnt/volume/shared/data_file/data/control/YDL', '/mnt/volume/shared/data_file/data/control/MOR', '/mnt/volume/shared/data_file/data/control/ENH', '/mnt/volume/shared/data_file/data/control/LAM', '/mnt/volume/shared/data_file/data/control/WOA', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_32', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_41', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_41', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_23', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_32', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_41', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_18', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_23'], 'RUNX1_RUNX1T1': ['/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/ONF', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/KRG', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/BOE', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/SWN', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/RHX', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/IIG', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/ILZ', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/GUE', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/XOB', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/VXU', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/UWF', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/VMO', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/RGG', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/XTK', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/NRB', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/LPA', '/mnt/volume/sha ...
# Save file paths for uncertain patients in /mnt/volume/shared/data_file/mixed_uncertain_seed1/ sum_20_percent
# {'control': ['/mnt/volume/shared/data_file/data/control/CIQ', '/mnt/volume/shared/data_file/data/control/FDW', '/mnt/volume/shared/data_file/data/control/ICS', '/mnt/volume/shared/data_file/data/control/WXO', '/mnt/volume/shared/data_file/data/control/NXO', '/mnt/volume/shared/data_file/data/control/ATM', '/mnt/volume/shared/data_file/data/control/MPP', '/mnt/volume/shared/data_file/data/control/DJJ', '/mnt/volume/shared/data_file/data/control/UNX', '/mnt/volume/shared/data_file/data/control/UOU', '/mnt/volume/shared/data_file/data/control/AVL', '/mnt/volume/shared/data_file/data/control/WSD', '/mnt/volume/shared/data_file/data/control/ZNK', '/mnt/volume/shared/data_file/data/control/TBZ', '/mnt/volume/shared/data_file/data/control/RDV', '/mnt/volume/shared/data_file/data/control/MKF', '/mnt/volume/shared/data_file/data/control/LCW', '/mnt/volume/shared/data_file/data/control/XXJ', '/mnt/volume/shared/data_file/data/control/YWQ', '/mnt/volume/shared/data_file/data/control/DNX', '/mnt/volume/shared/data_file/data/control/ZNL', '/mnt/volume/shared/data_file/data/control/UBG', '/mnt/volume/shared/data_file/data/control/GJZ', '/mnt/volume/shared/data_file/data/control/IPY', '/mnt/volume/shared/data_file/data/control/YXY', '/mnt/volume/shared/data_file/data/control/NOL', '/mnt/volume/shared/data_file/data/control/NFI', '/mnt/volume/shared/data_file/data/control/VPN', '/mnt/volume/shared/data_file/data/control/CDA', '/mnt/volume/shared/data_file/data/control/FAQ', '/mnt/volume/shared/data_file/data/control/DHE', '/mnt/volume/shared/data_file/data/control/XXI', '/mnt/volume/shared/data_file/data/control/GJQ', '/mnt/volume/shared/data_file/data/control/TVZ', '/mnt/volume/shared/data_file/data/control/CCO', '/mnt/volume/shared/data_file/data/control/GXQ', '/mnt/volume/shared/data_file/data/control/KDW', '/mnt/volume/shared/data_file/data/control/QIZ', '/mnt/volume/shared/data_file/data/control/ORD', '/mnt/volume/shared/data_file/data/control/HQQ', '/mnt/volume/shared/data_file/data/control/AIH', '/mnt/volume/shared/data_file/data/control/NRL', '/mnt/volume/shared/data_file/data/control/OTU', '/mnt/volume/shared/data_file/data/control/YDL', '/mnt/volume/shared/data_file/data/control/MOR', '/mnt/volume/shared/data_file/data/control/ENH', '/mnt/volume/shared/data_file/data/control/LAM', '/mnt/volume/shared/data_file/data/control/WOA', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_32', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_41', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_41', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_23', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_32', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_41', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_18', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_23', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_41', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_23', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_17', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_18'], 'RUNX1_RUNX1T1': ['/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/ONF', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/KRG', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/BOE', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/SWN', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/RHX', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/IIG', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/ILZ', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/GUE', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/XOB', '/mnt/volume/shared/data_file/data/RUNX1_ ...
# Save file paths for uncertain patients in /mnt/volume/shared/data_file/mixed_uncertain_seed1/misscl_30_percent
# {'control': ['/mnt/volume/shared/data_file/data/control/CIQ', '/mnt/volume/shared/data_file/data/control/FDW', '/mnt/volume/shared/data_file/data/control/ICS', '/mnt/volume/shared/data_file/data/control/WXO', '/mnt/volume/shared/data_file/data/control/NXO', '/mnt/volume/shared/data_file/data/control/ATM', '/mnt/volume/shared/data_file/data/control/MPP', '/mnt/volume/shared/data_file/data/control/DJJ', '/mnt/volume/shared/data_file/data/control/UNX', '/mnt/volume/shared/data_file/data/control/UOU', '/mnt/volume/shared/data_file/data/control/AVL', '/mnt/volume/shared/data_file/data/control/WSD', '/mnt/volume/shared/data_file/data/control/ZNK', '/mnt/volume/shared/data_file/data/control/TBZ', '/mnt/volume/shared/data_file/data/control/RDV', '/mnt/volume/shared/data_file/data/control/MKF', '/mnt/volume/shared/data_file/data/control/LCW', '/mnt/volume/shared/data_file/data/control/XXJ', '/mnt/volume/shared/data_file/data/control/YWQ', '/mnt/volume/shared/data_file/data/control/DNX', '/mnt/volume/shared/data_file/data/control/ZNL', '/mnt/volume/shared/data_file/data/control/UBG', '/mnt/volume/shared/data_file/data/control/GJZ', '/mnt/volume/shared/data_file/data/control/IPY', '/mnt/volume/shared/data_file/data/control/YXY', '/mnt/volume/shared/data_file/data/control/NOL', '/mnt/volume/shared/data_file/data/control/NFI', '/mnt/volume/shared/data_file/data/control/VPN', '/mnt/volume/shared/data_file/data/control/CDA', '/mnt/volume/shared/data_file/data/control/FAQ', '/mnt/volume/shared/data_file/data/control/DHE', '/mnt/volume/shared/data_file/data/control/XXI', '/mnt/volume/shared/data_file/data/control/GJQ', '/mnt/volume/shared/data_file/data/control/TVZ', '/mnt/volume/shared/data_file/data/control/CCO', '/mnt/volume/shared/data_file/data/control/GXQ', '/mnt/volume/shared/data_file/data/control/KDW', '/mnt/volume/shared/data_file/data/control/QIZ', '/mnt/volume/shared/data_file/data/control/ORD', '/mnt/volume/shared/data_file/data/control/HQQ', '/mnt/volume/shared/data_file/data/control/AIH', '/mnt/volume/shared/data_file/data/control/NRL', '/mnt/volume/shared/data_file/data/control/OTU', '/mnt/volume/shared/data_file/data/control/YDL', '/mnt/volume/shared/data_file/data/control/MOR', '/mnt/volume/shared/data_file/data/control/ENH', '/mnt/volume/shared/data_file/data/control/LAM', '/mnt/volume/shared/data_file/data/control/WOA', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_32', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_41', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_41', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_23', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_32', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_41', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_18', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_23', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_41', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_23', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_17', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_18', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_32', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_23'], 'RUNX1_RUNX1T1': ['/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/ONF', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/KRG', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/BOE', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/SWN', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/RHX', '/mnt/volume/shared/data_file/data/RUNX1_RUNX1T1/IIG', '/mnt/volume/shared/data_f ...
# Save file paths for uncertain patients in /mnt/volume/shared/data_file/mixed_uncertain_seed1/max_30_percent
# {'control': ['/mnt/volume/shared/data_file/data/control/CIQ', '/mnt/volume/shared/data_file/data/control/FDW', '/mnt/volume/shared/data_file/data/control/ICS', '/mnt/volume/shared/data_file/data/control/WXO', '/mnt/volume/shared/data_file/data/control/NXO', '/mnt/volume/shared/data_file/data/control/ATM', '/mnt/volume/shared/data_file/data/control/MPP', '/mnt/volume/shared/data_file/data/control/DJJ', '/mnt/volume/shared/data_file/data/control/UNX', '/mnt/volume/shared/data_file/data/control/UOU', '/mnt/volume/shared/data_file/data/control/AVL', '/mnt/volume/shared/data_file/data/control/WSD', '/mnt/volume/shared/data_file/data/control/ZNK', '/mnt/volume/shared/data_file/data/control/TBZ', '/mnt/volume/shared/data_file/data/control/RDV', '/mnt/volume/shared/data_file/data/control/MKF', '/mnt/volume/shared/data_file/data/control/LCW', '/mnt/volume/shared/data_file/data/control/XXJ', '/mnt/volume/shared/data_file/data/control/YWQ', '/mnt/volume/shared/data_file/data/control/DNX', '/mnt/volume/shared/data_file/data/control/ZNL', '/mnt/volume/shared/data_file/data/control/UBG', '/mnt/volume/shared/data_file/data/control/GJZ', '/mnt/volume/shared/data_file/data/control/IPY', '/mnt/volume/shared/data_file/data/control/YXY', '/mnt/volume/shared/data_file/data/control/NOL', '/mnt/volume/shared/data_file/data/control/NFI', '/mnt/volume/shared/data_file/data/control/VPN', '/mnt/volume/shared/data_file/data/control/CDA', '/mnt/volume/shared/data_file/data/control/FAQ', '/mnt/volume/shared/data_file/data/control/DHE', '/mnt/volume/shared/data_file/data/control/XXI', '/mnt/volume/shared/data_file/data/control/GJQ', '/mnt/volume/shared/data_file/data/control/TVZ', '/mnt/volume/shared/data_file/data/control/CCO', '/mnt/volume/shared/data_file/data/control/GXQ', '/mnt/volume/shared/data_file/data/control/KDW', '/mnt/volume/shared/data_file/data/control/QIZ', '/mnt/volume/shared/data_file/data/control/ORD', '/mnt/volume/shared/data_file/data/control/HQQ', '/mnt/volume/shared/data_file/data/control/AIH', '/mnt/volume/shared/data_file/data/control/NRL', '/mnt/volume/shared/data_file/data/control/OTU', '/mnt/volume/shared/data_file/data/control/YDL', '/mnt/volume/shared/data_file/data/control/MOR', '/mnt/volume/shared/data_file/data/control/ENH', '/mnt/volume/shared/data_file/data/control/LAM', '/mnt/volume/shared/data_file/data/control/WOA', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_32', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_41', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_41', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_23', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_32', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_41', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_18', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_23', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_41', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_23', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_17', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_18', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_32', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_23', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_41', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_18', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_23', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_17', '/mnt/volume/sh ...
# Save file paths for uncertain patients in /mnt/volume/shared/data_file/mixed_uncertain_seed1/ sum_30_percent
# {'control': ['/mnt/volume/shared/data_file/data/control/CIQ', '/mnt/volume/shared/data_file/data/control/FDW', '/mnt/volume/shared/data_file/data/control/ICS', '/mnt/volume/shared/data_file/data/control/WXO', '/mnt/volume/shared/data_file/data/control/NXO', '/mnt/volume/shared/data_file/data/control/ATM', '/mnt/volume/shared/data_file/data/control/MPP', '/mnt/volume/shared/data_file/data/control/DJJ', '/mnt/volume/shared/data_file/data/control/UNX', '/mnt/volume/shared/data_file/data/control/UOU', '/mnt/volume/shared/data_file/data/control/AVL', '/mnt/volume/shared/data_file/data/control/WSD', '/mnt/volume/shared/data_file/data/control/ZNK', '/mnt/volume/shared/data_file/data/control/TBZ', '/mnt/volume/shared/data_file/data/control/RDV', '/mnt/volume/shared/data_file/data/control/MKF', '/mnt/volume/shared/data_file/data/control/LCW', '/mnt/volume/shared/data_file/data/control/XXJ', '/mnt/volume/shared/data_file/data/control/YWQ', '/mnt/volume/shared/data_file/data/control/DNX', '/mnt/volume/shared/data_file/data/control/ZNL', '/mnt/volume/shared/data_file/data/control/UBG', '/mnt/volume/shared/data_file/data/control/GJZ', '/mnt/volume/shared/data_file/data/control/IPY', '/mnt/volume/shared/data_file/data/control/YXY', '/mnt/volume/shared/data_file/data/control/NOL', '/mnt/volume/shared/data_file/data/control/NFI', '/mnt/volume/shared/data_file/data/control/VPN', '/mnt/volume/shared/data_file/data/control/CDA', '/mnt/volume/shared/data_file/data/control/FAQ', '/mnt/volume/shared/data_file/data/control/DHE', '/mnt/volume/shared/data_file/data/control/XXI', '/mnt/volume/shared/data_file/data/control/GJQ', '/mnt/volume/shared/data_file/data/control/TVZ', '/mnt/volume/shared/data_file/data/control/CCO', '/mnt/volume/shared/data_file/data/control/GXQ', '/mnt/volume/shared/data_file/data/control/KDW', '/mnt/volume/shared/data_file/data/control/QIZ', '/mnt/volume/shared/data_file/data/control/ORD', '/mnt/volume/shared/data_file/data/control/HQQ', '/mnt/volume/shared/data_file/data/control/AIH', '/mnt/volume/shared/data_file/data/control/NRL', '/mnt/volume/shared/data_file/data/control/OTU', '/mnt/volume/shared/data_file/data/control/YDL', '/mnt/volume/shared/data_file/data/control/MOR', '/mnt/volume/shared/data_file/data/control/ENH', '/mnt/volume/shared/data_file/data/control/LAM', '/mnt/volume/shared/data_file/data/control/WOA', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_32', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_41', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_41', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_23', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_32', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_41', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_18', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_23', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_41', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_23', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_17', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_18', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_32', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_23', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_41', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_18', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_23', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_17', '/mnt/volume/sh ...
# Save file paths for uncertain patients in /mnt/volume/shared/data_file/mixed_uncertain_seed1/misscl_40_percent
# {'control': ['/mnt/volume/shared/data_file/data/control/CIQ', '/mnt/volume/shared/data_file/data/control/FDW', '/mnt/volume/shared/data_file/data/control/ICS', '/mnt/volume/shared/data_file/data/control/WXO', '/mnt/volume/shared/data_file/data/control/NXO', '/mnt/volume/shared/data_file/data/control/ATM', '/mnt/volume/shared/data_file/data/control/MPP', '/mnt/volume/shared/data_file/data/control/DJJ', '/mnt/volume/shared/data_file/data/control/UNX', '/mnt/volume/shared/data_file/data/control/UOU', '/mnt/volume/shared/data_file/data/control/AVL', '/mnt/volume/shared/data_file/data/control/WSD', '/mnt/volume/shared/data_file/data/control/ZNK', '/mnt/volume/shared/data_file/data/control/TBZ', '/mnt/volume/shared/data_file/data/control/RDV', '/mnt/volume/shared/data_file/data/control/MKF', '/mnt/volume/shared/data_file/data/control/LCW', '/mnt/volume/shared/data_file/data/control/XXJ', '/mnt/volume/shared/data_file/data/control/YWQ', '/mnt/volume/shared/data_file/data/control/DNX', '/mnt/volume/shared/data_file/data/control/ZNL', '/mnt/volume/shared/data_file/data/control/UBG', '/mnt/volume/shared/data_file/data/control/GJZ', '/mnt/volume/shared/data_file/data/control/IPY', '/mnt/volume/shared/data_file/data/control/YXY', '/mnt/volume/shared/data_file/data/control/NOL', '/mnt/volume/shared/data_file/data/control/NFI', '/mnt/volume/shared/data_file/data/control/VPN', '/mnt/volume/shared/data_file/data/control/CDA', '/mnt/volume/shared/data_file/data/control/FAQ', '/mnt/volume/shared/data_file/data/control/DHE', '/mnt/volume/shared/data_file/data/control/XXI', '/mnt/volume/shared/data_file/data/control/GJQ', '/mnt/volume/shared/data_file/data/control/TVZ', '/mnt/volume/shared/data_file/data/control/CCO', '/mnt/volume/shared/data_file/data/control/GXQ', '/mnt/volume/shared/data_file/data/control/KDW', '/mnt/volume/shared/data_file/data/control/QIZ', '/mnt/volume/shared/data_file/data/control/ORD', '/mnt/volume/shared/data_file/data/control/HQQ', '/mnt/volume/shared/data_file/data/control/AIH', '/mnt/volume/shared/data_file/data/control/NRL', '/mnt/volume/shared/data_file/data/control/OTU', '/mnt/volume/shared/data_file/data/control/YDL', '/mnt/volume/shared/data_file/data/control/MOR', '/mnt/volume/shared/data_file/data/control/ENH', '/mnt/volume/shared/data_file/data/control/LAM', '/mnt/volume/shared/data_file/data/control/WOA', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_32', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_41', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_41', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_23', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_32', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_41', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_18', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_23', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_41', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_23', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_17', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_18', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_32', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_23', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_41', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_18', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_23', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_17', '/mnt/volume/sh ...
# Save file paths for uncertain patients in /mnt/volume/shared/data_file/mixed_uncertain_seed1/max_40_percent
# {'control': ['/mnt/volume/shared/data_file/data/control/CIQ', '/mnt/volume/shared/data_file/data/control/FDW', '/mnt/volume/shared/data_file/data/control/ICS', '/mnt/volume/shared/data_file/data/control/WXO', '/mnt/volume/shared/data_file/data/control/NXO', '/mnt/volume/shared/data_file/data/control/ATM', '/mnt/volume/shared/data_file/data/control/MPP', '/mnt/volume/shared/data_file/data/control/DJJ', '/mnt/volume/shared/data_file/data/control/UNX', '/mnt/volume/shared/data_file/data/control/UOU', '/mnt/volume/shared/data_file/data/control/AVL', '/mnt/volume/shared/data_file/data/control/WSD', '/mnt/volume/shared/data_file/data/control/ZNK', '/mnt/volume/shared/data_file/data/control/TBZ', '/mnt/volume/shared/data_file/data/control/RDV', '/mnt/volume/shared/data_file/data/control/MKF', '/mnt/volume/shared/data_file/data/control/LCW', '/mnt/volume/shared/data_file/data/control/XXJ', '/mnt/volume/shared/data_file/data/control/YWQ', '/mnt/volume/shared/data_file/data/control/DNX', '/mnt/volume/shared/data_file/data/control/ZNL', '/mnt/volume/shared/data_file/data/control/UBG', '/mnt/volume/shared/data_file/data/control/GJZ', '/mnt/volume/shared/data_file/data/control/IPY', '/mnt/volume/shared/data_file/data/control/YXY', '/mnt/volume/shared/data_file/data/control/NOL', '/mnt/volume/shared/data_file/data/control/NFI', '/mnt/volume/shared/data_file/data/control/VPN', '/mnt/volume/shared/data_file/data/control/CDA', '/mnt/volume/shared/data_file/data/control/FAQ', '/mnt/volume/shared/data_file/data/control/DHE', '/mnt/volume/shared/data_file/data/control/XXI', '/mnt/volume/shared/data_file/data/control/GJQ', '/mnt/volume/shared/data_file/data/control/TVZ', '/mnt/volume/shared/data_file/data/control/CCO', '/mnt/volume/shared/data_file/data/control/GXQ', '/mnt/volume/shared/data_file/data/control/KDW', '/mnt/volume/shared/data_file/data/control/QIZ', '/mnt/volume/shared/data_file/data/control/ORD', '/mnt/volume/shared/data_file/data/control/HQQ', '/mnt/volume/shared/data_file/data/control/AIH', '/mnt/volume/shared/data_file/data/control/NRL', '/mnt/volume/shared/data_file/data/control/OTU', '/mnt/volume/shared/data_file/data/control/YDL', '/mnt/volume/shared/data_file/data/control/MOR', '/mnt/volume/shared/data_file/data/control/ENH', '/mnt/volume/shared/data_file/data/control/LAM', '/mnt/volume/shared/data_file/data/control/WOA', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_32', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_41', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_41', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_23', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_32', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_41', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_18', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_23', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_41', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_23', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_17', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_18', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_32', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_23', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_41', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_18', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_23', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_17', '/mnt/volume/sh ...
# Save file paths for uncertain patients in /mnt/volume/shared/data_file/mixed_uncertain_seed1/ sum_40_percent
# {'control': ['/mnt/volume/shared/data_file/data/control/CIQ', '/mnt/volume/shared/data_file/data/control/FDW', '/mnt/volume/shared/data_file/data/control/ICS', '/mnt/volume/shared/data_file/data/control/WXO', '/mnt/volume/shared/data_file/data/control/NXO', '/mnt/volume/shared/data_file/data/control/ATM', '/mnt/volume/shared/data_file/data/control/MPP', '/mnt/volume/shared/data_file/data/control/DJJ', '/mnt/volume/shared/data_file/data/control/UNX', '/mnt/volume/shared/data_file/data/control/UOU', '/mnt/volume/shared/data_file/data/control/AVL', '/mnt/volume/shared/data_file/data/control/WSD', '/mnt/volume/shared/data_file/data/control/ZNK', '/mnt/volume/shared/data_file/data/control/TBZ', '/mnt/volume/shared/data_file/data/control/RDV', '/mnt/volume/shared/data_file/data/control/MKF', '/mnt/volume/shared/data_file/data/control/LCW', '/mnt/volume/shared/data_file/data/control/XXJ', '/mnt/volume/shared/data_file/data/control/YWQ', '/mnt/volume/shared/data_file/data/control/DNX', '/mnt/volume/shared/data_file/data/control/ZNL', '/mnt/volume/shared/data_file/data/control/UBG', '/mnt/volume/shared/data_file/data/control/GJZ', '/mnt/volume/shared/data_file/data/control/IPY', '/mnt/volume/shared/data_file/data/control/YXY', '/mnt/volume/shared/data_file/data/control/NOL', '/mnt/volume/shared/data_file/data/control/NFI', '/mnt/volume/shared/data_file/data/control/VPN', '/mnt/volume/shared/data_file/data/control/CDA', '/mnt/volume/shared/data_file/data/control/FAQ', '/mnt/volume/shared/data_file/data/control/DHE', '/mnt/volume/shared/data_file/data/control/XXI', '/mnt/volume/shared/data_file/data/control/GJQ', '/mnt/volume/shared/data_file/data/control/TVZ', '/mnt/volume/shared/data_file/data/control/CCO', '/mnt/volume/shared/data_file/data/control/GXQ', '/mnt/volume/shared/data_file/data/control/KDW', '/mnt/volume/shared/data_file/data/control/QIZ', '/mnt/volume/shared/data_file/data/control/ORD', '/mnt/volume/shared/data_file/data/control/HQQ', '/mnt/volume/shared/data_file/data/control/AIH', '/mnt/volume/shared/data_file/data/control/NRL', '/mnt/volume/shared/data_file/data/control/OTU', '/mnt/volume/shared/data_file/data/control/YDL', '/mnt/volume/shared/data_file/data/control/MOR', '/mnt/volume/shared/data_file/data/control/ENH', '/mnt/volume/shared/data_file/data/control/LAM', '/mnt/volume/shared/data_file/data/control/WOA', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_32', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_41', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_41', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_23', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_32', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_41', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_18', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_23', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_41', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_23', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_17', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_18', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_32', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_23', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_41', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_18', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_23', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_17', '/mnt/volume/sh ...
# Save file paths for uncertain patients in /mnt/volume/shared/data_file/mixed_uncertain_seed1/misscl_50_percent
# {'control': ['/mnt/volume/shared/data_file/data/control/CIQ', '/mnt/volume/shared/data_file/data/control/FDW', '/mnt/volume/shared/data_file/data/control/ICS', '/mnt/volume/shared/data_file/data/control/WXO', '/mnt/volume/shared/data_file/data/control/NXO', '/mnt/volume/shared/data_file/data/control/ATM', '/mnt/volume/shared/data_file/data/control/MPP', '/mnt/volume/shared/data_file/data/control/DJJ', '/mnt/volume/shared/data_file/data/control/UNX', '/mnt/volume/shared/data_file/data/control/UOU', '/mnt/volume/shared/data_file/data/control/AVL', '/mnt/volume/shared/data_file/data/control/WSD', '/mnt/volume/shared/data_file/data/control/ZNK', '/mnt/volume/shared/data_file/data/control/TBZ', '/mnt/volume/shared/data_file/data/control/RDV', '/mnt/volume/shared/data_file/data/control/MKF', '/mnt/volume/shared/data_file/data/control/LCW', '/mnt/volume/shared/data_file/data/control/XXJ', '/mnt/volume/shared/data_file/data/control/YWQ', '/mnt/volume/shared/data_file/data/control/DNX', '/mnt/volume/shared/data_file/data/control/ZNL', '/mnt/volume/shared/data_file/data/control/UBG', '/mnt/volume/shared/data_file/data/control/GJZ', '/mnt/volume/shared/data_file/data/control/IPY', '/mnt/volume/shared/data_file/data/control/YXY', '/mnt/volume/shared/data_file/data/control/NOL', '/mnt/volume/shared/data_file/data/control/NFI', '/mnt/volume/shared/data_file/data/control/VPN', '/mnt/volume/shared/data_file/data/control/CDA', '/mnt/volume/shared/data_file/data/control/FAQ', '/mnt/volume/shared/data_file/data/control/DHE', '/mnt/volume/shared/data_file/data/control/XXI', '/mnt/volume/shared/data_file/data/control/GJQ', '/mnt/volume/shared/data_file/data/control/TVZ', '/mnt/volume/shared/data_file/data/control/CCO', '/mnt/volume/shared/data_file/data/control/GXQ', '/mnt/volume/shared/data_file/data/control/KDW', '/mnt/volume/shared/data_file/data/control/QIZ', '/mnt/volume/shared/data_file/data/control/ORD', '/mnt/volume/shared/data_file/data/control/HQQ', '/mnt/volume/shared/data_file/data/control/AIH', '/mnt/volume/shared/data_file/data/control/NRL', '/mnt/volume/shared/data_file/data/control/OTU', '/mnt/volume/shared/data_file/data/control/YDL', '/mnt/volume/shared/data_file/data/control/MOR', '/mnt/volume/shared/data_file/data/control/ENH', '/mnt/volume/shared/data_file/data/control/LAM', '/mnt/volume/shared/data_file/data/control/WOA', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_32', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_41', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_41', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_23', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_32', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_41', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_18', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_23', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_41', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_23', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_17', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_18', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_32', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_23', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_41', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_18', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_23', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_17', '/mnt/volume/sh ...
# Save file paths for uncertain patients in /mnt/volume/shared/data_file/mixed_uncertain_seed1/max_50_percent
# {'control': ['/mnt/volume/shared/data_file/data/control/CIQ', '/mnt/volume/shared/data_file/data/control/FDW', '/mnt/volume/shared/data_file/data/control/ICS', '/mnt/volume/shared/data_file/data/control/WXO', '/mnt/volume/shared/data_file/data/control/NXO', '/mnt/volume/shared/data_file/data/control/ATM', '/mnt/volume/shared/data_file/data/control/MPP', '/mnt/volume/shared/data_file/data/control/DJJ', '/mnt/volume/shared/data_file/data/control/UNX', '/mnt/volume/shared/data_file/data/control/UOU', '/mnt/volume/shared/data_file/data/control/AVL', '/mnt/volume/shared/data_file/data/control/WSD', '/mnt/volume/shared/data_file/data/control/ZNK', '/mnt/volume/shared/data_file/data/control/TBZ', '/mnt/volume/shared/data_file/data/control/RDV', '/mnt/volume/shared/data_file/data/control/MKF', '/mnt/volume/shared/data_file/data/control/LCW', '/mnt/volume/shared/data_file/data/control/XXJ', '/mnt/volume/shared/data_file/data/control/YWQ', '/mnt/volume/shared/data_file/data/control/DNX', '/mnt/volume/shared/data_file/data/control/ZNL', '/mnt/volume/shared/data_file/data/control/UBG', '/mnt/volume/shared/data_file/data/control/GJZ', '/mnt/volume/shared/data_file/data/control/IPY', '/mnt/volume/shared/data_file/data/control/YXY', '/mnt/volume/shared/data_file/data/control/NOL', '/mnt/volume/shared/data_file/data/control/NFI', '/mnt/volume/shared/data_file/data/control/VPN', '/mnt/volume/shared/data_file/data/control/CDA', '/mnt/volume/shared/data_file/data/control/FAQ', '/mnt/volume/shared/data_file/data/control/DHE', '/mnt/volume/shared/data_file/data/control/XXI', '/mnt/volume/shared/data_file/data/control/GJQ', '/mnt/volume/shared/data_file/data/control/TVZ', '/mnt/volume/shared/data_file/data/control/CCO', '/mnt/volume/shared/data_file/data/control/GXQ', '/mnt/volume/shared/data_file/data/control/KDW', '/mnt/volume/shared/data_file/data/control/QIZ', '/mnt/volume/shared/data_file/data/control/ORD', '/mnt/volume/shared/data_file/data/control/HQQ', '/mnt/volume/shared/data_file/data/control/AIH', '/mnt/volume/shared/data_file/data/control/NRL', '/mnt/volume/shared/data_file/data/control/OTU', '/mnt/volume/shared/data_file/data/control/YDL', '/mnt/volume/shared/data_file/data/control/MOR', '/mnt/volume/shared/data_file/data/control/ENH', '/mnt/volume/shared/data_file/data/control/LAM', '/mnt/volume/shared/data_file/data/control/WOA', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_32', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_41', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_41', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_23', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_32', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_41', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_18', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_23', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_41', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_23', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_17', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_18', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_32', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_23', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_41', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_18', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_23', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_17', '/mnt/volume/sh ...
# Save file paths for uncertain patients in /mnt/volume/shared/data_file/mixed_uncertain_seed1/ sum_50_percent
# {'control': ['/mnt/volume/shared/data_file/data/control/CIQ', '/mnt/volume/shared/data_file/data/control/FDW', '/mnt/volume/shared/data_file/data/control/ICS', '/mnt/volume/shared/data_file/data/control/WXO', '/mnt/volume/shared/data_file/data/control/NXO', '/mnt/volume/shared/data_file/data/control/ATM', '/mnt/volume/shared/data_file/data/control/MPP', '/mnt/volume/shared/data_file/data/control/DJJ', '/mnt/volume/shared/data_file/data/control/UNX', '/mnt/volume/shared/data_file/data/control/UOU', '/mnt/volume/shared/data_file/data/control/AVL', '/mnt/volume/shared/data_file/data/control/WSD', '/mnt/volume/shared/data_file/data/control/ZNK', '/mnt/volume/shared/data_file/data/control/TBZ', '/mnt/volume/shared/data_file/data/control/RDV', '/mnt/volume/shared/data_file/data/control/MKF', '/mnt/volume/shared/data_file/data/control/LCW', '/mnt/volume/shared/data_file/data/control/XXJ', '/mnt/volume/shared/data_file/data/control/YWQ', '/mnt/volume/shared/data_file/data/control/DNX', '/mnt/volume/shared/data_file/data/control/ZNL', '/mnt/volume/shared/data_file/data/control/UBG', '/mnt/volume/shared/data_file/data/control/GJZ', '/mnt/volume/shared/data_file/data/control/IPY', '/mnt/volume/shared/data_file/data/control/YXY', '/mnt/volume/shared/data_file/data/control/NOL', '/mnt/volume/shared/data_file/data/control/NFI', '/mnt/volume/shared/data_file/data/control/VPN', '/mnt/volume/shared/data_file/data/control/CDA', '/mnt/volume/shared/data_file/data/control/FAQ', '/mnt/volume/shared/data_file/data/control/DHE', '/mnt/volume/shared/data_file/data/control/XXI', '/mnt/volume/shared/data_file/data/control/GJQ', '/mnt/volume/shared/data_file/data/control/TVZ', '/mnt/volume/shared/data_file/data/control/CCO', '/mnt/volume/shared/data_file/data/control/GXQ', '/mnt/volume/shared/data_file/data/control/KDW', '/mnt/volume/shared/data_file/data/control/QIZ', '/mnt/volume/shared/data_file/data/control/ORD', '/mnt/volume/shared/data_file/data/control/HQQ', '/mnt/volume/shared/data_file/data/control/AIH', '/mnt/volume/shared/data_file/data/control/NRL', '/mnt/volume/shared/data_file/data/control/OTU', '/mnt/volume/shared/data_file/data/control/YDL', '/mnt/volume/shared/data_file/data/control/MOR', '/mnt/volume/shared/data_file/data/control/ENH', '/mnt/volume/shared/data_file/data/control/LAM', '/mnt/volume/shared/data_file/data/control/WOA', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_32', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_41', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_41', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_23', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_32', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_41', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_18', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_23', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_41', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_23', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_17', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_18', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_32', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_23', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_41', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_18', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_23', '/mnt/volume/shared/data_file/artificialdata/experiment_3_seed1/data/control/patient_17', '/mnt/volume/sh ...

# %%
def concatenate_metadata(original_metadata_path,uncertain_patients_folder):
    # Load the original metadata CSV file
    original_metadata_df = pd.read_csv(original_metadata_path)

    # Loop over folders in uncertain_patients
    for folder in os.listdir(uncertain_patients_folder):
        folder_path = os.path.join(uncertain_patients_folder, folder)
        print(folder_path)

        # Check if the item in the uncertain_patients_folder is a directory
        if os.path.isdir(folder_path):
            # Look for metadata.csv in each folder
            metadata_file_path = os.path.join(folder_path, 'metadata.csv')
            print("metadata is:")
            print(metadata_file_path)

            if os.path.exists(metadata_file_path):
                # Load the metadata from the current folder
                uncertain_metadata_df = pd.read_csv(metadata_file_path)

                # Concatenate with the original metadata
                concatenated_metadata_df = pd.concat([original_metadata_df, uncertain_metadata_df], ignore_index=True)
                print(metadata_file_path)
                # Save the concatenated metadata to a new CSV file in the output folder
                output_folder_new = uncertain_patients_folder + f'/{folder}'
                os.makedirs(output_folder_new, exist_ok=True)
                output_file_path = os.path.join(output_folder_new, 'metadata.csv')
                print("Output is:")
                print(output_file_path)
                concatenated_metadata_df.to_csv(output_file_path, index=False)

# %%
original_metadata_path="/mnt/volume/shared/data_file/metadata.csv"
concatenate_metadata(original_metadata_path,output_folder)
# Out:
# /mnt/volume/shared/data_file/mixed_uncertain_seed1/misscl_30_percent
# metadata is:
# /mnt/volume/shared/data_file/mixed_uncertain_seed1/misscl_30_percent/metadata.csv
# /mnt/volume/shared/data_file/mixed_uncertain_seed1/misscl_30_percent/metadata.csv
# Output is:
# /mnt/volume/shared/data_file/mixed_uncertain_seed1/misscl_30_percent/metadata.csv
# /mnt/volume/shared/data_file/mixed_uncertain_seed1/max_20_percent
# metadata is:
# /mnt/volume/shared/data_file/mixed_uncertain_seed1/max_20_percent/metadata.csv
# /mnt/volume/shared/data_file/mixed_uncertain_seed1/max_20_percent/metadata.csv
# Output is:
# /mnt/volume/shared/data_file/mixed_uncertain_seed1/max_20_percent/metadata.csv
# /mnt/volume/shared/data_file/mixed_uncertain_seed1/misscl_20_percent
# metadata is:
# /mnt/volume/shared/data_file/mixed_uncertain_seed1/misscl_20_percent/metadata.csv
# /mnt/volume/shared/data_file/mixed_uncertain_seed1/misscl_20_percent/metadata.csv
# Output is:
# /mnt/volume/shared/data_file/mixed_uncertain_seed1/misscl_20_percent/metadata.csv
# /mnt/volume/shared/data_file/mixed_uncertain_seed1/ sum_50_percent
# metadata is:
# /mnt/volume/shared/data_file/mixed_uncertain_seed1/ sum_50_percent/metadata.csv
# /mnt/volume/shared/data_file/mixed_uncertain_seed1/ sum_50_percent/metadata.csv
# Output is:
# /mnt/volume/shared/data_file/mixed_uncertain_seed1/ sum_50_percent/metadata.csv
# /mnt/volume/shared/data_file/mixed_uncertain_seed1/max_50_percent
# metadata is:
# /mnt/volume/shared/data_file/mixed_uncertain_seed1/max_50_percent/metadata.csv
# /mnt/volume/shared/data_file/mixed_uncertain_seed1/max_50_percent/metadata.csv
# Output is:
# /mnt/volume/shared/data_file/mixed_uncertain_seed1/max_50_percent/metadata.csv
# /mnt/volume/shared/data_file/mixed_uncertain_seed1/ sum_10_percent
# metadata is:
# /mnt/volume/shared/data_file/mixed_uncertain_seed1/ sum_10_percent/metadata.csv
# /mnt/volume/shared/data_file/mixed_uncertain_seed1/ sum_10_percent/metadata.csv
# Output is:
# /mnt/volume/shared/data_file/mixed_uncertain_seed1/ sum_10_percent/metadata.csv
# /mnt/volume/shared/data_file/mixed_uncertain_seed1/ sum_40_percent
# metadata is:
# /mnt/volume/shared/data_file/mixed_uncertain_seed1/ sum_40_percent/metadata.csv
# /mnt/volume/shared/data_file/mixed_uncertain_seed1/ sum_40_percent/metadata.csv
# Output is:
# /mnt/volume/shared/data_file/mixed_uncertain_seed1/ sum_40_percent/metadata.csv
# /mnt/volume/shared/data_file/mixed_uncertain_seed1/misscl_40_percent
# metadata is:
# /mnt/volume/shared/data_file/mixed_uncertain_seed1/misscl_40_percent/metadata.csv
# /mnt/volume/shared/data_file/mixed_uncertain_seed1/misscl_40_percent/metadata.csv
# Output is:
# /mnt/volume/shared/data_file/mixed_uncertain_seed1/misscl_40_percent/metadata.csv
# /mnt/volume/shared/data_file/mixed_uncertain_seed1/ sum_30_percent
# metadata is:
# /mnt/volume/shared/data_file/mixed_uncertain_seed1/ sum_30_percent/metadata.csv
# /mnt/volume/shared/data_file/mixed_uncertain_seed1/ sum_30_percent/metadata.csv
# Output is:
# /mnt/volume/shared/data_file/mixed_uncertain_seed1/ sum_30_percent/metadata.csv
# /mnt/volume/shared/data_file/mixed_uncertain_seed1/max_40_percent
# metadata is:
# /mnt/volume/shared/data_file/mixed_uncertain_seed1/max_40_percent/metadata.csv
# /mnt/volume/shared/data_file/mixed_uncertain_seed1/max_40_percent/metadata.csv
# Output is:
# /mnt/volume/shared/data_file/mixed_uncertain_seed1/max_40_percent/metadata.csv
# /mnt/volume/shared/data_file/mixed_uncertain_seed1/ sum_20_percent
# metadata is:
# /mnt/volume/shared/data_file/mixed_uncertain_seed1/ sum_20_percent/metadata.csv
# /mnt/volume/shared/data_file/mixed_uncertain_seed1/ sum_20_percent/metadata.csv
# Output is:
# /mnt/volume/shared/data_file/mixed_uncertain_seed1/ sum_20_percent/metadata.csv
# /mnt/volume/shared/data_file/mixed_uncertain_seed1/max_30_percent
# metadata is:
# /mnt/volume/shared/data_file/mixed_uncertain_seed1/max_30_percent/metadata.csv
# /mnt/volume/shared/data_file/mixed_uncertain_seed1/max_30_percent/metadata.csv
# Output is:
# /mnt/volume/shared/data_file/mixed_uncertain_seed1/max_30_percent/metadata.csv
# /mnt/volume/shared/data_file/mixed_uncertain_seed1/misscl_50_percent
# metadata is:
# /mnt/volume/shared/data_file/mixed_uncertain_seed1/misscl_50_percent/metadata.csv
# /mnt/volume/shared/data_file/mixed_uncertain_seed1/misscl_50_percent/metadata.csv
# Output is:
# /mnt/volume/shared/data_file/mixed_uncertain_seed1/misscl_50_percent/metadata.csv
# /mnt/volume/shared/data_file/mixed_uncertain_seed1/misscl_10_percent
# metadata is:
# /mnt/volume/shared/data_file/mixed_uncertain_seed1/misscl_10_percent/metadata.csv
# /mnt/volume/shared/data_file/mixed_uncertain_seed1/misscl_10_percent/metadata.csv
# Output is:
# /mnt/volume/shared/data_file/mixed_uncertain_seed1/misscl_10_percent/metadata.csv
# /mnt/volume/shared/data_file/mixed_uncertain_seed1/max_10_percent
# metadata is:
# /mnt/volume/shared/data_file/mixed_uncertain_seed1/max_10_percent/metadata.csv
# /mnt/volume/shared/data_file/mixed_uncertain_seed1/max_10_percent/metadata.csv
# Output is:
# /mnt/volume/shared/data_file/mixed_uncertain_seed1/max_10_percent/metadata.csv
