# %%
#same as plot.ipynb but with artificial data

import matplotlib.pyplot as plt
import numpy as np
import os
from matplotlib.cm import get_cmap
from matplotlib.lines import Line2D
import pickle
import re

# Path to the folder containing your subfolders
data_path = '../../artificialdata/experiment_2/data'

# %%
def get_counts_vector(labels_vector):
    unique_labels, label_counts = np.unique(labels_vector, return_counts=True)
    counts_vector = np.zeros(22, dtype=int)
    counts_vector[unique_labels] = label_counts
    return counts_vector, unique_labels


def get_patient_name(path):
    return re.search(r"/data/\w+/([A-Z]{3})", path).group(1)

def get_class_name(path):
    return re.search(r"/data/(\w+)", path).group(1)

def get_image_number(path):
    print(path)
    return int(re.search(r"image_(\d+).tif", path).group(1))
   

def get_classification_patient(patient_folder):
    probs_path = patient_folder + '/single_cell_probabilities.npy'
    sc_probs = np.load(probs_path)
    sc_class= np.argmax(sc_probs, axis=1)
    return sc_class

'''def save_single_cell_probabilities(data, folder_patient):
    # Create single cell probalities for specific artificial patient
    artificial_folder_path = "../../artificialdata/experiment_3/data/CBFB_MYH11/patient_1"
    with open( os.path.join(artificial_folder_path,"image_file_paths") ,'rb') as fp:
        image_file_paths=pickle.load(fp)

    prev_subtype= get_class_name(image_file_paths[0]) 
    prev_patient = get_patient_name(image_file_paths[0])
    probs_path = data_path +"/"+ prev_subtype +"/"+ prev_patient+'/single_cell_probabilities.npy'

    sc_probs_artificial_list=[]
    for image_path in image_file_paths:
        aml_subtype = get_class_name(image_path)    
        patient = get_patient_name(image_path)   
        image_number = get_image_number(image_path)
        if aml_subtype!=prev_subtype or prev_patient!=patient:
            probs_path = data_path +"/"+ aml_subtype +"/"+ patient+'/single_cell_probabilities.npy'
        prev_patient=patient
        prev_subtype=aml_subtype
        sc_probs = np.load(probs_path)[image_number]
        sc_probs_artificial_list.append([sc_probs])
    sc_probs_artificial = np.concatenate(sc_probs_artificial_list,axis=0)    

    np.save(artificial_folder_path+"/single_cell_probabilities.npy", sc_probs_artificial)'''

def save_single_cell_probabilities(data_folder_real, patient_folder_art):
# Create single cell probabilities for a specific patient
   
    print(patient_folder_art)
    with open(os.path.join(patient_folder_art, "image_file_paths"), 'rb') as fp:
        image_file_paths = pickle.load(fp)

    prev_subtype = get_class_name(image_file_paths[0])
    prev_patient = get_patient_name(image_file_paths[0])
    probs_path = os.path.join(data_folder_real, prev_subtype, prev_patient, 'single_cell_probabilities.npy')

    sc_probs_artificial_list = []

    for image_path in image_file_paths:
        aml_subtype = get_class_name(image_path)
        patient = get_patient_name(image_path)
        image_number = get_image_number(image_path)

        if aml_subtype != prev_subtype or prev_patient != patient:
            probs_path = os.path.join(data_folder_real, aml_subtype, patient, 'single_cell_probabilities.npy')
        print(f"Probspath: ",probs_path, "Patient: ",patient, "image: ", image_number, "AML subtype: ", aml_subtype)
        prev_patient = patient
        prev_subtype = aml_subtype
        sc_probs = np.load(probs_path)[image_number]
        sc_probs_artificial_list.append([sc_probs])

    sc_probs_artificial = np.concatenate(sc_probs_artificial_list, axis=0)

    np.save(os.path.join(patient_folder_art, "single_cell_probabilities.npy"), sc_probs_artificial)

# %%
data_path_art = "../../artificialdata/experiment_3/data"
data_path_real="../../data"
for data_folder in os.listdir(data_path_art):
        data_folder_path = os.path.join(data_path_art, data_folder)

        # Check if the item in the directory is a folder
        if os.path.isdir(data_folder_path):
            print(data_folder)
            # Iterate over all patients within each data folder
            for patient_folder in os.listdir(data_folder_path):
              
                patient_folder=os.path.join(data_folder_path,patient_folder)
                print(patient_folder)
                save_single_cell_probabilities(data_path_real, patient_folder)
# Out:
# PML_RARA
# ../../artificialdata/experiment_3/data/PML_RARA/patient_2
# ../../artificialdata/experiment_3/data/PML_RARA/patient_2
# ../../data/CBFB_MYH11/AQK/image_13.tif
# Probspath:  ../../data/CBFB_MYH11/AQK/single_cell_probabilities.npy Patient:  AQK image:  13 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/AQK/image_13.tif
# Probspath:  ../../data/CBFB_MYH11/AQK/single_cell_probabilities.npy Patient:  AQK image:  13 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/AQK/image_18.tif
# Probspath:  ../../data/CBFB_MYH11/AQK/single_cell_probabilities.npy Patient:  AQK image:  18 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/AQK/image_307.tif
# Probspath:  ../../data/CBFB_MYH11/AQK/single_cell_probabilities.npy Patient:  AQK image:  307 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/AQK/image_334.tif
# Probspath:  ../../data/CBFB_MYH11/AQK/single_cell_probabilities.npy Patient:  AQK image:  334 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/AQK/image_355.tif
# Probspath:  ../../data/CBFB_MYH11/AQK/single_cell_probabilities.npy Patient:  AQK image:  355 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/AQK/image_380.tif
# Probspath:  ../../data/CBFB_MYH11/AQK/single_cell_probabilities.npy Patient:  AQK image:  380 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/AQK/image_385.tif
# Probspath:  ../../data/CBFB_MYH11/AQK/single_cell_probabilities.npy Patient:  AQK image:  385 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/AQK/image_390.tif
# Probspath:  ../../data/CBFB_MYH11/AQK/single_cell_probabilities.npy Patient:  AQK image:  390 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BJK/image_152.tif
# Probspath:  ../../data/CBFB_MYH11/BJK/single_cell_probabilities.npy Patient:  BJK image:  152 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BJK/image_330.tif
# Probspath:  ../../data/CBFB_MYH11/BJK/single_cell_probabilities.npy Patient:  BJK image:  330 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BJK/image_4.tif
# Probspath:  ../../data/CBFB_MYH11/BJK/single_cell_probabilities.npy Patient:  BJK image:  4 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BJK/image_405.tif
# Probspath:  ../../data/CBFB_MYH11/BJK/single_cell_probabilities.npy Patient:  BJK image:  405 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BJK/image_466.tif
# Probspath:  ../../data/CBFB_MYH11/BJK/single_cell_probabilities.npy Patient:  BJK image:  466 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BSN/image_1.tif
# Probspath:  ../../data/CBFB_MYH11/BSN/single_cell_probabilities.npy Patient:  BSN image:  1 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BSN/image_173.tif
# Probspath:  ../../data/CBFB_MYH11/BSN/single_cell_probabilities.npy Patient:  BSN image:  173 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BSN/image_236.tif
# Probspath:  ../../data/CBFB_MYH11/BSN/single_cell_probabilities.npy Patient:  BSN image:  236 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BSN/image_242.tif
# Probspath:  ../../data/CBFB_MYH11/BSN/single_cell_probabilities.npy Patient:  BSN image:  242 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BSN/image_261.tif
# Probspath:  ../../data/CBFB_MYH11/BSN/single_cell_probabilities.npy Patient:  BSN image:  261 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BSN/image_280.tif
# Probspath:  ../../data/CBFB_MYH11/BSN/single_cell_probabilities.npy Patient:  BSN image:  280 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BSN/image_94.tif
# Probspath:  ../../data/CBFB_MYH11/BSN/single_cell_probabilities.npy Patient:  BSN image:  94 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BTB/image_164.tif
# Probspath:  ../../data/CBFB_MYH11/BTB/single_cell_probabilities.npy Patient:  BTB image:  164 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BTB/image_174.tif
# Probspath:  ../../data/CBFB_MYH11/BTB/single_cell_probabilities.npy Patient:  BTB image:  174 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BTB/image_175.tif
# Probspath:  ../../data/CBFB_MYH11/BTB/single_cell_probabilities.npy Patient:  BTB image:  175 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BTB/image_187.tif
# Probspath:  ../../data/CBFB_MYH11/BTB/single_cell_probabilities.npy Patient:  BTB image:  187 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BTB/image_206.tif
# Probspath:  ../../data/CBFB_MYH11/BTB/single_cell_probabilities.npy Patient:  BTB image:  206 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BTB/image_212.tif
# Probspath:  ../../data/CBFB_MYH11/BTB/single_cell_probabilities.npy Patient:  BTB image:  212 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BTB/image_28.tif
# Probspath:  ../../data/CBFB_MYH11/BTB/single_cell_probabilities.npy Patient:  BTB image:  28 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BTB/image_291.tif
# Probspath:  ../../data/CBFB_MYH11/BTB/single_cell_probabilities.npy Patient:  BTB image:  291 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BTB/image_35.tif
# Probspath:  ../../data/CBFB_MYH11/BTB/single_cell_probabilities.npy Patient:  BTB image:  35 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BTB/image_92.tif
# Probspath:  ../../data/CBFB_MYH11/BTB/single_cell_probabilities.npy Patient:  BTB image:  92 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BTB/image_96.tif
# Probspath:  ../../data/CBFB_MYH11/BTB/single_cell_probabilities.npy Patient:  BTB image:  96 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BTB/image_99.tif
# Probspath:  ../../data/CBFB_MYH11/BTB/single_cell_probabilities.npy Patient:  BTB image:  99 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/DQV/image_118.tif
# Probspath:  ../../data/CBFB_MYH11/DQV/single_cell_probabilities.npy Patient:  DQV image:  118 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/DQV/image_141.tif
# Probspath:  ../../data/CBFB_MYH11/DQV/single_cell_probabilities.npy Patient:  DQV image:  141 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/DQV/image_185.tif
# Probspath:  ../../data/CBFB_MYH11/DQV/single_cell_probabilities.npy Patient:  DQV image:  185 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/DQV/image_289.tif
# Probspath:  ../../data/CBFB_MYH11/DQV/single_cell_probabilities.npy Patient:  DQV image:  289 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/DQV/image_327.tif
# Probspath:  ../../data/CBFB_MYH11/DQV/single_cell_probabilities.npy Patient:  DQV image:  327 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/DQV/image_492.tif
# Probspath:  ../../data/CBFB_MYH11/DQV/single_cell_probabilities.npy Patient:  DQV image:  492 AML subtype:  CBFB_MYH11
# ../../data/NPM1/ALA/image_109.tif
# Probspath:  ../../data/NPM1/ALA/single_cell_probabilities.npy Patient:  ALA image:  109 AML subtype:  NPM1
# ../../data/NPM1/ALA/image_113.tif
# Probspath:  ../../data/NPM1/ALA/single_cell_probabilities.npy Patient:  ALA image:  113 AML subtype:  NPM1
# ../../data/NPM1/ALA/image_128.tif
# Probspath:  ../../data/NPM1/ALA/single_cell_probabilities.npy Patient:  ALA image:  128 AML subtype:  NPM1
# ../../data/NPM1/ALA/image_142.tif
# Probspath:  ../../data/NPM1/ALA/single_cell_probabilities.npy Patient:  ALA image:  142 AML subtype:  NPM1
# ../../data/NPM1/ALA/image_188.tif
# Probspath:  ../../data/NPM1/ALA/single_cell_probabilities.npy Patient:  ALA image:  188 AML subtype:  NPM1
# ../../data/NPM1/ALA/image_220.tif
# Probspath:  ../../data/NPM1/ALA/single_cell_probabilities.npy Patient:  ALA image:  220 AML subtype:  NPM1
# ../../data/NPM1/ALA/image_223.tif
# Probspath:  ../../data/NPM1/ALA/single_cell_probabilities.npy Patient:  ALA image:  223 AML subtype:  NPM1
# ../../data/NPM1/ALA/image_232.tif
# Probspath:  ../../data/NPM1/ALA/single_cell_probabilities.npy Patient:  ALA image:  232 AML subtype:  NPM1
# ../../data/NPM1/ALA/image_29.tif
# Probspath:  ../../data/NPM1/ALA/single_cell_probabilities.npy Patient:  ALA image:  29 AML subtype:  NPM1
# ../../data/NPM1/ALA/image_306.tif
# Probspath:  ../../data/NPM1/ALA/single_cell_probabilities.npy Patient:  ALA image:  306 AML subtype:  NPM1
# ../../data/NPM1/ALA/image_478.tif
# Probspath:  ../../data/NPM1/ALA/single_cell_probabilities.npy Patient:  ALA image:  478 AML subtype:  NPM1
# ../../data/NPM1/ALA/image_492.tif
# Probspath:  ../../data/NPM1/ALA/single_cell_probabilities.npy Patient:  ALA image:  492 AML subtype:  NPM1
# ../../data/NPM1/ALA/image_83.tif
# Probspath:  ../../data/NPM1/ALA/single_cell_probabilities.npy Patient:  ALA image:  83 AML subtype:  NPM1
# ../../data/NPM1/BHR/image_115.tif
# Probspath:  ../../data/NPM1/BHR/single_cell_probabilities.npy Patient:  BHR image:  115 AML subtype:  NPM1
# ../../data/NPM1/BHR/image_215.tif
# Probspath:  ../../data/NPM1/BHR/single_cell_probabilities.npy Patient:  BHR image:  215 AML subtype:  NPM1
# ../../data/NPM1/BHR/image_216.tif
# Probspath:  ../../data/NPM1/BHR/single_cell_probabilities.npy Patient:  BHR image:  216 AML subtype:  NPM1
# ../../data/NPM1/BHR/image_349.tif
# Probspath:  ../../data/NPM1/BHR/single_cell_probabilities.npy Patient:  BHR image:  349 AML subtype:  NPM1
# ../../data/NPM1/BHR/image_364.tif
# Probspath:  ../../data/NPM1/BHR/single_cell_probabilities.npy Patient:  BHR image:  364 AML subtype:  NPM1
# ../../data/NPM1/BHR/image_379.tif
# Probspath:  ../../data/NPM1/BHR/single_cell_probabilities.npy Patient:  BHR image:  379 AML subtype:  NPM1
# ../../data/NPM1/BHR/image_388.tif
# Probspath:  ../../data/NPM1/BHR/single_cell_probabilities.npy Patient:  BHR image:  388 AML subtype:  NPM1
# ../../data/NPM1/BHR/image_395.tif
# Probspath:  ../../data/NPM1/BHR/single_cell_probabilities.npy Patient:  BHR image:  395 AML subtype:  NPM1
# ../../data/NPM1/BHR/image_4.tif
# Probspath:  ../../data/NPM1/BHR/single_cell_probabilities.npy Patient:  BHR image:  4 AML subtype:  NPM1
# ../../data/NPM1/BHR/image_405.tif
# Probspath:  ../../data/NPM1/BHR/single_cell_probabilities.npy Patient:  BHR image:  405 AML subtype:  NPM1
# ../../data/NPM1/BHR/image_431.tif
# Probspath:  ../../data/NPM1/BHR/single_cell_probabilities.npy Patient:  BHR image:  431 AML subtype:  NPM1
# ../../data/NPM1/BHR/image_46.tif
# Probspath:  ../../data/NPM1/BHR/single_cell_probabilities.npy Patient:  BHR image:  46 AML subtype:  NPM1
# ../../data/NPM1/BHR/image_49.tif
# Probspath:  ../../data/NPM1/BHR/single_cell_probabilities.npy Patient:  BHR image:  49 AML subtype:  NPM1
# ../../data/NPM1/BHR/image_57.tif
# Probspath:  ../../data/NPM1/BHR/single_cell_probabilities.npy Patient:  BHR image:  57 AML subtype:  NPM1
# ../../data/NPM1/BHR/image_85.tif
# Probspath:  ../../data/NPM1/BHR/single_cell_probabilities.npy Patient:  BHR image:  85 AML subtype:  NPM1
# ../../data/NPM1/CVW/image_214.tif
# Probspath:  ../../data/NPM1/CVW/single_cell_probabilities.npy Patient:  CVW image:  214 AML subtype:  NPM1
# ../../data/NPM1/CVW/image_252.tif
# Probspath:  ../../data/NPM1/CVW/single_cell_probabilities.npy Patient:  CVW image:  252 AML subtype:  NPM1
# ../../data/NPM1/CVW/image_300.tif
# Probspath:  ../../data/NPM1/CVW/single_cell_probabilities.npy Patient:  CVW image:  300 AML subtype:  NPM1
# ../../data/NPM1/CVW/image_335.tif
# Probspath:  ../../data/NPM1/CVW/single_cell_probabilities.npy Patient:  CVW image:  335 AML subtype:  NPM1
# ../../data/NPM1/CVW/image_427.tif
# Probspath:  ../../data/NPM1/CVW/single_cell_probabilities.npy Patient:  CVW image:  427 AML subtype:  NPM1
# ../../data/NPM1/CVW/image_54.tif
# Probspath:  ../../data/NPM1/CVW/single_cell_probabilities.npy Patient:  CVW image:  54 AML subtype:  NPM1
# ../../data/NPM1/CVW/image_97.tif
# Probspath:  ../../data/NPM1/CVW/single_cell_probabilities.npy Patient:  CVW image:  97 AML subtype:  NPM1
# ../../data/NPM1/CVW/image_97.tif
# Probspath:  ../../data/NPM1/CVW/single_cell_probabilities.npy Patient:  CVW image:  97 AML subtype:  NPM1
# ../../data/NPM1/CZI/image_274.tif
# Probspath:  ../../data/NPM1/CZI/single_cell_probabilities.npy Patient:  CZI image:  274 AML subtype:  NPM1
# ../../data/NPM1/CZI/image_274.tif
# Probspath:  ../../data/NPM1/CZI/single_cell_probabilities.npy Patient:  CZI image:  274 AML subtype:  NPM1
# ../../data/NPM1/CZI/image_289.tif
# Probspath:  ../../data/NPM1/CZI/single_cell_probabilities.npy Patient:  CZI image:  289 AML subtype:  NPM1
# ../../data/NPM1/CZI/image_340.tif
# Probspath:  ../../data/NPM1/CZI/single_cell_probabilities.npy Patient:  CZI image:  340 AML subtype:  NPM1
# ../../data/NPM1/CZI/image_381.tif
# Probspath:  ../../data/NPM1/CZI/single_cell_probabilities.npy Patient:  CZI image:  381 AML subtype:  NPM1
# ../../data/NPM1/CZI/image_391.tif
# Probspath:  ../../data/NPM1/CZI/single_cell_probabilities.npy Patient:  CZI image:  391 AML subtype:  NPM1
# ../../data/NPM1/CZI/image_409.tif
# Probspath:  ../../data/NPM1/CZI/single_cell_probabilities.npy Patient:  CZI image:  409 AML subtype:  NPM1
# ../../data/NPM1/CZI/image_425.tif
# Probspath:  ../../data/NPM1/CZI/single_cell_probabilities.npy Patient:  CZI image:  425 AML subtype:  NPM1
# ../../data/NPM1/CZI/image_486.tif
# Probspath:  ../../data/NPM1/CZI/single_cell_probabilities.npy Patient:  CZI image:  486 AML subtype:  NPM1
# ../../data/NPM1/DPF/image_109.tif
# Probspath:  ../../data/NPM1/DPF/single_cell_probabilities.npy Patient:  DPF image:  109 AML subtype:  NPM1
# ../../data/NPM1/DPF/image_136.tif
# Probspath:  ../../data/NPM1/DPF/single_cell_probabilities.npy Patient:  DPF image:  136 AML subtype:  NPM1
# ../../data/NPM1/DPF/image_154.tif
# Probspath:  ../../data/NPM1/DPF/single_cell_probabilities.npy Patient:  DPF image:  154 AML subtype:  NPM1
# ../../data/NPM1/DPF/image_229.tif
# Probspath:  ../../data/NPM1/DPF/single_cell_probabilities.npy Patient:  DPF image:  229 AML subtype:  NPM1
# ../../data/NPM1/DPF/image_235.tif
# Probspath:  ../../data/NPM1/DPF/single_cell_probabilities.npy Patient:  DPF image:  235 AML subtype:  NPM1
# ../../data/NPM1/DPF/image_249.tif
# Probspath:  ../../data/NPM1/DPF/single_cell_probabilities.npy Patient:  DPF image:  249 AML subtype:  NPM1
# ../../data/NPM1/DPF/image_403.tif
# Probspath:  ../../data/NPM1/DPF/single_cell_probabilities.npy Patient:  DPF image:  403 AML subtype:  NPM1
# ../../data/NPM1/DPF/image_406.tif
# Probspath:  ../../data/NPM1/DPF/single_cell_probabilities.npy Patient:  DPF image:  406 AML subtype:  NPM1
# ../../data/NPM1/DPF/image_55.tif
# Probspath:  ../../data/NPM1/DPF/single_cell_probabilities.npy Patient:  DPF image:  55 AML subtype:  NPM1
# ../../data/PML_RARA/ALE/image_100.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  100 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_104.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  104 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_115.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  115 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_127.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  127 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_140.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  140 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_144.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  144 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_146.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  146 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_167.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  167 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_17.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  17 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_180.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  180 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_180.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  180 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_211.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  211 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_215.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  215 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_233.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  233 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_237.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  237 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_252.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  252 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_273.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  273 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_281.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  281 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_287.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  287 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_343.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  343 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_36.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  36 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_362.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  362 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_391.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  391 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_431.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  431 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_437.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  437 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_444.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  444 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_451.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  451 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_467.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  467 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_469.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  469 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_59.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  59 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_61.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  61 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_82.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  82 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_90.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  90 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_93.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  93 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_111.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  111 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_117.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  117 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_121.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  121 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_123.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  123 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_141.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  141 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_142.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  142 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_19.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  19 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_20.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  20 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_227.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  227 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_269.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  269 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_272.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  272 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_275.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  275 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_277.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  277 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_332.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  332 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_332.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  332 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_351.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  351 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_373.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  373 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_377.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  377 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_379.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  379 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_416.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  416 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_428.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  428 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_439.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  439 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_48.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  48 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_73.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  73 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_83.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  83 AML subtype:  PML_RARA
# ../../data/PML_RARA/BIK/image_125.tif
# Probspath:  ../../data/PML_RARA/BIK/single_cell_probabilities.npy Patient:  BIK image:  125 AML subtype:  PML_RARA
# ../../data/PML_RARA/BIK/image_24.tif
# Probspath:  ../../data/PML_RARA/BIK/single_cell_probabilities.npy Patient:  BIK image:  24 AML subtype:  PML_RARA
# ../../data/PML_RARA/BIK/image_245.tif
# Probspath:  ../../data/PML_RARA/BIK/single_cell_probabilities.npy Patient:  BIK image:  245 AML subtype:  PML_RARA
# ../../data/PML_RARA/BIK/image_270.tif
# Probspath:  ../../data/PML_RARA/BIK/single_cell_probabilities.npy Patient:  BIK image:  270 AML subtype:  PML_RARA
# ../../data/PML_RARA/BIK/image_3.tif
# Probspath:  ../../data/PML_RARA/BIK/single_cell_probabilities.npy Patient:  BIK image:  3 AML subtype:  PML_RARA
# ../../data/PML_RARA/BIK/image_323.tif
# Probspath:  ../../data/PML_RARA/BIK/single_cell_probabilities.npy Patient:  BIK image:  323 AML subtype:  PML_RARA
# ../../data/PML_RARA/BIK/image_389.tif
# Probspath:  ../../data/PML_RARA/BIK/single_cell_probabilities.npy Patient:  BIK image:  389 AML subtype:  PML_RARA
# ../../data/PML_RARA/BIK/image_419.tif
# Probspath:  ../../data/PML_RARA/BIK/single_cell_probabilities.npy Patient:  BIK image:  419 AML subtype:  PML_RARA
# ../../data/PML_RARA/BIK/image_432.tif
# Probspath:  ../../data/PML_RARA/BIK/single_cell_probabilities.npy Patient:  BIK image:  432 AML subtype:  PML_RARA
# ../../data/PML_RARA/BIK/image_433.tif
# Probspath:  ../../data/PML_RARA/BIK/single_cell_probabilities.npy Patient:  BIK image:  433 AML subtype:  PML_RARA
# ../../data/PML_RARA/BIK/image_459.tif
# Probspath:  ../../data/PML_RARA/BIK/single_cell_probabilities.npy Patient:  BIK image:  459 AML subtype:  PML_RARA
# ../../data/PML_RARA/BIK/image_46.tif
# Probspath:  ../../data/PML_RARA/BIK/single_cell_probabilities.npy Patient:  BIK image:  46 AML subtype:  PML_RARA
# ../../data/PML_RARA/BIK/image_467.tif
# Probspath:  ../../data/PML_RARA/BIK/single_cell_probabilities.npy Patient:  BIK image:  467 AML subtype:  PML_RARA
# ../../data/PML_RARA/BIK/image_484.tif
# Probspath:  ../../data/PML_RARA/BIK/single_cell_probabilities.npy Patient:  BIK image:  484 AML subtype:  PML_RARA
# ../../data/PML_RARA/BIK/image_490.tif
# Probspath:  ../../data/PML_RARA/BIK/single_cell_probabilities.npy Patient:  BIK image:  490 AML subtype:  PML_RARA
# ../../data/PML_RARA/BIK/image_490.tif
# Probspath:  ../../data/PML_RARA/BIK/single_cell_probabilities.npy Patient:  BIK image:  490 AML subtype:  PML_RARA
# ../../data/PML_RARA/BIK/image_53.tif
# Probspath:  ../../data/PML_RARA/BIK/single_cell_probabilities.npy Patient:  BIK image:  53 AML subtype:  PML_RARA
# ../../data/PML_RARA/CMR/image_147.tif
# Probspath:  ../../data/PML_RARA/CMR/single_cell_probabilities.npy Patient:  CMR image:  147 AML subtype:  PML_RARA
# ../../data/PML_RARA/CMR/image_156.tif
# Probspath:  ../../data/PML_RARA/CMR/single_cell_probabilities.npy Patient:  CMR image:  156 AML subtype:  PML_RARA
# ../../data/PML_RARA/CMR/image_166.tif
# Probspath:  ../../data/PML_RARA/CMR/single_cell_probabilities.npy Patient:  CMR image:  166 AML subtype:  PML_RARA
# ../../data/PML_RARA/CMR/image_167.tif
# Probspath:  ../../data/PML_RARA/CMR/single_cell_probabilities.npy Patient:  CMR image:  167 AML subtype:  PML_RARA
# ../../data/PML_RARA/CMR/image_170.tif
# Probspath:  ../../data/PML_RARA/CMR/single_cell_probabilities.npy Patient:  CMR image:  170 AML subtype:  PML_RARA
# ../../data/PML_RARA/CMR/image_175.tif
# Probspath:  ../../data/PML_RARA/CMR/single_cell_probabilities.npy Patient:  CMR image:  175 AML subtype:  PML_RARA
# ../../data/PML_RARA/CMR/image_175.tif
# Probspath:  ../../data/PML_RARA/CMR/single_cell_probabilities.npy Patient:  CMR image:  175 AML subtype:  PML_RARA
# ../../data/PML_RARA/CMR/image_211.tif
# Probspath:  ../../data/PML_RARA/CMR/single_cell_probabilities.npy Patient:  CMR image:  211 AML subtype:  PML_RARA
# ../../data/PML_RARA/CMR/image_215.tif
# Probspath:  ../../data/PML_RARA/CMR/single_cell_probabilities.npy Patient:  CMR image:  215 AML subtype:  PML_RARA
# ../../data/PML_RARA/CMR/image_220.tif
# Probspath:  ../../data/PML_RARA/CMR/single_cell_probabilities.npy Patient:  CMR image:  220 AML subtype:  PML_RARA
# ../../data/PML_RARA/CMR/image_226.tif
# Probspath:  ../../data/PML_RARA/CMR/single_cell_probabilities.npy Patient:  CMR image:  226 AML subtype:  PML_RARA
# ../../data/PML_RARA/CMR/image_26.tif
# Probspath:  ../../data/PML_RARA/CMR/single_cell_probabilities.npy Patient:  CMR image:  26 AML subtype:  PML_RARA
# ../../data/PML_RARA/CMR/image_262.tif
# Probspath:  ../../data/PML_RARA/CMR/single_cell_probabilities.npy Patient:  CMR image:  262 AML subtype:  PML_RARA
# ../../data/PML_RARA/CMR/image_262.tif
# Probspath:  ../../data/PML_RARA/CMR/single_cell_probabilities.npy Patient:  CMR image:  262 AML subtype:  PML_RARA
# ../../data/PML_RARA/CMR/image_278.tif
# Probspath:  ../../data/PML_RARA/CMR/single_cell_probabilities.npy Patient:  CMR image:  278 AML subtype:  PML_RARA
# ../../data/PML_RARA/CMR/image_33.tif
# Probspath:  ../../data/PML_RARA/CMR/single_cell_probabilities.npy Patient:  CMR image:  33 AML subtype:  PML_RARA
# ../../data/PML_RARA/CMR/image_333.tif
# Probspath:  ../../data/PML_RARA/CMR/single_cell_probabilities.npy Patient:  CMR image:  333 AML subtype:  PML_RARA
# ../../data/PML_RARA/CMR/image_352.tif
# Probspath:  ../../data/PML_RARA/CMR/single_cell_probabilities.npy Patient:  CMR image:  352 AML subtype:  PML_RARA
# ../../data/PML_RARA/CMR/image_367.tif
# Probspath:  ../../data/PML_RARA/CMR/single_cell_probabilities.npy Patient:  CMR image:  367 AML subtype:  PML_RARA
# ../../data/PML_RARA/CMR/image_383.tif
# Probspath:  ../../data/PML_RARA/CMR/single_cell_probabilities.npy Patient:  CMR image:  383 AML subtype:  PML_RARA
# ../../data/PML_RARA/CMR/image_388.tif
# Probspath:  ../../data/PML_RARA/CMR/single_cell_probabilities.npy Patient:  CMR image:  388 AML subtype:  PML_RARA
# ../../data/PML_RARA/CMR/image_400.tif
# Probspath:  ../../data/PML_RARA/CMR/single_cell_probabilities.npy Patient:  CMR image:  400 AML subtype:  PML_RARA
# ../../data/PML_RARA/CMR/image_427.tif
# Probspath:  ../../data/PML_RARA/CMR/single_cell_probabilities.npy Patient:  CMR image:  427 AML subtype:  PML_RARA
# ../../data/PML_RARA/CMR/image_448.tif
# Probspath:  ../../data/PML_RARA/CMR/single_cell_probabilities.npy Patient:  CMR image:  448 AML subtype:  PML_RARA
# ../../data/PML_RARA/CMR/image_456.tif
# Probspath:  ../../data/PML_RARA/CMR/single_cell_probabilities.npy Patient:  CMR image:  456 AML subtype:  PML_RARA
# ../../data/PML_RARA/CMR/image_464.tif
# Probspath:  ../../data/PML_RARA/CMR/single_cell_probabilities.npy Patient:  CMR image:  464 AML subtype:  PML_RARA
# ../../data/PML_RARA/CMR/image_469.tif
# Probspath:  ../../data/PML_RARA/CMR/single_cell_probabilities.npy Patient:  CMR image:  469 AML subtype:  PML_RARA
# ../../data/PML_RARA/CMR/image_471.tif
# Probspath:  ../../data/PML_RARA/CMR/single_cell_probabilities.npy Patient:  CMR image:  471 AML subtype:  PML_RARA
# ../../data/PML_RARA/CMR/image_478.tif
# Probspath:  ../../data/PML_RARA/CMR/single_cell_probabilities.npy Patient:  CMR image:  478 AML subtype:  PML_RARA
# ../../data/PML_RARA/CMR/image_50.tif
# Probspath:  ../../data/PML_RARA/CMR/single_cell_probabilities.npy Patient:  CMR image:  50 AML subtype:  PML_RARA
# ../../data/PML_RARA/CMR/image_85.tif
# Probspath:  ../../data/PML_RARA/CMR/single_cell_probabilities.npy Patient:  CMR image:  85 AML subtype:  PML_RARA
# ../../data/PML_RARA/CWF/image_109.tif
# Probspath:  ../../data/PML_RARA/CWF/single_cell_probabilities.npy Patient:  CWF image:  109 AML subtype:  PML_RARA
# ../../data/PML_RARA/CWF/image_111.tif
# Probspath:  ../../data/PML_RARA/CWF/single_cell_probabilities.npy Patient:  CWF image:  111 AML subtype:  PML_RARA
# ../../data/PML_RARA/CWF/image_143.tif
# Probspath:  ../../data/PML_RARA/CWF/single_cell_probabilities.npy Patient:  CWF image:  143 AML subtype:  PML_RARA
# ../../data/PML_RARA/CWF/image_181.tif
# Probspath:  ../../data/PML_RARA/CWF/single_cell_probabilities.npy Patient:  CWF image:  181 AML subtype:  PML_RARA
# ../../data/PML_RARA/CWF/image_202.tif
# Probspath:  ../../data/PML_RARA/CWF/single_cell_probabilities.npy Patient:  CWF image:  202 AML subtype:  PML_RARA
# ../../data/PML_RARA/CWF/image_206.tif
# Probspath:  ../../data/PML_RARA/CWF/single_cell_probabilities.npy Patient:  CWF image:  206 AML subtype:  PML_RARA
# ../../data/PML_RARA/CWF/image_220.tif
# Probspath:  ../../data/PML_RARA/CWF/single_cell_probabilities.npy Patient:  CWF image:  220 AML subtype:  PML_RARA
# ../../data/PML_RARA/CWF/image_234.tif
# Probspath:  ../../data/PML_RARA/CWF/single_cell_probabilities.npy Patient:  CWF image:  234 AML subtype:  PML_RARA
# ../../data/PML_RARA/CWF/image_239.tif
# Probspath:  ../../data/PML_RARA/CWF/single_cell_probabilities.npy Patient:  CWF image:  239 AML subtype:  PML_RARA
# ../../data/PML_RARA/CWF/image_266.tif
# Probspath:  ../../data/PML_RARA/CWF/single_cell_probabilities.npy Patient:  CWF image:  266 AML subtype:  PML_RARA
# ../../data/PML_RARA/CWF/image_327.tif
# Probspath:  ../../data/PML_RARA/CWF/single_cell_probabilities.npy Patient:  CWF image:  327 AML subtype:  PML_RARA
# ../../data/PML_RARA/CWF/image_349.tif
# Probspath:  ../../data/PML_RARA/CWF/single_cell_probabilities.npy Patient:  CWF image:  349 AML subtype:  PML_RARA
# ../../data/PML_RARA/CWF/image_355.tif
# Probspath:  ../../data/PML_RARA/CWF/single_cell_probabilities.npy Patient:  CWF image:  355 AML subtype:  PML_RARA
# ../../data/PML_RARA/CWF/image_367.tif
# Probspath:  ../../data/PML_RARA/CWF/single_cell_probabilities.npy Patient:  CWF image:  367 AML subtype:  PML_RARA
# ../../data/PML_RARA/CWF/image_369.tif
# Probspath:  ../../data/PML_RARA/CWF/single_cell_probabilities.npy Patient:  CWF image:  369 AML subtype:  PML_RARA
# ../../data/PML_RARA/CWF/image_384.tif
# Probspath:  ../../data/PML_RARA/CWF/single_cell_probabilities.npy Patient:  CWF image:  384 AML subtype:  PML_RARA
# ../../data/PML_RARA/CWF/image_384.tif
# Probspath:  ../../data/PML_RARA/CWF/single_cell_probabilities.npy Patient:  CWF image:  384 AML subtype:  PML_RARA
# ../../data/PML_RARA/CWF/image_429.tif
# Probspath:  ../../data/PML_RARA/CWF/single_cell_probabilities.npy Patient:  CWF image:  429 AML subtype:  PML_RARA
# ../../data/PML_RARA/CWF/image_441.tif
# Probspath:  ../../data/PML_RARA/CWF/single_cell_probabilities.npy Patient:  CWF image:  441 AML subtype:  PML_RARA
# ../../data/PML_RARA/CWF/image_443.tif
# Probspath:  ../../data/PML_RARA/CWF/single_cell_probabilities.npy Patient:  CWF image:  443 AML subtype:  PML_RARA
# ../../data/PML_RARA/CWF/image_46.tif
# Probspath:  ../../data/PML_RARA/CWF/single_cell_probabilities.npy Patient:  CWF image:  46 AML subtype:  PML_RARA
# ../../data/PML_RARA/CWF/image_478.tif
# Probspath:  ../../data/PML_RARA/CWF/single_cell_probabilities.npy Patient:  CWF image:  478 AML subtype:  PML_RARA
# ../../data/PML_RARA/CWF/image_54.tif
# Probspath:  ../../data/PML_RARA/CWF/single_cell_probabilities.npy Patient:  CWF image:  54 AML subtype:  PML_RARA
# ../../data/PML_RARA/CWF/image_92.tif
# Probspath:  ../../data/PML_RARA/CWF/single_cell_probabilities.npy Patient:  CWF image:  92 AML subtype:  PML_RARA
# ../../data/RUNX1_RUNX1T1/ABF/image_104.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/ABF/single_cell_probabilities.npy Patient:  ABF image:  104 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/ABF/image_116.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/ABF/single_cell_probabilities.npy Patient:  ABF image:  116 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/ABF/image_125.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/ABF/single_cell_probabilities.npy Patient:  ABF image:  125 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/ABF/image_13.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/ABF/single_cell_probabilities.npy Patient:  ABF image:  13 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/ABF/image_135.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/ABF/single_cell_probabilities.npy Patient:  ABF image:  135 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/ABF/image_150.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/ABF/single_cell_probabilities.npy Patient:  ABF image:  150 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/ABF/image_157.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/ABF/single_cell_probabilities.npy Patient:  ABF image:  157 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/ABF/image_161.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/ABF/single_cell_probabilities.npy Patient:  ABF image:  161 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/ABF/image_176.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/ABF/single_cell_probabilities.npy Patient:  ABF image:  176 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/ABF/image_278.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/ABF/single_cell_probabilities.npy Patient:  ABF image:  278 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/ABF/image_301.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/ABF/single_cell_probabilities.npy Patient:  ABF image:  301 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/ABF/image_334.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/ABF/single_cell_probabilities.npy Patient:  ABF image:  334 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/ABF/image_346.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/ABF/single_cell_probabilities.npy Patient:  ABF image:  346 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/ABF/image_359.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/ABF/single_cell_probabilities.npy Patient:  ABF image:  359 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/ABF/image_362.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/ABF/single_cell_probabilities.npy Patient:  ABF image:  362 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/ABF/image_380.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/ABF/single_cell_probabilities.npy Patient:  ABF image:  380 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/ABF/image_434.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/ABF/single_cell_probabilities.npy Patient:  ABF image:  434 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/ABF/image_98.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/ABF/single_cell_probabilities.npy Patient:  ABF image:  98 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/BHG/image_122.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/BHG/single_cell_probabilities.npy Patient:  BHG image:  122 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/BHG/image_163.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/BHG/single_cell_probabilities.npy Patient:  BHG image:  163 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/BHG/image_168.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/BHG/single_cell_probabilities.npy Patient:  BHG image:  168 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/BHG/image_268.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/BHG/single_cell_probabilities.npy Patient:  BHG image:  268 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/BHG/image_278.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/BHG/single_cell_probabilities.npy Patient:  BHG image:  278 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/BHG/image_281.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/BHG/single_cell_probabilities.npy Patient:  BHG image:  281 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/BHG/image_341.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/BHG/single_cell_probabilities.npy Patient:  BHG image:  341 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/BHG/image_349.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/BHG/single_cell_probabilities.npy Patient:  BHG image:  349 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/BHG/image_356.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/BHG/single_cell_probabilities.npy Patient:  BHG image:  356 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/BHG/image_36.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/BHG/single_cell_probabilities.npy Patient:  BHG image:  36 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/BHG/image_375.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/BHG/single_cell_probabilities.npy Patient:  BHG image:  375 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/BHG/image_398.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/BHG/single_cell_probabilities.npy Patient:  BHG image:  398 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/BHG/image_453.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/BHG/single_cell_probabilities.npy Patient:  BHG image:  453 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/BHG/image_456.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/BHG/single_cell_probabilities.npy Patient:  BHG image:  456 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/BHG/image_470.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/BHG/single_cell_probabilities.npy Patient:  BHG image:  470 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/BHG/image_483.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/BHG/single_cell_probabilities.npy Patient:  BHG image:  483 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/BHG/image_50.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/BHG/single_cell_probabilities.npy Patient:  BHG image:  50 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/BHG/image_52.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/BHG/single_cell_probabilities.npy Patient:  BHG image:  52 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/BHG/image_65.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/BHG/single_cell_probabilities.npy Patient:  BHG image:  65 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/BKR/image_105.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/BKR/single_cell_probabilities.npy Patient:  BKR image:  105 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/BKR/image_146.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/BKR/single_cell_probabilities.npy Patient:  BKR image:  146 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/BKR/image_190.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/BKR/single_cell_probabilities.npy Patient:  BKR image:  190 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/BKR/image_217.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/BKR/single_cell_probabilities.npy Patient:  BKR image:  217 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/BKR/image_270.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/BKR/single_cell_probabilities.npy Patient:  BKR image:  270 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/BKR/image_288.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/BKR/single_cell_probabilities.npy Patient:  BKR image:  288 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/BKR/image_330.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/BKR/single_cell_probabilities.npy Patient:  BKR image:  330 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/BKR/image_425.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/BKR/single_cell_probabilities.npy Patient:  BKR image:  425 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/BKR/image_471.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/BKR/single_cell_probabilities.npy Patient:  BKR image:  471 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/BKR/image_472.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/BKR/single_cell_probabilities.npy Patient:  BKR image:  472 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/BKR/image_474.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/BKR/single_cell_probabilities.npy Patient:  BKR image:  474 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/BKR/image_475.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/BKR/single_cell_probabilities.npy Patient:  BKR image:  475 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/BKR/image_487.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/BKR/single_cell_probabilities.npy Patient:  BKR image:  487 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/BOE/image_156.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/BOE/single_cell_probabilities.npy Patient:  BOE image:  156 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/BOE/image_161.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/BOE/single_cell_probabilities.npy Patient:  BOE image:  161 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/BOE/image_180.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/BOE/single_cell_probabilities.npy Patient:  BOE image:  180 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/BOE/image_193.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/BOE/single_cell_probabilities.npy Patient:  BOE image:  193 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/BOE/image_205.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/BOE/single_cell_probabilities.npy Patient:  BOE image:  205 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/BOE/image_215.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/BOE/single_cell_probabilities.npy Patient:  BOE image:  215 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/BOE/image_253.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/BOE/single_cell_probabilities.npy Patient:  BOE image:  253 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/BOE/image_258.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/BOE/single_cell_probabilities.npy Patient:  BOE image:  258 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/BOE/image_4.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/BOE/single_cell_probabilities.npy Patient:  BOE image:  4 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/BOE/image_42.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/BOE/single_cell_probabilities.npy Patient:  BOE image:  42 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/BOE/image_79.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/BOE/single_cell_probabilities.npy Patient:  BOE image:  79 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/BOE/image_84.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/BOE/single_cell_probabilities.npy Patient:  BOE image:  84 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/BOE/image_84.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/BOE/single_cell_probabilities.npy Patient:  BOE image:  84 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/DHA/image_118.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/DHA/single_cell_probabilities.npy Patient:  DHA image:  118 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/DHA/image_220.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/DHA/single_cell_probabilities.npy Patient:  DHA image:  220 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/DHA/image_258.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/DHA/single_cell_probabilities.npy Patient:  DHA image:  258 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/DHA/image_28.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/DHA/single_cell_probabilities.npy Patient:  DHA image:  28 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/DHA/image_296.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/DHA/single_cell_probabilities.npy Patient:  DHA image:  296 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/DHA/image_310.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/DHA/single_cell_probabilities.npy Patient:  DHA image:  310 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/DHA/image_315.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/DHA/single_cell_probabilities.npy Patient:  DHA image:  315 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/DHA/image_386.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/DHA/single_cell_probabilities.npy Patient:  DHA image:  386 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/DHA/image_411.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/DHA/single_cell_probabilities.npy Patient:  DHA image:  411 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/DHA/image_451.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/DHA/single_cell_probabilities.npy Patient:  DHA image:  451 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/DHA/image_464.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/DHA/single_cell_probabilities.npy Patient:  DHA image:  464 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/DHA/image_482.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/DHA/single_cell_probabilities.npy Patient:  DHA image:  482 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/DHA/image_493.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/DHA/single_cell_probabilities.npy Patient:  DHA image:  493 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/DHA/image_73.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/DHA/single_cell_probabilities.npy Patient:  DHA image:  73 AML subtype:  RUNX1_RUNX1T1
# ../../data/control/AEC/image_239.tif
# Probspath:  ../../data/control/AEC/single_cell_probabilities.npy Patient:  AEC image:  239 AML subtype:  control
# ../../data/control/AEC/image_264.tif
# Probspath:  ../../data/control/AEC/single_cell_probabilities.npy Patient:  AEC image:  264 AML subtype:  control
# ../../data/control/AEC/image_392.tif
# Probspath:  ../../data/control/AEC/single_cell_probabilities.npy Patient:  AEC image:  392 AML subtype:  control
# ../../data/control/AEC/image_423.tif
# Probspath:  ../../data/control/AEC/single_cell_probabilities.npy Patient:  AEC image:  423 AML subtype:  control
# ../../data/control/AEC/image_445.tif
# Probspath:  ../../data/control/AEC/single_cell_probabilities.npy Patient:  AEC image:  445 AML subtype:  control
# ../../data/control/AEC/image_46.tif
# Probspath:  ../../data/control/AEC/single_cell_probabilities.npy Patient:  AEC image:  46 AML subtype:  control
# ../../data/control/AEC/image_483.tif
# Probspath:  ../../data/control/AEC/single_cell_probabilities.npy Patient:  AEC image:  483 AML subtype:  control
# ../../data/control/AEC/image_487.tif
# Probspath:  ../../data/control/AEC/single_cell_probabilities.npy Patient:  AEC image:  487 AML subtype:  control
# ...
# ../../data/control/AVL/image_186.tif
# Probspath:  ../../data/control/AVL/single_cell_probabilities.npy Patient:  AVL image:  186 AML subtype:  control
# ../../data/control/AVL/image_19.tif
# Probspath:  ../../data/control/AVL/single_cell_probabilities.npy Patient:  AVL image:  19 AML subtype:  control
# ../../data/control/AVL/image_2.tif
# Probspath:  ../../data/control/AVL/single_cell_probabilities.npy Patient:  AVL image:  2 AML subtype:  control
# ../../data/control/AVL/image_206.tif
# Probspath:  ../../data/control/AVL/single_cell_probabilities.npy Patient:  AVL image:  206 AML subtype:  control
# ../../data/control/AVL/image_209.tif
# Probspath:  ../../data/control/AVL/single_cell_probabilities.npy Patient:  AVL image:  209 AML subtype:  control
# ../../data/control/AVL/image_235.tif
# Probspath:  ../../data/control/AVL/single_cell_probabilities.npy Patient:  AVL image:  235 AML subtype:  control
# ../../data/control/AVL/image_238.tif
# Probspath:  ../../data/control/AVL/single_cell_probabilities.npy Patient:  AVL image:  238 AML subtype:  control
# ../../data/control/AVL/image_244.tif
# Probspath:  ../../data/control/AVL/single_cell_probabilities.npy Patient:  AVL image:  244 AML subtype:  control
# ../../data/control/AVL/image_249.tif
# Probspath:  ../../data/control/AVL/single_cell_probabilities.npy Patient:  AVL image:  249 AML subtype:  control
# ../../data/control/AVL/image_262.tif
# Probspath:  ../../data/control/AVL/single_cell_probabilities.npy Patient:  AVL image:  262 AML subtype:  control
# ../../data/control/AVL/image_273.tif
# Probspath:  ../../data/control/AVL/single_cell_probabilities.npy Patient:  AVL image:  273 AML subtype:  control
# ../../data/control/AVL/image_276.tif
# Probspath:  ../../data/control/AVL/single_cell_probabilities.npy Patient:  AVL image:  276 AML subtype:  control
# ../../data/control/AVL/image_279.tif
# Probspath:  ../../data/control/AVL/single_cell_probabilities.npy Patient:  AVL image:  279 AML subtype:  control
# ../../data/control/AVL/image_293.tif
# Probspath:  ../../data/control/AVL/single_cell_probabilities.npy Patient:  AVL image:  293 AML subtype:  control
# ../../data/control/AVL/image_298.tif
# Probspath:  ../../data/control/AVL/single_cell_probabilities.npy Patient:  AVL image:  298 AML subtype:  control
# ../../data/control/AVL/image_302.tif
# Probspath:  ../../data/control/AVL/single_cell_probabilities.npy Patient:  AVL image:  302 AML subtype:  control
# ../../data/control/AVL/image_324.tif
# Probspath:  ../../data/control/AVL/single_cell_probabilities.npy Patient:  AVL image:  324 AML subtype:  control
# ../../data/control/AVL/image_324.tif
# Probspath:  ../../data/control/AVL/single_cell_probabilities.npy Patient:  AVL image:  324 AML subtype:  control
# ../../data/control/AVL/image_327.tif
# Probspath:  ../../data/control/AVL/single_cell_probabilities.npy Patient:  AVL image:  327 AML subtype:  control
# ../../data/control/AVL/image_332.tif
# Probspath:  ../../data/control/AVL/single_cell_probabilities.npy Patient:  AVL image:  332 AML subtype:  control
# ../../data/control/AVL/image_347.tif
# Probspath:  ../../data/control/AVL/single_cell_probabilities.npy Patient:  AVL image:  347 AML subtype:  control
# ../../data/control/AVL/image_351.tif
# Probspath:  ../../data/control/AVL/single_cell_probabilities.npy Patient:  AVL image:  351 AML subtype:  control
# ../../data/control/AVL/image_359.tif
# Probspath:  ../../data/control/AVL/single_cell_probabilities.npy Patient:  AVL image:  359 AML subtype:  control
# ../../data/control/AVL/image_365.tif
# Probspath:  ../../data/control/AVL/single_cell_probabilities.npy Patient:  AVL image:  365 AML subtype:  control
# ../../data/control/AVL/image_371.tif
# Probspath:  ../../data/control/AVL/single_cell_probabilities.npy Patient:  AVL image:  371 AML subtype:  control
# ../../data/control/AVL/image_380.tif
# Probspath:  ../../data/control/AVL/single_cell_probabilities.npy Patient:  AVL image:  380 AML subtype:  control
# ../../data/control/AVL/image_387.tif
# Probspath:  ../../data/control/AVL/single_cell_probabilities.npy Patient:  AVL image:  387 AML subtype:  control
# ../../data/control/AVL/image_62.tif
# Probspath:  ../../data/control/AVL/single_cell_probabilities.npy Patient:  AVL image:  62 AML subtype:  control
# ../../data/control/AVL/image_75.tif
# Probspath:  ../../data/control/AVL/single_cell_probabilities.npy Patient:  AVL image:  75 AML subtype:  control
# ../../data/control/AVL/image_77.tif
# Probspath:  ../../data/control/AVL/single_cell_probabilities.npy Patient:  AVL image:  77 AML subtype:  control
# ../../data/control/AVL/image_82.tif
# Probspath:  ../../data/control/AVL/single_cell_probabilities.npy Patient:  AVL image:  82 AML subtype:  control
# ../../data/control/AVL/image_83.tif
# Probspath:  ../../data/control/AVL/single_cell_probabilities.npy Patient:  AVL image:  83 AML subtype:  control
# ../../data/control/AVL/image_88.tif
# Probspath:  ../../data/control/AVL/single_cell_probabilities.npy Patient:  AVL image:  88 AML subtype:  control
# ../../data/control/AVL/image_90.tif
# Probspath:  ../../data/control/AVL/single_cell_probabilities.npy Patient:  AVL image:  90 AML subtype:  control
# ../../data/control/AVL/image_91.tif
# Probspath:  ../../data/control/AVL/single_cell_probabilities.npy Patient:  AVL image:  91 AML subtype:  control
# ../../data/control/AVL/image_93.tif
# Probspath:  ../../data/control/AVL/single_cell_probabilities.npy Patient:  AVL image:  93 AML subtype:  control
# ../../data/control/AVL/image_98.tif
# Probspath:  ../../data/control/AVL/single_cell_probabilities.npy Patient:  AVL image:  98 AML subtype:  control
# ../../data/control/BXR/image_0.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  0 AML subtype:  control
# ../../data/control/BXR/image_106.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  106 AML subtype:  control
# ../../data/control/BXR/image_109.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  109 AML subtype:  control
# ../../data/control/BXR/image_110.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  110 AML subtype:  control
# ../../data/control/BXR/image_114.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  114 AML subtype:  control
# ../../data/control/BXR/image_125.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  125 AML subtype:  control
# ../../data/control/BXR/image_127.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  127 AML subtype:  control
# ../../data/control/BXR/image_13.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  13 AML subtype:  control
# ../../data/control/BXR/image_133.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  133 AML subtype:  control
# ../../data/control/BXR/image_135.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  135 AML subtype:  control
# ../../data/control/BXR/image_160.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  160 AML subtype:  control
# ../../data/control/BXR/image_165.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  165 AML subtype:  control
# ../../data/control/BXR/image_167.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  167 AML subtype:  control
# ../../data/control/BXR/image_17.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  17 AML subtype:  control
# ../../data/control/BXR/image_171.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  171 AML subtype:  control
# ../../data/control/BXR/image_172.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  172 AML subtype:  control
# ../../data/control/BXR/image_174.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  174 AML subtype:  control
# ../../data/control/BXR/image_183.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  183 AML subtype:  control
# ../../data/control/BXR/image_190.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  190 AML subtype:  control
# ../../data/control/BXR/image_195.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  195 AML subtype:  control
# ../../data/control/BXR/image_198.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  198 AML subtype:  control
# ../../data/control/BXR/image_207.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  207 AML subtype:  control
# ../../data/control/BXR/image_241.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  241 AML subtype:  control
# ../../data/control/BXR/image_244.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  244 AML subtype:  control
# ../../data/control/BXR/image_258.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  258 AML subtype:  control
# ../../data/control/BXR/image_26.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  26 AML subtype:  control
# ../../data/control/BXR/image_261.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  261 AML subtype:  control
# ../../data/control/BXR/image_264.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  264 AML subtype:  control
# ../../data/control/BXR/image_27.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  27 AML subtype:  control
# ../../data/control/BXR/image_28.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  28 AML subtype:  control
# ../../data/control/BXR/image_282.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  282 AML subtype:  control
# ../../data/control/BXR/image_296.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  296 AML subtype:  control
# ../../data/control/BXR/image_304.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  304 AML subtype:  control
# ../../data/control/BXR/image_320.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  320 AML subtype:  control
# ../../data/control/BXR/image_322.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  322 AML subtype:  control
# ../../data/control/BXR/image_329.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  329 AML subtype:  control
# ../../data/control/BXR/image_335.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  335 AML subtype:  control
# ../../data/control/BXR/image_338.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  338 AML subtype:  control
# ../../data/control/BXR/image_340.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  340 AML subtype:  control
# ../../data/control/BXR/image_349.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  349 AML subtype:  control
# ../../data/control/BXR/image_35.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  35 AML subtype:  control
# ../../data/control/BXR/image_355.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  355 AML subtype:  control
# ../../data/control/BXR/image_355.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  355 AML subtype:  control
# ../../data/control/BXR/image_369.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  369 AML subtype:  control
# ../../data/control/BXR/image_373.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  373 AML subtype:  control
# ../../data/control/BXR/image_374.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  374 AML subtype:  control
# ../../data/control/BXR/image_40.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  40 AML subtype:  control
# ../../data/control/BXR/image_406.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  406 AML subtype:  control
# ../../data/control/BXR/image_415.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  415 AML subtype:  control
# ../../data/control/BXR/image_422.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  422 AML subtype:  control
# ../../data/control/BXR/image_426.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  426 AML subtype:  control
# ../../data/control/BXR/image_429.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  429 AML subtype:  control
# ../../data/control/BXR/image_440.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  440 AML subtype:  control
# ../../data/control/BXR/image_443.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  443 AML subtype:  control
# ../../data/control/BXR/image_444.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  444 AML subtype:  control
# ../../data/control/BXR/image_445.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  445 AML subtype:  control
# ../../data/control/BXR/image_449.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  449 AML subtype:  control
# ../../data/control/BXR/image_450.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  450 AML subtype:  control
# ../../data/control/BXR/image_468.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  468 AML subtype:  control
# ../../data/control/BXR/image_476.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  476 AML subtype:  control
# ../../data/control/BXR/image_5.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  5 AML subtype:  control
# ../../data/control/BXR/image_6.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  6 AML subtype:  control
# ../../data/control/BXR/image_61.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  61 AML subtype:  control
# ../../data/control/BXR/image_63.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  63 AML subtype:  control
# ../../data/control/BXR/image_73.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  73 AML subtype:  control
# ../../data/control/BXR/image_75.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  75 AML subtype:  control
# ../../data/control/BXR/image_78.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  78 AML subtype:  control
# ../../data/control/BXR/image_88.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  88 AML subtype:  control
# ../../data/control/BXR/image_89.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  89 AML subtype:  control
# ../../data/control/BXR/image_93.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  93 AML subtype:  control

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
from matplotlib.cm import get_cmap

# Assume you have the function get_counts_vector implemented

# Set your data_path variable
data_path = data_path_art

# Initialize figure for subplots
fig, axs = plt.subplots(nrows=1, ncols=len(os.listdir(data_path)), figsize=(12 * len(os.listdir(data_path)), 6), sharey=False)

# Initialize legend elements for the overall plot
legend_elements = []

# Iterate over all subfolders in the data folder
for i, class_folder in enumerate(os.listdir(data_path)):
    print(class_folder)
    class_path = os.path.join(data_path, class_folder)

    # Ensure that the item is a directory
    if os.path.isdir(class_path):
        # Initialize lists to store data for plotting
        patient_folder_names = []
        stacked_counts_vectors = []

        # Iterate over all files in the folder
        for j, patient_folder in enumerate(os.listdir(class_path)):
            print(patient_folder)
            # if len(patient_folder) == 3:
            probs_path = os.path.join(class_path, patient_folder) + '/single_cell_probabilities.npy'
            print(probs_path)
            sc_probs = np.load(probs_path)
            sc_class = np.argmax(sc_probs, axis=1)
            counts_vector, unique_labels = get_counts_vector(sc_class)

            # Normalize counts to percentages
            counts_percentages = counts_vector / np.sum(counts_vector) * 100

            # Create a custom color list for each position
            cmap = get_cmap('tab20c', len(unique_labels))
            colors = [cmap(i) for i in range(len(unique_labels))]

            # Create a horizontal stacked bar plot for each patient in the class
            left = 0
            for label, color in zip(unique_labels, colors):
                axs[i].barh(patient_folder, counts_percentages[label], label=f"Class {label}", alpha=1, color=color, left=left)
                left += counts_percentages[label]

        # Extend the legend elements for the overall plot (outside the patient loop)
        if i == 0:
            legend_elements.extend([Line2D([0], [0], color=color, lw=4, label=f'Class {label}') for label, color in zip(unique_labels, colors)])

        # Set title for each subplot with the name of the folder
        axs[i].set_title(class_folder, fontsize=20)

# Add labels with increased font size
fig.text(0.04, 0.5, "Patients", va='center', rotation='vertical', fontsize=16)

# Create a legend for the overall plot with increased font size
fig.legend(handles=legend_elements, title="Legend", bbox_to_anchor=(1.05, 0.5), loc='center left', fontsize=14)

# Adjust layout and save the overall plot
plt.tight_layout()
plt.savefig('fig3_based_on_scfeatures_art_exp_3.png', bbox_inches='tight')

# Show the plot
plt.show()
# Out:
# PML_RARA
# patient_2
# ../../artificialdata/experiment_3/data/PML_RARA/patient_2/single_cell_probabilities.npy
# patient_4
# ../../artificialdata/experiment_3/data/PML_RARA/patient_4/single_cell_probabilities.npy
# patient_1
# ../../artificialdata/experiment_3/data/PML_RARA/patient_1/single_cell_probabilities.npy
# patient_3
# ../../artificialdata/experiment_3/data/PML_RARA/patient_3/single_cell_probabilities.npy
# patient_5
# ../../artificialdata/experiment_3/data/PML_RARA/patient_5/single_cell_probabilities.npy
# CBFB_MYH11
# patient_2
# ../../artificialdata/experiment_3/data/CBFB_MYH11/patient_2/single_cell_probabilities.npy
# patient_4
# ../../artificialdata/experiment_3/data/CBFB_MYH11/patient_4/single_cell_probabilities.npy
# patient_1
# ../../artificialdata/experiment_3/data/CBFB_MYH11/patient_1/single_cell_probabilities.npy
# patient_3
# ../../artificialdata/experiment_3/data/CBFB_MYH11/patient_3/single_cell_probabilities.npy
# patient_5
# ../../artificialdata/experiment_3/data/CBFB_MYH11/patient_5/single_cell_probabilities.npy
# NPM1
# patient_2
# ../../artificialdata/experiment_3/data/NPM1/patient_2/single_cell_probabilities.npy
# patient_4
# ../../artificialdata/experiment_3/data/NPM1/patient_4/single_cell_probabilities.npy
# /tmp/ipykernel_262918/117953453.py:43: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = get_cmap('tab20c', len(unique_labels))
# patient_1
# ../../artificialdata/experiment_3/data/NPM1/patient_1/single_cell_probabilities.npy
# patient_3
# ../../artificialdata/experiment_3/data/NPM1/patient_3/single_cell_probabilities.npy
# patient_5
# ../../artificialdata/experiment_3/data/NPM1/patient_5/single_cell_probabilities.npy
# RUNX1_RUNX1T1
# patient_2
# ../../artificialdata/experiment_3/data/RUNX1_RUNX1T1/patient_2/single_cell_probabilities.npy
# patient_4
# ../../artificialdata/experiment_3/data/RUNX1_RUNX1T1/patient_4/single_cell_probabilities.npy
# patient_1
# ../../artificialdata/experiment_3/data/RUNX1_RUNX1T1/patient_1/single_cell_probabilities.npy
# patient_3
# ../../artificialdata/experiment_3/data/RUNX1_RUNX1T1/patient_3/single_cell_probabilities.npy
# patient_5
# ../../artificialdata/experiment_3/data/RUNX1_RUNX1T1/patient_5/single_cell_probabilities.npy
# control
# patient_2
# ../../artificialdata/experiment_3/data/control/patient_2/single_cell_probabilities.npy
# patient_4
# ../../artificialdata/experiment_3/data/control/patient_4/single_cell_probabilities.npy
# patient_1
# ../../artificialdata/experiment_3/data/control/patient_1/single_cell_probabilities.npy
# patient_3
# ../../artificialdata/experiment_3/data/control/patient_3/single_cell_probabilities.npy
# patient_5
# ../../artificialdata/experiment_3/data/control/patient_5/single_cell_probabilities.npy

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
from matplotlib.cm import get_cmap

# Assume you have the function get_counts_vector implemented

# Set your data_path variable
data_path = data_path_art

# Initialize figure for subplots
fig, axs = plt.subplots(nrows=len(os.listdir(data_path)), ncols=1, figsize=(12, 6 * len(os.listdir(data_path))), sharey=False)

# Initialize legend elements for the overall plot
legend_elements = []

# Iterate over all subfolders in the data folder
for i, class_folder in enumerate(os.listdir(data_path)):
    print(class_folder)
    class_path = os.path.join(data_path, class_folder)

    # Ensure that the item is a directory
    if os.path.isdir(class_path):
        # Initialize lists to store data for plotting
        patient_folder_names = []
        stacked_counts_vectors = []

        # Iterate over all files in the folder
        for j, patient_folder in enumerate(os.listdir(class_path)):
            print(patient_folder)
            # if len(patient_folder) == 3:
            probs_path = os.path.join(class_path, patient_folder) + '/single_cell_probabilities.npy'
            print(probs_path)
            sc_probs = np.load(probs_path)
            sc_class = np.argmax(sc_probs, axis=1)
            counts_vector, unique_labels = get_counts_vector(sc_class)

            # Normalize counts to percentages
            counts_percentages = counts_vector / np.sum(counts_vector) * 100

            # Create a custom color list for each position
            cmap = get_cmap('tab20c', len(unique_labels))
            colors = [cmap(i) for i in range(len(unique_labels))]

            # Create a horizontal stacked bar plot for each patient in the class
            left = 0
            for label, color in zip(unique_labels, colors):
                axs[i].barh(patient_folder, counts_percentages[label], label=f"Class {label}", alpha=1, color=color, left=left)
                left += counts_percentages[label]

        # Extend the legend elements for the overall plot (outside the patient loop)
        if i == 0:
            legend_elements.extend([Line2D([0], [0], color=color, lw=4, label=f'Class {label}') for label, color in zip(unique_labels, colors)])

        # Set title for each subplot with the name of the folder
        axs[i].set_title(class_folder, fontsize=20)

# Add labels with increased font size
fig.text(0.04, 0.5, "Patients", va='center', rotation='vertical', fontsize=16)

# Create a legend for the overall plot with increased font size
fig.legend(handles=legend_elements, title="Legend", bbox_to_anchor=(1.05, 0.5), loc='center left', fontsize=14)
plt.savefig('fig3_based_on_scfeatures_art_exp_3_hor.png', bbox_inches='tight')
# Adjust layout
# Out:
# PML_RARA
# patient_2
# ../../artificialdata/experiment_3/data/PML_RARA/patient_2/single_cell_probabilities.npy
# patient_4
# ../../artificialdata/experiment_3/data/PML_RARA/patient_4/single_cell_probabilities.npy
# patient_1
# ../../artificialdata/experiment_3/data/PML_RARA/patient_1/single_cell_probabilities.npy
# patient_3
# ../../artificialdata/experiment_3/data/PML_RARA/patient_3/single_cell_probabilities.npy
# patient_5
# ../../artificialdata/experiment_3/data/PML_RARA/patient_5/single_cell_probabilities.npy
# CBFB_MYH11
# patient_2
# ../../artificialdata/experiment_3/data/CBFB_MYH11/patient_2/single_cell_probabilities.npy
# patient_4
# ../../artificialdata/experiment_3/data/CBFB_MYH11/patient_4/single_cell_probabilities.npy
# patient_1
# ../../artificialdata/experiment_3/data/CBFB_MYH11/patient_1/single_cell_probabilities.npy
# patient_3
# ../../artificialdata/experiment_3/data/CBFB_MYH11/patient_3/single_cell_probabilities.npy
# patient_5
# ../../artificialdata/experiment_3/data/CBFB_MYH11/patient_5/single_cell_probabilities.npy
# NPM1
# patient_2
# ../../artificialdata/experiment_3/data/NPM1/patient_2/single_cell_probabilities.npy
# patient_4
# ../../artificialdata/experiment_3/data/NPM1/patient_4/single_cell_probabilities.npy
# /tmp/ipykernel_262918/2824657938.py:43: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = get_cmap('tab20c', len(unique_labels))
# patient_1
# ../../artificialdata/experiment_3/data/NPM1/patient_1/single_cell_probabilities.npy
# patient_3
# ../../artificialdata/experiment_3/data/NPM1/patient_3/single_cell_probabilities.npy
# patient_5
# ../../artificialdata/experiment_3/data/NPM1/patient_5/single_cell_probabilities.npy
# RUNX1_RUNX1T1
# patient_2
# ../../artificialdata/experiment_3/data/RUNX1_RUNX1T1/patient_2/single_cell_probabilities.npy
# patient_4
# ../../artificialdata/experiment_3/data/RUNX1_RUNX1T1/patient_4/single_cell_probabilities.npy
# patient_1
# ../../artificialdata/experiment_3/data/RUNX1_RUNX1T1/patient_1/single_cell_probabilities.npy
# patient_3
# ../../artificialdata/experiment_3/data/RUNX1_RUNX1T1/patient_3/single_cell_probabilities.npy
# patient_5
# ../../artificialdata/experiment_3/data/RUNX1_RUNX1T1/patient_5/single_cell_probabilities.npy
# control
# patient_2
# ../../artificialdata/experiment_3/data/control/patient_2/single_cell_probabilities.npy
# patient_4
# ../../artificialdata/experiment_3/data/control/patient_4/single_cell_probabilities.npy
# patient_1
# ../../artificialdata/experiment_3/data/control/patient_1/single_cell_probabilities.npy
# patient_3
# ../../artificialdata/experiment_3/data/control/patient_3/single_cell_probabilities.npy
# patient_5
# ../../artificialdata/experiment_3/data/control/patient_5/single_cell_probabilities.npy
