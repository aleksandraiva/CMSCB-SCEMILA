# %%
#same as plot.ipynb but with artificial data

import matplotlib.pyplot as plt
import numpy as np
import os
from matplotlib.cm import get_cmap
from matplotlib.lines import Line2D
import pickle
import re

# Path to the folder containing your subfolders
data_path = '../../artificialdata/experiment_3/data'

# %%
def get_counts_vector(labels_vector):
    unique_labels, label_counts = np.unique(labels_vector, return_counts=True)
    counts_vector = np.zeros(22, dtype=int)
    counts_vector[unique_labels] = label_counts
    return counts_vector, unique_labels


def get_patient_name(path):
    return re.search(r"/data/\w+/([A-Z]{3})", path).group(1)

def get_class_name(path):
    return re.search(r"/data/(\w+)", path).group(1)

def get_image_number(path):
    print(path)
    return int(re.search(r"image_(\d+).tif", path).group(1))
   

def get_classification_patient(patient_folder):
    probs_path = patient_folder + '/single_cell_probabilities.npy'
    sc_probs = np.load(probs_path)
    sc_class= np.argmax(sc_probs, axis=1)
    return sc_class

'''def save_single_cell_probabilities(data, folder_patient):
    # Create single cell probalities for specific artificial patient
    artificial_folder_path = "../../artificialdata/experiment_3/data/CBFB_MYH11/patient_1"
    with open( os.path.join(artificial_folder_path,"image_file_paths") ,'rb') as fp:
        image_file_paths=pickle.load(fp)

    prev_subtype= get_class_name(image_file_paths[0]) 
    prev_patient = get_patient_name(image_file_paths[0])
    probs_path = data_path +"/"+ prev_subtype +"/"+ prev_patient+'/single_cell_probabilities.npy'

    sc_probs_artificial_list=[]
    for image_path in image_file_paths:
        aml_subtype = get_class_name(image_path)    
        patient = get_patient_name(image_path)   
        image_number = get_image_number(image_path)
        if aml_subtype!=prev_subtype or prev_patient!=patient:
            probs_path = data_path +"/"+ aml_subtype +"/"+ patient+'/single_cell_probabilities.npy'
        prev_patient=patient
        prev_subtype=aml_subtype
        sc_probs = np.load(probs_path)[image_number]
        sc_probs_artificial_list.append([sc_probs])
    sc_probs_artificial = np.concatenate(sc_probs_artificial_list,axis=0)    

    np.save(artificial_folder_path+"/single_cell_probabilities.npy", sc_probs_artificial)'''

def save_single_cell_probabilities(data_folder_real, patient_folder_art):
# Create single cell probabilities for a specific patient
   
    print(patient_folder_art)
    with open(os.path.join(patient_folder_art, "image_file_paths"), 'rb') as fp:
        image_file_paths = pickle.load(fp)

    prev_subtype = get_class_name(image_file_paths[0])
    prev_patient = get_patient_name(image_file_paths[0])
    probs_path = os.path.join(data_folder_real, prev_subtype, prev_patient, 'single_cell_probabilities.npy')

    sc_probs_artificial_list = []

    for image_path in image_file_paths:
        aml_subtype = get_class_name(image_path)
        patient = get_patient_name(image_path)
        image_number = get_image_number(image_path)

        if aml_subtype != prev_subtype or prev_patient != patient:
            probs_path = os.path.join(data_folder_real, aml_subtype, patient, 'single_cell_probabilities.npy')
        print(f"Probspath: ",probs_path, "Patient: ",patient, "image: ", image_number, "AML subtype: ", aml_subtype)
        prev_patient = patient
        prev_subtype = aml_subtype
        sc_probs = np.load(probs_path)[image_number]
        sc_probs_artificial_list.append([sc_probs])

    sc_probs_artificial = np.concatenate(sc_probs_artificial_list, axis=0)

    np.save(os.path.join(patient_folder_art, "single_cell_probabilities.npy"), sc_probs_artificial)

# %%
data_path_art = data_path
data_path_real="../../data"
for data_folder in os.listdir(data_path_art):
        data_folder_path = os.path.join(data_path_art, data_folder)

        # Check if the item in the directory is a folder
        if os.path.isdir(data_folder_path):
            print(data_folder)
            # Iterate over all patients within each data folder
            for patient_folder in os.listdir(data_folder_path):
              
                patient_folder=os.path.join(data_folder_path,patient_folder)
                print(patient_folder)
                save_single_cell_probabilities(data_path_real, patient_folder)
# Out:
# PML_RARA
# ../../artificialdata/experiment_3/data/PML_RARA/patient_2
# ../../artificialdata/experiment_3/data/PML_RARA/patient_2
# ../../data/CBFB_MYH11/AQK/image_110.tif
# Probspath:  ../../data/CBFB_MYH11/AQK/single_cell_probabilities.npy Patient:  AQK image:  110 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/AQK/image_116.tif
# Probspath:  ../../data/CBFB_MYH11/AQK/single_cell_probabilities.npy Patient:  AQK image:  116 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/AQK/image_128.tif
# Probspath:  ../../data/CBFB_MYH11/AQK/single_cell_probabilities.npy Patient:  AQK image:  128 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/AQK/image_131.tif
# Probspath:  ../../data/CBFB_MYH11/AQK/single_cell_probabilities.npy Patient:  AQK image:  131 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/AQK/image_152.tif
# Probspath:  ../../data/CBFB_MYH11/AQK/single_cell_probabilities.npy Patient:  AQK image:  152 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/AQK/image_189.tif
# Probspath:  ../../data/CBFB_MYH11/AQK/single_cell_probabilities.npy Patient:  AQK image:  189 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/AQK/image_19.tif
# Probspath:  ../../data/CBFB_MYH11/AQK/single_cell_probabilities.npy Patient:  AQK image:  19 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/AQK/image_225.tif
# Probspath:  ../../data/CBFB_MYH11/AQK/single_cell_probabilities.npy Patient:  AQK image:  225 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/AQK/image_226.tif
# Probspath:  ../../data/CBFB_MYH11/AQK/single_cell_probabilities.npy Patient:  AQK image:  226 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/AQK/image_229.tif
# Probspath:  ../../data/CBFB_MYH11/AQK/single_cell_probabilities.npy Patient:  AQK image:  229 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/AQK/image_232.tif
# Probspath:  ../../data/CBFB_MYH11/AQK/single_cell_probabilities.npy Patient:  AQK image:  232 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/AQK/image_249.tif
# Probspath:  ../../data/CBFB_MYH11/AQK/single_cell_probabilities.npy Patient:  AQK image:  249 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/AQK/image_275.tif
# Probspath:  ../../data/CBFB_MYH11/AQK/single_cell_probabilities.npy Patient:  AQK image:  275 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/AQK/image_296.tif
# Probspath:  ../../data/CBFB_MYH11/AQK/single_cell_probabilities.npy Patient:  AQK image:  296 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/AQK/image_298.tif
# Probspath:  ../../data/CBFB_MYH11/AQK/single_cell_probabilities.npy Patient:  AQK image:  298 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/AQK/image_380.tif
# Probspath:  ../../data/CBFB_MYH11/AQK/single_cell_probabilities.npy Patient:  AQK image:  380 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/AQK/image_4.tif
# Probspath:  ../../data/CBFB_MYH11/AQK/single_cell_probabilities.npy Patient:  AQK image:  4 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/AQK/image_4.tif
# Probspath:  ../../data/CBFB_MYH11/AQK/single_cell_probabilities.npy Patient:  AQK image:  4 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/AQK/image_46.tif
# Probspath:  ../../data/CBFB_MYH11/AQK/single_cell_probabilities.npy Patient:  AQK image:  46 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/AQK/image_54.tif
# Probspath:  ../../data/CBFB_MYH11/AQK/single_cell_probabilities.npy Patient:  AQK image:  54 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/AQK/image_64.tif
# Probspath:  ../../data/CBFB_MYH11/AQK/single_cell_probabilities.npy Patient:  AQK image:  64 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/AQK/image_68.tif
# Probspath:  ../../data/CBFB_MYH11/AQK/single_cell_probabilities.npy Patient:  AQK image:  68 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/AQK/image_81.tif
# Probspath:  ../../data/CBFB_MYH11/AQK/single_cell_probabilities.npy Patient:  AQK image:  81 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/AQK/image_87.tif
# Probspath:  ../../data/CBFB_MYH11/AQK/single_cell_probabilities.npy Patient:  AQK image:  87 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/AQK/image_88.tif
# Probspath:  ../../data/CBFB_MYH11/AQK/single_cell_probabilities.npy Patient:  AQK image:  88 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BJK/image_110.tif
# Probspath:  ../../data/CBFB_MYH11/BJK/single_cell_probabilities.npy Patient:  BJK image:  110 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BJK/image_135.tif
# Probspath:  ../../data/CBFB_MYH11/BJK/single_cell_probabilities.npy Patient:  BJK image:  135 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BJK/image_16.tif
# Probspath:  ../../data/CBFB_MYH11/BJK/single_cell_probabilities.npy Patient:  BJK image:  16 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BJK/image_176.tif
# Probspath:  ../../data/CBFB_MYH11/BJK/single_cell_probabilities.npy Patient:  BJK image:  176 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BJK/image_189.tif
# Probspath:  ../../data/CBFB_MYH11/BJK/single_cell_probabilities.npy Patient:  BJK image:  189 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BJK/image_191.tif
# Probspath:  ../../data/CBFB_MYH11/BJK/single_cell_probabilities.npy Patient:  BJK image:  191 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BJK/image_193.tif
# Probspath:  ../../data/CBFB_MYH11/BJK/single_cell_probabilities.npy Patient:  BJK image:  193 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BJK/image_197.tif
# Probspath:  ../../data/CBFB_MYH11/BJK/single_cell_probabilities.npy Patient:  BJK image:  197 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BJK/image_205.tif
# Probspath:  ../../data/CBFB_MYH11/BJK/single_cell_probabilities.npy Patient:  BJK image:  205 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BJK/image_230.tif
# Probspath:  ../../data/CBFB_MYH11/BJK/single_cell_probabilities.npy Patient:  BJK image:  230 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BJK/image_236.tif
# Probspath:  ../../data/CBFB_MYH11/BJK/single_cell_probabilities.npy Patient:  BJK image:  236 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BJK/image_245.tif
# Probspath:  ../../data/CBFB_MYH11/BJK/single_cell_probabilities.npy Patient:  BJK image:  245 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BJK/image_258.tif
# Probspath:  ../../data/CBFB_MYH11/BJK/single_cell_probabilities.npy Patient:  BJK image:  258 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BJK/image_260.tif
# Probspath:  ../../data/CBFB_MYH11/BJK/single_cell_probabilities.npy Patient:  BJK image:  260 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BJK/image_293.tif
# Probspath:  ../../data/CBFB_MYH11/BJK/single_cell_probabilities.npy Patient:  BJK image:  293 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BJK/image_328.tif
# Probspath:  ../../data/CBFB_MYH11/BJK/single_cell_probabilities.npy Patient:  BJK image:  328 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BJK/image_331.tif
# Probspath:  ../../data/CBFB_MYH11/BJK/single_cell_probabilities.npy Patient:  BJK image:  331 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BJK/image_336.tif
# Probspath:  ../../data/CBFB_MYH11/BJK/single_cell_probabilities.npy Patient:  BJK image:  336 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BJK/image_343.tif
# Probspath:  ../../data/CBFB_MYH11/BJK/single_cell_probabilities.npy Patient:  BJK image:  343 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BJK/image_350.tif
# Probspath:  ../../data/CBFB_MYH11/BJK/single_cell_probabilities.npy Patient:  BJK image:  350 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BJK/image_371.tif
# Probspath:  ../../data/CBFB_MYH11/BJK/single_cell_probabilities.npy Patient:  BJK image:  371 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BJK/image_374.tif
# Probspath:  ../../data/CBFB_MYH11/BJK/single_cell_probabilities.npy Patient:  BJK image:  374 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BJK/image_377.tif
# Probspath:  ../../data/CBFB_MYH11/BJK/single_cell_probabilities.npy Patient:  BJK image:  377 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BJK/image_386.tif
# Probspath:  ../../data/CBFB_MYH11/BJK/single_cell_probabilities.npy Patient:  BJK image:  386 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BJK/image_412.tif
# Probspath:  ../../data/CBFB_MYH11/BJK/single_cell_probabilities.npy Patient:  BJK image:  412 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BJK/image_419.tif
# Probspath:  ../../data/CBFB_MYH11/BJK/single_cell_probabilities.npy Patient:  BJK image:  419 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BJK/image_455.tif
# Probspath:  ../../data/CBFB_MYH11/BJK/single_cell_probabilities.npy Patient:  BJK image:  455 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BJK/image_457.tif
# Probspath:  ../../data/CBFB_MYH11/BJK/single_cell_probabilities.npy Patient:  BJK image:  457 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BJK/image_480.tif
# Probspath:  ../../data/CBFB_MYH11/BJK/single_cell_probabilities.npy Patient:  BJK image:  480 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BJK/image_487.tif
# Probspath:  ../../data/CBFB_MYH11/BJK/single_cell_probabilities.npy Patient:  BJK image:  487 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BJK/image_492.tif
# Probspath:  ../../data/CBFB_MYH11/BJK/single_cell_probabilities.npy Patient:  BJK image:  492 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BJK/image_5.tif
# Probspath:  ../../data/CBFB_MYH11/BJK/single_cell_probabilities.npy Patient:  BJK image:  5 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BJK/image_5.tif
# Probspath:  ../../data/CBFB_MYH11/BJK/single_cell_probabilities.npy Patient:  BJK image:  5 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BJK/image_77.tif
# Probspath:  ../../data/CBFB_MYH11/BJK/single_cell_probabilities.npy Patient:  BJK image:  77 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BJK/image_77.tif
# Probspath:  ../../data/CBFB_MYH11/BJK/single_cell_probabilities.npy Patient:  BJK image:  77 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BJK/image_79.tif
# Probspath:  ../../data/CBFB_MYH11/BJK/single_cell_probabilities.npy Patient:  BJK image:  79 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BJK/image_87.tif
# Probspath:  ../../data/CBFB_MYH11/BJK/single_cell_probabilities.npy Patient:  BJK image:  87 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BJK/image_92.tif
# Probspath:  ../../data/CBFB_MYH11/BJK/single_cell_probabilities.npy Patient:  BJK image:  92 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BSN/image_102.tif
# Probspath:  ../../data/CBFB_MYH11/BSN/single_cell_probabilities.npy Patient:  BSN image:  102 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BSN/image_123.tif
# Probspath:  ../../data/CBFB_MYH11/BSN/single_cell_probabilities.npy Patient:  BSN image:  123 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BSN/image_135.tif
# Probspath:  ../../data/CBFB_MYH11/BSN/single_cell_probabilities.npy Patient:  BSN image:  135 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BSN/image_149.tif
# Probspath:  ../../data/CBFB_MYH11/BSN/single_cell_probabilities.npy Patient:  BSN image:  149 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BSN/image_181.tif
# Probspath:  ../../data/CBFB_MYH11/BSN/single_cell_probabilities.npy Patient:  BSN image:  181 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BSN/image_202.tif
# Probspath:  ../../data/CBFB_MYH11/BSN/single_cell_probabilities.npy Patient:  BSN image:  202 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BSN/image_228.tif
# Probspath:  ../../data/CBFB_MYH11/BSN/single_cell_probabilities.npy Patient:  BSN image:  228 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BSN/image_273.tif
# Probspath:  ../../data/CBFB_MYH11/BSN/single_cell_probabilities.npy Patient:  BSN image:  273 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BSN/image_283.tif
# Probspath:  ../../data/CBFB_MYH11/BSN/single_cell_probabilities.npy Patient:  BSN image:  283 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BSN/image_292.tif
# Probspath:  ../../data/CBFB_MYH11/BSN/single_cell_probabilities.npy Patient:  BSN image:  292 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BSN/image_48.tif
# Probspath:  ../../data/CBFB_MYH11/BSN/single_cell_probabilities.npy Patient:  BSN image:  48 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BSN/image_57.tif
# Probspath:  ../../data/CBFB_MYH11/BSN/single_cell_probabilities.npy Patient:  BSN image:  57 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BSN/image_6.tif
# Probspath:  ../../data/CBFB_MYH11/BSN/single_cell_probabilities.npy Patient:  BSN image:  6 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BSN/image_65.tif
# Probspath:  ../../data/CBFB_MYH11/BSN/single_cell_probabilities.npy Patient:  BSN image:  65 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BSN/image_84.tif
# Probspath:  ../../data/CBFB_MYH11/BSN/single_cell_probabilities.npy Patient:  BSN image:  84 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BTB/image_0.tif
# Probspath:  ../../data/CBFB_MYH11/BTB/single_cell_probabilities.npy Patient:  BTB image:  0 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BTB/image_104.tif
# Probspath:  ../../data/CBFB_MYH11/BTB/single_cell_probabilities.npy Patient:  BTB image:  104 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BTB/image_145.tif
# Probspath:  ../../data/CBFB_MYH11/BTB/single_cell_probabilities.npy Patient:  BTB image:  145 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BTB/image_146.tif
# Probspath:  ../../data/CBFB_MYH11/BTB/single_cell_probabilities.npy Patient:  BTB image:  146 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BTB/image_146.tif
# Probspath:  ../../data/CBFB_MYH11/BTB/single_cell_probabilities.npy Patient:  BTB image:  146 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BTB/image_167.tif
# Probspath:  ../../data/CBFB_MYH11/BTB/single_cell_probabilities.npy Patient:  BTB image:  167 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BTB/image_2.tif
# Probspath:  ../../data/CBFB_MYH11/BTB/single_cell_probabilities.npy Patient:  BTB image:  2 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BTB/image_206.tif
# Probspath:  ../../data/CBFB_MYH11/BTB/single_cell_probabilities.npy Patient:  BTB image:  206 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BTB/image_223.tif
# Probspath:  ../../data/CBFB_MYH11/BTB/single_cell_probabilities.npy Patient:  BTB image:  223 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BTB/image_227.tif
# Probspath:  ../../data/CBFB_MYH11/BTB/single_cell_probabilities.npy Patient:  BTB image:  227 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BTB/image_233.tif
# Probspath:  ../../data/CBFB_MYH11/BTB/single_cell_probabilities.npy Patient:  BTB image:  233 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BTB/image_273.tif
# Probspath:  ../../data/CBFB_MYH11/BTB/single_cell_probabilities.npy Patient:  BTB image:  273 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BTB/image_277.tif
# Probspath:  ../../data/CBFB_MYH11/BTB/single_cell_probabilities.npy Patient:  BTB image:  277 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BTB/image_282.tif
# Probspath:  ../../data/CBFB_MYH11/BTB/single_cell_probabilities.npy Patient:  BTB image:  282 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BTB/image_283.tif
# Probspath:  ../../data/CBFB_MYH11/BTB/single_cell_probabilities.npy Patient:  BTB image:  283 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BTB/image_290.tif
# Probspath:  ../../data/CBFB_MYH11/BTB/single_cell_probabilities.npy Patient:  BTB image:  290 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/BTB/image_33.tif
# Probspath:  ../../data/CBFB_MYH11/BTB/single_cell_probabilities.npy Patient:  BTB image:  33 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/DQV/image_1.tif
# Probspath:  ../../data/CBFB_MYH11/DQV/single_cell_probabilities.npy Patient:  DQV image:  1 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/DQV/image_119.tif
# Probspath:  ../../data/CBFB_MYH11/DQV/single_cell_probabilities.npy Patient:  DQV image:  119 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/DQV/image_122.tif
# Probspath:  ../../data/CBFB_MYH11/DQV/single_cell_probabilities.npy Patient:  DQV image:  122 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/DQV/image_13.tif
# Probspath:  ../../data/CBFB_MYH11/DQV/single_cell_probabilities.npy Patient:  DQV image:  13 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/DQV/image_153.tif
# Probspath:  ../../data/CBFB_MYH11/DQV/single_cell_probabilities.npy Patient:  DQV image:  153 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/DQV/image_171.tif
# Probspath:  ../../data/CBFB_MYH11/DQV/single_cell_probabilities.npy Patient:  DQV image:  171 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/DQV/image_194.tif
# Probspath:  ../../data/CBFB_MYH11/DQV/single_cell_probabilities.npy Patient:  DQV image:  194 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/DQV/image_236.tif
# Probspath:  ../../data/CBFB_MYH11/DQV/single_cell_probabilities.npy Patient:  DQV image:  236 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/DQV/image_239.tif
# Probspath:  ../../data/CBFB_MYH11/DQV/single_cell_probabilities.npy Patient:  DQV image:  239 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/DQV/image_246.tif
# Probspath:  ../../data/CBFB_MYH11/DQV/single_cell_probabilities.npy Patient:  DQV image:  246 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/DQV/image_28.tif
# Probspath:  ../../data/CBFB_MYH11/DQV/single_cell_probabilities.npy Patient:  DQV image:  28 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/DQV/image_371.tif
# Probspath:  ../../data/CBFB_MYH11/DQV/single_cell_probabilities.npy Patient:  DQV image:  371 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/DQV/image_422.tif
# Probspath:  ../../data/CBFB_MYH11/DQV/single_cell_probabilities.npy Patient:  DQV image:  422 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/DQV/image_430.tif
# Probspath:  ../../data/CBFB_MYH11/DQV/single_cell_probabilities.npy Patient:  DQV image:  430 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/DQV/image_430.tif
# Probspath:  ../../data/CBFB_MYH11/DQV/single_cell_probabilities.npy Patient:  DQV image:  430 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/DQV/image_497.tif
# Probspath:  ../../data/CBFB_MYH11/DQV/single_cell_probabilities.npy Patient:  DQV image:  497 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/DQV/image_65.tif
# Probspath:  ../../data/CBFB_MYH11/DQV/single_cell_probabilities.npy Patient:  DQV image:  65 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/DQV/image_70.tif
# Probspath:  ../../data/CBFB_MYH11/DQV/single_cell_probabilities.npy Patient:  DQV image:  70 AML subtype:  CBFB_MYH11
# ../../data/CBFB_MYH11/DQV/image_96.tif
# Probspath:  ../../data/CBFB_MYH11/DQV/single_cell_probabilities.npy Patient:  DQV image:  96 AML subtype:  CBFB_MYH11
# ../../data/NPM1/ALA/image_110.tif
# Probspath:  ../../data/NPM1/ALA/single_cell_probabilities.npy Patient:  ALA image:  110 AML subtype:  NPM1
# ../../data/NPM1/ALA/image_125.tif
# Probspath:  ../../data/NPM1/ALA/single_cell_probabilities.npy Patient:  ALA image:  125 AML subtype:  NPM1
# ../../data/NPM1/ALA/image_199.tif
# Probspath:  ../../data/NPM1/ALA/single_cell_probabilities.npy Patient:  ALA image:  199 AML subtype:  NPM1
# ../../data/NPM1/ALA/image_20.tif
# Probspath:  ../../data/NPM1/ALA/single_cell_probabilities.npy Patient:  ALA image:  20 AML subtype:  NPM1
# ../../data/NPM1/ALA/image_250.tif
# Probspath:  ../../data/NPM1/ALA/single_cell_probabilities.npy Patient:  ALA image:  250 AML subtype:  NPM1
# ../../data/NPM1/ALA/image_34.tif
# Probspath:  ../../data/NPM1/ALA/single_cell_probabilities.npy Patient:  ALA image:  34 AML subtype:  NPM1
# ../../data/NPM1/ALA/image_344.tif
# Probspath:  ../../data/NPM1/ALA/single_cell_probabilities.npy Patient:  ALA image:  344 AML subtype:  NPM1
# ../../data/NPM1/ALA/image_345.tif
# Probspath:  ../../data/NPM1/ALA/single_cell_probabilities.npy Patient:  ALA image:  345 AML subtype:  NPM1
# ../../data/NPM1/ALA/image_355.tif
# Probspath:  ../../data/NPM1/ALA/single_cell_probabilities.npy Patient:  ALA image:  355 AML subtype:  NPM1
# ../../data/NPM1/ALA/image_384.tif
# Probspath:  ../../data/NPM1/ALA/single_cell_probabilities.npy Patient:  ALA image:  384 AML subtype:  NPM1
# ../../data/NPM1/ALA/image_417.tif
# Probspath:  ../../data/NPM1/ALA/single_cell_probabilities.npy Patient:  ALA image:  417 AML subtype:  NPM1
# ../../data/NPM1/ALA/image_433.tif
# Probspath:  ../../data/NPM1/ALA/single_cell_probabilities.npy Patient:  ALA image:  433 AML subtype:  NPM1
# ../../data/NPM1/ALA/image_433.tif
# Probspath:  ../../data/NPM1/ALA/single_cell_probabilities.npy Patient:  ALA image:  433 AML subtype:  NPM1
# ../../data/NPM1/ALA/image_437.tif
# Probspath:  ../../data/NPM1/ALA/single_cell_probabilities.npy Patient:  ALA image:  437 AML subtype:  NPM1
# ../../data/NPM1/BHR/image_113.tif
# Probspath:  ../../data/NPM1/BHR/single_cell_probabilities.npy Patient:  BHR image:  113 AML subtype:  NPM1
# ../../data/NPM1/BHR/image_143.tif
# Probspath:  ../../data/NPM1/BHR/single_cell_probabilities.npy Patient:  BHR image:  143 AML subtype:  NPM1
# ../../data/NPM1/BHR/image_307.tif
# Probspath:  ../../data/NPM1/BHR/single_cell_probabilities.npy Patient:  BHR image:  307 AML subtype:  NPM1
# ../../data/NPM1/BHR/image_351.tif
# Probspath:  ../../data/NPM1/BHR/single_cell_probabilities.npy Patient:  BHR image:  351 AML subtype:  NPM1
# ../../data/NPM1/BHR/image_371.tif
# Probspath:  ../../data/NPM1/BHR/single_cell_probabilities.npy Patient:  BHR image:  371 AML subtype:  NPM1
# ../../data/NPM1/BHR/image_371.tif
# Probspath:  ../../data/NPM1/BHR/single_cell_probabilities.npy Patient:  BHR image:  371 AML subtype:  NPM1
# ../../data/NPM1/BHR/image_423.tif
# Probspath:  ../../data/NPM1/BHR/single_cell_probabilities.npy Patient:  BHR image:  423 AML subtype:  NPM1
# ../../data/NPM1/BHR/image_79.tif
# Probspath:  ../../data/NPM1/BHR/single_cell_probabilities.npy Patient:  BHR image:  79 AML subtype:  NPM1
# ../../data/NPM1/BHR/image_92.tif
# Probspath:  ../../data/NPM1/BHR/single_cell_probabilities.npy Patient:  BHR image:  92 AML subtype:  NPM1
# ../../data/NPM1/CVW/image_121.tif
# Probspath:  ../../data/NPM1/CVW/single_cell_probabilities.npy Patient:  CVW image:  121 AML subtype:  NPM1
# ../../data/NPM1/CVW/image_123.tif
# Probspath:  ../../data/NPM1/CVW/single_cell_probabilities.npy Patient:  CVW image:  123 AML subtype:  NPM1
# ../../data/NPM1/CVW/image_124.tif
# Probspath:  ../../data/NPM1/CVW/single_cell_probabilities.npy Patient:  CVW image:  124 AML subtype:  NPM1
# ../../data/NPM1/CVW/image_127.tif
# Probspath:  ../../data/NPM1/CVW/single_cell_probabilities.npy Patient:  CVW image:  127 AML subtype:  NPM1
# ../../data/NPM1/CVW/image_147.tif
# Probspath:  ../../data/NPM1/CVW/single_cell_probabilities.npy Patient:  CVW image:  147 AML subtype:  NPM1
# ../../data/NPM1/CVW/image_170.tif
# Probspath:  ../../data/NPM1/CVW/single_cell_probabilities.npy Patient:  CVW image:  170 AML subtype:  NPM1
# ../../data/NPM1/CVW/image_214.tif
# Probspath:  ../../data/NPM1/CVW/single_cell_probabilities.npy Patient:  CVW image:  214 AML subtype:  NPM1
# ../../data/NPM1/CVW/image_244.tif
# Probspath:  ../../data/NPM1/CVW/single_cell_probabilities.npy Patient:  CVW image:  244 AML subtype:  NPM1
# ../../data/NPM1/CVW/image_268.tif
# Probspath:  ../../data/NPM1/CVW/single_cell_probabilities.npy Patient:  CVW image:  268 AML subtype:  NPM1
# ../../data/NPM1/CVW/image_300.tif
# Probspath:  ../../data/NPM1/CVW/single_cell_probabilities.npy Patient:  CVW image:  300 AML subtype:  NPM1
# ../../data/NPM1/CVW/image_329.tif
# Probspath:  ../../data/NPM1/CVW/single_cell_probabilities.npy Patient:  CVW image:  329 AML subtype:  NPM1
# ../../data/NPM1/CVW/image_343.tif
# Probspath:  ../../data/NPM1/CVW/single_cell_probabilities.npy Patient:  CVW image:  343 AML subtype:  NPM1
# ../../data/NPM1/CVW/image_343.tif
# Probspath:  ../../data/NPM1/CVW/single_cell_probabilities.npy Patient:  CVW image:  343 AML subtype:  NPM1
# ../../data/NPM1/CVW/image_372.tif
# Probspath:  ../../data/NPM1/CVW/single_cell_probabilities.npy Patient:  CVW image:  372 AML subtype:  NPM1
# ../../data/NPM1/CVW/image_438.tif
# Probspath:  ../../data/NPM1/CVW/single_cell_probabilities.npy Patient:  CVW image:  438 AML subtype:  NPM1
# ../../data/NPM1/CVW/image_486.tif
# Probspath:  ../../data/NPM1/CVW/single_cell_probabilities.npy Patient:  CVW image:  486 AML subtype:  NPM1
# ../../data/NPM1/CVW/image_486.tif
# Probspath:  ../../data/NPM1/CVW/single_cell_probabilities.npy Patient:  CVW image:  486 AML subtype:  NPM1
# ../../data/NPM1/CVW/image_49.tif
# Probspath:  ../../data/NPM1/CVW/single_cell_probabilities.npy Patient:  CVW image:  49 AML subtype:  NPM1
# ../../data/NPM1/CVW/image_495.tif
# Probspath:  ../../data/NPM1/CVW/single_cell_probabilities.npy Patient:  CVW image:  495 AML subtype:  NPM1
# ../../data/NPM1/CVW/image_96.tif
# Probspath:  ../../data/NPM1/CVW/single_cell_probabilities.npy Patient:  CVW image:  96 AML subtype:  NPM1
# ../../data/NPM1/CZI/image_14.tif
# Probspath:  ../../data/NPM1/CZI/single_cell_probabilities.npy Patient:  CZI image:  14 AML subtype:  NPM1
# ../../data/NPM1/CZI/image_225.tif
# Probspath:  ../../data/NPM1/CZI/single_cell_probabilities.npy Patient:  CZI image:  225 AML subtype:  NPM1
# ../../data/NPM1/CZI/image_262.tif
# Probspath:  ../../data/NPM1/CZI/single_cell_probabilities.npy Patient:  CZI image:  262 AML subtype:  NPM1
# ../../data/NPM1/CZI/image_264.tif
# Probspath:  ../../data/NPM1/CZI/single_cell_probabilities.npy Patient:  CZI image:  264 AML subtype:  NPM1
# ../../data/NPM1/CZI/image_277.tif
# Probspath:  ../../data/NPM1/CZI/single_cell_probabilities.npy Patient:  CZI image:  277 AML subtype:  NPM1
# ../../data/NPM1/CZI/image_293.tif
# Probspath:  ../../data/NPM1/CZI/single_cell_probabilities.npy Patient:  CZI image:  293 AML subtype:  NPM1
# ../../data/NPM1/CZI/image_309.tif
# Probspath:  ../../data/NPM1/CZI/single_cell_probabilities.npy Patient:  CZI image:  309 AML subtype:  NPM1
# ../../data/NPM1/CZI/image_309.tif
# Probspath:  ../../data/NPM1/CZI/single_cell_probabilities.npy Patient:  CZI image:  309 AML subtype:  NPM1
# ../../data/NPM1/CZI/image_32.tif
# Probspath:  ../../data/NPM1/CZI/single_cell_probabilities.npy Patient:  CZI image:  32 AML subtype:  NPM1
# ../../data/NPM1/CZI/image_326.tif
# Probspath:  ../../data/NPM1/CZI/single_cell_probabilities.npy Patient:  CZI image:  326 AML subtype:  NPM1
# ../../data/NPM1/CZI/image_384.tif
# Probspath:  ../../data/NPM1/CZI/single_cell_probabilities.npy Patient:  CZI image:  384 AML subtype:  NPM1
# ../../data/NPM1/CZI/image_396.tif
# Probspath:  ../../data/NPM1/CZI/single_cell_probabilities.npy Patient:  CZI image:  396 AML subtype:  NPM1
# ../../data/NPM1/CZI/image_419.tif
# Probspath:  ../../data/NPM1/CZI/single_cell_probabilities.npy Patient:  CZI image:  419 AML subtype:  NPM1
# ../../data/NPM1/CZI/image_45.tif
# Probspath:  ../../data/NPM1/CZI/single_cell_probabilities.npy Patient:  CZI image:  45 AML subtype:  NPM1
# ../../data/NPM1/CZI/image_47.tif
# Probspath:  ../../data/NPM1/CZI/single_cell_probabilities.npy Patient:  CZI image:  47 AML subtype:  NPM1
# ../../data/NPM1/CZI/image_48.tif
# Probspath:  ../../data/NPM1/CZI/single_cell_probabilities.npy Patient:  CZI image:  48 AML subtype:  NPM1
# ../../data/NPM1/CZI/image_483.tif
# Probspath:  ../../data/NPM1/CZI/single_cell_probabilities.npy Patient:  CZI image:  483 AML subtype:  NPM1
# ../../data/NPM1/CZI/image_491.tif
# Probspath:  ../../data/NPM1/CZI/single_cell_probabilities.npy Patient:  CZI image:  491 AML subtype:  NPM1
# ../../data/NPM1/CZI/image_59.tif
# Probspath:  ../../data/NPM1/CZI/single_cell_probabilities.npy Patient:  CZI image:  59 AML subtype:  NPM1
# ../../data/NPM1/CZI/image_69.tif
# Probspath:  ../../data/NPM1/CZI/single_cell_probabilities.npy Patient:  CZI image:  69 AML subtype:  NPM1
# ../../data/NPM1/CZI/image_74.tif
# Probspath:  ../../data/NPM1/CZI/single_cell_probabilities.npy Patient:  CZI image:  74 AML subtype:  NPM1
# ../../data/NPM1/CZI/image_94.tif
# Probspath:  ../../data/NPM1/CZI/single_cell_probabilities.npy Patient:  CZI image:  94 AML subtype:  NPM1
# ../../data/NPM1/CZI/image_98.tif
# Probspath:  ../../data/NPM1/CZI/single_cell_probabilities.npy Patient:  CZI image:  98 AML subtype:  NPM1
# ../../data/NPM1/DPF/image_107.tif
# Probspath:  ../../data/NPM1/DPF/single_cell_probabilities.npy Patient:  DPF image:  107 AML subtype:  NPM1
# ../../data/NPM1/DPF/image_126.tif
# Probspath:  ../../data/NPM1/DPF/single_cell_probabilities.npy Patient:  DPF image:  126 AML subtype:  NPM1
# ../../data/NPM1/DPF/image_15.tif
# Probspath:  ../../data/NPM1/DPF/single_cell_probabilities.npy Patient:  DPF image:  15 AML subtype:  NPM1
# ../../data/NPM1/DPF/image_175.tif
# Probspath:  ../../data/NPM1/DPF/single_cell_probabilities.npy Patient:  DPF image:  175 AML subtype:  NPM1
# ../../data/NPM1/DPF/image_187.tif
# Probspath:  ../../data/NPM1/DPF/single_cell_probabilities.npy Patient:  DPF image:  187 AML subtype:  NPM1
# ../../data/NPM1/DPF/image_194.tif
# Probspath:  ../../data/NPM1/DPF/single_cell_probabilities.npy Patient:  DPF image:  194 AML subtype:  NPM1
# ../../data/NPM1/DPF/image_196.tif
# Probspath:  ../../data/NPM1/DPF/single_cell_probabilities.npy Patient:  DPF image:  196 AML subtype:  NPM1
# ../../data/NPM1/DPF/image_198.tif
# Probspath:  ../../data/NPM1/DPF/single_cell_probabilities.npy Patient:  DPF image:  198 AML subtype:  NPM1
# ../../data/NPM1/DPF/image_20.tif
# Probspath:  ../../data/NPM1/DPF/single_cell_probabilities.npy Patient:  DPF image:  20 AML subtype:  NPM1
# ../../data/NPM1/DPF/image_209.tif
# Probspath:  ../../data/NPM1/DPF/single_cell_probabilities.npy Patient:  DPF image:  209 AML subtype:  NPM1
# ../../data/NPM1/DPF/image_216.tif
# Probspath:  ../../data/NPM1/DPF/single_cell_probabilities.npy Patient:  DPF image:  216 AML subtype:  NPM1
# ../../data/NPM1/DPF/image_219.tif
# Probspath:  ../../data/NPM1/DPF/single_cell_probabilities.npy Patient:  DPF image:  219 AML subtype:  NPM1
# ../../data/NPM1/DPF/image_247.tif
# Probspath:  ../../data/NPM1/DPF/single_cell_probabilities.npy Patient:  DPF image:  247 AML subtype:  NPM1
# ../../data/NPM1/DPF/image_251.tif
# Probspath:  ../../data/NPM1/DPF/single_cell_probabilities.npy Patient:  DPF image:  251 AML subtype:  NPM1
# ../../data/NPM1/DPF/image_26.tif
# Probspath:  ../../data/NPM1/DPF/single_cell_probabilities.npy Patient:  DPF image:  26 AML subtype:  NPM1
# ../../data/NPM1/DPF/image_265.tif
# Probspath:  ../../data/NPM1/DPF/single_cell_probabilities.npy Patient:  DPF image:  265 AML subtype:  NPM1
# ../../data/NPM1/DPF/image_269.tif
# Probspath:  ../../data/NPM1/DPF/single_cell_probabilities.npy Patient:  DPF image:  269 AML subtype:  NPM1
# ../../data/NPM1/DPF/image_292.tif
# Probspath:  ../../data/NPM1/DPF/single_cell_probabilities.npy Patient:  DPF image:  292 AML subtype:  NPM1
# ../../data/NPM1/DPF/image_293.tif
# Probspath:  ../../data/NPM1/DPF/single_cell_probabilities.npy Patient:  DPF image:  293 AML subtype:  NPM1
# ../../data/NPM1/DPF/image_30.tif
# Probspath:  ../../data/NPM1/DPF/single_cell_probabilities.npy Patient:  DPF image:  30 AML subtype:  NPM1
# ../../data/NPM1/DPF/image_30.tif
# Probspath:  ../../data/NPM1/DPF/single_cell_probabilities.npy Patient:  DPF image:  30 AML subtype:  NPM1
# ../../data/NPM1/DPF/image_317.tif
# Probspath:  ../../data/NPM1/DPF/single_cell_probabilities.npy Patient:  DPF image:  317 AML subtype:  NPM1
# ../../data/NPM1/DPF/image_33.tif
# Probspath:  ../../data/NPM1/DPF/single_cell_probabilities.npy Patient:  DPF image:  33 AML subtype:  NPM1
# ../../data/NPM1/DPF/image_344.tif
# Probspath:  ../../data/NPM1/DPF/single_cell_probabilities.npy Patient:  DPF image:  344 AML subtype:  NPM1
# ../../data/NPM1/DPF/image_346.tif
# Probspath:  ../../data/NPM1/DPF/single_cell_probabilities.npy Patient:  DPF image:  346 AML subtype:  NPM1
# ../../data/NPM1/DPF/image_361.tif
# Probspath:  ../../data/NPM1/DPF/single_cell_probabilities.npy Patient:  DPF image:  361 AML subtype:  NPM1
# ../../data/NPM1/DPF/image_364.tif
# Probspath:  ../../data/NPM1/DPF/single_cell_probabilities.npy Patient:  DPF image:  364 AML subtype:  NPM1
# ../../data/NPM1/DPF/image_376.tif
# Probspath:  ../../data/NPM1/DPF/single_cell_probabilities.npy Patient:  DPF image:  376 AML subtype:  NPM1
# ../../data/NPM1/DPF/image_381.tif
# Probspath:  ../../data/NPM1/DPF/single_cell_probabilities.npy Patient:  DPF image:  381 AML subtype:  NPM1
# ../../data/NPM1/DPF/image_399.tif
# Probspath:  ../../data/NPM1/DPF/single_cell_probabilities.npy Patient:  DPF image:  399 AML subtype:  NPM1
# ../../data/NPM1/DPF/image_40.tif
# Probspath:  ../../data/NPM1/DPF/single_cell_probabilities.npy Patient:  DPF image:  40 AML subtype:  NPM1
# ../../data/NPM1/DPF/image_412.tif
# Probspath:  ../../data/NPM1/DPF/single_cell_probabilities.npy Patient:  DPF image:  412 AML subtype:  NPM1
# ../../data/NPM1/DPF/image_452.tif
# Probspath:  ../../data/NPM1/DPF/single_cell_probabilities.npy Patient:  DPF image:  452 AML subtype:  NPM1
# ../../data/NPM1/DPF/image_470.tif
# Probspath:  ../../data/NPM1/DPF/single_cell_probabilities.npy Patient:  DPF image:  470 AML subtype:  NPM1
# ../../data/NPM1/DPF/image_49.tif
# Probspath:  ../../data/NPM1/DPF/single_cell_probabilities.npy Patient:  DPF image:  49 AML subtype:  NPM1
# ../../data/NPM1/DPF/image_490.tif
# Probspath:  ../../data/NPM1/DPF/single_cell_probabilities.npy Patient:  DPF image:  490 AML subtype:  NPM1
# ../../data/NPM1/DPF/image_72.tif
# Probspath:  ../../data/NPM1/DPF/single_cell_probabilities.npy Patient:  DPF image:  72 AML subtype:  NPM1
# ../../data/NPM1/DPF/image_76.tif
# Probspath:  ../../data/NPM1/DPF/single_cell_probabilities.npy Patient:  DPF image:  76 AML subtype:  NPM1
# ../../data/NPM1/DPF/image_79.tif
# Probspath:  ../../data/NPM1/DPF/single_cell_probabilities.npy Patient:  DPF image:  79 AML subtype:  NPM1
# ../../data/PML_RARA/ALE/image_112.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  112 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_114.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  114 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_117.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  117 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_132.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  132 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_136.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  136 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_143.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  143 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_154.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  154 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_158.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  158 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_162.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  162 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_165.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  165 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_171.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  171 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_171.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  171 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_174.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  174 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_187.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  187 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_19.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  19 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_192.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  192 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_206.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  206 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_21.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  21 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_212.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  212 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_230.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  230 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_237.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  237 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_254.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  254 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_265.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  265 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_29.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  29 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_292.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  292 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_333.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  333 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_333.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  333 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_336.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  336 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_34.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  34 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_348.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  348 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_351.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  351 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_369.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  369 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_369.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  369 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_397.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  397 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_421.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  421 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_429.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  429 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_430.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  430 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_430.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  430 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_435.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  435 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_438.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  438 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_445.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  445 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_458.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  458 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_468.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  468 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_477.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  477 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_59.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  59 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_7.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  7 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_7.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  7 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_83.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  83 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_90.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  90 AML subtype:  PML_RARA
# ../../data/PML_RARA/ALE/image_90.tif
# Probspath:  ../../data/PML_RARA/ALE/single_cell_probabilities.npy Patient:  ALE image:  90 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_110.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  110 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_113.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  113 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_118.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  118 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_120.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  120 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_123.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  123 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_129.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  129 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_13.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  13 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_158.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  158 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_165.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  165 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_165.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  165 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_167.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  167 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_178.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  178 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_18.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  18 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_189.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  189 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_193.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  193 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_196.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  196 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_197.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  197 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_200.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  200 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_200.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  200 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_215.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  215 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_221.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  221 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_224.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  224 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_230.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  230 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_231.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  231 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_247.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  247 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_267.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  267 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_277.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  277 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_281.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  281 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_283.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  283 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_285.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  285 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_288.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  288 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_296.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  296 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_3.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  3 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_325.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  325 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_326.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  326 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_33.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  33 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_338.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  338 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_356.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  356 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_357.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  357 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_365.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  365 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_376.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  376 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_389.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  389 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_389.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  389 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_390.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  390 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_411.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  411 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_415.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  415 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_418.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  418 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_421.tif
# Probspath:  ../../data/PML_RARA/BHS/single_cell_probabilities.npy Patient:  BHS image:  421 AML subtype:  PML_RARA
# ../../data/PML_RARA/BHS/image_444.tif
# ...
# ../../data/RUNX1_RUNX1T1/BHG/image_113.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/BHG/single_cell_probabilities.npy Patient:  BHG image:  113 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/BHG/image_119.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/BHG/single_cell_probabilities.npy Patient:  BHG image:  119 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/BHG/image_462.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/BHG/single_cell_probabilities.npy Patient:  BHG image:  462 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/BHG/image_484.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/BHG/single_cell_probabilities.npy Patient:  BHG image:  484 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/BHG/image_58.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/BHG/single_cell_probabilities.npy Patient:  BHG image:  58 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/BKR/image_110.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/BKR/single_cell_probabilities.npy Patient:  BKR image:  110 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/BKR/image_170.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/BKR/single_cell_probabilities.npy Patient:  BKR image:  170 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/BKR/image_235.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/BKR/single_cell_probabilities.npy Patient:  BKR image:  235 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/BKR/image_264.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/BKR/single_cell_probabilities.npy Patient:  BKR image:  264 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/BKR/image_309.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/BKR/single_cell_probabilities.npy Patient:  BKR image:  309 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/BKR/image_337.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/BKR/single_cell_probabilities.npy Patient:  BKR image:  337 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/BKR/image_398.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/BKR/single_cell_probabilities.npy Patient:  BKR image:  398 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/BKR/image_399.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/BKR/single_cell_probabilities.npy Patient:  BKR image:  399 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/BKR/image_402.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/BKR/single_cell_probabilities.npy Patient:  BKR image:  402 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/BKR/image_87.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/BKR/single_cell_probabilities.npy Patient:  BKR image:  87 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/BOE/image_11.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/BOE/single_cell_probabilities.npy Patient:  BOE image:  11 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/BOE/image_122.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/BOE/single_cell_probabilities.npy Patient:  BOE image:  122 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/BOE/image_181.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/BOE/single_cell_probabilities.npy Patient:  BOE image:  181 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/BOE/image_202.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/BOE/single_cell_probabilities.npy Patient:  BOE image:  202 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/BOE/image_233.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/BOE/single_cell_probabilities.npy Patient:  BOE image:  233 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/DHA/image_115.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/DHA/single_cell_probabilities.npy Patient:  DHA image:  115 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/DHA/image_134.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/DHA/single_cell_probabilities.npy Patient:  DHA image:  134 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/DHA/image_222.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/DHA/single_cell_probabilities.npy Patient:  DHA image:  222 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/DHA/image_239.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/DHA/single_cell_probabilities.npy Patient:  DHA image:  239 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/DHA/image_277.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/DHA/single_cell_probabilities.npy Patient:  DHA image:  277 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/DHA/image_298.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/DHA/single_cell_probabilities.npy Patient:  DHA image:  298 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/DHA/image_304.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/DHA/single_cell_probabilities.npy Patient:  DHA image:  304 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/DHA/image_371.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/DHA/single_cell_probabilities.npy Patient:  DHA image:  371 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/DHA/image_443.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/DHA/single_cell_probabilities.npy Patient:  DHA image:  443 AML subtype:  RUNX1_RUNX1T1
# ../../data/RUNX1_RUNX1T1/DHA/image_488.tif
# Probspath:  ../../data/RUNX1_RUNX1T1/DHA/single_cell_probabilities.npy Patient:  DHA image:  488 AML subtype:  RUNX1_RUNX1T1
# ../../data/control/AEC/image_115.tif
# Probspath:  ../../data/control/AEC/single_cell_probabilities.npy Patient:  AEC image:  115 AML subtype:  control
# ../../data/control/AEC/image_116.tif
# Probspath:  ../../data/control/AEC/single_cell_probabilities.npy Patient:  AEC image:  116 AML subtype:  control
# ../../data/control/AEC/image_143.tif
# Probspath:  ../../data/control/AEC/single_cell_probabilities.npy Patient:  AEC image:  143 AML subtype:  control
# ../../data/control/AEC/image_164.tif
# Probspath:  ../../data/control/AEC/single_cell_probabilities.npy Patient:  AEC image:  164 AML subtype:  control
# ../../data/control/AEC/image_176.tif
# Probspath:  ../../data/control/AEC/single_cell_probabilities.npy Patient:  AEC image:  176 AML subtype:  control
# ../../data/control/AEC/image_184.tif
# Probspath:  ../../data/control/AEC/single_cell_probabilities.npy Patient:  AEC image:  184 AML subtype:  control
# ../../data/control/AEC/image_198.tif
# Probspath:  ../../data/control/AEC/single_cell_probabilities.npy Patient:  AEC image:  198 AML subtype:  control
# ../../data/control/AEC/image_259.tif
# Probspath:  ../../data/control/AEC/single_cell_probabilities.npy Patient:  AEC image:  259 AML subtype:  control
# ../../data/control/AEC/image_285.tif
# Probspath:  ../../data/control/AEC/single_cell_probabilities.npy Patient:  AEC image:  285 AML subtype:  control
# ../../data/control/AEC/image_295.tif
# Probspath:  ../../data/control/AEC/single_cell_probabilities.npy Patient:  AEC image:  295 AML subtype:  control
# ../../data/control/AEC/image_365.tif
# Probspath:  ../../data/control/AEC/single_cell_probabilities.npy Patient:  AEC image:  365 AML subtype:  control
# ../../data/control/AEC/image_370.tif
# Probspath:  ../../data/control/AEC/single_cell_probabilities.npy Patient:  AEC image:  370 AML subtype:  control
# ../../data/control/AEC/image_373.tif
# Probspath:  ../../data/control/AEC/single_cell_probabilities.npy Patient:  AEC image:  373 AML subtype:  control
# ../../data/control/AEC/image_407.tif
# Probspath:  ../../data/control/AEC/single_cell_probabilities.npy Patient:  AEC image:  407 AML subtype:  control
# ../../data/control/AEC/image_410.tif
# Probspath:  ../../data/control/AEC/single_cell_probabilities.npy Patient:  AEC image:  410 AML subtype:  control
# ../../data/control/AEC/image_446.tif
# Probspath:  ../../data/control/AEC/single_cell_probabilities.npy Patient:  AEC image:  446 AML subtype:  control
# ../../data/control/AEC/image_450.tif
# Probspath:  ../../data/control/AEC/single_cell_probabilities.npy Patient:  AEC image:  450 AML subtype:  control
# ../../data/control/AEC/image_60.tif
# Probspath:  ../../data/control/AEC/single_cell_probabilities.npy Patient:  AEC image:  60 AML subtype:  control
# ../../data/control/AEC/image_64.tif
# Probspath:  ../../data/control/AEC/single_cell_probabilities.npy Patient:  AEC image:  64 AML subtype:  control
# ../../data/control/AIH/image_104.tif
# Probspath:  ../../data/control/AIH/single_cell_probabilities.npy Patient:  AIH image:  104 AML subtype:  control
# ../../data/control/AIH/image_151.tif
# Probspath:  ../../data/control/AIH/single_cell_probabilities.npy Patient:  AIH image:  151 AML subtype:  control
# ../../data/control/AIH/image_50.tif
# Probspath:  ../../data/control/AIH/single_cell_probabilities.npy Patient:  AIH image:  50 AML subtype:  control
# ../../data/control/AIH/image_52.tif
# Probspath:  ../../data/control/AIH/single_cell_probabilities.npy Patient:  AIH image:  52 AML subtype:  control
# ../../data/control/ATM/image_136.tif
# Probspath:  ../../data/control/ATM/single_cell_probabilities.npy Patient:  ATM image:  136 AML subtype:  control
# ../../data/control/ATM/image_155.tif
# Probspath:  ../../data/control/ATM/single_cell_probabilities.npy Patient:  ATM image:  155 AML subtype:  control
# ../../data/control/ATM/image_171.tif
# Probspath:  ../../data/control/ATM/single_cell_probabilities.npy Patient:  ATM image:  171 AML subtype:  control
# ../../data/control/ATM/image_173.tif
# Probspath:  ../../data/control/ATM/single_cell_probabilities.npy Patient:  ATM image:  173 AML subtype:  control
# ../../data/control/ATM/image_193.tif
# Probspath:  ../../data/control/ATM/single_cell_probabilities.npy Patient:  ATM image:  193 AML subtype:  control
# ../../data/control/ATM/image_199.tif
# Probspath:  ../../data/control/ATM/single_cell_probabilities.npy Patient:  ATM image:  199 AML subtype:  control
# ../../data/control/ATM/image_201.tif
# Probspath:  ../../data/control/ATM/single_cell_probabilities.npy Patient:  ATM image:  201 AML subtype:  control
# ../../data/control/ATM/image_221.tif
# Probspath:  ../../data/control/ATM/single_cell_probabilities.npy Patient:  ATM image:  221 AML subtype:  control
# ../../data/control/ATM/image_309.tif
# Probspath:  ../../data/control/ATM/single_cell_probabilities.npy Patient:  ATM image:  309 AML subtype:  control
# ../../data/control/ATM/image_31.tif
# Probspath:  ../../data/control/ATM/single_cell_probabilities.npy Patient:  ATM image:  31 AML subtype:  control
# ../../data/control/ATM/image_316.tif
# Probspath:  ../../data/control/ATM/single_cell_probabilities.npy Patient:  ATM image:  316 AML subtype:  control
# ../../data/control/ATM/image_323.tif
# Probspath:  ../../data/control/ATM/single_cell_probabilities.npy Patient:  ATM image:  323 AML subtype:  control
# ../../data/control/ATM/image_59.tif
# Probspath:  ../../data/control/ATM/single_cell_probabilities.npy Patient:  ATM image:  59 AML subtype:  control
# ../../data/control/AVL/image_101.tif
# Probspath:  ../../data/control/AVL/single_cell_probabilities.npy Patient:  AVL image:  101 AML subtype:  control
# ../../data/control/AVL/image_104.tif
# Probspath:  ../../data/control/AVL/single_cell_probabilities.npy Patient:  AVL image:  104 AML subtype:  control
# ../../data/control/AVL/image_107.tif
# Probspath:  ../../data/control/AVL/single_cell_probabilities.npy Patient:  AVL image:  107 AML subtype:  control
# ../../data/control/AVL/image_109.tif
# Probspath:  ../../data/control/AVL/single_cell_probabilities.npy Patient:  AVL image:  109 AML subtype:  control
# ../../data/control/AVL/image_13.tif
# Probspath:  ../../data/control/AVL/single_cell_probabilities.npy Patient:  AVL image:  13 AML subtype:  control
# ../../data/control/AVL/image_147.tif
# Probspath:  ../../data/control/AVL/single_cell_probabilities.npy Patient:  AVL image:  147 AML subtype:  control
# ../../data/control/AVL/image_160.tif
# Probspath:  ../../data/control/AVL/single_cell_probabilities.npy Patient:  AVL image:  160 AML subtype:  control
# ../../data/control/AVL/image_167.tif
# Probspath:  ../../data/control/AVL/single_cell_probabilities.npy Patient:  AVL image:  167 AML subtype:  control
# ../../data/control/AVL/image_173.tif
# Probspath:  ../../data/control/AVL/single_cell_probabilities.npy Patient:  AVL image:  173 AML subtype:  control
# ../../data/control/AVL/image_212.tif
# Probspath:  ../../data/control/AVL/single_cell_probabilities.npy Patient:  AVL image:  212 AML subtype:  control
# ../../data/control/AVL/image_249.tif
# Probspath:  ../../data/control/AVL/single_cell_probabilities.npy Patient:  AVL image:  249 AML subtype:  control
# ../../data/control/AVL/image_251.tif
# Probspath:  ../../data/control/AVL/single_cell_probabilities.npy Patient:  AVL image:  251 AML subtype:  control
# ../../data/control/AVL/image_285.tif
# Probspath:  ../../data/control/AVL/single_cell_probabilities.npy Patient:  AVL image:  285 AML subtype:  control
# ../../data/control/AVL/image_335.tif
# Probspath:  ../../data/control/AVL/single_cell_probabilities.npy Patient:  AVL image:  335 AML subtype:  control
# ../../data/control/AVL/image_336.tif
# Probspath:  ../../data/control/AVL/single_cell_probabilities.npy Patient:  AVL image:  336 AML subtype:  control
# ../../data/control/AVL/image_35.tif
# Probspath:  ../../data/control/AVL/single_cell_probabilities.npy Patient:  AVL image:  35 AML subtype:  control
# ../../data/control/AVL/image_363.tif
# Probspath:  ../../data/control/AVL/single_cell_probabilities.npy Patient:  AVL image:  363 AML subtype:  control
# ../../data/control/AVL/image_384.tif
# Probspath:  ../../data/control/AVL/single_cell_probabilities.npy Patient:  AVL image:  384 AML subtype:  control
# ../../data/control/BXR/image_108.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  108 AML subtype:  control
# ../../data/control/BXR/image_151.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  151 AML subtype:  control
# ../../data/control/BXR/image_157.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  157 AML subtype:  control
# ../../data/control/BXR/image_162.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  162 AML subtype:  control
# ../../data/control/BXR/image_164.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  164 AML subtype:  control
# ../../data/control/BXR/image_169.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  169 AML subtype:  control
# ../../data/control/BXR/image_170.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  170 AML subtype:  control
# ../../data/control/BXR/image_20.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  20 AML subtype:  control
# ../../data/control/BXR/image_209.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  209 AML subtype:  control
# ../../data/control/BXR/image_220.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  220 AML subtype:  control
# ../../data/control/BXR/image_222.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  222 AML subtype:  control
# ../../data/control/BXR/image_323.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  323 AML subtype:  control
# ../../data/control/BXR/image_335.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  335 AML subtype:  control
# ../../data/control/BXR/image_351.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  351 AML subtype:  control
# ../../data/control/BXR/image_407.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  407 AML subtype:  control
# ../../data/control/BXR/image_415.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  415 AML subtype:  control
# ../../data/control/BXR/image_64.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  64 AML subtype:  control
# ../../data/control/BXR/image_72.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  72 AML subtype:  control
# ../../data/control/BXR/image_74.tif
# Probspath:  ../../data/control/BXR/single_cell_probabilities.npy Patient:  BXR image:  74 AML subtype:  control

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
from matplotlib.cm import get_cmap

# Assume you have the function get_counts_vector implemented

# Set your data_path variable
data_path = data_path_art

# Initialize figure for subplots
fig, axs = plt.subplots(nrows=1, ncols=len(os.listdir(data_path)), figsize=(12 * len(os.listdir(data_path)), 6), sharey=False)

# Initialize legend elements for the overall plot
legend_elements = []

# Iterate over all subfolders in the data folder
for i, class_folder in enumerate(os.listdir(data_path)):
    print(class_folder)
    class_path = os.path.join(data_path, class_folder)

    # Ensure that the item is a directory
    if os.path.isdir(class_path):
        # Initialize lists to store data for plotting
        patient_folder_names = []
        stacked_counts_vectors = []

        # Iterate over all files in the folder
        for j, patient_folder in enumerate(os.listdir(class_path)):
            print(patient_folder)
            # if len(patient_folder) == 3:
            probs_path = os.path.join(class_path, patient_folder) + '/single_cell_probabilities.npy'
            print(probs_path)
            sc_probs = np.load(probs_path)
            sc_class = np.argmax(sc_probs, axis=1)
            counts_vector, unique_labels = get_counts_vector(sc_class)

            # Normalize counts to percentages
            counts_percentages = counts_vector / np.sum(counts_vector) * 100

            # Create a custom color list for each position
            cmap = get_cmap('tab20c', len(unique_labels))
            colors = [cmap(i) for i in range(len(unique_labels))]

            # Create a horizontal stacked bar plot for each patient in the class
            left = 0
            for label, color in zip(unique_labels, colors):
                axs[i].barh(patient_folder, counts_percentages[label], label=f"Class {label}", alpha=1, color=color, left=left)
                left += counts_percentages[label]

        # Extend the legend elements for the overall plot (outside the patient loop)
        if i == 0:
            legend_elements.extend([Line2D([0], [0], color=color, lw=4, label=f'Class {label}') for label, color in zip(unique_labels, colors)])

        # Set title for each subplot with the name of the folder
        axs[i].set_title(class_folder, fontsize=20)

# Add labels with increased font size
fig.text(0.04, 0.5, "Patients", va='center', rotation='vertical', fontsize=16)

# Create a legend for the overall plot with increased font size
fig.legend(handles=legend_elements, title="Legend", bbox_to_anchor=(1.05, 0.5), loc='center left', fontsize=14)

# Adjust layout and save the overall plot
plt.tight_layout()
plt.savefig('fig3_based_on_scfeatures_art_exp_3.png', bbox_inches='tight')

# Show the plot
plt.show()
# Out:
# PML_RARA
# patient_2
# ../../artificialdata/experiment_3/data/PML_RARA/patient_2/single_cell_probabilities.npy
# patient_4
# ../../artificialdata/experiment_3/data/PML_RARA/patient_4/single_cell_probabilities.npy
# patient_1
# ../../artificialdata/experiment_3/data/PML_RARA/patient_1/single_cell_probabilities.npy
# patient_3
# ../../artificialdata/experiment_3/data/PML_RARA/patient_3/single_cell_probabilities.npy
# patient_5
# ../../artificialdata/experiment_3/data/PML_RARA/patient_5/single_cell_probabilities.npy
# /tmp/ipykernel_270772/117953453.py:43: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = get_cmap('tab20c', len(unique_labels))
# CBFB_MYH11
# patient_2
# ../../artificialdata/experiment_3/data/CBFB_MYH11/patient_2/single_cell_probabilities.npy
# patient_4
# ../../artificialdata/experiment_3/data/CBFB_MYH11/patient_4/single_cell_probabilities.npy
# patient_1
# ../../artificialdata/experiment_3/data/CBFB_MYH11/patient_1/single_cell_probabilities.npy
# patient_3
# ../../artificialdata/experiment_3/data/CBFB_MYH11/patient_3/single_cell_probabilities.npy
# patient_5
# ../../artificialdata/experiment_3/data/CBFB_MYH11/patient_5/single_cell_probabilities.npy
# NPM1
# patient_2
# ../../artificialdata/experiment_3/data/NPM1/patient_2/single_cell_probabilities.npy
# patient_4
# ../../artificialdata/experiment_3/data/NPM1/patient_4/single_cell_probabilities.npy
# patient_1
# ../../artificialdata/experiment_3/data/NPM1/patient_1/single_cell_probabilities.npy
# patient_3
# ../../artificialdata/experiment_3/data/NPM1/patient_3/single_cell_probabilities.npy
# patient_5
# ../../artificialdata/experiment_3/data/NPM1/patient_5/single_cell_probabilities.npy
# RUNX1_RUNX1T1
# patient_2
# ../../artificialdata/experiment_3/data/RUNX1_RUNX1T1/patient_2/single_cell_probabilities.npy
# patient_4
# ../../artificialdata/experiment_3/data/RUNX1_RUNX1T1/patient_4/single_cell_probabilities.npy
# patient_1
# ../../artificialdata/experiment_3/data/RUNX1_RUNX1T1/patient_1/single_cell_probabilities.npy
# patient_3
# ../../artificialdata/experiment_3/data/RUNX1_RUNX1T1/patient_3/single_cell_probabilities.npy
# patient_5
# ../../artificialdata/experiment_3/data/RUNX1_RUNX1T1/patient_5/single_cell_probabilities.npy
# control
# patient_2
# ../../artificialdata/experiment_3/data/control/patient_2/single_cell_probabilities.npy
# patient_4
# ../../artificialdata/experiment_3/data/control/patient_4/single_cell_probabilities.npy
# patient_1
# ../../artificialdata/experiment_3/data/control/patient_1/single_cell_probabilities.npy
# patient_3
# ../../artificialdata/experiment_3/data/control/patient_3/single_cell_probabilities.npy
# patient_5
# ../../artificialdata/experiment_3/data/control/patient_5/single_cell_probabilities.npy

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
from matplotlib.cm import get_cmap

# Assume you have the function get_counts_vector implemented

# Set your data_path variable
data_path = data_path_art

# Initialize figure for subplots
fig, axs = plt.subplots(nrows=len(os.listdir(data_path)), ncols=1, figsize=(12, 6 * len(os.listdir(data_path))), sharey=False)

# Initialize legend elements for the overall plot
legend_elements = []

# Iterate over all subfolders in the data folder
for i, class_folder in enumerate(os.listdir(data_path)):
    print(class_folder)
    class_path = os.path.join(data_path, class_folder)

    # Ensure that the item is a directory
    if os.path.isdir(class_path):
        # Initialize lists to store data for plotting
        patient_folder_names = []
        stacked_counts_vectors = []

        # Iterate over all files in the folder
        for j, patient_folder in enumerate(os.listdir(class_path)):
            print(patient_folder)
            # if len(patient_folder) == 3:
            probs_path = os.path.join(class_path, patient_folder) + '/single_cell_probabilities.npy'
            print(probs_path)
            sc_probs = np.load(probs_path)
            sc_class = np.argmax(sc_probs, axis=1)
            counts_vector, unique_labels = get_counts_vector(sc_class)

            # Normalize counts to percentages
            counts_percentages = counts_vector / np.sum(counts_vector) * 100

            # Create a custom color list for each position
            cmap = get_cmap('tab20c', len(unique_labels))
            colors = [cmap(i) for i in range(len(unique_labels))]

            # Create a horizontal stacked bar plot for each patient in the class
            left = 0
            for label, color in zip(unique_labels, colors):
                axs[i].barh(patient_folder, counts_percentages[label], label=f"Class {label}", alpha=1, color=color, left=left)
                left += counts_percentages[label]

        # Extend the legend elements for the overall plot (outside the patient loop)
        if i == 0:
            legend_elements.extend([Line2D([0], [0], color=color, lw=4, label=f'Class {label}') for label, color in zip(unique_labels, colors)])

        # Set title for each subplot with the name of the folder
        axs[i].set_title(class_folder, fontsize=20)

# Add labels with increased font size
fig.text(0.04, 0.5, "Patients", va='center', rotation='vertical', fontsize=16)

# Create a legend for the overall plot with increased font size
fig.legend(handles=legend_elements, title="Legend", bbox_to_anchor=(1.05, 0.5), loc='center left', fontsize=14)
plt.savefig('fig3_based_on_scfeatures_art_exp_3_hor.png', bbox_inches='tight')
# Adjust layout
# Out:
# PML_RARA
# patient_2
# ../../artificialdata/experiment_3/data/PML_RARA/patient_2/single_cell_probabilities.npy
# patient_4
# ../../artificialdata/experiment_3/data/PML_RARA/patient_4/single_cell_probabilities.npy
# patient_1
# ../../artificialdata/experiment_3/data/PML_RARA/patient_1/single_cell_probabilities.npy
# patient_3
# ../../artificialdata/experiment_3/data/PML_RARA/patient_3/single_cell_probabilities.npy
# patient_5
# ../../artificialdata/experiment_3/data/PML_RARA/patient_5/single_cell_probabilities.npy
# CBFB_MYH11
# patient_2
# ../../artificialdata/experiment_3/data/CBFB_MYH11/patient_2/single_cell_probabilities.npy
# patient_4
# ../../artificialdata/experiment_3/data/CBFB_MYH11/patient_4/single_cell_probabilities.npy
# patient_1
# ../../artificialdata/experiment_3/data/CBFB_MYH11/patient_1/single_cell_probabilities.npy
# patient_3
# ../../artificialdata/experiment_3/data/CBFB_MYH11/patient_3/single_cell_probabilities.npy
# patient_5
# ../../artificialdata/experiment_3/data/CBFB_MYH11/patient_5/single_cell_probabilities.npy
# NPM1
# patient_2
# ../../artificialdata/experiment_3/data/NPM1/patient_2/single_cell_probabilities.npy
# /tmp/ipykernel_270772/2824657938.py:43: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = get_cmap('tab20c', len(unique_labels))
# patient_4
# ../../artificialdata/experiment_3/data/NPM1/patient_4/single_cell_probabilities.npy
# patient_1
# ../../artificialdata/experiment_3/data/NPM1/patient_1/single_cell_probabilities.npy
# patient_3
# ../../artificialdata/experiment_3/data/NPM1/patient_3/single_cell_probabilities.npy
# patient_5
# ../../artificialdata/experiment_3/data/NPM1/patient_5/single_cell_probabilities.npy
# RUNX1_RUNX1T1
# patient_2
# ../../artificialdata/experiment_3/data/RUNX1_RUNX1T1/patient_2/single_cell_probabilities.npy
# patient_4
# ../../artificialdata/experiment_3/data/RUNX1_RUNX1T1/patient_4/single_cell_probabilities.npy
# patient_1
# ../../artificialdata/experiment_3/data/RUNX1_RUNX1T1/patient_1/single_cell_probabilities.npy
# patient_3
# ../../artificialdata/experiment_3/data/RUNX1_RUNX1T1/patient_3/single_cell_probabilities.npy
# patient_5
# ../../artificialdata/experiment_3/data/RUNX1_RUNX1T1/patient_5/single_cell_probabilities.npy
# control
# patient_2
# ../../artificialdata/experiment_3/data/control/patient_2/single_cell_probabilities.npy
# patient_4
# ../../artificialdata/experiment_3/data/control/patient_4/single_cell_probabilities.npy
# patient_1
# ../../artificialdata/experiment_3/data/control/patient_1/single_cell_probabilities.npy
# patient_3
# ../../artificialdata/experiment_3/data/control/patient_3/single_cell_probabilities.npy
# patient_5
# ../../artificialdata/experiment_3/data/control/patient_5/single_cell_probabilities.npy
