# %%
import matplotlib.pyplot as plt
import numpy as np
import os
from matplotlib.cm import get_cmap
from matplotlib.lines import Line2D
import pandas as pd
# Out:
# /tmp/ipykernel_231274/2552883982.py:6: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
def get_counts_vector(labels_vector):
    unique_labels, label_counts = np.unique(labels_vector, return_counts=True)
    counts_vector = np.zeros(21, dtype=int)
    counts_vector[unique_labels] = label_counts
    return counts_vector, unique_labels

# %%
'''# Path to the folder containing your subfolders
data_path = '../data'

# Iterate over all subfolders in the data folder
for class_folder in os.listdir(data_path):
    class_path = os.path.join(data_path, class_folder)
    
    # Ensure that the item is a directory
    if os.path.isdir(class_path):
        # Initialize lists to store data for plotting
        patient_folder_names = []
        stacked_counts_vectors = []

        # Iterate over all files in the folder
        for patient_folder in os.listdir(class_path):
            if len(patient_folder) == 3:
                probs_path = os.path.join(class_path, patient_folder) + '/single_cell_probabilities.npy'

                #print(probs_path)
                sc_probs = np.load(probs_path)
                sc_class = np.argmax(sc_probs, axis=1)
                counts_vector, unique_labels = get_counts_vector(sc_class)

                # Normalize counts to percentages
                counts_percentages = counts_vector / np.sum(counts_vector) * 100

                # Create a custom color list for each position
                cmap = get_cmap('tab20', len(unique_labels))
                colors = [cmap(i) for i in range(len(unique_labels))]

                # Append data for plotting
                patient_folder_names.append(patient_folder)
                stacked_counts_vectors.append((counts_percentages, unique_labels, colors))

        # Create a stacked bar plot for each file in the class
        fig, ax = plt.subplots(figsize=(12, 6))
        for i, (counts_percentages, unique_labels, colors) in enumerate(stacked_counts_vectors):
            bottom = 0
            for label, color in zip(unique_labels, colors):
                ax.bar(patient_folder_names[i], counts_percentages[label], label=f"Class {label}", alpha=0.7, color=color, bottom=bottom)
                bottom += counts_percentages[label]

        # Create a legend showing which color corresponds to which class label
        legend_elements = [Line2D([0], [0], color=color, lw=4, label=f'Class {label}') for label, color in zip(unique_labels, colors)]
        ax.legend(handles=legend_elements, title="Legend", bbox_to_anchor=(1.05, 1), loc='upper left')

        # Add labels and legend
        ax.set_xlabel("Patients")
        ax.set_ylabel("Percentage of Single-cell Counts")
        ax.set_title(f"Stacked Bar Plot of Single-cell Counts for Each Patient in {class_folder} (Scaled to 100%)")

        # Rotate x-axis labels for better visibility
        plt.xticks(rotation=45, ha='right')

        # Show the plot for each class
        plt.show()'''
# Out:
# '# Path to the folder containing your subfolders\ndata_path = \'../data\'\n\n# Iterate over all subfolders in the data folder\nfor class_folder in os.listdir(data_path):\n    class_path = os.path.join(data_path, class_folder)\n    \n    # Ensure that the item is a directory\n    if os.path.isdir(class_path):\n        # Initialize lists to store data for plotting\n        patient_folder_names = []\n        stacked_counts_vectors = []\n\n        # Iterate over all files in the folder\n        for patient_folder in os.listdir(class_path):\n            if len(patient_folder) == 3:\n                probs_path = os.path.join(class_path, patient_folder) + \'/single_cell_probabilities.npy\'\n\n                #print(probs_path)\n                sc_probs = np.load(probs_path)\n                sc_class = np.argmax(sc_probs, axis=1)\n                counts_vector, unique_labels = get_counts_vector(sc_class)\n\n                # Normalize counts to percentages\n                counts_percentages = counts_vector / np.sum(counts_vector) * 100\n\n                # Create a custom color list for each position\n                cmap = get_cmap(\'tab20\', len(unique_labels))\n                colors = [cmap(i) for i in range(len(unique_labels))]\n\n                # Append data for plotting\n                patient_folder_names.append(patient_folder)\n                stacked_counts_vectors.append((counts_percentages, unique_labels, colors))\n\n        # Create a stacked bar plot for each file in the class\n        fig, ax = plt.subplots(figsize=(12, 6))\n        for i, (counts_percentages, unique_labels, colors) in enumerate(stacked_counts_vectors):\n            bottom = 0\n            for label, color in zip(unique_labels, colors):\n                ax.bar(patient_folder_names[i], counts_percentages[label], label=f"Class {label}", alpha=0.7, color=color, bottom=bottom)\n                bottom += counts_percentages[label]\n\n        # Create a legend showing which color corresponds to which class label\n        legend_elements = [Line2D([0], [0], color=color, lw=4, label=f\'Class {label}\') for label, color in zip(unique_labels, colors)]\n        ax.legend(handles=legend_elements, title="Legend", bbox_to_anchor=(1.05, 1), loc=\'upper left\')\n\n        # Add labels and legend\n        ax.set_xlabel("Patients")\n        ax.set_ylabel("Percentage of Single-cell Counts")\n        ax.set_title(f"Stacked Bar Plot of Single-cell Counts for Each Patient in {class_folder} (Scaled to 100%)")\n\n        # Rotate x-axis labels for better visibility\n        plt.xticks(rotation=45, ha=\'right\')\n\n        # Show the plot for each class\n        plt.show()'

# %%
'''# Path to the folder containing your subfolders
data_path = '../data'

# Initialize figure for subplots
fig, axs = plt.subplots(nrows=len(os.listdir(data_path)), figsize=(12, 6 * len(os.listdir(data_path))), sharex=True)

# Initialize legend elements for the overall plot
legend_elements = []

# Iterate over all subfolders in the data folder
for i, class_folder in enumerate(os.listdir(data_path)):
    class_path = os.path.join(data_path, class_folder)
    
    # Ensure that the item is a directory
    if os.path.isdir(class_path):
        # Initialize lists to store data for plotting
        patient_folder_names = []
        stacked_counts_vectors = []

        # Iterate over all files in the folder
        for j, patient_folder in enumerate(os.listdir(class_path)):
            if len(patient_folder) == 3:
                probs_path = os.path.join(class_path, patient_folder) + '/single_cell_probabilities.npy'
                sc_probs = np.load(probs_path)
                sc_class = np.argmax(sc_probs, axis=1)
                counts_vector, unique_labels = get_counts_vector(sc_class)

                # Normalize counts to percentages
                counts_percentages = counts_vector / np.sum(counts_vector) * 100

                # Create a custom color list for each position
                cmap = get_cmap('tab20', len(unique_labels))
                colors = [cmap(i) for i in range(len(unique_labels))]

                # Append data for plotting
                patient_folder_names.append(patient_folder)
                stacked_counts_vectors.append((counts_percentages, unique_labels, colors))

        # Create a horizontal stacked bar plot for each file in the class
        axs[i].set_title(f"Horizontal Stacked Bar Plot of Single-cell Counts for Each Patient in {class_folder} (Scaled to 100%)")
        for k, (counts_percentages, unique_labels, colors) in enumerate(stacked_counts_vectors):
            left = 0
            for label, color in zip(unique_labels, colors):
                axs[i].barh(patient_folder_names[k], counts_percentages[label], label=f"Class {label}", alpha=0.7, color=color, left=left)
                left += counts_percentages[label]

            # Extend the legend elements for the overall plot
            if i == 0 and k == 0:
                legend_elements.extend([Line2D([0], [0], color=color, lw=4, label=f'Class {label}') for label, color in zip(unique_labels, colors)])

# Add labels
fig.text(0.5, 0.04, "Percentage of Single-cell Counts", ha='center')
fig.text(0.04, 0.5, "Patients", va='center', rotation='vertical')

# Create a legend for the overall plot
fig.legend(handles=legend_elements, title="Legend", bbox_to_anchor=(1.05, 0.5), loc='center left')

# Adjust layout and save the overall plot
plt.tight_layout()
plt.savefig('fig3_based_on_features.png', bbox_inches='tight')

# Show the plot
plt.show()
'''
# Out:
# '# Path to the folder containing your subfolders\ndata_path = \'../data\'\n\n# Initialize figure for subplots\nfig, axs = plt.subplots(nrows=len(os.listdir(data_path)), figsize=(12, 6 * len(os.listdir(data_path))), sharex=True)\n\n# Initialize legend elements for the overall plot\nlegend_elements = []\n\n# Iterate over all subfolders in the data folder\nfor i, class_folder in enumerate(os.listdir(data_path)):\n    class_path = os.path.join(data_path, class_folder)\n    \n    # Ensure that the item is a directory\n    if os.path.isdir(class_path):\n        # Initialize lists to store data for plotting\n        patient_folder_names = []\n        stacked_counts_vectors = []\n\n        # Iterate over all files in the folder\n        for j, patient_folder in enumerate(os.listdir(class_path)):\n            if len(patient_folder) == 3:\n                probs_path = os.path.join(class_path, patient_folder) + \'/single_cell_probabilities.npy\'\n                sc_probs = np.load(probs_path)\n                sc_class = np.argmax(sc_probs, axis=1)\n                counts_vector, unique_labels = get_counts_vector(sc_class)\n\n                # Normalize counts to percentages\n                counts_percentages = counts_vector / np.sum(counts_vector) * 100\n\n                # Create a custom color list for each position\n                cmap = get_cmap(\'tab20\', len(unique_labels))\n                colors = [cmap(i) for i in range(len(unique_labels))]\n\n                # Append data for plotting\n                patient_folder_names.append(patient_folder)\n                stacked_counts_vectors.append((counts_percentages, unique_labels, colors))\n\n        # Create a horizontal stacked bar plot for each file in the class\n        axs[i].set_title(f"Horizontal Stacked Bar Plot of Single-cell Counts for Each Patient in {class_folder} (Scaled to 100%)")\n        for k, (counts_percentages, unique_labels, colors) in enumerate(stacked_counts_vectors):\n            left = 0\n            for label, color in zip(unique_labels, colors):\n                axs[i].barh(patient_folder_names[k], counts_percentages[label], label=f"Class {label}", alpha=0.7, color=color, left=left)\n                left += counts_percentages[label]\n\n            # Extend the legend elements for the overall plot\n            if i == 0 and k == 0:\n                legend_elements.extend([Line2D([0], [0], color=color, lw=4, label=f\'Class {label}\') for label, color in zip(unique_labels, colors)])\n\n# Add labels\nfig.text(0.5, 0.04, "Percentage of Single-cell Counts", ha=\'center\')\nfig.text(0.04, 0.5, "Patients", va=\'center\', rotation=\'vertical\')\n\n# Create a legend for the overall plot\nfig.legend(handles=legend_elements, title="Legend", bbox_to_anchor=(1.05, 0.5), loc=\'center left\')\n\n# Adjust layout and save the overall plot\nplt.tight_layout()\nplt.savefig(\'fig3_based_on_features.png\', bbox_inches=\'tight\')\n\n# Show the plot\nplt.show()\n'

# %%
cv = pd.read_csv("class_converion.csv", index_col=0)
cv.drop(['size_tot', 'train_size', 'val_size', 'test_size'], axis=1, inplace=True)
cv = cv.set_index('art_lbl').T.to_dict(orient="index")
cv = cv['true_lbl']
cv
# Out:
# {0: 'eosinophil granulocyte',
#  1: 'reactive lymphocyte',
#  2: 'neutrophil granulocyte (segmented)',
#  3: 'typical lymphocyte',
#  4: 'other',
#  5: 'neutrophil granulocyte (band)',
#  6: 'monocyte',
#  7: 'large granulated lymphocyte',
#  8: 'atypical promyelocyte',
#  9: 'basophil granulocyte',
#  10: 'smudge cell',
#  11: 'neoplastic lymphocyte',
#  12: 'promyelocyte',
#  13: 'myelocyte',
#  14: 'myeloblast',
#  15: 'metamyelocyte',
#  16: 'normo',
#  17: 'plasma cell',
#  18: 'hair cell',
#  19: 'bilobed M3v',
#  20: 'mononucleosis'}

# %%
# Path to the folder containing your subfolders
data_path = '/mnt/volume/shared/data_file/data'
import pylab
# Initialize figure for subplots
fig, axs = plt.subplots(nrows=1, ncols=len(os.listdir(data_path)), figsize=(12 * len(os.listdir(data_path)), 6), sharey=False)
figlegend = pylab.figure(figsize=(3,2))
# Initialize legend elements for the overall plot
legend_elements = []

cmap = get_cmap('tab20c', 21)
colors = [cmap(i) for i in range(21)]

# Iterate over all subfolders in the data folder
for i, class_folder in enumerate(os.listdir(data_path)):
    class_path = os.path.join(data_path, class_folder)
    
    # Ensure that the item is a directory
    if os.path.isdir(class_path):
        # Initialize lists to store data for plotting
        patient_folder_names = []
        stacked_counts_vectors = []

        # Iterate over all files in the folder
        for j, patient_folder in enumerate(os.listdir(class_path)):
            if len(patient_folder) == 3:
                probs_path = os.path.join(class_path, patient_folder) + '/single_cell_probabilities.npy'
                sc_probs = np.load(probs_path)
                sc_class = np.argmax(sc_probs, axis=1)
                counts_vector, unique_labels = get_counts_vector(sc_class)
                #print(unique_labels)

                # Normalize counts to percentages
                counts_percentages = counts_vector / np.sum(counts_vector) * 100

                # Create a custom color list for each position
                # Create a custom color list for each position
                #cmap = get_cmap('tab20c', len(unique_labels))
                #colors = [cmap(i) for i in range(len(unique_labels))]

                # Create a horizontal stacked bar plot for each patient in the class
                left = 0
                for label in unique_labels:
                    axs[i].barh(patient_folder, counts_percentages[label], label=f"Class {cv[label]}", alpha=1, color=colors[label], left=left)
                    left += counts_percentages[label]

                # Extend the legend elements for the overall plot
                #if i == 0 and j == 0:
                    #legend_elements.extend([Line2D([0], [0], color=color, lw=4, label=f'Class {cv[label]}') for label, color in zip(unique_labels, colors)])

        # Set title for each subplot with the name of the folder
        axs[i].set_title(class_folder, fontsize=20)

# Add labels with increased font size
fig.text(0.105, 0.5, "Patients", va='center', rotation='vertical', fontsize=16)
legend_elements.extend([Line2D([0], [0], color=colors[color], lw=4, label=f'Class {cv[color]}') for color in range(len(colors))])
# Create a legend for the overall plot with increased font size
legend = fig.legend(handles=legend_elements, title="Legend", bbox_to_anchor=(1.05, 0.5), loc='center left', fontsize=14)

# Adjust layout and save the overall plot
plt.tight_layout()
plt.savefig('fig3_based_on_scfeatures.png', bbox_inches='tight')
def export_legend(legend, filename="legend.png"):
    fig  = legend.figure
    fig.canvas.draw()
    bbox  = legend.get_window_extent().transformed(fig.dpi_scale_trans.inverted())
    fig.savefig(filename, dpi="figure", bbox_inches=bbox)

export_legend(legend)
# Show the plot
plt.show()
fig.savefig('plot.pdf', bbox_inches='tight')
# Out:
# /tmp/ipykernel_231274/1527105595.py:10: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = get_cmap('tab20c', 21)

# %%
legend_elements

# %%
colors
