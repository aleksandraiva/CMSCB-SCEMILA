# %%
import numpy as np
import glob
import os
import random
import re
from collections import Counter
import pandas as pd
import pickle

class_labels = ["CBFB_MYH11","control","NPM1","PML_RARA","RUNX1_RUNX1T1"]
n_classes = len(class_labels)

#Function to get list of image_paths in one folder
def get_image_path_list(folder_path):
    tif_files = glob.glob(f"{folder_path}/*.tif")
    return tif_files


#exracts the number of image in the file_path e.g. "image_123.tif"
def extract_number_image(file_path):
    # Use a regular expression to find the number after "image_" and before ".tif"
    match = re.search(r'image_(\d+).tif', file_path)
    return int(match.group(1))

def get_patient_name(path):
    return re.search(r"/data/\w+/([A-Z]{3})", path).group(1)

def get_class_name(path):
    return re.search(r"/data/(\w+)", path).group(1)

def get_classification_patient(patient_folder):
    probs_path = patient_folder + '/single_cell_probabilities.npy'
    sc_probs = np.load(probs_path)
    sc_class= np.argmax(sc_probs, axis=1)
    return sc_class

data_directory = '../../data'
subtype=data_directory+"/NPM1"
n_patients=5
experiment_name = "experiment_3"
output_folder = '../../artificialdata/'+experiment_name+'/data'
output_folder_csv='../../artificialdata/'+experiment_name

# %%
#Iterate over real dataset and store image paths in a dataframe df
df = pd.DataFrame(columns=["patient","AML_subtype", "SC_Label", "image_path"])
for folder_class in os.listdir(data_directory):
    folder_class = os.path.join(data_directory, folder_class)    
    if os.path.isdir(folder_class):
       #print(folder_class)
       AML_subtype=get_class_name(folder_class)
       for folder_patient in os.listdir(folder_class):
            folder_patient = os.path.join(folder_class, folder_patient)
            if os.path.isdir(folder_patient):
                images=get_image_path_list(folder_patient)
                sc_classes=get_classification_patient(folder_patient)
                #print(sc_classes)
                for image in images:
                    number=extract_number_image(image)
                    df.loc[len(df)]=[get_patient_name(folder_patient), AML_subtype, sc_classes[number],image]

# %%
#calculate mean and std for each cell type that will be later used to sample data with normal distribution
sc_class_labels= ['eosinophil granulocyte', 'reactive lymphocyte',
       'neutrophil granulocyte (segmented)', 'typical lymphocyte',
       'other', 'neutrophil granulocyte (band)', 'monocyte',
       'large granulated lymphocyte', 'atypical promyelocyte',
       'basophil granulocyte', 'smudge cell', 'neoplastic lymphocyte',
       'promyelocyte', 'myelocyte', 'myeloblast', 'metamyelocyte',
       'normo', 'plasma cell', 'hair cell', 'bilobed M3v',
       'mononucleosis']
df_sc_res=pd.read_csv(data_directory+"/single_cell_results.csv",index_col=0).drop("patient", axis=1)
df_meanstd = df_sc_res.groupby(["AML_subtype"]).agg(["mean","std"])

# %%
df_meanstd
# Out:
#               eosinophil granulocyte           reactive lymphocyte            \
#                                 mean       std                mean       std
# AML_subtype
# CBFB_MYH11                       1.2  0.836660                 7.0  7.141428
# NPM1                             4.6  5.412947                 4.6  6.542171
# PML_RARA                         1.4  1.516575                 2.8  3.346640
# RUNX1_RUNX1T1                    0.8  1.788854                 1.0  1.414214
# control                         11.6  5.549775                10.0  9.000000
#
#               neutrophil granulocyte (segmented)             \
#                                             mean        std
# AML_subtype
# CBFB_MYH11                                  16.8  16.284962
# NPM1                                        32.2  56.406560
# PML_RARA                                    12.6  11.148991
# RUNX1_RUNX1T1                               10.4  10.899541
# control                                    179.8  70.489006
#
#               typical lymphocyte            other             ... normo  \
#                             mean        std  mean        std  ...  mean
# AML_subtype                                                   ...
# CBFB_MYH11                 105.6  79.651114  21.2  10.009995  ...   1.8
# NPM1                        77.0  64.074176  49.4  34.158454  ...  11.6
# PML_RARA                    39.8  56.459720  88.4  36.637413  ...   9.2
# RUNX1_RUNX1T1               75.8  79.678730  25.6  16.379866  ...   4.0
# control                     50.2  17.412639  66.4  47.395147  ...   0.8
#
#                          plasma cell            hair cell            \
#                      std        mean        std      mean       std
# AML_subtype
# CBFB_MYH11      2.489980         5.2   4.549725       1.2  0.836660
# NPM1           16.009372         7.8   6.180615       7.4  9.864076
# PML_RARA       16.709279         4.4   6.426508       2.4  3.361547
# RUNX1_RUNX1T1   3.535534        14.4  10.922454       3.2  3.114482
# control         1.788854         1.4   2.190890       0.8  0.447214
#
#               bilobed M3v            mononucleosis
#                      mean        std          mean        std
# AML_subtype
# CBFB_MYH11            0.8   1.303840          11.8  16.177144
# NPM1                  2.8   2.588436          12.6  17.826946
# PML_RARA             16.0  28.956864           2.8   3.834058
# RUNX1_RUNX1T1        12.6  12.739702           5.0   4.795832
# control               0.0   0.000000           3.8   3.898718
#
# [5 rows x 42 columns]

# %%
#This cell creates artificial patients and stores the single cell couunts per patient in cell_type_counts_dict, also it counts the selected_images_per_patient as a sanity check
# Dictionary stores cell type counts (how often each cell type appears)
cell_type_counts_dict = {}

# Dictionary stores the selected images and counts them per SC class per patient
selected_images_per_patient = {}

# Iterate over all AML subtypes
for aml_subtype in class_labels:
    output_class_folder = output_folder + "/" + aml_subtype
    # Get distribution
    class_means = df_meanstd.loc[aml_subtype, :].loc[:, "mean"].values
    class_variances = df_meanstd.loc[aml_subtype, :].loc[:, "std"].values
    for patient_number in range(n_patients):
        print(f"Generating data for patient {patient_number+1} of subtype {aml_subtype}...")
        # Calculate how many images from each SC class
        generated_data = np.random.normal(class_means, class_variances, 21).astype(int)
        generated_data = generated_data * (generated_data > 0)
        image_file_paths = []
        # Randomly choose SC image and concatenate them into image_file_paths
        selected_images_count = {}
        for cell_type_number, cell_type in enumerate(sc_class_labels):
            df_cell_type = df[df["SC_Label"] == cell_type_number]
            # print(f"\tImages for cell type {cell_type}...")
            file_path = df_cell_type["image_path"].values
            image_paths = np.random.choice(file_path, size=generated_data[cell_type_number]).tolist()
            print(f"\t\tSelected {len(image_paths)} images for {cell_type}")
            image_file_paths += image_paths
            # Store selected images count per SC class
            selected_images_count[cell_type] = len(image_paths)
        # Store selected images count per SC class per patient
        patient_id = f"{aml_subtype}/patient_{patient_number+1}"
        selected_images_per_patient[patient_id] = selected_images_count
        # Store patient classes and number images for metadata
        new_patient_folder = os.path.join(output_class_folder, f'patient_{patient_number+1}')
        os.makedirs(new_patient_folder, exist_ok=True)

        # Sort the shuffled image paths for the current patient
        image_file_paths.sort()
        # Save the shuffled image paths into a text file
        txt_file_path = os.path.join(new_patient_folder, 'images.txt')
        with open(txt_file_path, 'w') as txt_file:
            for image_path in image_file_paths:
                txt_file.write(image_path + '\n')

        with open(os.path.join(new_patient_folder, "image_file_paths"), 'wb') as fp:
            pickle.dump(image_file_paths, fp)

        # Count cell types in the current patient
        cell_type_count = {cell_type: image_file_paths.count(cell_type) for cell_type in set(image_file_paths)}
        print(f"\tCell type count for patient {patient_number+1}: {cell_type_count}")

        # Add the cell type count to the dictionary with the patient as the key
        # and the cell type count as the value
        cell_type_counts_dict[(aml_subtype, patient_id)] = cell_type_count
        print(f"\tCell type counts dictionary for patient {patient_id}: {cell_type_count}")

# Print selected images count per SC class per patient
print("\nSelected Images Count per SC class per Patient:")
for patient_id, sc_counts in selected_images_per_patient.items():
    print(patient_id)
    for sc_class, count in sc_counts.items():
        print(f"\t{sc_class}: {count}")
# Out:
# Generating data for patient 1 of subtype CBFB_MYH11...
# 		Selected 1 images for eosinophil granulocyte
# 		Selected 8 images for reactive lymphocyte
# 		Selected 22 images for neutrophil granulocyte (segmented)
# 		Selected 113 images for typical lymphocyte
# 		Selected 0 images for other
# 		Selected 4 images for neutrophil granulocyte (band)
# 		Selected 35 images for monocyte
# 		Selected 33 images for large granulated lymphocyte
# 		Selected 8 images for atypical promyelocyte
# 		Selected 0 images for basophil granulocyte
# 		Selected 2 images for smudge cell
# 		Selected 0 images for neoplastic lymphocyte
# 		Selected 0 images for promyelocyte
# 		Selected 0 images for myelocyte
# 		Selected 36 images for myeloblast
# 		Selected 0 images for metamyelocyte
# 		Selected 0 images for normo
# 		Selected 10 images for plasma cell
# 		Selected 1 images for hair cell
# 		Selected 1 images for bilobed M3v
# 		Selected 46 images for mononucleosis
# 	Cell type count for patient 1: {'../../data/NPM1/BHR/image_11.tif': 1, '../../data/control/BXR/image_148.tif': 1, '../../data/PML_RARA/BHS/image_26.tif': 1, '../../data/RUNX1_RUNX1T1/BKR/image_325.tif': 1, '../../data/control/AEC/image_295.tif': 1, '../../data/CBFB_MYH11/DQV/image_384.tif': 1, '../../data/CBFB_MYH11/BSN/image_230.tif': 1, '../../data/CBFB_MYH11/AQK/image_16.tif': 1, '../../data/PML_RARA/BIK/image_68.tif': 1, '../../data/CBFB_MYH11/DQV/image_473.tif': 1, '../../data/PML_RARA/ALE/image_221.tif': 1, '../../data/CBFB_MYH11/BJK/image_481.tif': 1, '../../data/control/AEC/image_368.tif': 1, '../../data/NPM1/CZI/image_276.tif': 1, '../../data/RUNX1_RUNX1T1/BKR/image_210.tif': 1, '../../data/CBFB_MYH11/BJK/image_364.tif': 1, '../../data/RUNX1_RUNX1T1/BKR/image_38.tif': 1, '../../data/CBFB_MYH11/AQK/image_374.tif': 1, '../../data/CBFB_MYH11/DQV/image_162.tif': 2, '../../data/CBFB_MYH11/AQK/image_217.tif': 1, '../../data/control/BXR/image_286.tif': 1, '../../data/CBFB_MYH11/BJK/image_126.tif': 1, '../../data/control/AVL/image_186.tif': 1, '../../data/CBFB_MYH11/AQK/image_42.tif': 1, '../../data/NPM1/CZI/image_293.tif': 2, '../../data/NPM1/BHR/image_25.tif': 1, '../../data/NPM1/CZI/image_74.tif': 1, '../../data/CBFB_MYH11/BTB/image_194.tif': 1, '../../data/RUNX1_RUNX1T1/DHA/image_98.tif': 1, '../../data/RUNX1_RUNX1T1/ABF/image_94.tif': 1, '../../data/CBFB_MYH11/DQV/image_55.tif': 1, '../../data/NPM1/DPF/image_464.tif': 1, '../../data/CBFB_MYH11/AQK/image_283.tif': 1, '../../data/NPM1/DPF/image_107.tif': 1, '../../data/CBFB_MYH11/BTB/image_159.tif': 1, '../../data/RUNX1_RUNX1T1/DHA/image_431.tif': 1, '../../data/RUNX1_RUNX1T1/DHA/image_308.tif': 1, '../../data/RUNX1_RUNX1T1/ABF/image_97.tif': 1, '../../data/PML_RARA/CMR/image_216.tif': 1, '../../data/CBFB_MYH11/AQK/image_308.tif': 1, '../../data/PML_RARA/BHS/image_412.tif': 1, '../../data/control/AIH/image_16.tif': 1, '../../data/NPM1/CZI/image_76.tif': 1, '../../data/RUNX1_RUNX1T1/ABF/image_152.tif': 1, '../../data/CBFB_MYH11/AQK/image_1.tif': 1, '../../data/NPM1/CVW/image_209.tif': 1, '../../data/CBFB_MYH11/BSN/image_125.tif': 1, '../../data/control/AIH/image_182.tif': 1, '../../data/CBFB_MYH11/BJK/image_222.tif': 1, '../../data/PML_RARA/BIK/image_262.tif': 1, '../../data/CBFB_MYH11/BSN/image_54.tif': 1, '../../data/RUNX1_RUNX1T1/BKR/image_148.tif': 1, '../../data/NPM1/ALA/image_74.tif': 1, '../../data/RUNX1_RUNX1T1/DHA/image_82.tif': 1, '../../data/NPM1/DPF/image_127.tif': 1, '../../data/control/AIH/image_144.tif': 1, '../../data/RUNX1_RUNX1T1/BHG/image_473.tif': 1, '../../data/NPM1/CVW/image_469.tif': 1, '../../data/CBFB_MYH11/AQK/image_364.tif': 1, '../../data/PML_RARA/ALE/image_60.tif': 1, '../../data/control/AEC/image_61.tif': 1, '../../data/NPM1/DPF/image_293.tif': 1, '../../data/PML_RARA/BHS/image_150.tif': 1, '../../data/RUNX1_RUNX1T1/ABF/image_410.tif': 1, '../../data/control/BXR/image_268.tif': 1, '../../data/NPM1/CZI/image_403.tif': 1, '../../data/NPM1/CVW/image_385.tif': 1, '../../data/NPM1/CVW/image_223.tif': 1, '../../data/RUNX1_RUNX1T1/DHA/image_467.tif': 1, '../../data/control/BXR/image_428.tif': 1, '../../data/RUNX1_RUNX1T1/BKR/image_488.tif': 1, '../../data/RUNX1_RUNX1T1/ABF/image_350.tif': 1, '../../data/NPM1/CVW/image_417.tif': 1, '../../data/RUNX1_RUNX1T1/DHA/image_393.tif': 1, '../../data/control/ATM/image_282.tif': 1, '../../data/PML_RARA/BIK/image_158.tif': 1, '../../data/NPM1/CVW/image_171.tif': 1, '../../data/PML_RARA/BHS/image_362.tif': 1, '../../data/NPM1/CVW/image_34.tif': 1, '../../data/NPM1/CZI/image_38.tif': 1, '../../data/CBFB_MYH11/DQV/image_314.tif': 1, '../../data/RUNX1_RUNX1T1/ABF/image_294.tif': 1, '../../data/RUNX1_RUNX1T1/DHA/image_225.tif': 1, '../../data/PML_RARA/CWF/image_401.tif': 1, '../../data/NPM1/CVW/image_12.tif': 2, '../../data/CBFB_MYH11/BJK/image_11.tif': 1, '../../data/CBFB_MYH11/BJK/image_234.tif': 1, '../../data/control/AVL/image_85.tif': 1, '../../data/RUNX1_RUNX1T1/BHG/image_334.tif': 1, '../../data/NPM1/CZI/image ...
# 	Cell type counts dictionary for patient CBFB_MYH11/patient_1: {'../../data/NPM1/BHR/image_11.tif': 1, '../../data/control/BXR/image_148.tif': 1, '../../data/PML_RARA/BHS/image_26.tif': 1, '../../data/RUNX1_RUNX1T1/BKR/image_325.tif': 1, '../../data/control/AEC/image_295.tif': 1, '../../data/CBFB_MYH11/DQV/image_384.tif': 1, '../../data/CBFB_MYH11/BSN/image_230.tif': 1, '../../data/CBFB_MYH11/AQK/image_16.tif': 1, '../../data/PML_RARA/BIK/image_68.tif': 1, '../../data/CBFB_MYH11/DQV/image_473.tif': 1, '../../data/PML_RARA/ALE/image_221.tif': 1, '../../data/CBFB_MYH11/BJK/image_481.tif': 1, '../../data/control/AEC/image_368.tif': 1, '../../data/NPM1/CZI/image_276.tif': 1, '../../data/RUNX1_RUNX1T1/BKR/image_210.tif': 1, '../../data/CBFB_MYH11/BJK/image_364.tif': 1, '../../data/RUNX1_RUNX1T1/BKR/image_38.tif': 1, '../../data/CBFB_MYH11/AQK/image_374.tif': 1, '../../data/CBFB_MYH11/DQV/image_162.tif': 2, '../../data/CBFB_MYH11/AQK/image_217.tif': 1, '../../data/control/BXR/image_286.tif': 1, '../../data/CBFB_MYH11/BJK/image_126.tif': 1, '../../data/control/AVL/image_186.tif': 1, '../../data/CBFB_MYH11/AQK/image_42.tif': 1, '../../data/NPM1/CZI/image_293.tif': 2, '../../data/NPM1/BHR/image_25.tif': 1, '../../data/NPM1/CZI/image_74.tif': 1, '../../data/CBFB_MYH11/BTB/image_194.tif': 1, '../../data/RUNX1_RUNX1T1/DHA/image_98.tif': 1, '../../data/RUNX1_RUNX1T1/ABF/image_94.tif': 1, '../../data/CBFB_MYH11/DQV/image_55.tif': 1, '../../data/NPM1/DPF/image_464.tif': 1, '../../data/CBFB_MYH11/AQK/image_283.tif': 1, '../../data/NPM1/DPF/image_107.tif': 1, '../../data/CBFB_MYH11/BTB/image_159.tif': 1, '../../data/RUNX1_RUNX1T1/DHA/image_431.tif': 1, '../../data/RUNX1_RUNX1T1/DHA/image_308.tif': 1, '../../data/RUNX1_RUNX1T1/ABF/image_97.tif': 1, '../../data/PML_RARA/CMR/image_216.tif': 1, '../../data/CBFB_MYH11/AQK/image_308.tif': 1, '../../data/PML_RARA/BHS/image_412.tif': 1, '../../data/control/AIH/image_16.tif': 1, '../../data/NPM1/CZI/image_76.tif': 1, '../../data/RUNX1_RUNX1T1/ABF/image_152.tif': 1, '../../data/CBFB_MYH11/AQK/image_1.tif': 1, '../../data/NPM1/CVW/image_209.tif': 1, '../../data/CBFB_MYH11/BSN/image_125.tif': 1, '../../data/control/AIH/image_182.tif': 1, '../../data/CBFB_MYH11/BJK/image_222.tif': 1, '../../data/PML_RARA/BIK/image_262.tif': 1, '../../data/CBFB_MYH11/BSN/image_54.tif': 1, '../../data/RUNX1_RUNX1T1/BKR/image_148.tif': 1, '../../data/NPM1/ALA/image_74.tif': 1, '../../data/RUNX1_RUNX1T1/DHA/image_82.tif': 1, '../../data/NPM1/DPF/image_127.tif': 1, '../../data/control/AIH/image_144.tif': 1, '../../data/RUNX1_RUNX1T1/BHG/image_473.tif': 1, '../../data/NPM1/CVW/image_469.tif': 1, '../../data/CBFB_MYH11/AQK/image_364.tif': 1, '../../data/PML_RARA/ALE/image_60.tif': 1, '../../data/control/AEC/image_61.tif': 1, '../../data/NPM1/DPF/image_293.tif': 1, '../../data/PML_RARA/BHS/image_150.tif': 1, '../../data/RUNX1_RUNX1T1/ABF/image_410.tif': 1, '../../data/control/BXR/image_268.tif': 1, '../../data/NPM1/CZI/image_403.tif': 1, '../../data/NPM1/CVW/image_385.tif': 1, '../../data/NPM1/CVW/image_223.tif': 1, '../../data/RUNX1_RUNX1T1/DHA/image_467.tif': 1, '../../data/control/BXR/image_428.tif': 1, '../../data/RUNX1_RUNX1T1/BKR/image_488.tif': 1, '../../data/RUNX1_RUNX1T1/ABF/image_350.tif': 1, '../../data/NPM1/CVW/image_417.tif': 1, '../../data/RUNX1_RUNX1T1/DHA/image_393.tif': 1, '../../data/control/ATM/image_282.tif': 1, '../../data/PML_RARA/BIK/image_158.tif': 1, '../../data/NPM1/CVW/image_171.tif': 1, '../../data/PML_RARA/BHS/image_362.tif': 1, '../../data/NPM1/CVW/image_34.tif': 1, '../../data/NPM1/CZI/image_38.tif': 1, '../../data/CBFB_MYH11/DQV/image_314.tif': 1, '../../data/RUNX1_RUNX1T1/ABF/image_294.tif': 1, '../../data/RUNX1_RUNX1T1/DHA/image_225.tif': 1, '../../data/PML_RARA/CWF/image_401.tif': 1, '../../data/NPM1/CVW/image_12.tif': 2, '../../data/CBFB_MYH11/BJK/image_11.tif': 1, '../../data/CBFB_MYH11/BJK/image_234.tif': 1, '../../data/control/AVL/image_85.tif': 1, '../../data/RUNX1_RUNX1T1/BHG/image_334.tif' ...
# Generating data for patient 2 of subtype CBFB_MYH11...
# 		Selected 0 images for eosinophil granulocyte
# 		Selected 5 images for reactive lymphocyte
# 		Selected 18 images for neutrophil granulocyte (segmented)
# 		Selected 56 images for typical lymphocyte
# 		Selected 17 images for other
# 		Selected 3 images for neutrophil granulocyte (band)
# 		Selected 195 images for monocyte
# 		Selected 11 images for large granulated lymphocyte
# 		Selected 9 images for atypical promyelocyte
# 		Selected 0 images for basophil granulocyte
# 		Selected 0 images for smudge cell
# 		Selected 2 images for neoplastic lymphocyte
# 		Selected 1 images for promyelocyte
# 		Selected 0 images for myelocyte
# 		Selected 81 images for myeloblast
# 		Selected 2 images for metamyelocyte
# 		Selected 2 images for normo
# 		Selected 1 images for plasma cell
# 		Selected 2 images for hair cell
# 		Selected 0 images for bilobed M3v
# 		Selected 9 images for mononucleosis
# 	Cell type count for patient 2: {'../../data/control/AIH/image_136.tif': 1, '../../data/control/BXR/image_330.tif': 1, '../../data/RUNX1_RUNX1T1/BOE/image_295.tif': 1, '../../data/control/AEC/image_479.tif': 1, '../../data/NPM1/CZI/image_411.tif': 1, '../../data/RUNX1_RUNX1T1/DHA/image_110.tif': 1, '../../data/RUNX1_RUNX1T1/ABF/image_43.tif': 1, '../../data/NPM1/CZI/image_174.tif': 1, '../../data/CBFB_MYH11/BSN/image_230.tif': 1, '../../data/control/AVL/image_117.tif': 1, '../../data/control/AVL/image_67.tif': 1, '../../data/CBFB_MYH11/AQK/image_227.tif': 1, '../../data/RUNX1_RUNX1T1/BOE/image_207.tif': 1, '../../data/RUNX1_RUNX1T1/DHA/image_370.tif': 1, '../../data/PML_RARA/BHS/image_183.tif': 1, '../../data/RUNX1_RUNX1T1/BHG/image_132.tif': 1, '../../data/RUNX1_RUNX1T1/ABF/image_474.tif': 1, '../../data/PML_RARA/CWF/image_314.tif': 1, '../../data/PML_RARA/CMR/image_6.tif': 1, '../../data/NPM1/CVW/image_435.tif': 2, '../../data/CBFB_MYH11/AQK/image_295.tif': 1, '../../data/CBFB_MYH11/AQK/image_333.tif': 1, '../../data/RUNX1_RUNX1T1/BHG/image_80.tif': 1, '../../data/CBFB_MYH11/DQV/image_278.tif': 1, '../../data/control/AEC/image_173.tif': 1, '../../data/RUNX1_RUNX1T1/BHG/image_449.tif': 1, '../../data/RUNX1_RUNX1T1/BKR/image_282.tif': 1, '../../data/RUNX1_RUNX1T1/BOE/image_121.tif': 1, '../../data/NPM1/CVW/image_410.tif': 2, '../../data/control/AIH/image_74.tif': 2, '../../data/RUNX1_RUNX1T1/DHA/image_77.tif': 1, '../../data/RUNX1_RUNX1T1/BHG/image_331.tif': 1, '../../data/NPM1/CVW/image_110.tif': 1, '../../data/CBFB_MYH11/DQV/image_230.tif': 1, '../../data/PML_RARA/ALE/image_112.tif': 1, '../../data/control/AVL/image_386.tif': 1, '../../data/NPM1/BHR/image_288.tif': 1, '../../data/RUNX1_RUNX1T1/DHA/image_45.tif': 1, '../../data/CBFB_MYH11/DQV/image_376.tif': 1, '../../data/NPM1/DPF/image_219.tif': 1, '../../data/NPM1/BHR/image_262.tif': 1, '../../data/RUNX1_RUNX1T1/BKR/image_341.tif': 2, '../../data/CBFB_MYH11/BSN/image_67.tif': 1, '../../data/NPM1/CVW/image_226.tif': 1, '../../data/CBFB_MYH11/BJK/image_412.tif': 1, '../../data/CBFB_MYH11/DQV/image_55.tif': 1, '../../data/NPM1/CVW/image_432.tif': 1, '../../data/CBFB_MYH11/BJK/image_341.tif': 1, '../../data/control/AEC/image_478.tif': 1, '../../data/RUNX1_RUNX1T1/ABF/image_384.tif': 1, '../../data/RUNX1_RUNX1T1/ABF/image_97.tif': 1, '../../data/RUNX1_RUNX1T1/BHG/image_161.tif': 1, '../../data/control/BXR/image_123.tif': 1, '../../data/NPM1/CVW/image_20.tif': 1, '../../data/NPM1/BHR/image_463.tif': 1, '../../data/CBFB_MYH11/BJK/image_276.tif': 1, '../../data/CBFB_MYH11/AQK/image_235.tif': 2, '../../data/NPM1/BHR/image_36.tif': 1, '../../data/control/AIH/image_16.tif': 2, '../../data/control/ATM/image_97.tif': 1, '../../data/CBFB_MYH11/DQV/image_402.tif': 1, '../../data/NPM1/ALA/image_145.tif': 1, '../../data/NPM1/ALA/image_317.tif': 1, '../../data/PML_RARA/ALE/image_298.tif': 1, '../../data/control/AEC/image_380.tif': 1, '../../data/control/BXR/image_287.tif': 1, '../../data/control/AVL/image_77.tif': 1, '../../data/CBFB_MYH11/DQV/image_177.tif': 1, '../../data/CBFB_MYH11/BJK/image_206.tif': 1, '../../data/CBFB_MYH11/DQV/image_137.tif': 1, '../../data/CBFB_MYH11/BJK/image_123.tif': 1, '../../data/RUNX1_RUNX1T1/DHA/image_85.tif': 1, '../../data/control/AVL/image_120.tif': 1, '../../data/CBFB_MYH11/DQV/image_385.tif': 1, '../../data/PML_RARA/BHS/image_346.tif': 1, '../../data/CBFB_MYH11/DQV/image_216.tif': 1, '../../data/NPM1/CVW/image_221.tif': 1, '../../data/NPM1/CVW/image_403.tif': 1, '../../data/RUNX1_RUNX1T1/DHA/image_424.tif': 1, '../../data/NPM1/DPF/image_160.tif': 1, '../../data/CBFB_MYH11/AQK/image_317.tif': 1, '../../data/PML_RARA/ALE/image_470.tif': 1, '../../data/NPM1/ALA/image_459.tif': 1, '../../data/NPM1/CZI/image_23.tif': 1, '../../data/control/AEC/image_257.tif': 2, '../../data/RUNX1_RUNX1T1/BOE/image_53.tif': 1, '../../data/NPM1/CVW/image_485.tif': 1, '../../data/CBFB_MYH11/AQK/image_47.tif': 1, '../../data/RUNX1_RUNX1T1/BHG/image_152.tif': 1, '../../data/PML_RA ...
# 	Cell type counts dictionary for patient CBFB_MYH11/patient_2: {'../../data/control/AIH/image_136.tif': 1, '../../data/control/BXR/image_330.tif': 1, '../../data/RUNX1_RUNX1T1/BOE/image_295.tif': 1, '../../data/control/AEC/image_479.tif': 1, '../../data/NPM1/CZI/image_411.tif': 1, '../../data/RUNX1_RUNX1T1/DHA/image_110.tif': 1, '../../data/RUNX1_RUNX1T1/ABF/image_43.tif': 1, '../../data/NPM1/CZI/image_174.tif': 1, '../../data/CBFB_MYH11/BSN/image_230.tif': 1, '../../data/control/AVL/image_117.tif': 1, '../../data/control/AVL/image_67.tif': 1, '../../data/CBFB_MYH11/AQK/image_227.tif': 1, '../../data/RUNX1_RUNX1T1/BOE/image_207.tif': 1, '../../data/RUNX1_RUNX1T1/DHA/image_370.tif': 1, '../../data/PML_RARA/BHS/image_183.tif': 1, '../../data/RUNX1_RUNX1T1/BHG/image_132.tif': 1, '../../data/RUNX1_RUNX1T1/ABF/image_474.tif': 1, '../../data/PML_RARA/CWF/image_314.tif': 1, '../../data/PML_RARA/CMR/image_6.tif': 1, '../../data/NPM1/CVW/image_435.tif': 2, '../../data/CBFB_MYH11/AQK/image_295.tif': 1, '../../data/CBFB_MYH11/AQK/image_333.tif': 1, '../../data/RUNX1_RUNX1T1/BHG/image_80.tif': 1, '../../data/CBFB_MYH11/DQV/image_278.tif': 1, '../../data/control/AEC/image_173.tif': 1, '../../data/RUNX1_RUNX1T1/BHG/image_449.tif': 1, '../../data/RUNX1_RUNX1T1/BKR/image_282.tif': 1, '../../data/RUNX1_RUNX1T1/BOE/image_121.tif': 1, '../../data/NPM1/CVW/image_410.tif': 2, '../../data/control/AIH/image_74.tif': 2, '../../data/RUNX1_RUNX1T1/DHA/image_77.tif': 1, '../../data/RUNX1_RUNX1T1/BHG/image_331.tif': 1, '../../data/NPM1/CVW/image_110.tif': 1, '../../data/CBFB_MYH11/DQV/image_230.tif': 1, '../../data/PML_RARA/ALE/image_112.tif': 1, '../../data/control/AVL/image_386.tif': 1, '../../data/NPM1/BHR/image_288.tif': 1, '../../data/RUNX1_RUNX1T1/DHA/image_45.tif': 1, '../../data/CBFB_MYH11/DQV/image_376.tif': 1, '../../data/NPM1/DPF/image_219.tif': 1, '../../data/NPM1/BHR/image_262.tif': 1, '../../data/RUNX1_RUNX1T1/BKR/image_341.tif': 2, '../../data/CBFB_MYH11/BSN/image_67.tif': 1, '../../data/NPM1/CVW/image_226.tif': 1, '../../data/CBFB_MYH11/BJK/image_412.tif': 1, '../../data/CBFB_MYH11/DQV/image_55.tif': 1, '../../data/NPM1/CVW/image_432.tif': 1, '../../data/CBFB_MYH11/BJK/image_341.tif': 1, '../../data/control/AEC/image_478.tif': 1, '../../data/RUNX1_RUNX1T1/ABF/image_384.tif': 1, '../../data/RUNX1_RUNX1T1/ABF/image_97.tif': 1, '../../data/RUNX1_RUNX1T1/BHG/image_161.tif': 1, '../../data/control/BXR/image_123.tif': 1, '../../data/NPM1/CVW/image_20.tif': 1, '../../data/NPM1/BHR/image_463.tif': 1, '../../data/CBFB_MYH11/BJK/image_276.tif': 1, '../../data/CBFB_MYH11/AQK/image_235.tif': 2, '../../data/NPM1/BHR/image_36.tif': 1, '../../data/control/AIH/image_16.tif': 2, '../../data/control/ATM/image_97.tif': 1, '../../data/CBFB_MYH11/DQV/image_402.tif': 1, '../../data/NPM1/ALA/image_145.tif': 1, '../../data/NPM1/ALA/image_317.tif': 1, '../../data/PML_RARA/ALE/image_298.tif': 1, '../../data/control/AEC/image_380.tif': 1, '../../data/control/BXR/image_287.tif': 1, '../../data/control/AVL/image_77.tif': 1, '../../data/CBFB_MYH11/DQV/image_177.tif': 1, '../../data/CBFB_MYH11/BJK/image_206.tif': 1, '../../data/CBFB_MYH11/DQV/image_137.tif': 1, '../../data/CBFB_MYH11/BJK/image_123.tif': 1, '../../data/RUNX1_RUNX1T1/DHA/image_85.tif': 1, '../../data/control/AVL/image_120.tif': 1, '../../data/CBFB_MYH11/DQV/image_385.tif': 1, '../../data/PML_RARA/BHS/image_346.tif': 1, '../../data/CBFB_MYH11/DQV/image_216.tif': 1, '../../data/NPM1/CVW/image_221.tif': 1, '../../data/NPM1/CVW/image_403.tif': 1, '../../data/RUNX1_RUNX1T1/DHA/image_424.tif': 1, '../../data/NPM1/DPF/image_160.tif': 1, '../../data/CBFB_MYH11/AQK/image_317.tif': 1, '../../data/PML_RARA/ALE/image_470.tif': 1, '../../data/NPM1/ALA/image_459.tif': 1, '../../data/NPM1/CZI/image_23.tif': 1, '../../data/control/AEC/image_257.tif': 2, '../../data/RUNX1_RUNX1T1/BOE/image_53.tif': 1, '../../data/NPM1/CVW/image_485.tif': 1, '../../data/CBFB_MYH11/AQK/image_47.tif': 1, '../../data/RUNX1_RUNX1T1/BHG/image_ ...
# Generating data for patient 3 of subtype CBFB_MYH11...
# 		Selected 0 images for eosinophil granulocyte
# 		Selected 16 images for reactive lymphocyte
# 		Selected 32 images for neutrophil granulocyte (segmented)
# 		Selected 0 images for typical lymphocyte
# 		Selected 12 images for other
# 		Selected 19 images for neutrophil granulocyte (band)
# 		Selected 74 images for monocyte
# 		Selected 9 images for large granulated lymphocyte
# 		Selected 15 images for atypical promyelocyte
# 		Selected 0 images for basophil granulocyte
# 		Selected 4 images for smudge cell
# 		Selected 2 images for neoplastic lymphocyte
# 		Selected 2 images for promyelocyte
# 		Selected 2 images for myelocyte
# 		Selected 66 images for myeloblast
# 		Selected 5 images for metamyelocyte
# 		Selected 0 images for normo
# 		Selected 0 images for plasma cell
# 		Selected 0 images for hair cell
# 		Selected 0 images for bilobed M3v
# 		Selected 0 images for mononucleosis
# 	Cell type count for patient 3: {'../../data/CBFB_MYH11/DQV/image_15.tif': 1, '../../data/CBFB_MYH11/DQV/image_165.tif': 1, '../../data/NPM1/BHR/image_432.tif': 1, '../../data/PML_RARA/ALE/image_482.tif': 1, '../../data/PML_RARA/BIK/image_359.tif': 1, '../../data/NPM1/BHR/image_387.tif': 1, '../../data/RUNX1_RUNX1T1/BHG/image_126.tif': 1, '../../data/control/AIH/image_56.tif': 1, '../../data/CBFB_MYH11/DQV/image_312.tif': 1, '../../data/control/BXR/image_413.tif': 2, '../../data/RUNX1_RUNX1T1/BOE/image_216.tif': 1, '../../data/CBFB_MYH11/BTB/image_60.tif': 1, '../../data/CBFB_MYH11/BJK/image_139.tif': 1, '../../data/CBFB_MYH11/BJK/image_279.tif': 1, '../../data/NPM1/BHR/image_15.tif': 1, '../../data/NPM1/CVW/image_39.tif': 1, '../../data/PML_RARA/CWF/image_216.tif': 1, '../../data/control/ATM/image_175.tif': 1, '../../data/control/AVL/image_38.tif': 1, '../../data/NPM1/DPF/image_5.tif': 1, '../../data/PML_RARA/BHS/image_240.tif': 1, '../../data/CBFB_MYH11/AQK/image_202.tif': 1, '../../data/NPM1/ALA/image_405.tif': 1, '../../data/CBFB_MYH11/BJK/image_437.tif': 1, '../../data/NPM1/BHR/image_303.tif': 1, '../../data/NPM1/DPF/image_143.tif': 1, '../../data/NPM1/BHR/image_49.tif': 1, '../../data/RUNX1_RUNX1T1/BHG/image_132.tif': 1, '../../data/CBFB_MYH11/BTB/image_210.tif': 1, '../../data/CBFB_MYH11/DQV/image_108.tif': 1, '../../data/PML_RARA/CMR/image_196.tif': 1, '../../data/RUNX1_RUNX1T1/BHG/image_21.tif': 1, '../../data/control/BXR/image_375.tif': 1, '../../data/control/AEC/image_263.tif': 1, '../../data/NPM1/CVW/image_489.tif': 1, '../../data/RUNX1_RUNX1T1/BHG/image_188.tif': 1, '../../data/control/AEC/image_301.tif': 1, '../../data/NPM1/BHR/image_130.tif': 1, '../../data/control/AEC/image_434.tif': 1, '../../data/NPM1/DPF/image_235.tif': 1, '../../data/PML_RARA/CMR/image_426.tif': 1, '../../data/CBFB_MYH11/BSN/image_68.tif': 1, '../../data/control/ATM/image_22.tif': 1, '../../data/control/AEC/image_48.tif': 1, '../../data/NPM1/CVW/image_365.tif': 1, '../../data/PML_RARA/CMR/image_112.tif': 1, '../../data/control/AEC/image_2.tif': 1, '../../data/control/BXR/image_40.tif': 1, '../../data/NPM1/CVW/image_374.tif': 1, '../../data/RUNX1_RUNX1T1/DHA/image_323.tif': 1, '../../data/control/AEC/image_362.tif': 1, '../../data/CBFB_MYH11/BSN/image_98.tif': 1, '../../data/NPM1/CVW/image_76.tif': 1, '../../data/CBFB_MYH11/DQV/image_176.tif': 1, '../../data/control/ATM/image_185.tif': 1, '../../data/RUNX1_RUNX1T1/BHG/image_192.tif': 1, '../../data/PML_RARA/ALE/image_126.tif': 1, '../../data/control/AVL/image_288.tif': 1, '../../data/PML_RARA/ALE/image_307.tif': 1, '../../data/RUNX1_RUNX1T1/ABF/image_356.tif': 1, '../../data/control/BXR/image_21.tif': 1, '../../data/CBFB_MYH11/DQV/image_237.tif': 1, '../../data/PML_RARA/BHS/image_430.tif': 1, '../../data/PML_RARA/ALE/image_416.tif': 1, '../../data/NPM1/ALA/image_70.tif': 1, '../../data/NPM1/BHR/image_0.tif': 1, '../../data/RUNX1_RUNX1T1/DHA/image_187.tif': 1, '../../data/PML_RARA/BIK/image_458.tif': 1, '../../data/RUNX1_RUNX1T1/ABF/image_108.tif': 1, '../../data/control/BXR/image_126.tif': 1, '../../data/CBFB_MYH11/BJK/image_441.tif': 1, '../../data/PML_RARA/BHS/image_143.tif': 1, '../../data/CBFB_MYH11/DQV/image_58.tif': 1, '../../data/PML_RARA/BHS/image_89.tif': 1, '../../data/CBFB_MYH11/BTB/image_192.tif': 1, '../../data/RUNX1_RUNX1T1/ABF/image_467.tif': 1, '../../data/PML_RARA/CMR/image_79.tif': 1, '../../data/control/BXR/image_254.tif': 1, '../../data/NPM1/CVW/image_474.tif': 1, '../../data/RUNX1_RUNX1T1/BKR/image_351.tif': 1, '../../data/CBFB_MYH11/BJK/image_0.tif': 1, '../../data/RUNX1_RUNX1T1/BOE/image_220.tif': 1, '../../data/CBFB_MYH11/DQV/image_19.tif': 1, '../../data/NPM1/BHR/image_171.tif': 1, '../../data/PML_RARA/BHS/image_243.tif': 1, '../../data/RUNX1_RUNX1T1/DHA/image_377.tif': 1, '../../data/CBFB_MYH11/AQK/image_208.tif': 1, '../../data/control/AEC/image_423.tif': 1, '../../data/PML_RARA/BHS/image_475.tif': 1, '../../data/control/BXR/image_231.tif': 1, '../../data/PML_RARA/ ...
# 	Cell type counts dictionary for patient CBFB_MYH11/patient_3: {'../../data/CBFB_MYH11/DQV/image_15.tif': 1, '../../data/CBFB_MYH11/DQV/image_165.tif': 1, '../../data/NPM1/BHR/image_432.tif': 1, '../../data/PML_RARA/ALE/image_482.tif': 1, '../../data/PML_RARA/BIK/image_359.tif': 1, '../../data/NPM1/BHR/image_387.tif': 1, '../../data/RUNX1_RUNX1T1/BHG/image_126.tif': 1, '../../data/control/AIH/image_56.tif': 1, '../../data/CBFB_MYH11/DQV/image_312.tif': 1, '../../data/control/BXR/image_413.tif': 2, '../../data/RUNX1_RUNX1T1/BOE/image_216.tif': 1, '../../data/CBFB_MYH11/BTB/image_60.tif': 1, '../../data/CBFB_MYH11/BJK/image_139.tif': 1, '../../data/CBFB_MYH11/BJK/image_279.tif': 1, '../../data/NPM1/BHR/image_15.tif': 1, '../../data/NPM1/CVW/image_39.tif': 1, '../../data/PML_RARA/CWF/image_216.tif': 1, '../../data/control/ATM/image_175.tif': 1, '../../data/control/AVL/image_38.tif': 1, '../../data/NPM1/DPF/image_5.tif': 1, '../../data/PML_RARA/BHS/image_240.tif': 1, '../../data/CBFB_MYH11/AQK/image_202.tif': 1, '../../data/NPM1/ALA/image_405.tif': 1, '../../data/CBFB_MYH11/BJK/image_437.tif': 1, '../../data/NPM1/BHR/image_303.tif': 1, '../../data/NPM1/DPF/image_143.tif': 1, '../../data/NPM1/BHR/image_49.tif': 1, '../../data/RUNX1_RUNX1T1/BHG/image_132.tif': 1, '../../data/CBFB_MYH11/BTB/image_210.tif': 1, '../../data/CBFB_MYH11/DQV/image_108.tif': 1, '../../data/PML_RARA/CMR/image_196.tif': 1, '../../data/RUNX1_RUNX1T1/BHG/image_21.tif': 1, '../../data/control/BXR/image_375.tif': 1, '../../data/control/AEC/image_263.tif': 1, '../../data/NPM1/CVW/image_489.tif': 1, '../../data/RUNX1_RUNX1T1/BHG/image_188.tif': 1, '../../data/control/AEC/image_301.tif': 1, '../../data/NPM1/BHR/image_130.tif': 1, '../../data/control/AEC/image_434.tif': 1, '../../data/NPM1/DPF/image_235.tif': 1, '../../data/PML_RARA/CMR/image_426.tif': 1, '../../data/CBFB_MYH11/BSN/image_68.tif': 1, '../../data/control/ATM/image_22.tif': 1, '../../data/control/AEC/image_48.tif': 1, '../../data/NPM1/CVW/image_365.tif': 1, '../../data/PML_RARA/CMR/image_112.tif': 1, '../../data/control/AEC/image_2.tif': 1, '../../data/control/BXR/image_40.tif': 1, '../../data/NPM1/CVW/image_374.tif': 1, '../../data/RUNX1_RUNX1T1/DHA/image_323.tif': 1, '../../data/control/AEC/image_362.tif': 1, '../../data/CBFB_MYH11/BSN/image_98.tif': 1, '../../data/NPM1/CVW/image_76.tif': 1, '../../data/CBFB_MYH11/DQV/image_176.tif': 1, '../../data/control/ATM/image_185.tif': 1, '../../data/RUNX1_RUNX1T1/BHG/image_192.tif': 1, '../../data/PML_RARA/ALE/image_126.tif': 1, '../../data/control/AVL/image_288.tif': 1, '../../data/PML_RARA/ALE/image_307.tif': 1, '../../data/RUNX1_RUNX1T1/ABF/image_356.tif': 1, '../../data/control/BXR/image_21.tif': 1, '../../data/CBFB_MYH11/DQV/image_237.tif': 1, '../../data/PML_RARA/BHS/image_430.tif': 1, '../../data/PML_RARA/ALE/image_416.tif': 1, '../../data/NPM1/ALA/image_70.tif': 1, '../../data/NPM1/BHR/image_0.tif': 1, '../../data/RUNX1_RUNX1T1/DHA/image_187.tif': 1, '../../data/PML_RARA/BIK/image_458.tif': 1, '../../data/RUNX1_RUNX1T1/ABF/image_108.tif': 1, '../../data/control/BXR/image_126.tif': 1, '../../data/CBFB_MYH11/BJK/image_441.tif': 1, '../../data/PML_RARA/BHS/image_143.tif': 1, '../../data/CBFB_MYH11/DQV/image_58.tif': 1, '../../data/PML_RARA/BHS/image_89.tif': 1, '../../data/CBFB_MYH11/BTB/image_192.tif': 1, '../../data/RUNX1_RUNX1T1/ABF/image_467.tif': 1, '../../data/PML_RARA/CMR/image_79.tif': 1, '../../data/control/BXR/image_254.tif': 1, '../../data/NPM1/CVW/image_474.tif': 1, '../../data/RUNX1_RUNX1T1/BKR/image_351.tif': 1, '../../data/CBFB_MYH11/BJK/image_0.tif': 1, '../../data/RUNX1_RUNX1T1/BOE/image_220.tif': 1, '../../data/CBFB_MYH11/DQV/image_19.tif': 1, '../../data/NPM1/BHR/image_171.tif': 1, '../../data/PML_RARA/BHS/image_243.tif': 1, '../../data/RUNX1_RUNX1T1/DHA/image_377.tif': 1, '../../data/CBFB_MYH11/AQK/image_208.tif': 1, '../../data/control/AEC/image_423.tif': 1, '../../data/PML_RARA/BHS/image_475.tif': 1, '../../data/control/BXR/image_231 ...
# Generating data for patient 4 of subtype CBFB_MYH11...
# 		Selected 1 images for eosinophil granulocyte
# 		Selected 1 images for reactive lymphocyte
# 		Selected 36 images for neutrophil granulocyte (segmented)
# 		Selected 75 images for typical lymphocyte
# 		Selected 25 images for other
# 		Selected 0 images for neutrophil granulocyte (band)
# 		Selected 77 images for monocyte
# 		Selected 0 images for large granulated lymphocyte
# 		Selected 17 images for atypical promyelocyte
# 		Selected 0 images for basophil granulocyte
# 		Selected 9 images for smudge cell
# 		Selected 5 images for neoplastic lymphocyte
# 		Selected 2 images for promyelocyte
# 		Selected 2 images for myelocyte
# 		Selected 150 images for myeloblast
# 		Selected 8 images for metamyelocyte
# 		Selected 4 images for normo
# 		Selected 5 images for plasma cell
# 		Selected 2 images for hair cell
# 		Selected 1 images for bilobed M3v
# 		Selected 21 images for mononucleosis
# 	Cell type count for patient 4: {'../../data/control/BXR/image_118.tif': 1, '../../data/RUNX1_RUNX1T1/ABF/image_470.tif': 1, '../../data/NPM1/CZI/image_411.tif': 1, '../../data/CBFB_MYH11/BJK/image_52.tif': 1, '../../data/PML_RARA/ALE/image_376.tif': 1, '../../data/CBFB_MYH11/DQV/image_351.tif': 1, '../../data/control/BXR/image_50.tif': 1, '../../data/NPM1/BHR/image_127.tif': 1, '../../data/RUNX1_RUNX1T1/BHG/image_240.tif': 1, '../../data/NPM1/DPF/image_5.tif': 2, '../../data/PML_RARA/CWF/image_196.tif': 1, '../../data/CBFB_MYH11/AQK/image_123.tif': 1, '../../data/RUNX1_RUNX1T1/BKR/image_80.tif': 1, '../../data/PML_RARA/ALE/image_221.tif': 1, '../../data/RUNX1_RUNX1T1/DHA/image_40.tif': 1, '../../data/PML_RARA/CWF/image_214.tif': 1, '../../data/NPM1/CZI/image_342.tif': 1, '../../data/NPM1/ALA/image_217.tif': 1, '../../data/NPM1/BHR/image_312.tif': 1, '../../data/CBFB_MYH11/AQK/image_370.tif': 1, '../../data/PML_RARA/CWF/image_391.tif': 1, '../../data/RUNX1_RUNX1T1/ABF/image_365.tif': 1, '../../data/PML_RARA/BIK/image_486.tif': 2, '../../data/PML_RARA/BIK/image_488.tif': 1, '../../data/PML_RARA/BIK/image_465.tif': 1, '../../data/control/AEC/image_442.tif': 1, '../../data/CBFB_MYH11/BSN/image_92.tif': 1, '../../data/CBFB_MYH11/BTB/image_140.tif': 1, '../../data/CBFB_MYH11/AQK/image_74.tif': 1, '../../data/RUNX1_RUNX1T1/ABF/image_422.tif': 1, '../../data/control/ATM/image_155.tif': 1, '../../data/NPM1/ALA/image_322.tif': 1, '../../data/RUNX1_RUNX1T1/DHA/image_449.tif': 1, '../../data/RUNX1_RUNX1T1/BHG/image_46.tif': 1, '../../data/PML_RARA/ALE/image_485.tif': 1, '../../data/PML_RARA/BHS/image_100.tif': 1, '../../data/RUNX1_RUNX1T1/BOE/image_44.tif': 1, '../../data/RUNX1_RUNX1T1/BKR/image_341.tif': 1, '../../data/control/AIH/image_27.tif': 1, '../../data/NPM1/ALA/image_167.tif': 1, '../../data/control/AEC/image_118.tif': 1, '../../data/CBFB_MYH11/DQV/image_470.tif': 1, '../../data/NPM1/BHR/image_90.tif': 1, '../../data/PML_RARA/ALE/image_249.tif': 1, '../../data/PML_RARA/BHS/image_43.tif': 1, '../../data/control/BXR/image_125.tif': 1, '../../data/NPM1/BHR/image_463.tif': 1, '../../data/CBFB_MYH11/BJK/image_276.tif': 1, '../../data/RUNX1_RUNX1T1/BHG/image_229.tif': 1, '../../data/RUNX1_RUNX1T1/DHA/image_75.tif': 1, '../../data/CBFB_MYH11/AQK/image_365.tif': 1, '../../data/NPM1/CZI/image_39.tif': 1, '../../data/control/AIH/image_16.tif': 1, '../../data/RUNX1_RUNX1T1/BHG/image_119.tif': 1, '../../data/PML_RARA/CMR/image_164.tif': 1, '../../data/PML_RARA/BIK/image_469.tif': 1, '../../data/control/BXR/image_347.tif': 1, '../../data/RUNX1_RUNX1T1/ABF/image_259.tif': 1, '../../data/RUNX1_RUNX1T1/BKR/image_20.tif': 1, '../../data/CBFB_MYH11/DQV/image_332.tif': 1, '../../data/control/AEC/image_429.tif': 2, '../../data/control/AEC/image_176.tif': 1, '../../data/CBFB_MYH11/AQK/image_82.tif': 1, '../../data/RUNX1_RUNX1T1/ABF/image_433.tif': 1, '../../data/control/AVL/image_297.tif': 1, '../../data/RUNX1_RUNX1T1/DHA/image_387.tif': 1, '../../data/NPM1/BHR/image_80.tif': 1, '../../data/NPM1/CZI/image_176.tif': 1, '../../data/PML_RARA/BIK/image_281.tif': 1, '../../data/RUNX1_RUNX1T1/ABF/image_434.tif': 1, '../../data/control/AVL/image_24.tif': 1, '../../data/RUNX1_RUNX1T1/BKR/image_388.tif': 1, '../../data/NPM1/CVW/image_25.tif': 1, '../../data/PML_RARA/CMR/image_279.tif': 1, '../../data/NPM1/BHR/image_188.tif': 1, '../../data/control/BXR/image_215.tif': 1, '../../data/NPM1/DPF/image_157.tif': 1, '../../data/CBFB_MYH11/BTB/image_44.tif': 1, '../../data/PML_RARA/CWF/image_341.tif': 1, '../../data/RUNX1_RUNX1T1/BKR/image_115.tif': 1, '../../data/NPM1/CVW/image_485.tif': 1, '../../data/PML_RARA/CWF/image_465.tif': 1, '../../data/RUNX1_RUNX1T1/BHG/image_152.tif': 1, '../../data/control/BXR/image_52.tif': 1, '../../data/NPM1/CVW/image_416.tif': 1, '../../data/NPM1/CVW/image_92.tif': 1, '../../data/PML_RARA/BHS/image_15.tif': 1, '../../data/NPM1/CVW/image_413.tif': 1, '../../data/NPM1/DPF/image_295.tif': 1, '../../data/PML_RARA/BIK/image_386.tif': 1,  ...
# 	Cell type counts dictionary for patient CBFB_MYH11/patient_4: {'../../data/control/BXR/image_118.tif': 1, '../../data/RUNX1_RUNX1T1/ABF/image_470.tif': 1, '../../data/NPM1/CZI/image_411.tif': 1, '../../data/CBFB_MYH11/BJK/image_52.tif': 1, '../../data/PML_RARA/ALE/image_376.tif': 1, '../../data/CBFB_MYH11/DQV/image_351.tif': 1, '../../data/control/BXR/image_50.tif': 1, '../../data/NPM1/BHR/image_127.tif': 1, '../../data/RUNX1_RUNX1T1/BHG/image_240.tif': 1, '../../data/NPM1/DPF/image_5.tif': 2, '../../data/PML_RARA/CWF/image_196.tif': 1, '../../data/CBFB_MYH11/AQK/image_123.tif': 1, '../../data/RUNX1_RUNX1T1/BKR/image_80.tif': 1, '../../data/PML_RARA/ALE/image_221.tif': 1, '../../data/RUNX1_RUNX1T1/DHA/image_40.tif': 1, '../../data/PML_RARA/CWF/image_214.tif': 1, '../../data/NPM1/CZI/image_342.tif': 1, '../../data/NPM1/ALA/image_217.tif': 1, '../../data/NPM1/BHR/image_312.tif': 1, '../../data/CBFB_MYH11/AQK/image_370.tif': 1, '../../data/PML_RARA/CWF/image_391.tif': 1, '../../data/RUNX1_RUNX1T1/ABF/image_365.tif': 1, '../../data/PML_RARA/BIK/image_486.tif': 2, '../../data/PML_RARA/BIK/image_488.tif': 1, '../../data/PML_RARA/BIK/image_465.tif': 1, '../../data/control/AEC/image_442.tif': 1, '../../data/CBFB_MYH11/BSN/image_92.tif': 1, '../../data/CBFB_MYH11/BTB/image_140.tif': 1, '../../data/CBFB_MYH11/AQK/image_74.tif': 1, '../../data/RUNX1_RUNX1T1/ABF/image_422.tif': 1, '../../data/control/ATM/image_155.tif': 1, '../../data/NPM1/ALA/image_322.tif': 1, '../../data/RUNX1_RUNX1T1/DHA/image_449.tif': 1, '../../data/RUNX1_RUNX1T1/BHG/image_46.tif': 1, '../../data/PML_RARA/ALE/image_485.tif': 1, '../../data/PML_RARA/BHS/image_100.tif': 1, '../../data/RUNX1_RUNX1T1/BOE/image_44.tif': 1, '../../data/RUNX1_RUNX1T1/BKR/image_341.tif': 1, '../../data/control/AIH/image_27.tif': 1, '../../data/NPM1/ALA/image_167.tif': 1, '../../data/control/AEC/image_118.tif': 1, '../../data/CBFB_MYH11/DQV/image_470.tif': 1, '../../data/NPM1/BHR/image_90.tif': 1, '../../data/PML_RARA/ALE/image_249.tif': 1, '../../data/PML_RARA/BHS/image_43.tif': 1, '../../data/control/BXR/image_125.tif': 1, '../../data/NPM1/BHR/image_463.tif': 1, '../../data/CBFB_MYH11/BJK/image_276.tif': 1, '../../data/RUNX1_RUNX1T1/BHG/image_229.tif': 1, '../../data/RUNX1_RUNX1T1/DHA/image_75.tif': 1, '../../data/CBFB_MYH11/AQK/image_365.tif': 1, '../../data/NPM1/CZI/image_39.tif': 1, '../../data/control/AIH/image_16.tif': 1, '../../data/RUNX1_RUNX1T1/BHG/image_119.tif': 1, '../../data/PML_RARA/CMR/image_164.tif': 1, '../../data/PML_RARA/BIK/image_469.tif': 1, '../../data/control/BXR/image_347.tif': 1, '../../data/RUNX1_RUNX1T1/ABF/image_259.tif': 1, '../../data/RUNX1_RUNX1T1/BKR/image_20.tif': 1, '../../data/CBFB_MYH11/DQV/image_332.tif': 1, '../../data/control/AEC/image_429.tif': 2, '../../data/control/AEC/image_176.tif': 1, '../../data/CBFB_MYH11/AQK/image_82.tif': 1, '../../data/RUNX1_RUNX1T1/ABF/image_433.tif': 1, '../../data/control/AVL/image_297.tif': 1, '../../data/RUNX1_RUNX1T1/DHA/image_387.tif': 1, '../../data/NPM1/BHR/image_80.tif': 1, '../../data/NPM1/CZI/image_176.tif': 1, '../../data/PML_RARA/BIK/image_281.tif': 1, '../../data/RUNX1_RUNX1T1/ABF/image_434.tif': 1, '../../data/control/AVL/image_24.tif': 1, '../../data/RUNX1_RUNX1T1/BKR/image_388.tif': 1, '../../data/NPM1/CVW/image_25.tif': 1, '../../data/PML_RARA/CMR/image_279.tif': 1, '../../data/NPM1/BHR/image_188.tif': 1, '../../data/control/BXR/image_215.tif': 1, '../../data/NPM1/DPF/image_157.tif': 1, '../../data/CBFB_MYH11/BTB/image_44.tif': 1, '../../data/PML_RARA/CWF/image_341.tif': 1, '../../data/RUNX1_RUNX1T1/BKR/image_115.tif': 1, '../../data/NPM1/CVW/image_485.tif': 1, '../../data/PML_RARA/CWF/image_465.tif': 1, '../../data/RUNX1_RUNX1T1/BHG/image_152.tif': 1, '../../data/control/BXR/image_52.tif': 1, '../../data/NPM1/CVW/image_416.tif': 1, '../../data/NPM1/CVW/image_92.tif': 1, '../../data/PML_RARA/BHS/image_15.tif': 1, '../../data/NPM1/CVW/image_413.tif': 1, '../../data/NPM1/DPF/image_295.tif': 1, '../../data/P ...
# Generating data for patient 5 of subtype CBFB_MYH11...
# 		Selected 2 images for eosinophil granulocyte
# 		Selected 2 images for reactive lymphocyte
# 		Selected 25 images for neutrophil granulocyte (segmented)
# 		Selected 0 images for typical lymphocyte
# 		Selected 19 images for other
# 		Selected 4 images for neutrophil granulocyte (band)
# 		Selected 140 images for monocyte
# 		Selected 0 images for large granulated lymphocyte
# 		Selected 19 images for atypical promyelocyte
# 		Selected 0 images for basophil granulocyte
# 		Selected 11 images for smudge cell
# 		Selected 0 images for neoplastic lymphocyte
# 		Selected 1 images for promyelocyte
# 		Selected 0 images for myelocyte
# 		Selected 178 images for myeloblast
# 		Selected 6 images for metamyelocyte
# 		Selected 4 images for normo
# 		Selected 3 images for plasma cell
# 		Selected 2 images for hair cell
# 		Selected 2 images for bilobed M3v
# 		Selected 5 images for mononucleosis
# 	Cell type count for patient 5: {'../../data/RUNX1_RUNX1T1/BOE/image_247.tif': 1, '../../data/RUNX1_RUNX1T1/ABF/image_115.tif': 1, '../../data/CBFB_MYH11/BJK/image_416.tif': 1, '../../data/control/AEC/image_230.tif': 1, '../../data/control/AVL/image_117.tif': 1, '../../data/NPM1/BHR/image_39.tif': 1, '../../data/CBFB_MYH11/AQK/image_413.tif': 1, '../../data/NPM1/ALA/image_194.tif': 1, '../../data/control/BXR/image_307.tif': 1, '../../data/CBFB_MYH11/AQK/image_30.tif': 1, '../../data/NPM1/ALA/image_448.tif': 1, '../../data/PML_RARA/ALE/image_118.tif': 1, '../../data/RUNX1_RUNX1T1/BHG/image_449.tif': 1, '../../data/NPM1/CVW/image_274.tif': 1, '../../data/NPM1/CZI/image_60.tif': 1, '../../data/NPM1/BHR/image_27.tif': 1, '../../data/RUNX1_RUNX1T1/BHG/image_159.tif': 1, '../../data/CBFB_MYH11/DQV/image_272.tif': 1, '../../data/PML_RARA/CMR/image_386.tif': 1, '../../data/CBFB_MYH11/AQK/image_147.tif': 1, '../../data/RUNX1_RUNX1T1/BHG/image_110.tif': 1, '../../data/control/AVL/image_96.tif': 1, '../../data/RUNX1_RUNX1T1/BOE/image_234.tif': 1, '../../data/RUNX1_RUNX1T1/BOE/image_57.tif': 1, '../../data/control/BXR/image_93.tif': 1, '../../data/control/AEC/image_426.tif': 1, '../../data/NPM1/CVW/image_226.tif': 1, '../../data/RUNX1_RUNX1T1/BHG/image_386.tif': 1, '../../data/RUNX1_RUNX1T1/BOE/image_2.tif': 1, '../../data/RUNX1_RUNX1T1/BHG/image_221.tif': 1, '../../data/PML_RARA/CWF/image_262.tif': 1, '../../data/RUNX1_RUNX1T1/DHA/image_101.tif': 2, '../../data/CBFB_MYH11/BJK/image_418.tif': 1, '../../data/CBFB_MYH11/DQV/image_147.tif': 1, '../../data/NPM1/CVW/image_20.tif': 1, '../../data/NPM1/DPF/image_109.tif': 1, '../../data/NPM1/DPF/image_161.tif': 1, '../../data/PML_RARA/ALE/image_48.tif': 1, '../../data/CBFB_MYH11/AQK/image_235.tif': 1, '../../data/NPM1/BHR/image_478.tif': 1, '../../data/NPM1/ALA/image_178.tif': 1, '../../data/PML_RARA/CWF/image_250.tif': 1, '../../data/PML_RARA/CMR/image_59.tif': 1, '../../data/CBFB_MYH11/DQV/image_402.tif': 1, '../../data/control/BXR/image_197.tif': 1, '../../data/control/AEC/image_380.tif': 1, '../../data/NPM1/CVW/image_50.tif': 1, '../../data/CBFB_MYH11/BTB/image_100.tif': 1, '../../data/PML_RARA/ALE/image_41.tif': 1, '../../data/RUNX1_RUNX1T1/BKR/image_108.tif': 1, '../../data/PML_RARA/BHS/image_214.tif': 1, '../../data/NPM1/BHR/image_123.tif': 1, '../../data/RUNX1_RUNX1T1/ABF/image_261.tif': 1, '../../data/PML_RARA/BIK/image_469.tif': 1, '../../data/NPM1/CVW/image_480.tif': 1, '../../data/control/BXR/image_471.tif': 1, '../../data/RUNX1_RUNX1T1/ABF/image_13.tif': 1, '../../data/RUNX1_RUNX1T1/BKR/image_227.tif': 1, '../../data/CBFB_MYH11/BJK/image_290.tif': 1, '../../data/CBFB_MYH11/BSN/image_233.tif': 1, '../../data/PML_RARA/CWF/image_477.tif': 1, '../../data/control/BXR/image_176.tif': 1, '../../data/NPM1/ALA/image_371.tif': 1, '../../data/control/AEC/image_405.tif': 1, '../../data/control/BXR/image_102.tif': 1, '../../data/NPM1/CVW/image_403.tif': 1, '../../data/CBFB_MYH11/DQV/image_482.tif': 2, '../../data/RUNX1_RUNX1T1/ABF/image_193.tif': 1, '../../data/CBFB_MYH11/AQK/image_11.tif': 2, '../../data/RUNX1_RUNX1T1/ABF/image_106.tif': 1, '../../data/RUNX1_RUNX1T1/BKR/image_115.tif': 1, '../../data/control/AEC/image_257.tif': 1, '../../data/NPM1/BHR/image_369.tif': 1, '../../data/CBFB_MYH11/BJK/image_184.tif': 1, '../../data/NPM1/CVW/image_347.tif': 1, '../../data/NPM1/ALA/image_228.tif': 1, '../../data/CBFB_MYH11/DQV/image_276.tif': 2, '../../data/RUNX1_RUNX1T1/ABF/image_187.tif': 1, '../../data/NPM1/DPF/image_71.tif': 1, '../../data/CBFB_MYH11/BJK/image_31.tif': 1, '../../data/NPM1/CVW/image_414.tif': 1, '../../data/control/AEC/image_306.tif': 1, '../../data/PML_RARA/CMR/image_15.tif': 1, '../../data/CBFB_MYH11/BTB/image_253.tif': 1, '../../data/RUNX1_RUNX1T1/BOE/image_101.tif': 1, '../../data/PML_RARA/CWF/image_435.tif': 1, '../../data/CBFB_MYH11/BTB/image_69.tif': 1, '../../data/RUNX1_RUNX1T1/ABF/image_234.tif': 1, '../../data/CBFB_MYH11/AQK/image_193.tif': 1, '../../data/CBFB_MYH11/DQV/i ...
# 	Cell type counts dictionary for patient CBFB_MYH11/patient_5: {'../../data/RUNX1_RUNX1T1/BOE/image_247.tif': 1, '../../data/RUNX1_RUNX1T1/ABF/image_115.tif': 1, '../../data/CBFB_MYH11/BJK/image_416.tif': 1, '../../data/control/AEC/image_230.tif': 1, '../../data/control/AVL/image_117.tif': 1, '../../data/NPM1/BHR/image_39.tif': 1, '../../data/CBFB_MYH11/AQK/image_413.tif': 1, '../../data/NPM1/ALA/image_194.tif': 1, '../../data/control/BXR/image_307.tif': 1, '../../data/CBFB_MYH11/AQK/image_30.tif': 1, '../../data/NPM1/ALA/image_448.tif': 1, '../../data/PML_RARA/ALE/image_118.tif': 1, '../../data/RUNX1_RUNX1T1/BHG/image_449.tif': 1, '../../data/NPM1/CVW/image_274.tif': 1, '../../data/NPM1/CZI/image_60.tif': 1, '../../data/NPM1/BHR/image_27.tif': 1, '../../data/RUNX1_RUNX1T1/BHG/image_159.tif': 1, '../../data/CBFB_MYH11/DQV/image_272.tif': 1, '../../data/PML_RARA/CMR/image_386.tif': 1, '../../data/CBFB_MYH11/AQK/image_147.tif': 1, '../../data/RUNX1_RUNX1T1/BHG/image_110.tif': 1, '../../data/control/AVL/image_96.tif': 1, '../../data/RUNX1_RUNX1T1/BOE/image_234.tif': 1, '../../data/RUNX1_RUNX1T1/BOE/image_57.tif': 1, '../../data/control/BXR/image_93.tif': 1, '../../data/control/AEC/image_426.tif': 1, '../../data/NPM1/CVW/image_226.tif': 1, '../../data/RUNX1_RUNX1T1/BHG/image_386.tif': 1, '../../data/RUNX1_RUNX1T1/BOE/image_2.tif': 1, '../../data/RUNX1_RUNX1T1/BHG/image_221.tif': 1, '../../data/PML_RARA/CWF/image_262.tif': 1, '../../data/RUNX1_RUNX1T1/DHA/image_101.tif': 2, '../../data/CBFB_MYH11/BJK/image_418.tif': 1, '../../data/CBFB_MYH11/DQV/image_147.tif': 1, '../../data/NPM1/CVW/image_20.tif': 1, '../../data/NPM1/DPF/image_109.tif': 1, '../../data/NPM1/DPF/image_161.tif': 1, '../../data/PML_RARA/ALE/image_48.tif': 1, '../../data/CBFB_MYH11/AQK/image_235.tif': 1, '../../data/NPM1/BHR/image_478.tif': 1, '../../data/NPM1/ALA/image_178.tif': 1, '../../data/PML_RARA/CWF/image_250.tif': 1, '../../data/PML_RARA/CMR/image_59.tif': 1, '../../data/CBFB_MYH11/DQV/image_402.tif': 1, '../../data/control/BXR/image_197.tif': 1, '../../data/control/AEC/image_380.tif': 1, '../../data/NPM1/CVW/image_50.tif': 1, '../../data/CBFB_MYH11/BTB/image_100.tif': 1, '../../data/PML_RARA/ALE/image_41.tif': 1, '../../data/RUNX1_RUNX1T1/BKR/image_108.tif': 1, '../../data/PML_RARA/BHS/image_214.tif': 1, '../../data/NPM1/BHR/image_123.tif': 1, '../../data/RUNX1_RUNX1T1/ABF/image_261.tif': 1, '../../data/PML_RARA/BIK/image_469.tif': 1, '../../data/NPM1/CVW/image_480.tif': 1, '../../data/control/BXR/image_471.tif': 1, '../../data/RUNX1_RUNX1T1/ABF/image_13.tif': 1, '../../data/RUNX1_RUNX1T1/BKR/image_227.tif': 1, '../../data/CBFB_MYH11/BJK/image_290.tif': 1, '../../data/CBFB_MYH11/BSN/image_233.tif': 1, '../../data/PML_RARA/CWF/image_477.tif': 1, '../../data/control/BXR/image_176.tif': 1, '../../data/NPM1/ALA/image_371.tif': 1, '../../data/control/AEC/image_405.tif': 1, '../../data/control/BXR/image_102.tif': 1, '../../data/NPM1/CVW/image_403.tif': 1, '../../data/CBFB_MYH11/DQV/image_482.tif': 2, '../../data/RUNX1_RUNX1T1/ABF/image_193.tif': 1, '../../data/CBFB_MYH11/AQK/image_11.tif': 2, '../../data/RUNX1_RUNX1T1/ABF/image_106.tif': 1, '../../data/RUNX1_RUNX1T1/BKR/image_115.tif': 1, '../../data/control/AEC/image_257.tif': 1, '../../data/NPM1/BHR/image_369.tif': 1, '../../data/CBFB_MYH11/BJK/image_184.tif': 1, '../../data/NPM1/CVW/image_347.tif': 1, '../../data/NPM1/ALA/image_228.tif': 1, '../../data/CBFB_MYH11/DQV/image_276.tif': 2, '../../data/RUNX1_RUNX1T1/ABF/image_187.tif': 1, '../../data/NPM1/DPF/image_71.tif': 1, '../../data/CBFB_MYH11/BJK/image_31.tif': 1, '../../data/NPM1/CVW/image_414.tif': 1, '../../data/control/AEC/image_306.tif': 1, '../../data/PML_RARA/CMR/image_15.tif': 1, '../../data/CBFB_MYH11/BTB/image_253.tif': 1, '../../data/RUNX1_RUNX1T1/BOE/image_101.tif': 1, '../../data/PML_RARA/CWF/image_435.tif': 1, '../../data/CBFB_MYH11/BTB/image_69.tif': 1, '../../data/RUNX1_RUNX1T1/ABF/image_234.tif': 1, '../../data/CBFB_MYH11/AQK/image_193.tif':  ...
# Generating data for patient 1 of subtype control...
# 		Selected 21 images for eosinophil granulocyte
# 		Selected 22 images for reactive lymphocyte
# 		Selected 117 images for neutrophil granulocyte (segmented)
# 		Selected 23 images for typical lymphocyte
# 		Selected 50 images for other
# 		Selected 0 images for neutrophil granulocyte (band)
# 		Selected 15 images for monocyte
# 		Selected 28 images for large granulated lymphocyte
# 		Selected 0 images for atypical promyelocyte
# 		Selected 13 images for basophil granulocyte
# 		Selected 2 images for smudge cell
# 		Selected 1 images for neoplastic lymphocyte
# 		Selected 0 images for promyelocyte
# 		Selected 0 images for myelocyte
# 		Selected 0 images for myeloblast
# 		Selected 0 images for metamyelocyte
# 		Selected 0 images for normo
# 		Selected 0 images for plasma cell
# 		Selected 1 images for hair cell
# 		Selected 0 images for bilobed M3v
# 		Selected 3 images for mononucleosis
# ...
# 	Cell type counts dictionary for patient RUNX1_RUNX1T1/patient_5: {'../../data/CBFB_MYH11/BJK/image_362.tif': 1, '../../data/NPM1/BHR/image_11.tif': 1, '../../data/control/AEC/image_1.tif': 1, '../../data/PML_RARA/ALE/image_326.tif': 1, '../../data/PML_RARA/ALE/image_396.tif': 1, '../../data/NPM1/CZI/image_110.tif': 1, '../../data/NPM1/ALA/image_58.tif': 1, '../../data/CBFB_MYH11/BJK/image_271.tif': 3, '../../data/PML_RARA/BHS/image_183.tif': 1, '../../data/PML_RARA/BHS/image_270.tif': 1, '../../data/RUNX1_RUNX1T1/DHA/image_40.tif': 1, '../../data/CBFB_MYH11/AQK/image_158.tif': 1, '../../data/PML_RARA/CMR/image_364.tif': 2, '../../data/control/AIH/image_74.tif': 1, '../../data/PML_RARA/BHS/image_264.tif': 1, '../../data/PML_RARA/ALE/image_35.tif': 1, '../../data/PML_RARA/BHS/image_469.tif': 1, '../../data/RUNX1_RUNX1T1/ABF/image_345.tif': 1, '../../data/RUNX1_RUNX1T1/BHG/image_99.tif': 1, '../../data/PML_RARA/CMR/image_175.tif': 1, '../../data/CBFB_MYH11/BTB/image_155.tif': 2, '../../data/RUNX1_RUNX1T1/BOE/image_161.tif': 1, '../../data/PML_RARA/CMR/image_146.tif': 1, '../../data/NPM1/CZI/image_293.tif': 1, '../../data/RUNX1_RUNX1T1/DHA/image_383.tif': 1, '../../data/RUNX1_RUNX1T1/BHG/image_46.tif': 2, '../../data/PML_RARA/CWF/image_118.tif': 1, '../../data/NPM1/ALA/image_260.tif': 1, '../../data/RUNX1_RUNX1T1/ABF/image_417.tif': 1, '../../data/NPM1/ALA/image_167.tif': 1, '../../data/PML_RARA/BHS/image_382.tif': 1, '../../data/control/AEC/image_210.tif': 1, '../../data/RUNX1_RUNX1T1/BHG/image_26.tif': 1, '../../data/NPM1/CZI/image_10.tif': 1, '../../data/control/BXR/image_335.tif': 1, '../../data/RUNX1_RUNX1T1/ABF/image_88.tif': 1, '../../data/PML_RARA/CMR/image_313.tif': 1, '../../data/RUNX1_RUNX1T1/BKR/image_161.tif': 1, '../../data/PML_RARA/ALE/image_462.tif': 1, '../../data/PML_RARA/CWF/image_440.tif': 1, '../../data/PML_RARA/CWF/image_481.tif': 1, '../../data/RUNX1_RUNX1T1/BKR/image_238.tif': 1, '../../data/CBFB_MYH11/BJK/image_318.tif': 1, '../../data/PML_RARA/BIK/image_89.tif': 1, '../../data/RUNX1_RUNX1T1/ABF/image_152.tif': 1, '../../data/control/BXR/image_287.tif': 2, '../../data/RUNX1_RUNX1T1/BKR/image_108.tif': 1, '../../data/RUNX1_RUNX1T1/DHA/image_388.tif': 1, '../../data/RUNX1_RUNX1T1/ABF/image_146.tif': 1, '../../data/NPM1/ALA/image_282.tif': 1, '../../data/NPM1/CZI/image_303.tif': 1, '../../data/PML_RARA/BIK/image_115.tif': 1, '../../data/PML_RARA/ALE/image_56.tif': 1, '../../data/CBFB_MYH11/BTB/image_108.tif': 1, '../../data/CBFB_MYH11/BSN/image_174.tif': 1, '../../data/PML_RARA/CMR/image_340.tif': 1, '../../data/NPM1/BHR/image_80.tif': 1, '../../data/PML_RARA/ALE/image_366.tif': 1, '../../data/NPM1/DPF/image_127.tif': 1, '../../data/PML_RARA/CMR/image_126.tif': 1, '../../data/NPM1/ALA/image_252.tif': 1, '../../data/PML_RARA/BHS/image_184.tif': 1, '../../data/NPM1/ALA/image_54.tif': 1, '../../data/CBFB_MYH11/DQV/image_468.tif': 2, '../../data/RUNX1_RUNX1T1/DHA/image_238.tif': 1, '../../data/NPM1/CZI/image_6.tif': 1, '../../data/RUNX1_RUNX1T1/BHG/image_487.tif': 1, '../../data/RUNX1_RUNX1T1/BHG/image_19.tif': 1, '../../data/RUNX1_RUNX1T1/ABF/image_232.tif': 1, '../../data/RUNX1_RUNX1T1/BHG/image_270.tif': 1, '../../data/RUNX1_RUNX1T1/BHG/image_401.tif': 1, '../../data/RUNX1_RUNX1T1/BHG/image_92.tif': 1, '../../data/NPM1/CZI/image_317.tif': 1, '../../data/NPM1/CVW/image_416.tif': 1, '../../data/control/AIH/image_179.tif': 1, '../../data/PML_RARA/CWF/image_212.tif': 1, '../../data/RUNX1_RUNX1T1/BKR/image_4.tif': 1, '../../data/RUNX1_RUNX1T1/DHA/image_305.tif': 2, '../../data/CBFB_MYH11/BJK/image_485.tif': 1, '../../data/control/BXR/image_481.tif': 1, '../../data/PML_RARA/CMR/image_24.tif': 1, '../../data/PML_RARA/ALE/image_308.tif': 1, '../../data/PML_RARA/ALE/image_12.tif': 1, '../../data/PML_RARA/ALE/image_166.tif': 1, '../../data/PML_RARA/ALE/image_173.tif': 1, '../../data/control/ATM/image_30.tif': 2, '../../data/CBFB_MYH11/AQK/image_384.tif': 1, '../../data/control/AIH/image_37.tif': 1, '../../data/RUNX1_RU ...
#
# Selected Images Count per SC class per Patient:
# CBFB_MYH11/patient_1
# 	eosinophil granulocyte: 1
# 	reactive lymphocyte: 8
# 	neutrophil granulocyte (segmented): 22
# 	typical lymphocyte: 113
# 	other: 0
# 	neutrophil granulocyte (band): 4
# 	monocyte: 35
# 	large granulated lymphocyte: 33
# 	atypical promyelocyte: 8
# 	basophil granulocyte: 0
# 	smudge cell: 2
# 	neoplastic lymphocyte: 0
# 	promyelocyte: 0
# 	myelocyte: 0
# 	myeloblast: 36
# 	metamyelocyte: 0
# 	normo: 0
# 	plasma cell: 10
# 	hair cell: 1
# 	bilobed M3v: 1
# 	mononucleosis: 46
# CBFB_MYH11/patient_2
# 	eosinophil granulocyte: 0
# 	reactive lymphocyte: 5
# 	neutrophil granulocyte (segmented): 18
# 	typical lymphocyte: 56
# 	other: 17
# 	neutrophil granulocyte (band): 3
# 	monocyte: 195
# 	large granulated lymphocyte: 11
# 	atypical promyelocyte: 9
# 	basophil granulocyte: 0
# 	smudge cell: 0
# 	neoplastic lymphocyte: 2
# 	promyelocyte: 1
# 	myelocyte: 0
# 	myeloblast: 81
# 	metamyelocyte: 2
# 	normo: 2
# 	plasma cell: 1
# 	hair cell: 2
# 	bilobed M3v: 0
# 	mononucleosis: 9
# CBFB_MYH11/patient_3
# 	eosinophil granulocyte: 0
# 	reactive lymphocyte: 16
# 	neutrophil granulocyte (segmented): 32
# 	typical lymphocyte: 0
# 	other: 12
# 	neutrophil granulocyte (band): 19
# 	monocyte: 74
# 	large granulated lymphocyte: 9
# 	atypical promyelocyte: 15
# 	basophil granulocyte: 0
# 	smudge cell: 4
# 	neoplastic lymphocyte: 2
# 	promyelocyte: 2
# 	myelocyte: 2
# 	myeloblast: 66
# 	metamyelocyte: 5
# 	normo: 0
# 	plasma cell: 0
# 	hair cell: 0
# 	bilobed M3v: 0
# 	mononucleosis: 0
# CBFB_MYH11/patient_4
# 	eosinophil granulocyte: 1
# 	reactive lymphocyte: 1
# 	neutrophil granulocyte (segmented): 36
# 	typical lymphocyte: 75
# 	other: 25
# 	neutrophil granulocyte (band): 0
# 	monocyte: 77
# 	large granulated lymphocyte: 0
# 	atypical promyelocyte: 17
# 	basophil granulocyte: 0
# 	smudge cell: 9
# 	neoplastic lymphocyte: 5
# 	promyelocyte: 2
# 	myelocyte: 2
# 	myeloblast: 150
# 	metamyelocyte: 8
# 	normo: 4
# 	plasma cell: 5
# 	hair cell: 2
# 	bilobed M3v: 1
# 	mononucleosis: 21
# CBFB_MYH11/patient_5
# 	eosinophil granulocyte: 2
# 	reactive lymphocyte: 2
# 	neutrophil granulocyte (segmented): 25
# 	typical lymphocyte: 0
# 	other: 19
# 	neutrophil granulocyte (band): 4
# 	monocyte: 140
# 	large granulated lymphocyte: 0
# 	atypical promyelocyte: 19
# 	basophil granulocyte: 0
# 	smudge cell: 11
# 	neoplastic lymphocyte: 0
# 	promyelocyte: 1
# 	myelocyte: 0
# 	myeloblast: 178
# 	metamyelocyte: 6
# 	normo: 4
# 	plasma cell: 3
# 	hair cell: 2
# 	bilobed M3v: 2
# 	mononucleosis: 5
# control/patient_1
# 	eosinophil granulocyte: 21
# 	reactive lymphocyte: 22
# 	neutrophil granulocyte (segmented): 117
# 	typical lymphocyte: 23
# 	other: 50
# 	neutrophil granulocyte (band): 0
# 	monocyte: 15
# 	large granulated lymphocyte: 28
# 	atypical promyelocyte: 0
# 	basophil granulocyte: 13
# 	smudge cell: 2
# 	neoplastic lymphocyte: 1
# 	promyelocyte: 0
# 	myelocyte: 0
# 	myeloblast: 0
# 	metamyelocyte: 0
# 	normo: 0
# 	plasma cell: 0
# 	hair cell: 1
# 	bilobed M3v: 0
# 	mononucleosis: 3
# control/patient_2
# 	eosinophil granulocyte: 10
# 	reactive lymphocyte: 0
# 	neutrophil granulocyte (segmented): 175
# 	typical lymphocyte: 42
# 	other: 102
# 	neutrophil granulocyte (band): 20
# 	monocyte: 34
# 	large granulated lymphocyte: 0
# 	atypical promyelocyte: 0
# 	basophil granulocyte: 2
# 	smudge cell: 4
# 	neoplastic lymphocyte: 3
# 	promyelocyte: 0
# 	myelocyte: 0
# 	myeloblast: 2
# 	metamyelocyte: 0
# 	normo: 2
# 	plasma cell: 0
# 	hair cell: 0
# 	bilobed M3v: 0
# 	mononucleosis: 0
# control/patient_3
# 	eosinophil granulocyte: 16
# 	reactive lymphocyte: 13
# 	neutrophil granulocyte (segmented): 180
# 	typical lymphocyte: 34
# 	other: 69
# 	neutrophil granulocyte (band): 13
# 	monocyte: 30
# 	large granulated lymphocyte: 23
# 	atypical promyelocyte: 0
# 	basophil granulocyte: 8
# 	smudge cell: 2
# 	neoplastic lymphocyte: 4
# 	promyelocyte: 0
# 	myelocyte: 0
# 	myeloblast: 1
# 	metamyelocyte: 0
# 	normo: 1
# 	plasma cell: 1
# 	hair cell: 0
# 	bilobed M3v: 0
# 	mononucleosis: 6
# control/patient_4
# 	eosinophil granulocyte: 16
# 	reactive lymphocyte: 20
# 	neutrophil granulocyte (segmented): 126
# 	typical lymphocyte: 59
# 	other: 42
# 	neutrophil granulocyte (band): 14
# 	monocyte: 17
# 	large granulated lymphocyte: 14
# 	atypical promyelocyte: 0
# 	basophil granulocyte: 0
# 	smudge cell: 2
# 	neoplastic lymphocyte: 5
# 	promyelocyte: 0
# 	myelocyte: 0
# 	myeloblast: 0
# 	metamyelocyte: 0
# 	normo: 2
# 	plasma cell: 4
# 	hair cell: 0
# 	bilobed M3v: 0
# 	mononucleosis: 0
# control/patient_5
# 	eosinophil granulocyte: 16
# 	reactive lymphocyte: 0
# 	neutrophil granulocyte (segmented): 109
# 	typical lymphocyte: 22
# 	other: 43
# 	neutrophil granulocyte (band): 9
# 	monocyte: 13
# 	large granulated lymphocyte: 21
# 	atypical promyelocyte: 0
# 	basophil granulocyte: 0
# 	smudge cell: 2
# 	neoplastic lymphocyte: 0
# 	promyelocyte: 0
# 	myelocyte: 0
# 	myeloblast: 0
# 	metamyelocyte: 0
# 	normo: 0
# 	plasma cell: 0
# 	hair cell: 0
# 	bilobed M3v: 0
# 	mononucleosis: 11
# NPM1/patient_1
# 	eosinophil granulocyte: 1
# 	reactive lymphocyte: 0
# 	neutrophil granulocyte (segmented): 17
# 	typical lymphocyte: 113
# 	other: 0
# 	neutrophil granulocyte (band): 18
# 	monocyte: 0
# 	large granulated lymphocyte: 26
# 	atypical promyelocyte: 17
# 	basophil granulocyte: 2
# 	smudge cell: 10
# 	neoplastic lymphocyte: 11
# 	promyelocyte: 1
# 	myelocyte: 0
# 	myeloblast: 144
# 	metamyelocyte: 0
# 	normo: 1
# 	plasma cell: 1
# 	hair cell: 0
# 	bilobed M3v: 1
# 	mononucleosis: 16
# NPM1/patient_2
# 	eosinophil granulocyte: 1
# 	reactive lymphocyte: 7
# 	neutrophil granulocyte (segmented): 0
# 	typical lymphocyte: 14
# 	other: 125
# 	neutrophil granulocyte (band): 40
# 	monocyte: 3
# 	large granulated lymphocyte: 14
# 	atypical promyelocyte: 9
# 	basophil granulocyte: 0
# 	smudge cell: 5
# 	neoplastic lymphocyte: 1
# 	promyelocyte: 1
# 	myelocyte: 0
# 	myeloblast: 83
# 	metamyelocyte: 1
# 	normo: 19
# 	plasma cell: 7
# 	hair cell: 17
# 	bilobed M3v: 2
# 	mononucleosis: 3
# NPM1/patient_3
# 	eosinophil granulocyte: 11
# 	reactive lymphocyte: 11
# 	neutrophil granulocyte (segmented): 0
# 	typical lymphocyte: 41
# 	other: 77
# 	neutrophil granulocyte (band): 0
# 	monocyte: 20
# 	large granulated lymphocyte: 8
# 	atypical promyelocyte: 10
# 	basophil granulocyte: 5
# 	smudge cell: 4
# 	neoplastic lymphocyte: 0
# 	promyelocyte: 1
# 	myelocyte: 0
# 	myeloblast: 402
# 	metamyelocyte: 0
# 	normo: 6
# 	plasma cell: 12
# 	hair cell: 0
# 	bilobed M3v: 2
# 	mononucleosis: 30
# NPM1/patient_4
# 	eosinophil granulocyte: 2
# 	reactive lymphocyte: 0
# 	neutrophil granulocyte (segmented): 86
# 	typical lymphocyte: 13
# 	other: 0
# 	neutrophil granulocyte (band): 2
# 	monocyte: 92
# 	large granulated lymphocyte: 13
# 	atypical promyelocyte: 11
# 	basophil granulocyte: 5
# 	smudge cell: 12
# 	neoplastic lymphocyte: 30
# 	promyelocyte: 1
# 	myelocyte: 1
# 	myeloblast: 3
# 	metamyelocyte: 12
# 	normo: 0
# 	plasma cell: 12
# 	hair cell: 20
# 	bilobed M3v: 2
# 	mononucleosis: 13
# NPM1/patient_5
# 	eosinophil granulocyte: 0
# 	reactive lymphocyte: 8
# 	neutrophil granulocyte (segmented): 97
# 	typical lymphocyte: 137
# 	other: 24
# 	neutrophil granulocyte (band): 25
# 	monocyte: 99
# 	large granulated lymphocyte: 26
# 	atypical promyelocyte: 7
# 	basophil granulocyte: 5
# 	smudge cell: 5
# 	neoplastic lymphocyte: 4
# 	promyelocyte: 2
# 	myelocyte: 0
# 	myeloblast: 105
# 	metamyelocyte: 6
# 	normo: 3
# 	plasma cell: 8
# 	hair cell: 0
# 	bilobed M3v: 0
# 	mononucleosis: 5
# PML_RARA/patient_1
# 	eosinophil granulocyte: 1
# 	reactive lymphocyte: 0
# 	neutrophil granulocyte (segmented): 8
# 	typical lymphocyte: 88
# 	other: 49
# 	neutrophil granulocyte (band): 0
# 	monocyte: 1
# 	large granulated lymphocyte: 27
# 	atypical promyelocyte: 164
# 	basophil granulocyte: 4
# 	smudge cell: 24
# 	neoplastic lymphocyte: 0
# 	promyelocyte: 1
# 	myelocyte: 7
# 	myeloblast: 20
# 	metamyelocyte: 6
# 	normo: 12
# 	plasma cell: 14
# 	hair cell: 0
# 	bilobed M3v: 50
# 	mononucleosis: 0
# PML_RARA/patient_2
# 	eosinophil granulocyte: 1
# 	reactive lymphocyte: 0
# 	neutrophil granulocyte (segmented): 25
# 	typical lymphocyte: 111
# 	other: 66
# 	neutrophil granulocyte (band): 11
# 	monocyte: 6
# 	large granulated lymphocyte: 22
# 	atypical promyelocyte: 112
# 	basophil granulocyte: 0
# 	smudge cell: 23
# 	neoplastic lymphocyte: 0
# 	promyelocyte: 10
# 	myelocyte: 0
# 	myeloblast: 98
# 	metamyelocyte: 14
# 	normo: 11
# 	plasma cell: 10
# 	hair cell: 4
# 	bilobed M3v: 11
# 	mononucleosis: 4
# PML_RARA/patient_3
# 	eosinophil granulocyte: 0
# 	reactive lymphocyte: 4
# 	neutrophil granulocyte (segmented): 17
# 	typical lymphocyte: 119
# 	other: 94
# 	neutrophil granulocyte (band): 13
# 	monocyte: 10
# 	large granulated lymphocyte: 8
# 	atypical promyelocyte: 103
# 	basophil granulocyte: 2
# 	smudge cell: 10
# 	neoplastic lymphocyte: 0
# 	promyelocyte: 6
# 	myelocyte: 1
# 	myeloblast: 42
# 	metamyelocyte: 24
# 	normo: 8
# 	plasma cell: 7
# 	hair cell: 0
# 	bilobed M3v: 44
# 	mononucleosis: 5
# PML_RARA/patient_4
# 	eosinophil granulocyte: 0
# 	reactive lymphocyte: 0
# 	neutrophil granulocyte (segmented): 20
# 	typical lymphocyte: 0
# 	other: 54
# 	neutrophil granulocyte (band): 6
# 	monocyte: 4
# 	large granulated lymphocyte: 3
# 	atypical promyelocyte: 153
# 	basophil granulocyte: 9
# 	smudge cell: 9
# 	neoplastic lymphocyte: 0
# 	promyelocyte: 8
# 	myelocyte: 6
# 	myeloblast: 278
# 	metamyelocyte: 1
# 	normo: 25
# 	plasma cell: 12
# 	hair cell: 0
# 	bilobed M3v: 40
# 	mononucleosis: 1
# PML_RARA/patient_5
# 	eosinophil granulocyte: 0
# 	reactive lymphocyte: 3
# 	neutrophil granulocyte (segmented): 30
# 	typical lymphocyte: 14
# 	other: 73
# 	neutrophil granulocyte (band): 18
# 	monocyte: 5
# 	large granulated lymphocyte: 9
# 	atypical promyelocyte: 135
# 	basophil granulocyte: 12
# 	smudge cell: 29
# 	neoplastic lymphocyte: 0
# 	promyelocyte: 1
# 	myelocyte: 1
# 	myeloblast: 191
# 	metamyelocyte: 0
# 	normo: 2
# 	plasma cell: 0
# 	hair cell: 0
# 	bilobed M3v: 2
# 	mononucleosis: 5
# RUNX1_RUNX1T1/patient_1
# 	eosinophil granulocyte: 0
# 	reactive lymphocyte: 0
# 	neutrophil granulocyte (segmented): 24
# 	typical lymphocyte: 119
# 	other: 30
# 	neutrophil granulocyte (band): 19
# 	monocyte: 22
# 	large granulated lymphocyte: 4
# 	atypical promyelocyte: 0
# 	basophil granulocyte: 1
# 	smudge cell: 0
# 	neoplastic lymphocyte: 0
# 	promyelocyte: 6
# 	myelocyte: 2
# 	myeloblast: 168
# 	metamyelocyte: 0
# 	normo: 10
# 	plasma cell: 16
# 	hair cell: 2
# 	bilobed M3v: 16
# 	mononucleosis: 10
# RUNX1_RUNX1T1/patient_2
# 	eosinophil granulocyte: 0
# 	reactive lymphocyte: 3
# 	neutrophil granulocyte (segmented): 2
# 	typical lymphocyte: 208
# 	other: 11
# 	neutrophil granulocyte (band): 4
# 	monocyte: 7
# 	large granulated lymphocyte: 4
# 	atypical promyelocyte: 12
# 	basophil granulocyte: 0
# 	smudge cell: 14
# 	neoplastic lymphocyte: 0
# 	promyelocyte: 0
# 	myelocyte: 1
# 	myeloblast: 129
# 	metamyelocyte: 35
# 	normo: 0
# 	plasma cell: 14
# 	hair cell: 0
# 	bilobed M3v: 11
# 	mononucleosis: 6
# RUNX1_RUNX1T1/patient_3
# 	eosinophil granulocyte: 0
# 	reactive lymphocyte: 0
# 	neutrophil granulocyte (segmented): 9
# 	typical lymphocyte: 189
# 	other: 54
# 	neutrophil granulocyte (band): 12
# 	monocyte: 24
# 	large granulated lymphocyte: 4
# 	atypical promyelocyte: 9
# 	basophil granulocyte: 0
# 	smudge cell: 21
# 	neoplastic lymphocyte: 0
# 	promyelocyte: 6
# 	myelocyte: 7
# 	myeloblast: 150
# 	metamyelocyte: 49
# 	normo: 0
# 	plasma cell: 22
# 	hair cell: 0
# 	bilobed M3v: 25
# 	mononucleosis: 0
# RUNX1_RUNX1T1/patient_4
# 	eosinophil granulocyte: 0
# 	reactive lymphocyte: 2
# 	neutrophil granulocyte (segmented): 0
# 	typical lymphocyte: 212
# 	other: 49
# 	neutrophil granulocyte (band): 11
# 	monocyte: 19
# 	large granulated lymphocyte: 4
# 	atypical promyelocyte: 9
# 	basophil granulocyte: 0
# 	smudge cell: 10
# 	neoplastic lymphocyte: 0
# 	promyelocyte: 16
# 	myelocyte: 0
# 	myeloblast: 313
# 	metamyelocyte: 51
# 	normo: 2
# 	plasma cell: 16
# 	hair cell: 0
# 	bilobed M3v: 8
# 	mononucleosis: 9
# RUNX1_RUNX1T1/patient_5
# 	eosinophil granulocyte: 0
# 	reactive lymphocyte: 0
# 	neutrophil granulocyte (segmented): 25
# 	typical lymphocyte: 56
# 	other: 22
# 	neutrophil granulocyte (band): 0
# 	monocyte: 17
# 	large granulated lymphocyte: 3
# 	atypical promyelocyte: 28
# 	basophil granulocyte: 0
# 	smudge cell: 36
# 	neoplastic lymphocyte: 0
# 	promyelocyte: 3
# 	myelocyte: 10
# 	myeloblast: 151
# 	metamyelocyte: 30
# 	normo: 0
# 	plasma cell: 7
# 	hair cell: 4
# 	bilobed M3v: 22
# 	mononucleosis: 4

# %%
#saving images in npy files
for aml_subtype in class_labels:
    output_class_folder=output_folder+"/"+aml_subtype    
    for patient_number in range(n_patients):
        patient_folder = os.path.join(output_class_folder, f'patient_{patient_number+1}')
        with open( os.path.join(patient_folder,"image_file_paths") ,'rb') as fp:
            image_file_paths=pickle.load(fp)
        array_list=[]
        previous_patient_id=None
        # Iterate through each image path
        for image_path in image_file_paths:
            patient_id = image_path[:image_path.find("/image")]
            if previous_patient_id!=patient_id:
                #print(f"New patient: {patient_id}, old patient : {previous_patient_id}")
                features=np.load(patient_id+"/fnl34_bn_features_layer_7.npy")
            array_list.append([features[extract_number_image(image_path)]])
            previous_patient_id=patient_id 
        #Concatenate all features for one artificial patient    
        artificial_features = np.concatenate(array_list,axis=0)
        output_npy_file = output_folder+f"/{aml_subtype}/patient_{patient_number+1}/fnl34_bn_features_layer_7.npy"
        # Save the array to the .npy file
        np.save(output_npy_file, artificial_features)

# %%
#Create metadata including single cell types, not including age, gender and leucocytes_per_µl
# Create a list to hold the rows of the DataFrame
rows = []
'''sc_class_labels= ['eosinophil granulocyte', 'reactive lymphocyte',
       'neutrophil granulocyte (segmented)', 'typical lymphocyte',
       'other', 'neutrophil granulocyte (band)', 'monocyte',
       'large granulated lymphocyte', 'atypical promyelocyte',
       'basophil granulocyte', 'smudge cell', 'neoplastic lymphocyte',
       'promyelocyte', 'myelocyte', 'myeloblast', 'metamyelocyte',
       'normo', 'plasma cell', 'hair cell', 'bilobed M3v',
       'mononucleosis']'''

# Fill in the DataFrame with values from the dictionary
for patient_id, cell_counts in selected_images_per_patient.items():
    myeloblast_count = cell_counts.get('myeloblast', 0)
    # Extract counts for other cell types
    promyelocyte_count = cell_counts.get('promyelocyte', 0)
    myelocyte_count = cell_counts.get('myelocyte', 0)
    metamyelocyte_count = cell_counts.get('metamyelocyte', 0)
    neutrophil_band_count = cell_counts.get('neutrophil granulocyte (band)', 0)
    neutrophil_segmented_count = cell_counts.get('neutrophil granulocyte (segmented)', 0)
    eosinophil_count = cell_counts.get('eosinophil granulocyte', 0)
    basophil_count = cell_counts.get('basophil granulocyte', 0)
    monocyte_count = cell_counts.get('monocyte', 0)
    lymph_typ_count = cell_counts.get('typical lymphocyte', 0)
    lymph_atyp_react_count = cell_counts.get('reactive lymphocyte', 0)
    lymph_atyp_neopl_count = cell_counts.get('neoplastic lymphocyte', 0)
    other_count = cell_counts.get('other', 0)
    total_count = sum(cell_counts.values())#check

  
    index = patient_id.find("/patient")
    bag = patient_id[:index] if index != -1 else patient_id

    id = patient_id.find("/")
    patient = patient_id[id + 1:] if index != -1 else ""

    age = 0 #dummy
    row = {'patient_id': patient,
           'sex_1f_2m': None,  # Placeholder value
           'age': age,
           'bag_label': bag, 
           'instance_count': total_count,#check
           'leucocytes_per_µl': None,  # Placeholder value
           'pb_myeloblast': round((myeloblast_count/total_count)*100,1),
           'pb_promyelocyte': round((promyelocyte_count/total_count)*100,1),
           'pb_myelocyte': round((myelocyte_count/total_count)*100,1),
           'pb_metamyelocyte': round((metamyelocyte_count/total_count)*100,1),
           'pb_neutrophil_band': round((neutrophil_band_count/total_count)*100,1),
           'pb_neutrophil_segmented': round((neutrophil_segmented_count/total_count)*100,1),
           'pb_eosinophil': round((eosinophil_count/total_count)*100,1),
           'pb_basophil': round((basophil_count/total_count)*100,1),
           'pb_monocyte': round((monocyte_count/total_count)*100,1),
           'pb_lymph_typ': round((lymph_typ_count/total_count)*100,1),
           'pb_lymph_atyp_react': round((lymph_atyp_react_count/total_count)*100,1),
           'pb_lymph_atyp_neopl': round((lymph_atyp_neopl_count/total_count)*100,1),
           'pb_other': round((other_count/total_count)*100,1),
           'pb_total': round((total_count/total_count)*100,1)}#check
    rows.append(row)

# Create DataFrame from the list of rows
artificial_metadata = pd.DataFrame(rows)

# Save the DataFrame to a CSV file
metadata_csv_path = os.path.join(output_folder_csv, 'metadata.csv')
artificial_metadata.to_csv(metadata_csv_path, index=False)
print(f"Metadata saved to {metadata_csv_path}")
# Out:
# Metadata saved to ../../artificialdata/experiment_3/metadata.csv

# %%
artificial_metadata
# Out:
#    patient_id sex_1f_2m  age      bag_label  instance_count leucocytes_per_µl  \
# 0   patient_1      None    0     CBFB_MYH11             320              None
# 1   patient_2      None    0     CBFB_MYH11             414              None
# 2   patient_3      None    0     CBFB_MYH11             258              None
# 3   patient_4      None    0     CBFB_MYH11             441              None
# 4   patient_5      None    0     CBFB_MYH11             423              None
# 5   patient_1      None    0        control             296              None
# 6   patient_2      None    0        control             396              None
# 7   patient_3      None    0        control             401              None
# 8   patient_4      None    0        control             321              None
# 9   patient_5      None    0        control             246              None
# 10  patient_1      None    0           NPM1             379              None
# 11  patient_2      None    0           NPM1             352              None
# 12  patient_3      None    0           NPM1             640              None
# 13  patient_4      None    0           NPM1             330              None
# 14  patient_5      None    0           NPM1             566              None
# 15  patient_1      None    0       PML_RARA             476              None
# 16  patient_2      None    0       PML_RARA             539              None
# 17  patient_3      None    0       PML_RARA             517              None
# 18  patient_4      None    0       PML_RARA             629              None
# 19  patient_5      None    0       PML_RARA             530              None
# 20  patient_1      None    0  RUNX1_RUNX1T1             449              None
# 21  patient_2      None    0  RUNX1_RUNX1T1             461              None
# 22  patient_3      None    0  RUNX1_RUNX1T1             581              None
# 23  patient_4      None    0  RUNX1_RUNX1T1             731              None
# 24  patient_5      None    0  RUNX1_RUNX1T1             418              None
#
#     pb_myeloblast  pb_promyelocyte  pb_myelocyte  pb_metamyelocyte  \
# 0              36                0             0                 0
# 1              81                1             0                 2
# 2              66                2             2                 5
# 3             150                2             2                 8
# 4             178                1             0                 6
# 5               0                0             0                 0
# 6               2                0             0                 0
# 7               1                0             0                 0
# 8               0                0             0                 0
# 9               0                0             0                 0
# 10            144                1             0                 0
# 11             83                1             0                 1
# 12            402                1             0                 0
# 13              3                1             1                12
# 14            105                2             0                 6
# 15             20                1             7                 6
# 16             98               10             0                14
# 17             42                6             1                24
# 18            278                8             6                 1
# 19            191                1             1                 0
# 20            168                6             2                 0
# 21            129                0             1                35
# 22            150                6             7                49
# 23            313               16             0                51
# 24            151                3            10                30
#
#     pb_neutrophil_band  pb_neutrophil_segmented  pb_eosinophil  pb_basophil  \
# 0                    4                       22              1            0
# 1                    3                       18              0            0
# 2                   19                       32              0            0
# 3                    0                       36              1            0
# 4                    4                       25              2            0
# 5                    0                      117             21           13
# 6                   20                      175             10            2
# 7                   13                      180             16            8
# 8                   14                      126             16            0
# 9                    9                      109             16            0
# 10                  18                       17              1            2
# 11                  40                        0              1            0
# 12                   0                        0             11            5
# 13                   2                       86              2            5
# 14                  25                       97              0            5
# 15                   0                        8              1            4
# 16                  11                       25              1            0
# 17                  13                       17              0            2
# 18                   6                       20              0            9
# 19                  18                       30              0           12
# 20                  19                       24              0            1
# 21                   4                        2              0            0
# 22                  12                        9              0            0
# 23                  11                        0              0            0
# 24                   0                       25              0            0
#
#     pb_monocyte  pb_lymph_typ  pb_lymph_atyp_react  pb_lymph_atyp_neopl  \
# 0            35           113                    8                    0
# 1           195            56                    5                    2
# 2            74             0                   16                    2
# 3            77            75                    1                    5
# 4           140             0                    2                    0
# 5            15            23                   22                    1
# 6            34            42                    0                    3
# 7            30            34                   13                    4
# 8            17            59                   20                    5
# 9            13            22                    0                    0
# 10            0           113                    0                   11
# 11            3            14                    7                    1
# 12           20            41                   11                    0
# 13           92            13                    0                   30
# 14           99           137                    8                    4
# 15            1            88                    0                    0
# 16            6           111                    0                    0
# 17           10           119                    4                    0
# 18            4             0                    0                    0
# 19            5            14                    3                    0
# 20           22           119                    0                    0
# 21            7           208                    3                    0
# 22           24           189                    0                    0
# 23           19           212                    2                    0
# 24           17            56                    0                    0
#
#     pb_other  pb_total
# 0          0       320
# 1         17       414
# 2         12       258
# 3         25       441
# 4         19       423
# 5         50       296
# 6        102       396
# 7         69       401
# 8         42       321
# 9         43       246
# 10         0       379
# 11       125       352
# 12        77       640
# 13         0       330
# 14        24       566
# 15        49       476
# 16        66       539
# 17        94       517
# 18        54       629
# 19        73       530
# 20        30       449
# 21        11       461
# 22        54       581
# 23        49       731
# 24        22       418
